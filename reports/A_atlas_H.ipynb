# %% [markdown]
# # 도감 H — 격자 — λ/12 대신 더 촘촘한 격자
#
# [← 도감 지도](A_atlas.ipynb) 로 돌아간다. 이 편은 도감의 **절 10** 하나다 — 주제마다 파일을 나눴다.

# %% [markdown]
# ---
#
# ## 절 10. 격자 — λ/12 대신 더 촘촘한 격자
#
# > **묻는 것** — 표면 격자를 λ/12 에서 λ/24 로 조이면 잣대가 얼마나 움직이나 — **판정 문턱을 정하는 판**이다.
#
# 팔 4 개 · 칸 19 개 · 그림 11 장. 그림 파일은 전부 `outputs/figures/atlas/08grid__…` 로 시작한다.

# %% [markdown]
# ![grid — 08grid__000-overview-rhythm.png](../outputs/figures/atlas/08grid__000-overview-rhythm.png)
#
# **그림 949.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![grid — 08grid__01-compare-tile-15-p1.png](../outputs/figures/atlas/08grid__01-compare-tile-15-p1.png)
#
# **그림 950.** 앙각이 **−15° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![grid — 08grid__02-compare-stack-p1.png](../outputs/figures/atlas/08grid__02-compare-stack-p1.png)
#
# **그림 951.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 10.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mavic 4 Pro ≈ 13.5 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −15° | −30° | −45° | −52° | −60° | −68° | −75° | −82° | −90° |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# | `ours_r15_n8192_div24` | DJI Matrice 4E · 126.667 Hz | 15 m | 52 | 73 | 62 | 37 | — | 69 | — | 44 | — | 81\* |
# | `ours_r15_n8192_div24_shift0.5` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 74 | — | — | — | — | — | — | — | — |
# | `ours_r15_n8192_div48` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 55 | — | — | — | — | — | — | — | — |
# | `ours_r15_n8192_mfixbatteryi5_blperairframe_div24` | DJI Matrice 4E · 126.667 Hz | 15 m | 43 | 72 | 61 | 34 | 67 | 71 | 90 | 49 | 93 | 78\* |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 10.2 `ours_r15_n8192_div24`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/24 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_div24 micro-Doppler maps](../outputs/figures/atlas/08grid__ours_r15_n8192_div24__map.png)
#
# **그림 952.** `ours_r15_n8192_div24` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_div24 blade-band rhythm spectrum](../outputs/figures/atlas/08grid__ours_r15_n8192_div24__band.png)
#
# **그림 953.** `ours_r15_n8192_div24` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 51.5 | 12.5 | 1.5 | +47.7 | 126.1 | 0.99 | −74.26 | 4.722 |
# | −15° | 1230 Hz | 72.8 | 12.6 | 4.6 | +44.6 | 126.1 | 0.99 | −72.36 | 0.535 |
# | −30° | 1102 Hz | 61.5 | 12.6 | 1.4 | +47.5 | 126.1 | 0.99 | −69.48 | 36.370 |
# | −45° | 900 Hz | 36.8 | 12.5 | 0.3 | +51.7 | 126.1 | 0.99 | −67.10 | 8.823 |
# | −60° | 636 Hz | 68.8 | 12.6 | 0.5 | +49.4 | 126.1 | 0.99 | −66.06 | 44.660 |
# | −75° | 330 Hz | 43.8 | 12.6 | 0.0 | — | 126.1 | 0.99 | −57.81 | 8.991 |
# | −90°\* | 0 Hz | 81.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −87.18 | 0.002 |

# %% [markdown]
# ### 절 10.3 `ours_r15_n8192_div24_shift0.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/24 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_div24_shift0.5 micro-Doppler maps](../outputs/figures/atlas/08grid__ours_r15_n8192_div24_shift0.5__map.png)
#
# **그림 954.** `ours_r15_n8192_div24_shift0.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_div24_shift0.5 blade-band rhythm spectrum](../outputs/figures/atlas/08grid__ours_r15_n8192_div24_shift0.5__band.png)
#
# **그림 955.** `ours_r15_n8192_div24_shift0.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | 74.4 | 12.6 | 4.2 | +45.0 | 126.1 | 0.99 | −72.16 | 0.712 |

# %% [markdown]
# ### 절 10.4 `ours_r15_n8192_div48`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/48 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_div48 micro-Doppler maps](../outputs/figures/atlas/08grid__ours_r15_n8192_div48__map.png)
#
# **그림 956.** `ours_r15_n8192_div48` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_div48 blade-band rhythm spectrum](../outputs/figures/atlas/08grid__ours_r15_n8192_div48__band.png)
#
# **그림 957.** `ours_r15_n8192_div48` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | 55.0 | 12.6 | 0.7 | +50.2 | 126.1 | 0.99 | −72.48 | 0.522 |

# %% [markdown]
# ### 절 10.5 `ours_r15_n8192_mfixbatteryi5_blperairframe_div24`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/24 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_mfixbatteryi5_blperairframe_div24 micro-Doppler maps](../outputs/figures/atlas/08grid__ours_r15_n8192_mfixbatteryi5_blperairframe_div24__map.png)
#
# **그림 958.** `ours_r15_n8192_mfixbatteryi5_blperairframe_div24` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_mfixbatteryi5_blperairframe_div24 blade-band rhythm spectrum](../outputs/figures/atlas/08grid__ours_r15_n8192_mfixbatteryi5_blperairframe_div24__band.png)
#
# **그림 959.** `ours_r15_n8192_mfixbatteryi5_blperairframe_div24` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 43.1 | 12.5 | 0.8 | +51.3 | 126.1 | 0.99 | −72.51 | 5.011 |
# | −15° | 1230 Hz | 71.8 | 12.6 | 3.9 | +45.9 | 126.1 | 0.99 | −72.36 | 0.650 |
# | −30° | 1102 Hz | 60.8 | 12.6 | 1.3 | +48.3 | 126.1 | 0.99 | −69.90 | 12.081 |
# | −45° | 900 Hz | 33.7 | 12.5 | 0.3 | +52.0 | 126.1 | 0.99 | −68.04 | 8.025 |
# | −52° | 784 Hz | 66.6 | 12.5 | 0.4 | +51.1 | 126.1 | 0.99 | −65.27 | 20.505 |
# | −60° | 636 Hz | 71.3 | 12.6 | 0.4 | +50.1 | 126.1 | 0.99 | −64.92 | 3.778 |
# | −68° | 477 Hz | 89.8 | 12.6 | 0.7 | +57.8 | 252.2 | 1.99 | −63.39 | 34.590 |
# | −75° | 330 Hz | 49.1 | 12.6 | 0.1 | — | 126.1 | 0.99 | −61.52 | 3.920 |
# | −82° | 177 Hz | 92.8 | 12.6 | 0.6 | — | 126.1 | 0.99 | −60.51 | 1.842 |
# | −90°\* | 0 Hz | 77.6 | 12.6 | 100.0 | — | 126.1 | 0.99 | −88.29 | 0.003 |
