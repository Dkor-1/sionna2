# %% [markdown]
# # 도감 A — 기본 엔진 — 엔진·광선예산·자세수, ⚠거리도 10 m·15 m 로 섞여 있다
#
# [← 도감 지도](A_atlas.ipynb) 로 돌아간다. 이 편은 도감의 **절 3** 하나다 — 주제마다 파일을 나눴다.

# %% [markdown]
# ---
#
# ## 절 3. 기본 엔진 — 엔진·광선예산·자세수, ⚠거리도 10 m·15 m 로 섞여 있다
#
# > **묻는 것** — 엔진과 광선 예산만 바꾸면 날개 무늬가 달라지나 — 그리고 얼마나 부어야 달라지기를 멈추나.
#
# 팔 61 개 · 칸 249 개 · 그림 133 장. 그림 파일은 전부 `outputs/figures/atlas/01base__…` 로 시작한다.

# %% [markdown]
# ![base engines — 01base__000-overview-rhythm.png](../outputs/figures/atlas/01base__000-overview-rhythm.png)
#
# **그림 1.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![base engines — 01base__01-compare-tile-15-p1.png](../outputs/figures/atlas/01base__01-compare-tile-15-p1.png)
#
# **그림 2.** 앙각이 **−15° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![base engines — 01base__01-compare-tile-30-p1.png](../outputs/figures/atlas/01base__01-compare-tile-30-p1.png)
#
# **그림 3.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p1.png](../outputs/figures/atlas/01base__02-compare-stack-p1.png)
#
# **그림 4.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p2.png](../outputs/figures/atlas/01base__02-compare-stack-p2.png)
#
# **그림 5.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p3.png](../outputs/figures/atlas/01base__02-compare-stack-p3.png)
#
# **그림 6.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p4.png](../outputs/figures/atlas/01base__02-compare-stack-p4.png)
#
# **그림 7.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p5.png](../outputs/figures/atlas/01base__02-compare-stack-p5.png)
#
# **그림 8.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p6.png](../outputs/figures/atlas/01base__02-compare-stack-p6.png)
#
# **그림 9.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p7.png](../outputs/figures/atlas/01base__02-compare-stack-p7.png)
#
# **그림 10.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p8.png](../outputs/figures/atlas/01base__02-compare-stack-p8.png)
#
# **그림 11.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 3.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mavic 4 Pro ≈ 13.5 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −4° | −8° | −11° | −15° | −30° | −45° | −52° | −60° | −68° | −75° | −82° | −90° |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# | `ours` | DJI Matrice 4E · 126.667 Hz | 10 m | 58 | — | — | — | 62 | 83 | 51 | — | 48 | — | 50 | — | 73\* |
# | `ours_free_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 63 | — | — | — | 72 | 83 | 49 | — | 52 | — | 48 | — | 56\* |
# | `ours_n8192_rep1_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 10 m | 62 | — | — | — | — | 88 | — | — | 54 | — | — | — | — |
# | `ours_r15_n32768` | DJI Matrice 4E · 126.667 Hz | 15 m | 63 | — | — | — | — | 86 | — | — | 46 | — | — | — | — |
# | `ours_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 63 | 73 | 72 | 64 | 73 | 83 | 50 | 60 | 53 | 75 | 46 | 70 | 65\* |
# | `ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 59 | — | — | — | — | 85 | — | — | 58 | — | — | — | — |
# | `ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 55 | — | — | — | — | 85 | — | — | 56 | — | — | — | — |
# | `ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 57 | — | — | — | — | 88 | — | — | 61 | — | — | — | — |
# | `ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 58 | — | — | — | — | 88 | — | — | — | — | — | — | — |
# | `ours_r15_n8192_fs2_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 64 | — | — | — | — | 87 | — | — | — | — | — | — | — |
# | `ours_r15_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 62 | — | — | — | 68 | 88 | 43 | 58 | 53 | 68 | 50 | 75 | 62\* |
# | `ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 11 | — | — | — | — | 13 | — | — | 8 | — | — | — | 8\* |
# | `ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 43 | — | — | — | — | 34 | — | — | 35 | — | — | — | 37\* |
# | `ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 20 | — | — | — | — | 21 | — | — | 22 | — | — | — | 16\* |
# | `ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 81 | — | — | — | — | ◐ | — | — | — | — | — | — | — |
# | `ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 69 | — | — | — | — | 78 | — | — | — | — | — | — | — |
# | `ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 89 | — | — | — | — | 92 | — | — | — | — | — | — | — |
# | `ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 75 | — | — | — | — | 92 | — | — | — | — | — | — | — |
# | `ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 88 | — | — | — | — | 86 | — | — | — | — | — | — | — |
# | `ours_r15_n8192_ps2_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 92 | — | — | — | — | 90 | — | — | — | — | — | — | — |
# | `ours_r15_n8192_rep1_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 62 | — | — | — | 68 | 88 | 43 | — | 53 | — | 50 | — | — |
# | `ours_r15_n8192_rep2_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 62 | — | — | — | 68 | 88 | 43 | — | 53 | — | 50 | — | — |
# | `ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 52 | — | — | — | — | 84 | 40 | — | 55 | — | — | — | — |
# | `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 52 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 52 | — | — | — | — | 84 | — | — | 55 | — | — | — | — |
# | `ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 17 | 12 | — | 22 | — | — | — | — |
# | `ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 20 | — | — | — | — | 22 | 12 | — | 10 | — | — | — | 29\* |
# | `ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 10 | — | — | — | — | 10 | — | — | 7 | — | — | — | — |
# | `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 10 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 21 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 21 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 10 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | ◐ | — | — | ◐ | — | — | — | — |
# | `ours_r15_n8192_shift0.37x-0.19` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | 67 | — | — | — | — | — | — | — | — |
# | `ours_r15_n8192_shift0.5` | DJI Matrice 4E · 126.667 Hz | 15 m | 62 | — | — | — | 64 | 82 | 50 | — | — | — | — | — | — |
# | `ours_r15_n8192_shift1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | ◐ | — | — | — | — | — | — | — | — |
# | `sionna` | DJI Matrice 4E · 126.667 Hz | 10 m | 91 | — | — | — | 73 | 76 | 82 | — | 80 | — | 92 | — | 95\* |
# | `sionna_p1000000000` | DJI Matrice 4E · 126.667 Hz | 10 m | 12 | — | — | — | 80 | 78 | 83 | — | 84 | — | 93 | — | 98\* |
# | `sionna_p250000000` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | 73 | 82 | 83 | — | 82 | — | 92 | — | 97\* |
# | `sionna_p250000000_phys` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | 14 | 15 | 15 | — | 18 | — | 13 | — | 12\* |
# | `sionna_p4000000000` | DJI Matrice 4E · 126.667 Hz | 10 m | 11 | — | — | — | 74 | — | 83 | — | 89 | — | ◐ | — | — |
# | `sionna_p4000000000_phys_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 10 m | 16 | — | — | — | 13 | 13 | 12 | — | 15 | — | 13 | — | 17\* |
# | `sionna_p4000000000_phys_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | 12 | 12 | 14 | — | 15 | — | 12 | 13 | 14\* |
# | `sionna_p4000000000_phys_r15_n8192_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | 12 | 12 | 14 | — | 15 | — | 12 | — | 14\* |
# | `sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_r15_n32768_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 82 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | 88 | 83 | 76 | 81 | 80 | 84 | 89 | 87 | 92 | 95 | 98 | 98\* |
# | `sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | 78 | 80 | 86 | 86 | 90 | 96 | 95 | 98 | 98\* |
# | `sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 19 | — | — | 17 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.5mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 80 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 80 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 74 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | 77 | 75 | — | — | 87 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 77 | — | — | 87 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 78 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell1.5mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 80 | — | — | — | — | — | — | — |
# | `sionna_phys` | DJI Matrice 4E · 126.667 Hz | 10 m | 14 | — | — | — | 18 | 52 | 40 | — | 61 | — | 58 | — | 45\* |
# | `sionna_r15_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | 82 | — | 85 | — | — | — | 95 | — | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 3.2 `ours`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 10 m · 자세 4,096 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours micro-Doppler maps](../outputs/figures/atlas/01base__ours__map.png)
#
# **그림 12.** `ours` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours__band.png)
#
# **그림 13.** `ours` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 58.0 | 12.6 | 2.3 | +48.9 | 127.2 | 1.00 | −69.77 | 2.853 |
# | −15° | 1230 Hz | 62.3 | 12.7 | 15.7 | +39.7 | 127.2 | 1.00 | −70.81 | 1.077 |
# | −30° | 1102 Hz | 82.6 | 12.6 | 11.2 | +43.9 | 127.2 | 1.00 | −68.50 | 27.583 |
# | −45° | 900 Hz | 51.2 | 12.5 | 2.2 | +46.4 | 127.2 | 1.00 | −67.08 | 13.592 |
# | −60° | 636 Hz | 47.7 | 12.6 | 1.3 | +46.6 | 127.2 | 1.00 | −65.37 | 94.911 |
# | −75° | 330 Hz | 50.2 | 12.6 | 0.3 | — | 127.2 | 1.00 | −58.00 | 8.233 |
# | −90°\* | 0 Hz | 73.4 | 12.6 | 100.0 | — | 127.2 | 1.00 | −79.96 | 0.015 |

# %% [markdown]
# ### 절 3.3 `ours_free_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO), 동체 «면» 을 빼서 가림을 없앤 대조군** · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_free_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/01base__ours_free_r15_n8192__map.png)
#
# **그림 14.** `ours_free_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_free_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_free_r15_n8192__band.png)
#
# **그림 15.** `ours_free_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.3 | 12.5 | 2.7 | +47.8 | 126.1 | 0.99 | −70.40 | 94.752 |
# | −15° | 1230 Hz | 72.2 | 12.6 | 19.3 | +39.7 | 126.1 | 0.99 | −71.17 | 70.136 |
# | −30° | 1102 Hz | 82.9 | 12.6 | 10.2 | +42.8 | 126.1 | 0.99 | −68.81 | 90.229 |
# | −45° | 900 Hz | 48.7 | 12.5 | 1.8 | +47.3 | 126.1 | 0.99 | −67.07 | 94.491 |
# | −60° | 636 Hz | 52.4 | 12.6 | 1.7 | +45.0 | 126.1 | 0.99 | −65.99 | 72.063 |
# | −75° | 330 Hz | 47.7 | 12.6 | 0.2 | — | 126.1 | 0.99 | −57.74 | 86.885 |
# | −90°\* | 0 Hz | 55.6 | 12.6 | 100.0 | — | 126.1 | 0.99 | −82.59 | 0.019 |

# %% [markdown]
# ### 절 3.4 `ours_n8192_rep1_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 10 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_n8192_rep1_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_n8192_rep1_mfixbatteryi5_blperairframe__map.png)
#
# **그림 16.** `ours_n8192_rep1_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_n8192_rep1_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_n8192_rep1_mfixbatteryi5_blperairframe__band.png)
#
# **그림 17.** `ours_n8192_rep1_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.1 | 12.5 | 2.5 | +50.4 | 126.1 | 0.99 | −69.46 | 2.514 |
# | −30° | 1102 Hz | 87.8 | 12.6 | 14.7 | +42.6 | 126.1 | 0.99 | −68.79 | 8.428 |
# | −60° | 636 Hz | 53.7 | 12.6 | 1.3 | +45.8 | 126.1 | 0.99 | −64.83 | 6.279 |

# %% [markdown]
# ### 절 3.5 `ours_r15_n32768`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 32,768 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n32768 micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n32768__map.png)
#
# **그림 18.** `ours_r15_n32768` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n32768 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n32768__band.png)
#
# **그림 19.** `ours_r15_n32768` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.0 | 12.5 | 3.5 | +47.9 | 127.1 | 1.00 | −70.86 | 2.294 |
# | −30° | 1102 Hz | 85.6 | 12.6 | 13.5 | +42.8 | 127.1 | 1.00 | −68.98 | 23.713 |
# | −60° | 636 Hz | 46.0 | 12.6 | 1.0 | +52.6 | 253.6 | 2.00 | −64.36 | 89.509 |

# %% [markdown]
# ### 절 3.6 `ours_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192__map.png)
#
# **그림 20.** `ours_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192__band.png)
#
# **그림 21.** `ours_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.3 | 12.5 | 2.7 | +47.8 | 126.1 | 0.99 | −70.40 | 2.563 |
# | −4° | 1270 Hz | 72.6 | 12.6 | 11.5 | +42.9 | 126.1 | 0.99 | −70.50 | 21.961 |
# | −8° | 1260 Hz | 72.0 | 12.7 | 12.7 | +41.8 | 126.1 | 0.99 | −70.93 | 1.494 |
# | −11° | 1250 Hz | 64.1 | 12.7 | 9.9 | +39.8 | 126.1 | 0.99 | −70.37 | 0.952 |
# | −15° | 1230 Hz | 72.7 | 12.6 | 17.2 | +40.5 | 126.1 | 0.99 | −71.05 | 1.040 |
# | −30° | 1102 Hz | 83.3 | 12.6 | 10.6 | +42.9 | 126.1 | 0.99 | −69.11 | 27.399 |
# | −45° | 900 Hz | 49.7 | 12.5 | 1.8 | +47.1 | 126.1 | 0.99 | −67.19 | 13.227 |
# | −52° | 784 Hz | 60.4 | 12.5 | 1.2 | +45.0 | 254.6 | 2.01 | −63.55 | 13.002 |
# | −60° | 636 Hz | 52.8 | 12.6 | 1.8 | +45.4 | 126.1 | 0.99 | −66.04 | 79.883 |
# | −68° | 477 Hz | 75.1 | 12.6 | 2.0 | +54.3 | 126.1 | 0.99 | −64.42 | 10.975 |
# | −75° | 330 Hz | 46.3 | 12.6 | 0.2 | — | 126.1 | 0.99 | −57.71 | 8.826 |
# | −82° | 177 Hz | 69.5 | 12.6 | 0.6 | — | 126.1 | 0.99 | −60.16 | 2.640 |
# | −90°\* | 0 Hz | 64.9 | 12.6 | 100.0 | — | 126.1 | 0.99 | −81.56 | 0.009 |

# %% [markdown]
# ### 절 3.7 `ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe__map.png)
#
# **그림 22.** `ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe__band.png)
#
# **그림 23.** `ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 59.3 | 12.5 | 2.5 | +49.3 | 126.1 | 0.99 | −68.28 | 16.817 |
# | −30° | 1102 Hz | 84.9 | 12.6 | 10.5 | +42.8 | 126.1 | 0.99 | −68.98 | 8.910 |
# | −60° | 636 Hz | 57.9 | 12.6 | 1.4 | +45.1 | 126.1 | 0.99 | −64.66 | 48.830 |

# %% [markdown]
# ### 절 3.8 `ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe__map.png)
#
# **그림 24.** `ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe__band.png)
#
# **그림 25.** `ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 55.3 | 12.5 | 4.6 | +47.8 | 126.1 | 0.99 | −69.17 | 70.975 |
# | −30° | 1102 Hz | 85.3 | 12.6 | 12.7 | +42.1 | 126.1 | 0.99 | −68.59 | 37.980 |
# | −60° | 636 Hz | 56.2 | 12.6 | 1.5 | +45.1 | 126.1 | 0.99 | −64.88 | 3.359 |

# %% [markdown]
# ### 절 3.9 `ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe__map.png)
#
# **그림 26.** `ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe__band.png)
#
# **그림 27.** `ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 56.8 | 12.5 | 2.4 | +49.6 | 126.1 | 0.99 | −68.36 | 5.102 |
# | −30° | 1102 Hz | 87.6 | 12.6 | 13.6 | +42.3 | 126.1 | 0.99 | −68.64 | 17.736 |
# | −60° | 636 Hz | 60.7 | 12.6 | 1.5 | +45.5 | 126.1 | 0.99 | −64.68 | 5.039 |

# %% [markdown]
# ### 절 3.10 `ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe__map.png)
#
# **그림 28.** `ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe__band.png)
#
# **그림 29.** `ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 58.0 | 12.5 | 7.6 | +44.3 | 126.1 | 0.99 | −69.30 | 0.705 |
# | −30° | 1102 Hz | 88.0 | 12.6 | 15.5 | +42.2 | 126.1 | 0.99 | −68.26 | 1.261 |

# %% [markdown]
# ### 절 3.11 `ours_r15_n8192_fs2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_fs2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_fs2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 30.** `ours_r15_n8192_fs2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_fs2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_fs2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 31.** `ours_r15_n8192_fs2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.9 | 12.5 | 6.9 | +44.9 | 126.1 | 0.99 | −70.97 | 0.082 |
# | −30° | 1102 Hz | 87.3 | 12.6 | 15.0 | +42.6 | 126.1 | 0.99 | −69.55 | 1.516 |

# %% [markdown]
# ### 절 3.12 `ours_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 32.** `ours_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 33.** `ours_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.2 | 12.5 | 2.4 | +50.6 | 126.1 | 0.99 | −69.42 | 2.545 |
# | −15° | 1230 Hz | 68.5 | 12.6 | 14.5 | +40.7 | 126.1 | 0.99 | −71.01 | 0.999 |
# | −30° | 1102 Hz | 87.7 | 12.6 | 13.6 | +42.9 | 126.1 | 0.99 | −68.73 | 8.221 |
# | −45° | 900 Hz | 43.1 | 12.5 | 1.8 | +47.3 | 126.1 | 0.99 | −67.96 | 6.845 |
# | −52° | 784 Hz | 58.1 | 12.5 | 1.8 | +44.3 | 254.6 | 2.01 | −65.28 | 11.038 |
# | −60° | 636 Hz | 53.4 | 12.6 | 1.2 | +45.7 | 126.1 | 0.99 | −64.75 | 6.206 |
# | −68° | 477 Hz | 68.5 | 12.6 | 1.3 | +48.6 | 254.6 | 2.01 | −63.29 | 13.449 |
# | −75° | 330 Hz | 49.7 | 12.6 | 0.6 | — | 126.1 | 0.99 | −61.63 | 3.361 |
# | −82° | 177 Hz | 75.2 | 12.6 | 0.8 | — | 126.1 | 0.99 | −60.39 | 1.690 |
# | −90°\* | 0 Hz | 61.6 | 12.6 | 100.0 | — | 126.1 | 0.99 | −81.93 | 0.010 |

# %% [markdown]
# ### 절 3.13 `ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe__map.png)
#
# **그림 34.** `ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe__band.png)
#
# **그림 35.** `ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 11.1 | 12.5 | 1.4 | −5.6 | 94.6 | 0.75 | −73.57 | 0.991 |
# | −30° | 1102 Hz | 13.2 | 12.6 | 1.7 | −2.8 | 94.6 | 0.75 | −69.98 | 6.431 |
# | −60° | 636 Hz | 8.2 | 12.6 | 0.3 | −3.2 | 31.5 | 0.25 | −62.55 | 10.075 |
# | −90°\* | 0 Hz | 7.7 | 12.6 | 100.0 | — | 349.2 | 2.76 | −81.94 | 0.010 |

# %% [markdown]
# ### 절 3.14 `ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe__map.png)
#
# **그림 36.** `ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe__band.png)
#
# **그림 37.** `ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 43.2 | 12.5 | 2.2 | +0.3 | 63.0 | 0.50 | −69.03 | 2.808 |
# | −30° | 1102 Hz | 34.2 | 12.6 | 3.6 | +0.6 | 63.0 | 0.50 | −67.84 | 9.909 |
# | −60° | 636 Hz | 35.1 | 12.6 | 0.8 | −1.0 | 63.0 | 0.50 | −63.73 | 7.770 |
# | −90°\* | 0 Hz | 36.7 | 12.6 | 100.0 | — | 380.7 | 3.01 | −81.80 | 0.010 |

# %% [markdown]
# ### 절 3.15 `ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe__map.png)
#
# **그림 38.** `ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe__band.png)
#
# **그림 39.** `ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 19.8 | 12.5 | 1.8 | −0.7 | 189.1 | 1.49 | −71.40 | 1.623 |
# | −30° | 1102 Hz | 20.8 | 12.6 | 2.2 | +3.3 | 31.5 | 0.25 | −68.80 | 8.076 |
# | −60° | 636 Hz | 22.3 | 12.6 | 0.6 | −1.5 | 31.5 | 0.25 | −62.98 | 9.160 |
# | −90°\* | 0 Hz | 15.7 | 12.6 | 100.0 | — | 63.0 | 0.50 | −81.76 | 0.010 |

# %% [markdown]
# ### 절 3.16 `ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe__map.png)
#
# **그림 40.** `ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe__band.png)
#
# **그림 41.** `ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 81.4 | 12.5 | 14.0 | +39.3 | 126.1 | 0.99 | −80.43 | 0.909 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.17 `ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe__map.png)
#
# **그림 42.** `ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe__band.png)
#
# **그림 43.** `ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 68.8 | 12.5 | 2.9 | +50.7 | 126.1 | 0.99 | −70.61 | 20.847 |
# | −30° | 1102 Hz | 77.8 | 12.6 | 13.2 | +38.9 | 126.1 | 0.99 | −74.31 | 2.773 |

# %% [markdown]
# ### 절 3.18 `ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe__map.png)
#
# **그림 44.** `ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe__band.png)
#
# **그림 45.** `ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 89.4 | 12.5 | 28.3 | +45.7 | 126.1 | 0.99 | −68.44 | 0.782 |
# | −30° | 1102 Hz | 92.4 | 12.6 | 42.1 | +37.8 | 126.1 | 0.99 | −66.30 | 1.977 |

# %% [markdown]
# ### 절 3.19 `ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe__map.png)
#
# **그림 46.** `ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe__band.png)
#
# **그림 47.** `ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 74.9 | 12.5 | 12.8 | +44.3 | 126.1 | 0.99 | −68.75 | 3.134 |
# | −30° | 1102 Hz | 91.8 | 12.6 | 36.1 | +39.7 | 126.1 | 0.99 | −66.44 | 13.457 |

# %% [markdown]
# ### 절 3.20 `ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 48.** `ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 49.** `ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 88.5 | 12.5 | 55.3 | +39.3 | 126.1 | 0.99 | −66.57 | 0.242 |
# | −30° | 1102 Hz | 86.3 | 12.6 | 60.1 | +34.5 | 126.1 | 0.99 | −65.73 | 3.049 |

# %% [markdown]
# ### 절 3.21 `ours_r15_n8192_ps2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_ps2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_ps2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 50.** `ours_r15_n8192_ps2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_ps2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_ps2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 51.** `ours_r15_n8192_ps2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 92.2 | 12.5 | 61.5 | +38.7 | 126.1 | 0.99 | −67.21 | 17.909 |
# | −30° | 1102 Hz | 90.0 | 12.6 | 55.7 | +36.1 | 126.1 | 0.99 | −64.65 | 36.469 |

# %% [markdown]
# ### 절 3.22 `ours_r15_n8192_rep1_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rep1_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rep1_mfixbatteryi5_blperairframe__map.png)
#
# **그림 52.** `ours_r15_n8192_rep1_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rep1_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rep1_mfixbatteryi5_blperairframe__band.png)
#
# **그림 53.** `ours_r15_n8192_rep1_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.2 | 12.5 | 2.4 | +50.6 | 126.1 | 0.99 | −69.42 | 2.545 |
# | −15° | 1230 Hz | 68.5 | 12.6 | 14.5 | +40.7 | 126.1 | 0.99 | −71.01 | 0.999 |
# | −30° | 1102 Hz | 87.7 | 12.6 | 13.6 | +42.9 | 126.1 | 0.99 | −68.73 | 8.221 |
# | −45° | 900 Hz | 43.1 | 12.5 | 1.8 | +47.3 | 126.1 | 0.99 | −67.96 | 6.845 |
# | −60° | 636 Hz | 53.4 | 12.6 | 1.2 | +45.7 | 126.1 | 0.99 | −64.75 | 6.206 |
# | −75° | 330 Hz | 49.7 | 12.6 | 0.6 | — | 126.1 | 0.99 | −61.63 | 3.361 |

# %% [markdown]
# ### 절 3.23 `ours_r15_n8192_rep2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rep2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rep2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 54.** `ours_r15_n8192_rep2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rep2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rep2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 55.** `ours_r15_n8192_rep2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.2 | 12.5 | 2.4 | +50.6 | 126.1 | 0.99 | −69.42 | 2.545 |
# | −15° | 1230 Hz | 68.5 | 12.6 | 14.5 | +40.7 | 126.1 | 0.99 | −71.01 | 0.999 |
# | −30° | 1102 Hz | 87.7 | 12.6 | 13.6 | +42.9 | 126.1 | 0.99 | −68.73 | 8.221 |
# | −45° | 900 Hz | 43.1 | 12.5 | 1.8 | +47.3 | 126.1 | 0.99 | −67.96 | 6.845 |
# | −60° | 636 Hz | 53.4 | 12.6 | 1.2 | +45.7 | 126.1 | 0.99 | −64.75 | 6.206 |
# | −75° | 330 Hz | 49.7 | 12.6 | 0.6 | — | 126.1 | 0.99 | −61.63 | 3.361 |

# %% [markdown]
# ### 절 3.24 `ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe__map.png)
#
# **그림 56.** `ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe__band.png)
#
# **그림 57.** `ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 52.0 | 12.5 | 3.3 | +42.0 | 126.1 | 0.99 | −70.75 | 1.905 |
# | −30° | 1102 Hz | 84.5 | 12.6 | 20.9 | +36.8 | 126.1 | 0.99 | −69.51 | 6.803 |
# | −45° | 900 Hz | 40.0 | 12.5 | 2.2 | +43.6 | 126.1 | 0.99 | −68.69 | 5.750 |
# | −60° | 636 Hz | 55.4 | 12.6 | 1.4 | +42.9 | 126.1 | 0.99 | −64.72 | 5.917 |

# %% [markdown]
# ### 절 3.25 `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe__map.png)
#
# **그림 58.** `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe__band.png)
#
# **그림 59.** `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 52.0 | 12.5 | 3.3 | +42.0 | 126.1 | 0.99 | −70.75 | 1.905 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.26 `ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 60.** `ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 61.** `ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 52.0 | 12.5 | 3.3 | +42.0 | 126.1 | 0.99 | −70.75 | 1.905 |
# | −30° | 1102 Hz | 84.5 | 12.6 | 20.9 | +36.8 | 126.1 | 0.99 | −69.51 | 6.803 |
# | −60° | 636 Hz | 55.4 | 12.6 | 1.4 | +42.9 | 126.1 | 0.99 | −64.72 | 5.917 |

# %% [markdown]
# ### 절 3.27 `ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe__map.png)
#
# **그림 62.** `ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe__band.png)
#
# **그림 63.** `ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.9 | 12.5 | 3.1 | +33.4 | 128.5 | 1.01 | −69.34 | 2.621 |
# | −30° | 1102 Hz | 16.8 | 12.6 | 13.1 | +31.2 | 128.5 | 1.01 | −67.77 | 11.900 |
# | −45° | 900 Hz | 11.7 | 12.5 | 1.4 | +37.7 | 128.5 | 1.01 | −65.47 | 11.760 |
# | −60° | 636 Hz | 21.7 | 12.6 | 1.6 | +41.6 | 383.1 | 3.02 | −63.73 | 7.739 |

# %% [markdown]
# ### 절 3.28 `ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 64.** `ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 65.** `ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 19.6 | 12.5 | 3.6 | +31.0 | 24.2 | 0.19 | −69.56 | 2.518 |
# | −30° | 1102 Hz | 22.5 | 12.6 | 15.2 | +25.0 | 252.2 | 1.99 | −68.12 | 9.756 |
# | −45° | 900 Hz | 11.6 | 12.5 | 1.9 | +36.8 | 249.8 | 1.97 | −65.79 | 11.034 |
# | −60° | 636 Hz | 10.3 | 12.6 | 1.2 | +44.0 | 252.2 | 1.99 | −63.23 | 8.053 |
# | −90°\* | 0 Hz | 28.9 | 12.6 | 100.0 | — | 259.5 | 2.05 | −82.40 | 0.009 |

# %% [markdown]
# ### 절 3.29 `ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe__map.png)
#
# **그림 66.** `ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe__band.png)
#
# **그림 67.** `ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 10.3 | 12.5 | 3.9 | +10.4 | 118.8 | 0.94 | −69.70 | 2.383 |
# | −30° | 1102 Hz | 9.9 | 12.6 | 14.8 | +12.8 | 126.1 | 0.99 | −68.26 | 9.241 |
# | −60° | 636 Hz | 7.0 | 12.6 | 1.4 | +40.1 | 264.3 | 2.09 | −63.43 | 8.225 |

# %% [markdown]
# ### 절 3.30 `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 68.** `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 69.** `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 9.5 | 12.5 | 3.7 | −10.1 | 138.2 | 1.09 | −69.79 | 2.345 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.31 `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe__map.png)
#
# **그림 70.** `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe__band.png)
#
# **그림 71.** `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 20.9 | 12.5 | 3.4 | +0.9 | 140.6 | 1.11 | −69.43 | 2.540 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.32 `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe__map.png)
#
# **그림 72.** `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe__band.png)
#
# **그림 73.** `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 3.6 | −10.5 | 114.0 | 0.90 | −69.64 | 2.421 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.33 `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe__map.png)
#
# **그림 74.** `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe__band.png)
#
# **그림 75.** `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 20.7 | 12.5 | 3.6 | +36.8 | 126.1 | 0.99 | −70.00 | 2.228 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.34 `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe__map.png)
#
# **그림 76.** `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe__band.png)
#
# **그림 77.** `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 3.6 | +27.9 | 128.5 | 1.01 | −69.35 | 2.586 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.35 `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 78.** `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 79.** `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 10.2 | 12.5 | 3.5 | +11.0 | 130.9 | 1.03 | −69.54 | 2.541 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.36 `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe__map.png)
#
# **그림 80.** `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe__band.png)
#
# **그림 81.** `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.2 | 12.5 | 4.0 | +24.9 | 121.2 | 0.96 | −69.29 | 2.622 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.37 `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe__map.png)
#
# **그림 82.** `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe__band.png)
#
# **그림 83.** `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.4 | 12.5 | 3.0 | +12.8 | 123.7 | 0.98 | −69.57 | 2.915 |
# | −30° | 1102 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.38 `ours_r15_n8192_shift0.37x-0.19`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_shift0.37x-0.19 micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_shift0.37x-0.19__map.png)
#
# **그림 84.** `ours_r15_n8192_shift0.37x-0.19` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_shift0.37x-0.19 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_shift0.37x-0.19__band.png)
#
# **그림 85.** `ours_r15_n8192_shift0.37x-0.19` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | 67.1 | 12.6 | 20.1 | +37.7 | 126.1 | 0.99 | −72.81 | 0.460 |

# %% [markdown]
# ### 절 3.39 `ours_r15_n8192_shift0.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_shift0.5 micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_shift0.5__map.png)
#
# **그림 86.** `ours_r15_n8192_shift0.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_shift0.5 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_shift0.5__band.png)
#
# **그림 87.** `ours_r15_n8192_shift0.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.2 | 12.5 | 7.7 | +42.9 | 126.1 | 0.99 | −70.91 | 20.182 |
# | −15° | 1230 Hz | 64.5 | 12.6 | 10.0 | +40.1 | 126.1 | 0.99 | −70.40 | 0.895 |
# | −30° | 1102 Hz | 82.3 | 12.6 | 11.0 | +42.6 | 126.1 | 0.99 | −68.07 | 18.990 |
# | −45° | 900 Hz | 50.2 | 12.5 | 1.7 | +47.2 | 126.1 | 0.99 | −66.89 | 9.464 |

# %% [markdown]
# ### 절 3.40 `ours_r15_n8192_shift1`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_shift1 micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192_shift1__map.png)
#
# **그림 88.** `ours_r15_n8192_shift1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_shift1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192_shift1__band.png)
#
# **그림 89.** `ours_r15_n8192_shift1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | ◐ 덜 참(512/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.41 `sionna`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 1,111 만 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna micro-Doppler maps](../outputs/figures/atlas/01base__sionna__map.png)
#
# **그림 90.** `sionna` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna__band.png)
#
# **그림 91.** `sionna` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 91.3 | 12.6 | 29.0 | +43.5 | 635.8 | 5.02 | −143.21 | 0.000 |
# | −15° | 1230 Hz | 72.9 | 12.7 | 40.0 | +35.8 | 127.2 | 1.00 | −144.82 | 0.993 |
# | −30° | 1102 Hz | 75.7 | 12.6 | 8.8 | +41.8 | 254.3 | 2.01 | −136.79 | 59.980 |
# | −45° | 900 Hz | 82.1 | 12.5 | 25.3 | +41.5 | 127.2 | 1.00 | −136.46 | 8.459 |
# | −60° | 636 Hz | 80.3 | 12.6 | 28.5 | +41.7 | 127.2 | 1.00 | −132.70 | 27.510 |
# | −75° | 330 Hz | 91.7 | 12.6 | 47.1 | — | 127.2 | 1.00 | −131.67 | 32.443 |
# | −90°\* | 0 Hz | 95.3 | 12.6 | 100.0 | — | 127.2 | 1.00 | −132.21 | 49.365 |

# %% [markdown]
# ### 절 3.42 `sionna_p1000000000`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 10 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p1000000000 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p1000000000__map.png)
#
# **그림 92.** `sionna_p1000000000` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p1000000000 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p1000000000__band.png)
#
# **그림 93.** `sionna_p1000000000` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.6 | 87.4 | −2.7 | 24.5 ⚠튐 | 0.19 | −93.58 | 0.041 |
# | −15° | 1230 Hz | 80.5 | 12.7 | 8.5 | +42.5 | 127.2 | 1.00 | −138.66 | 0.294 |
# | −30° | 1102 Hz | 77.6 | 12.6 | 1.4 | +50.4 | 127.2 | 1.00 | −129.61 | 95.050 |
# | −45° | 900 Hz | 82.6 | 12.5 | 1.6 | +54.3 | 127.2 | 1.00 | −124.25 | 44.202 |
# | −60° | 636 Hz | 84.2 | 12.6 | 3.6 | +44.9 | 254.3 | 2.01 | −123.60 | 26.701 |
# | −75° | 330 Hz | 93.4 | 12.6 | 1.5 | — | 127.2 | 1.00 | −115.62 | 25.441 |
# | −90°\* | 0 Hz | 98.4 | 12.6 | 100.0 | — | 127.2 | 1.00 | −126.52 | 3.070 |

# %% [markdown]
# ### 절 3.43 `sionna_p250000000`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 2.5 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p250000000 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p250000000__map.png)
#
# **그림 94.** `sionna_p250000000` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p250000000 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p250000000__band.png)
#
# **그림 95.** `sionna_p250000000` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.6 | 87.0 | +0.0 | 29.3 ⚠튐 | 0.23 | −99.31 | 0.011 |
# | −15° | 1230 Hz | 73.2 | 12.7 | 30.9 | +37.3 | 127.2 | 1.00 | −145.66 | 0.212 |
# | −30° | 1102 Hz | 82.4 | 12.6 | 5.1 | +47.2 | 127.2 | 1.00 | −134.32 | 71.499 |
# | −45° | 900 Hz | 82.9 | 12.5 | 7.4 | +47.9 | 127.2 | 1.00 | −130.98 | 20.179 |
# | −60° | 636 Hz | 82.2 | 12.6 | 18.5 | +44.5 | 127.2 | 1.00 | −130.76 | 7.827 |
# | −75° | 330 Hz | 91.7 | 12.6 | 5.8 | — | 127.2 | 1.00 | −122.40 | 16.838 |
# | −90°\* | 0 Hz | 97.0 | 12.6 | 100.0 | — | 254.3 | 2.01 | −129.81 | 6.832 |

# %% [markdown]
# ### 절 3.44 `sionna_p250000000_phys`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 2.5 억 발 · 반사 깊이 3 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p250000000_phys micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p250000000_phys__map.png)
#
# **그림 96.** `sionna_p250000000_phys` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p250000000_phys blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p250000000_phys__band.png)
#
# **그림 97.** `sionna_p250000000_phys` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.6 | 87.1 | −2.4 | 450.0 ⚠튐 | 3.55 | −94.81 | 0.018 |
# | −15° | 1230 Hz | 14.2 | 12.7 | 85.4 | +6.0 | 78.3 ⚠튐 | 0.62 | −127.27 | 0.094 |
# | −30° | 1102 Hz | 15.0 | 12.6 | 82.0 | +7.7 | 254.3 | 2.01 | −127.28 | 0.155 |
# | −45° | 900 Hz | 15.4 | 12.5 | 79.5 | +10.9 | 254.3 | 2.01 | −125.22 | 0.046 |
# | −60° | 636 Hz | 17.6 | 12.6 | 87.6 | +7.5 | 127.2 | 1.00 | −123.08 | 0.935 |
# | −75° | 330 Hz | 12.9 | 12.6 | 96.4 | — | 127.2 ⚠튐 | 1.00 | −111.90 | 0.054 |
# | −90°\* | 0 Hz | 12.4 | 12.6 | 100.0 | — | 39.1 ⚠튐 | 0.31 | −100.07 | 0.014 |

# %% [markdown]
# ### 절 3.45 `sionna_p4000000000`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000__map.png)
#
# **그림 98.** `sionna_p4000000000` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000__band.png)
#
# **그림 99.** `sionna_p4000000000` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 11.4 | 12.6 | 86.4 | +0.9 | 58.7 ⚠튐 | 0.46 | −90.44 | 0.084 |
# | −15° | 1230 Hz | 74.3 | 12.7 | 3.5 | +44.4 | 127.2 | 1.00 | −135.75 | 0.178 |
# | −45° | 900 Hz | 82.7 | 12.5 | 0.5 | +59.3 | 127.2 | 1.00 | −118.98 | 34.594 |
# | −60° | 636 Hz | 88.8 | 12.6 | 1.5 | +50.8 | 127.2 | 1.00 | −117.92 | 20.061 |
# | −75° | 330 Hz | ◐ 덜 참(2,048/4,096 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.46 `sionna_p4000000000_phys_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_phys_n8192_d1__map.png)
#
# **그림 100.** `sionna_p4000000000_phys_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_phys_n8192_d1__band.png)
#
# **그림 101.** `sionna_p4000000000_phys_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.0 | 12.5 | 71.8 | +10.8 | 254.6 | 2.01 | −87.88 | 0.087 |
# | −15° | 1230 Hz | 13.1 | 12.6 | 87.2 | −0.1 | 252.2 ⚠튐 | 1.99 | −117.00 | 0.133 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 83.3 | +8.6 | 252.2 | 1.99 | −118.38 | 0.293 |
# | −45° | 900 Hz | 12.2 | 12.5 | 90.0 | +2.4 | 506.8 ⚠튐 | 4.00 | −100.13 | 0.109 |
# | −60° | 636 Hz | 14.8 | 12.6 | 84.9 | +7.6 | 126.1 | 0.99 | −116.19 | 1.095 |
# | −75° | 330 Hz | 12.6 | 12.6 | 93.8 | — | 126.1 ⚠튐 | 0.99 | −104.63 | 0.122 |
# | −90°\* | 0 Hz | 16.6 | 12.6 | 100.0 | — | 254.6 ⚠튐 | 2.01 | −110.64 | 0.004 |

# %% [markdown]
# ### 절 3.47 `sionna_p4000000000_phys_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_d1__map.png)
#
# **그림 102.** `sionna_p4000000000_phys_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_d1__band.png)
#
# **그림 103.** `sionna_p4000000000_phys_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.0 | 12.5 | 86.4 | −2.1 | 82.4 ⚠튐 | 0.65 | −94.84 | 0.053 |
# | −15° | 1230 Hz | 11.9 | 12.6 | 87.8 | −0.5 | 143.1 ⚠튐 | 1.13 | −115.02 | 0.758 |
# | −30° | 1102 Hz | 12.5 | 12.6 | 85.8 | +6.3 | 252.2 | 1.99 | −126.60 | 0.077 |
# | −45° | 900 Hz | 13.8 | 12.5 | 78.1 | +11.8 | 506.8 | 4.00 | −126.90 | 0.126 |
# | −60° | 636 Hz | 14.9 | 12.6 | 86.7 | +7.0 | 126.1 | 0.99 | −125.88 | 1.013 |
# | −75° | 330 Hz | 12.4 | 12.6 | 96.2 | — | 126.1 ⚠튐 | 0.99 | −110.96 | 0.081 |
# | −82° | 177 Hz | 13.4 | 12.6 | 93.4 | — | 126.1 | 0.99 | −117.84 | 0.990 |
# | −90°\* | 0 Hz | 14.3 | 12.6 | 100.0 | — | 194.0 ⚠튐 | 1.53 | −118.37 | 0.001 |

# %% [markdown]
# ### 절 3.48 `sionna_p4000000000_phys_r15_n8192_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_d2 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_d2__map.png)
#
# **그림 104.** `sionna_p4000000000_phys_r15_n8192_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_d2 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_d2__band.png)
#
# **그림 105.** `sionna_p4000000000_phys_r15_n8192_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.8 | 12.5 | 86.6 | −2.5 | 123.7 ⚠튐 | 0.98 | −94.42 | 0.058 |
# | −15° | 1230 Hz | 12.1 | 12.6 | 87.7 | −0.5 | 143.1 ⚠튐 | 1.13 | −114.58 | 0.838 |
# | −30° | 1102 Hz | 12.4 | 12.6 | 86.0 | +6.1 | 252.2 | 1.99 | −126.14 | 0.086 |
# | −45° | 900 Hz | 13.8 | 12.5 | 78.4 | +11.7 | 252.2 | 1.99 | −126.57 | 0.136 |
# | −60° | 636 Hz | 15.0 | 12.6 | 86.7 | +7.1 | 126.1 | 0.99 | −125.87 | 1.003 |
# | −75° | 330 Hz | 12.4 | 12.6 | 96.1 | — | 126.1 ⚠튐 | 0.99 | −110.85 | 0.083 |
# | −90°\* | 0 Hz | 14.3 | 12.6 | 100.0 | — | 160.0 ⚠튐 | 1.26 | −118.38 | 0.001 |

# %% [markdown]
# ### 절 3.49 `sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 106.** `sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 107.** `sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.9 | 12.6 | 80.5 | +9.8 | 252.2 | 1.99 | −128.32 | 0.088 |

# %% [markdown]
# ### 절 3.50 `sionna_p4000000000_r15_n32768_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 32,768 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n32768_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n32768_d1__map.png)
#
# **그림 108.** `sionna_p4000000000_r15_n32768_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n32768_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n32768_d1__band.png)
#
# **그림 109.** `sionna_p4000000000_r15_n32768_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 82.5 | 12.6 | 0.8 | +55.1 | 127.1 | 1.00 | −134.57 | 64.136 |

# %% [markdown]
# ### 절 3.51 `sionna_p4000000000_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_d1__map.png)
#
# **그림 110.** `sionna_p4000000000_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_d1__band.png)
#
# **그림 111.** `sionna_p4000000000_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 86.2 | −0.8 | 84.9 ⚠튐 | 0.67 | −94.30 | 0.078 |
# | −4° | 1270 Hz | 87.5 | 12.6 | 5.1 | +49.2 | 126.1 | 0.99 | −145.45 | 2.039 |
# | −8° | 1260 Hz | 83.4 | 12.7 | 7.6 | +45.5 | 126.1 | 0.99 | −146.60 | 1.243 |
# | −11° | 1250 Hz | 75.5 | 12.7 | 4.9 | +44.6 | 126.1 | 0.99 | −146.24 | 0.815 |
# | −15° | 1230 Hz | 81.3 | 12.6 | 6.5 | +45.4 | 126.1 | 0.99 | −145.33 | 0.226 |
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 58.125 |
# | −45° | 900 Hz | 84.1 | 12.5 | 0.9 | +54.1 | 126.1 | 0.99 | −129.61 | 25.376 |
# | −52° | 784 Hz | 89.4 | 12.5 | 1.3 | +51.3 | 126.1 | 0.99 | −126.02 | 50.652 |
# | −60° | 636 Hz | 86.6 | 12.6 | 3.3 | +48.3 | 126.1 | 0.99 | −129.72 | 12.742 |
# | −68° | 477 Hz | 92.4 | 12.6 | 2.6 | +51.8 | 126.1 | 0.99 | −126.59 | 8.989 |
# | −75° | 330 Hz | 95.2 | 12.6 | 0.8 | — | 126.1 | 0.99 | −119.73 | 20.050 |
# | −82° | 177 Hz | 97.5 | 12.6 | 4.6 | — | 126.1 | 0.99 | −124.28 | 11.396 |
# | −90°\* | 0 Hz | 98.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.72 | 1.665 |

# %% [markdown]
# ### 절 3.52 `sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 112.** `sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 113.** `sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 84.6 | −0.2 | 50.9 ⚠튐 | 0.40 | −96.36 | 0.049 |
# | −15° | 1230 Hz | 78.5 | 12.6 | 7.6 | +44.4 | 126.1 | 0.99 | −146.55 | 0.203 |
# | −30° | 1102 Hz | 79.6 | 12.6 | 1.0 | +53.1 | 126.1 | 0.99 | −135.82 | 38.920 |
# | −45° | 900 Hz | 85.9 | 12.5 | 1.1 | +55.7 | 126.1 | 0.99 | −130.81 | 62.826 |
# | −52° | 784 Hz | 86.3 | 12.5 | 1.2 | +51.9 | 126.1 | 0.99 | −127.22 | 52.036 |
# | −60° | 636 Hz | 90.5 | 12.6 | 3.3 | +47.2 | 126.1 | 0.99 | −128.22 | 11.726 |
# | −68° | 477 Hz | 96.2 | 12.6 | 4.2 | +51.8 | 126.1 | 0.99 | −125.49 | 9.735 |
# | −75° | 330 Hz | 95.0 | 12.6 | 1.8 | — | 126.1 | 0.99 | −123.02 | 16.597 |
# | −82° | 177 Hz | 97.5 | 12.6 | 3.8 | — | 126.1 | 0.99 | −123.67 | 13.945 |
# | −90°\* | 0 Hz | 98.4 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.88 | 0.277 |

# %% [markdown]
# ### 절 3.53 `sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 114.** `sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 115.** `sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 87.2 | −0.3 | 109.1 ⚠튐 | 0.86 | −97.30 | 0.039 |
# | −30° | 1102 Hz | 19.2 | 12.6 | 0.9 | +35.3 | 259.5 | 2.05 | −134.13 | 48.449 |
# | −60° | 636 Hz | 17.0 | 12.6 | 2.4 | +49.0 | 249.8 | 1.97 | −126.15 | 17.627 |

# %% [markdown]
# ### 절 3.54 `sionna_p4000000000_r15_n8192_shell0.5mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.5mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.5mm_d1__map.png)
#
# **그림 116.** `sionna_p4000000000_r15_n8192_shell0.5mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.5mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.5mm_d1__band.png)
#
# **그림 117.** `sionna_p4000000000_r15_n8192_shell0.5mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 87.769 |

# %% [markdown]
# ### 절 3.55 `sionna_p4000000000_r15_n8192_shell0.75mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_d1__map.png)
#
# **그림 118.** `sionna_p4000000000_r15_n8192_shell0.75mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_d1__band.png)
#
# **그림 119.** `sionna_p4000000000_r15_n8192_shell0.75mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 85.386 |

# %% [markdown]
# ### 절 3.56 `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1__map.png)
#
# **그림 120.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1__band.png)
#
# **그림 121.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 73.8 | 12.6 | 3.1 | +44.1 | 126.1 | 0.99 | −157.74 | 19.840 |

# %% [markdown]
# ### 절 3.57 `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1__map.png)
#
# **그림 122.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1__band.png)
#
# **그림 123.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 86.2 | −0.8 | 84.9 ⚠튐 | 0.67 | −94.30 | 0.078 |
# | −15° | 1230 Hz | 76.9 | 12.6 | 22.0 | +36.7 | 126.1 | 0.99 | −158.40 | 0.419 |
# | −30° | 1102 Hz | 75.3 | 12.6 | 2.9 | +45.0 | 126.1 | 0.99 | −152.65 | 40.065 |
# | −60° | 636 Hz | 86.9 | 12.6 | 2.7 | +50.0 | 126.1 | 0.99 | −144.44 | 20.496 |

# %% [markdown]
# ### 절 3.58 `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1__map.png)
#
# **그림 124.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1__band.png)
#
# **그림 125.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 86.2 | −0.8 | 84.9 ⚠튐 | 0.67 | −94.30 | 0.078 |
# | −30° | 1102 Hz | 76.7 | 12.6 | 2.8 | +45.8 | 126.1 | 0.99 | −148.68 | 57.034 |
# | −60° | 636 Hz | 86.9 | 12.6 | 2.7 | +50.0 | 126.1 | 0.99 | −140.47 | 47.800 |

# %% [markdown]
# ### 절 3.59 `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1__map.png)
#
# **그림 126.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1__band.png)
#
# **그림 127.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 77.7 | 12.6 | 2.7 | +46.4 | 126.1 | 0.99 | −145.85 | 67.063 |

# %% [markdown]
# ### 절 3.60 `sionna_p4000000000_r15_n8192_shell1.5mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell1.5mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell1.5mm_d1__map.png)
#
# **그림 128.** `sionna_p4000000000_r15_n8192_shell1.5mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell1.5mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell1.5mm_d1__band.png)
#
# **그림 129.** `sionna_p4000000000_r15_n8192_shell1.5mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 78.282 |

# %% [markdown]
# ### 절 3.61 `sionna_phys`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 1,111 만 발 · 반사 깊이 3 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_phys micro-Doppler maps](../outputs/figures/atlas/01base__sionna_phys__map.png)
#
# **그림 130.** `sionna_phys` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_phys blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_phys__band.png)
#
# **그림 131.** `sionna_phys` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.0 | 12.6 | 83.1 | +1.4 | 420.6 ⚠튐 | 3.32 | −131.99 | 0.000 |
# | −15° | 1230 Hz | 17.7 | 12.7 | 83.1 | +7.6 | 24.5 ⚠튐 | 0.19 | −133.57 | 0.230 |
# | −30° | 1102 Hz | 51.6 | 12.6 | 69.9 | +18.2 | 254.3 | 2.01 | −136.58 | 0.011 |
# | −45° | 900 Hz | 40.4 | 12.5 | 46.1 | +21.0 | 127.2 | 1.00 | −131.88 | 0.032 |
# | −60° | 636 Hz | 60.7 | 12.6 | 88.0 | +19.9 | 127.2 | 1.00 | −132.14 | 88.149 |
# | −75° | 330 Hz | 58.3 | 12.6 | 82.3 | — | 127.2 | 1.00 | −131.35 | 0.043 |
# | −90°\* | 0 Hz | 45.0 | 12.6 | 100.0 | — | 254.3 | 2.01 | −130.92 | 0.000 |

# %% [markdown]
# ### 절 3.62 `sionna_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 2,500 만 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/01base__sionna_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 132.** `sionna_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 133.** `sionna_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | 81.6 | 12.6 | 17.8 | +42.2 | 126.1 | 0.99 | −148.73 | 35.232 |
# | −45° | 900 Hz | 85.2 | 12.5 | 20.0 | +42.2 | 126.1 | 0.99 | −142.90 | 10.352 |
# | −75° | 330 Hz | 95.4 | 12.6 | 55.4 | — | 126.1 | 0.99 | −137.24 | 58.877 |
