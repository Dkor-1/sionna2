# %% [markdown]
# # 도감 F — 거리 — 15 m 아닌 판(30 m)
#
# [← 도감 지도](A_atlas.ipynb) 로 돌아간다. 이 편은 도감의 **절 8** 하나다 — 주제마다 파일을 나눴다.

# %% [markdown]
# ---
#
# ## 절 8. 거리 — 15 m 아닌 판(30 m)
#
# > **묻는 것** — 15 m 에서 30 m 로 물러나면 날개 무늬가 남나.
#
# 팔 57 개 · 칸 119 개 · 그림 122 장. 그림 파일은 전부 `outputs/figures/atlas/06range__…` 로 시작한다.

# %% [markdown]
# ![range — 06range__000-overview-rhythm.png](../outputs/figures/atlas/06range__000-overview-rhythm.png)
#
# **그림 817.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![range — 06range__01-compare-tile-30-p1.png](../outputs/figures/atlas/06range__01-compare-tile-30-p1.png)
#
# **그림 818.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![range — 06range__01-compare-tile-30-p2.png](../outputs/figures/atlas/06range__01-compare-tile-30-p2.png)
#
# **그림 819.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p1.png](../outputs/figures/atlas/06range__02-compare-stack-p1.png)
#
# **그림 820.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p2.png](../outputs/figures/atlas/06range__02-compare-stack-p2.png)
#
# **그림 821.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p3.png](../outputs/figures/atlas/06range__02-compare-stack-p3.png)
#
# **그림 822.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p4.png](../outputs/figures/atlas/06range__02-compare-stack-p4.png)
#
# **그림 823.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p5.png](../outputs/figures/atlas/06range__02-compare-stack-p5.png)
#
# **그림 824.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 8.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mavic 4 Pro ≈ 13.5 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −15° | −30° | −45° | −60° | −75° | −90° |
# |---|---|---|---|---|---|---|---|---|---|
# | `ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 120 m | — | — | 87 | — | — | — | — |
# | `ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 240 m | — | — | 87 | — | — | — | — |
# | `ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 30 m | — | — | 87 | — | — | — | — |
# | `ours_mini5pro_r120_n8192` | DJI Mini 5 Pro · 183.333 Hz | 120 m | 66 | — | 83 | — | — | — | — |
# | `ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 120 m | — | — | 87 | — | — | — | — |
# | `ours_mini5pro_r240_n8192` | DJI Mini 5 Pro · 183.333 Hz | 240 m | — | — | 83 | — | — | — | — |
# | `ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 240 m | — | — | 87 | — | — | — | — |
# | `ours_mini5pro_r30_n8192` | DJI Mini 5 Pro · 183.333 Hz | 30 m | 66 | — | 83 | — | — | — | — |
# | `ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 30 m | — | — | 87 | — | — | — | — |
# | `ours_mini5pro_r60_n8192` | DJI Mini 5 Pro · 183.333 Hz | 60 m | 66 | — | 83 | — | — | — | — |
# | `ours_ptd_r120_n8192` | DJI Matrice 4E · 126.667 Hz | 120 m | — | — | 83 | — | — | — | — |
# | `ours_ptd_r30_n8192` | DJI Matrice 4E · 126.667 Hz | 30 m | — | — | 83 | — | — | — | — |
# | `ours_ptd_r60_n8192` | DJI Matrice 4E · 126.667 Hz | 60 m | — | — | 83 | — | — | — | — |
# | `ours_r120_n8192` | DJI Matrice 4E · 126.667 Hz | 120 m | 64 | — | 83 | — | 53 | — | — |
# | `ours_r120_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 120 m | — | — | 88 | — | — | — | — |
# | `ours_r240_n8192` | DJI Matrice 4E · 126.667 Hz | 240 m | 64 | — | 83 | — | — | — | — |
# | `ours_r240_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 240 m | — | — | 87 | — | — | — | — |
# | `ours_r30_n8192` | DJI Matrice 4E · 126.667 Hz | 30 m | 64 | — | 83 | — | 53 | — | — |
# | `ours_r30_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 30 m | 62 | 68 | 88 | 43 | 53 | 49 | 57\* |
# | `ours_r45_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 45 m | 62 | 68 | 88 | 43 | 53 | 49 | 56\* |
# | `ours_r480_n8192` | DJI Matrice 4E · 126.667 Hz | 480 m | 64 | — | 83 | — | — | — | — |
# | `ours_r480_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 480 m | — | — | 87 | — | — | — | — |
# | `ours_r60_n8192` | DJI Matrice 4E · 126.667 Hz | 60 m | 64 | — | 83 | — | 53 | — | — |
# | `ours_r60_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 60 m | 62 | 68 | 88 | 43 | 53 | 49 | 56\* |
# | `ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 60 m | 43 | — | 33 | — | — | — | — |
# | `ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 60 m | 20 | — | 20 | — | — | — | — |
# | `ours_r90_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 90 m | 62 | 67 | 88 | 43 | 53 | 49 | 56\* |
# | `ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 90 m | 43 | — | 33 | — | — | — | — |
# | `ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 90 m | 20 | — | 20 | — | — | — | — |
# | `ours_s1000plus_r120_n8192` | DJI S1000+ · 148.9 Hz | 120 m | 51 | — | 75 | — | — | — | — |
# | `ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe` | DJI S1000+ · 148.9 Hz | 120 m | — | — | 78 | — | — | — | — |
# | `ours_s1000plus_r240_n8192` | DJI S1000+ · 148.9 Hz | 240 m | — | — | 76 | — | — | — | — |
# | `ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe` | DJI S1000+ · 148.9 Hz | 240 m | — | — | 78 | — | — | — | — |
# | `ours_s1000plus_r30_n8192` | DJI S1000+ · 148.9 Hz | 30 m | 52 | — | 74 | — | — | — | — |
# | `ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe` | DJI S1000+ · 148.9 Hz | 30 m | — | — | 76 | — | — | — | — |
# | `ours_s1000plus_r60_n8192` | DJI S1000+ · 148.9 Hz | 60 m | 51 | — | 75 | — | — | — | — |
# | `sionna_p4000000000_mini5pro_r120_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 120 m | 86 | — | 83 | — | — | — | — |
# | `sionna_p4000000000_mini5pro_r30_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 30 m | 9 | — | 89 | — | — | — | — |
# | `sionna_p4000000000_mini5pro_r60_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 60 m | 88 | — | 87 | — | — | — | — |
# | `sionna_p4000000000_phys_r120_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 120 m | 12 | — | 14 | — | 62 | — | — |
# | `sionna_p4000000000_phys_r30_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 30 m | 13 | — | 14 | — | 17 | — | — |
# | `sionna_p4000000000_phys_r60_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | 15 | — | 21 | — | — |
# | `sionna_p4000000000_r120_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 120 m | 12 | — | 81 | — | 87 | — | — |
# | `sionna_p4000000000_r120_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 120 m | — | — | 81 | — | — | — | — |
# | `sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 120 m | — | — | 76 | — | — | — | — |
# | `sionna_p4000000000_r240_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 240 m | 92 | — | 79 | — | — | — | — |
# | `sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 240 m | — | — | 78 | — | — | — | — |
# | `sionna_p4000000000_r30_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 30 m | 12 | — | 80 | — | 90 | — | — |
# | `sionna_p4000000000_r30_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 30 m | — | — | 80 | — | — | — | — |
# | `sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 30 m | — | — | 79 | — | — | — | — |
# | `sionna_p4000000000_r480_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 480 m | ○ | — | ◐ | — | — | — | — |
# | `sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 480 m | — | — | ◐ | — | — | — | — |
# | `sionna_p4000000000_r60_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 60 m | 12 | — | 84 | — | 84 | — | — |
# | `sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 60 m | — | — | 82 | — | — | — | — |
# | `sionna_p4000000000_s1000plus_r120_n8192_d1` | DJI S1000+ · 148.9 Hz | 120 m | 54 | — | 50 | — | — | — | — |
# | `sionna_p4000000000_s1000plus_r30_n8192_d1` | DJI S1000+ · 148.9 Hz | 30 m | 38 | — | 46 | — | — | — | — |
# | `sionna_p4000000000_s1000plus_r60_n8192_d1` | DJI S1000+ · 148.9 Hz | 60 m | 46 | — | 41 | — | — | — | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 8.2 `ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 825.** `ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 826.** `ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1018 Hz | 87.1 | 13.5 | 8.4 | +38.9 | 118.9 | 0.99 | −69.01 | 1.659 |

# %% [markdown]
# ### 절 8.3 `ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 240 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 827.** `ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 828.** `ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1018 Hz | 87.0 | 13.5 | 8.4 | +38.9 | 118.9 | 0.99 | −69.00 | 1.652 |

# %% [markdown]
# ### 절 8.4 `ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 829.** `ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 830.** `ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1018 Hz | 87.2 | 13.5 | 8.6 | +38.8 | 118.9 | 0.99 | −69.10 | 1.699 |

# %% [markdown]
# ### 절 8.5 `ours_mini5pro_r120_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r120_n8192__map.png)
#
# **그림 831.** `ours_mini5pro_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r120_n8192__band.png)
#
# **그림 832.** `ours_mini5pro_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.8 | +47.5 | 183.8 | 1.00 | −74.42 | 3.007 |
# | −30° | 887 Hz | 83.1 | 8.7 | 33.0 | +39.7 | 183.8 | 1.00 | −77.68 | 1.754 |

# %% [markdown]
# ### 절 8.6 `ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 833.** `ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 834.** `ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 86.9 | 8.7 | 41.1 | +42.4 | 732.8 | 4.00 | −78.28 | 1.569 |

# %% [markdown]
# ### 절 8.7 `ours_mini5pro_r240_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 240 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r240_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r240_n8192__map.png)
#
# **그림 835.** `ours_mini5pro_r240_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r240_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r240_n8192__band.png)
#
# **그림 836.** `ours_mini5pro_r240_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 83.1 | 8.7 | 33.1 | +39.7 | 183.8 | 1.00 | −77.68 | 1.746 |

# %% [markdown]
# ### 절 8.8 `ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 240 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 837.** `ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 838.** `ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 86.9 | 8.7 | 41.1 | +42.4 | 732.8 | 4.00 | −78.28 | 1.562 |

# %% [markdown]
# ### 절 8.9 `ours_mini5pro_r30_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r30_n8192__map.png)
#
# **그림 839.** `ours_mini5pro_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r30_n8192__band.png)
#
# **그림 840.** `ours_mini5pro_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.8 | +47.5 | 183.8 | 1.00 | −74.43 | 2.991 |
# | −30° | 887 Hz | 83.0 | 8.7 | 32.9 | +39.7 | 183.8 | 1.00 | −77.65 | 1.799 |

# %% [markdown]
# ### 절 8.10 `ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 841.** `ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 842.** `ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 87.0 | 8.7 | 41.0 | +42.3 | 732.8 | 4.00 | −78.26 | 1.607 |

# %% [markdown]
# ### 절 8.11 `ours_mini5pro_r60_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r60_n8192__map.png)
#
# **그림 843.** `ours_mini5pro_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r60_n8192__band.png)
#
# **그림 844.** `ours_mini5pro_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.8 | +47.5 | 183.8 | 1.00 | −74.42 | 3.002 |
# | −30° | 887 Hz | 83.0 | 8.7 | 33.0 | +39.7 | 183.8 | 1.00 | −77.67 | 1.769 |

# %% [markdown]
# ### 절 8.12 `ours_ptd_r120_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_ptd_r120_n8192__map.png)
#
# **그림 845.** `ours_ptd_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_ptd_r120_n8192__band.png)
#
# **그림 846.** `ours_ptd_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 82.8 | 12.6 | 9.2 | +43.6 | 126.1 | 0.99 | −68.82 | 58.206 |

# %% [markdown]
# ### 절 8.13 `ours_ptd_r30_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_ptd_r30_n8192__map.png)
#
# **그림 847.** `ours_ptd_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_ptd_r30_n8192__band.png)
#
# **그림 848.** `ours_ptd_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 83.0 | 12.6 | 9.8 | +43.3 | 126.1 | 0.99 | −68.95 | 55.259 |

# %% [markdown]
# ### 절 8.14 `ours_ptd_r60_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_ptd_r60_n8192__map.png)
#
# **그림 849.** `ours_ptd_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_ptd_r60_n8192__band.png)
#
# **그림 850.** `ours_ptd_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 82.9 | 12.6 | 9.4 | +43.5 | 126.1 | 0.99 | −68.86 | 57.194 |

# %% [markdown]
# ### 절 8.15 `ours_r120_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r120_n8192__map.png)
#
# **그림 851.** `ours_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r120_n8192__band.png)
#
# **그림 852.** `ours_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.8 | 12.5 | 2.6 | +48.2 | 126.1 | 0.99 | −70.42 | 2.689 |
# | −30° | 1102 Hz | 82.9 | 12.6 | 9.2 | +43.7 | 126.1 | 0.99 | −68.81 | 30.645 |
# | −60° | 636 Hz | 53.2 | 12.6 | 1.8 | +45.1 | 126.1 | 0.99 | −66.05 | 57.685 |

# %% [markdown]
# ### 절 8.16 `ours_r120_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r120_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r120_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 853.** `ours_r120_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r120_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r120_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 854.** `ours_r120_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 87.5 | 12.6 | 12.1 | +43.4 | 126.1 | 0.99 | −68.65 | 7.842 |

# %% [markdown]
# ### 절 8.17 `ours_r240_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 240 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r240_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r240_n8192__map.png)
#
# **그림 855.** `ours_r240_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r240_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r240_n8192__band.png)
#
# **그림 856.** `ours_r240_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.8 | 12.5 | 2.6 | +48.2 | 126.1 | 0.99 | −70.42 | 2.697 |
# | −30° | 1102 Hz | 82.9 | 12.6 | 9.1 | +43.7 | 126.1 | 0.99 | −68.79 | 30.834 |

# %% [markdown]
# ### 절 8.18 `ours_r240_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 240 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r240_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r240_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 857.** `ours_r240_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r240_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r240_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 858.** `ours_r240_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 87.4 | 12.6 | 12.0 | +43.4 | 126.1 | 0.99 | −68.64 | 7.814 |

# %% [markdown]
# ### 절 8.19 `ours_r30_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r30_n8192__map.png)
#
# **그림 859.** `ours_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r30_n8192__band.png)
#
# **그림 860.** `ours_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.6 | 12.5 | 2.6 | +48.0 | 126.1 | 0.99 | −70.41 | 2.636 |
# | −30° | 1102 Hz | 83.1 | 12.6 | 9.8 | +43.4 | 126.1 | 0.99 | −68.94 | 29.374 |
# | −60° | 636 Hz | 53.0 | 12.6 | 1.8 | +45.2 | 126.1 | 0.99 | −66.05 | 66.847 |

# %% [markdown]
# ### 절 8.20 `ours_r30_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r30_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r30_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 861.** `ours_r30_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r30_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r30_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 862.** `ours_r30_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.2 | 12.5 | 2.4 | +50.7 | 126.1 | 0.99 | −69.37 | 2.571 |
# | −15° | 1230 Hz | 67.8 | 12.6 | 14.6 | +40.5 | 126.1 | 0.99 | −71.14 | 1.016 |
# | −30° | 1102 Hz | 87.6 | 12.6 | 12.7 | +43.2 | 126.1 | 0.99 | −68.68 | 8.006 |
# | −45° | 900 Hz | 43.2 | 12.5 | 1.7 | +47.6 | 126.1 | 0.99 | −67.95 | 6.671 |
# | −60° | 636 Hz | 53.2 | 12.6 | 1.2 | +45.6 | 126.1 | 0.99 | −64.67 | 6.162 |
# | −75° | 330 Hz | 49.3 | 12.6 | 0.7 | — | 126.1 | 0.99 | −62.28 | 3.031 |
# | −90°\* | 0 Hz | 57.0 | 12.6 | 100.0 | — | 254.6 | 2.01 | −82.39 | 0.010 |

# %% [markdown]
# ### 절 8.21 `ours_r45_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 45 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r45_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r45_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 863.** `ours_r45_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r45_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r45_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 864.** `ours_r45_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.3 | 12.5 | 2.4 | +50.8 | 126.1 | 0.99 | −69.36 | 2.578 |
# | −15° | 1230 Hz | 67.6 | 12.6 | 14.6 | +40.4 | 126.1 | 0.99 | −71.18 | 1.023 |
# | −30° | 1102 Hz | 87.5 | 12.6 | 12.4 | +43.3 | 126.1 | 0.99 | −68.67 | 7.934 |
# | −45° | 900 Hz | 43.2 | 12.5 | 1.7 | +47.7 | 126.1 | 0.99 | −67.95 | 6.612 |
# | −60° | 636 Hz | 53.2 | 12.6 | 1.2 | +45.6 | 126.1 | 0.99 | −64.64 | 6.154 |
# | −75° | 330 Hz | 49.1 | 12.6 | 0.8 | — | 126.1 | 0.99 | −62.51 | 2.920 |
# | −90°\* | 0 Hz | 56.3 | 12.6 | 100.0 | — | 254.6 | 2.01 | −82.45 | 0.010 |

# %% [markdown]
# ### 절 8.22 `ours_r480_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 480 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r480_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r480_n8192__map.png)
#
# **그림 865.** `ours_r480_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r480_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r480_n8192__band.png)
#
# **그림 866.** `ours_r480_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.8 | 12.5 | 2.6 | +48.2 | 126.1 | 0.99 | −70.42 | 2.702 |
# | −30° | 1102 Hz | 82.9 | 12.6 | 9.1 | +43.7 | 126.1 | 0.99 | −68.78 | 30.926 |

# %% [markdown]
# ### 절 8.23 `ours_r480_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 480 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r480_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r480_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 867.** `ours_r480_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r480_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r480_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 868.** `ours_r480_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 87.4 | 12.6 | 11.9 | +43.4 | 126.1 | 0.99 | −68.64 | 7.801 |

# %% [markdown]
# ### 절 8.24 `ours_r60_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r60_n8192__map.png)
#
# **그림 869.** `ours_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r60_n8192__band.png)
#
# **그림 870.** `ours_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.7 | 12.5 | 2.6 | +48.1 | 126.1 | 0.99 | −70.41 | 2.671 |
# | −30° | 1102 Hz | 83.0 | 12.6 | 9.4 | +43.6 | 126.1 | 0.99 | −68.85 | 30.246 |
# | −60° | 636 Hz | 53.1 | 12.6 | 1.8 | +45.2 | 126.1 | 0.99 | −66.05 | 60.631 |

# %% [markdown]
# ### 절 8.25 `ours_r60_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r60_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r60_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 871.** `ours_r60_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r60_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r60_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 872.** `ours_r60_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.3 | 12.5 | 2.4 | +50.8 | 126.1 | 0.99 | −69.35 | 2.582 |
# | −15° | 1230 Hz | 67.5 | 12.6 | 14.6 | +40.4 | 126.1 | 0.99 | −71.20 | 1.027 |
# | −30° | 1102 Hz | 87.5 | 12.6 | 12.3 | +43.3 | 126.1 | 0.99 | −68.66 | 7.897 |
# | −45° | 900 Hz | 43.3 | 12.5 | 1.7 | +47.8 | 126.1 | 0.99 | −67.95 | 6.582 |
# | −60° | 636 Hz | 53.2 | 12.6 | 1.2 | +45.6 | 126.1 | 0.99 | −64.62 | 6.152 |
# | −75° | 330 Hz | 49.1 | 12.6 | 0.8 | — | 126.1 | 0.99 | −62.63 | 2.865 |
# | −90°\* | 0 Hz | 56.1 | 12.6 | 100.0 | — | 254.6 | 2.01 | −82.47 | 0.010 |

# %% [markdown]
# ### 절 8.26 `ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe__map.png)
#
# **그림 873.** `ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe__band.png)
#
# **그림 874.** `ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 43.1 | 12.5 | 2.4 | +0.4 | 63.0 | 0.50 | −69.29 | 2.650 |
# | −30° | 1102 Hz | 33.2 | 12.6 | 3.4 | +0.6 | 63.0 | 0.50 | −67.85 | 9.360 |

# %% [markdown]
# ### 절 8.27 `ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe__map.png)
#
# **그림 875.** `ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe__band.png)
#
# **그림 876.** `ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 19.7 | 12.5 | 2.2 | −1.0 | 189.1 | 1.49 | −72.13 | 1.375 |
# | −30° | 1102 Hz | 20.3 | 12.6 | 2.4 | +2.6 | 31.5 | 0.25 | −69.16 | 7.074 |

# %% [markdown]
# ### 절 8.28 `ours_r90_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 90 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r90_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r90_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 877.** `ours_r90_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r90_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r90_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 878.** `ours_r90_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.3 | 12.5 | 2.4 | +50.8 | 126.1 | 0.99 | −69.35 | 2.585 |
# | −15° | 1230 Hz | 67.3 | 12.6 | 14.7 | +40.4 | 126.1 | 0.99 | −71.22 | 1.030 |
# | −30° | 1102 Hz | 87.5 | 12.6 | 12.1 | +43.4 | 126.1 | 0.99 | −68.65 | 7.860 |
# | −45° | 900 Hz | 43.3 | 12.5 | 1.7 | +47.8 | 126.1 | 0.99 | −67.95 | 6.552 |
# | −60° | 636 Hz | 53.2 | 12.6 | 1.2 | +45.6 | 126.1 | 0.99 | −64.61 | 6.150 |
# | −75° | 330 Hz | 49.0 | 12.6 | 0.8 | — | 126.1 | 0.99 | −62.75 | 2.810 |
# | −90°\* | 0 Hz | 55.9 | 12.6 | 100.0 | — | 254.6 | 2.01 | −82.49 | 0.010 |

# %% [markdown]
# ### 절 8.29 `ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 90 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe__map.png)
#
# **그림 879.** `ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe__band.png)
#
# **그림 880.** `ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 43.1 | 12.5 | 2.4 | +0.4 | 63.0 | 0.50 | −69.32 | 2.630 |
# | −30° | 1102 Hz | 33.1 | 12.6 | 3.4 | +0.6 | 63.0 | 0.50 | −67.86 | 9.294 |

# %% [markdown]
# ### 절 8.30 `ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 90 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe__map.png)
#
# **그림 881.** `ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe__band.png)
#
# **그림 882.** `ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 19.7 | 12.5 | 2.2 | −1.0 | 189.1 | 1.49 | −72.21 | 1.348 |
# | −30° | 1102 Hz | 20.3 | 12.6 | 2.4 | +2.5 | 31.5 | 0.25 | −69.21 | 6.962 |

# %% [markdown]
# ### 절 8.31 `ours_s1000plus_r120_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r120_n8192__map.png)
#
# **그림 883.** `ours_s1000plus_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r120_n8192__band.png)
#
# **그림 884.** `ours_s1000plus_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 50.7 | 10.9 | 5.0 | +37.9 | 147.7 | 0.99 | −66.11 | 0.118 |
# | −30° | 1802 Hz | 75.3 | 10.8 | 16.1 | +33.2 | 147.7 | 0.99 | −64.25 | 3.925 |

# %% [markdown]
# ### 절 8.32 `ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 885.** `ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 886.** `ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 78.0 | 10.8 | 18.4 | +32.5 | 147.7 | 0.99 | −64.30 | 4.091 |

# %% [markdown]
# ### 절 8.33 `ours_s1000plus_r240_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 240 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r240_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r240_n8192__map.png)
#
# **그림 887.** `ours_s1000plus_r240_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r240_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r240_n8192__band.png)
#
# **그림 888.** `ours_s1000plus_r240_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 75.5 | 10.8 | 16.2 | +33.2 | 147.7 | 0.99 | −64.22 | 4.026 |

# %% [markdown]
# ### 절 8.34 `ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 240 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 889.** `ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 890.** `ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 78.2 | 10.8 | 18.6 | +32.6 | 147.7 | 0.99 | −64.27 | 4.200 |

# %% [markdown]
# ### 절 8.35 `ours_s1000plus_r30_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r30_n8192__map.png)
#
# **그림 891.** `ours_s1000plus_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r30_n8192__band.png)
#
# **그림 892.** `ours_s1000plus_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 52.3 | 10.9 | 4.9 | +38.4 | 147.7 | 0.99 | −65.96 | 0.126 |
# | −30° | 1802 Hz | 73.7 | 10.8 | 15.3 | +33.0 | 147.7 | 0.99 | −64.53 | 3.305 |

# %% [markdown]
# ### 절 8.36 `ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 893.** `ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 894.** `ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 76.5 | 10.8 | 17.2 | +32.3 | 147.7 | 0.99 | −64.58 | 3.438 |

# %% [markdown]
# ### 절 8.37 `ours_s1000plus_r60_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r60_n8192__map.png)
#
# **그림 895.** `ours_s1000plus_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r60_n8192__band.png)
#
# **그림 896.** `ours_s1000plus_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 51.3 | 10.9 | 5.0 | +38.1 | 147.7 | 0.99 | −66.07 | 0.120 |
# | −30° | 1802 Hz | 74.8 | 10.8 | 15.8 | +33.1 | 147.7 | 0.99 | −64.32 | 3.720 |

# %% [markdown]
# ### 절 8.38 `sionna_p4000000000_mini5pro_r120_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r120_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r120_n8192_d1__map.png)
#
# **그림 897.** `sionna_p4000000000_mini5pro_r120_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r120_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r120_n8192_d1__band.png)
#
# **그림 898.** `sionna_p4000000000_mini5pro_r120_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 86.2 | 8.7 | 14.0 | +52.6 | 183.8 | 1.00 | −187.23 | 0.000 |
# | −30° | 887 Hz | 82.9 | 8.7 | 24.0 | +44.5 | 183.8 | 1.00 | −188.14 | 28.471 |

# %% [markdown]
# ### 절 8.39 `sionna_p4000000000_mini5pro_r30_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r30_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r30_n8192_d1__map.png)
#
# **그림 899.** `sionna_p4000000000_mini5pro_r30_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r30_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r30_n8192_d1__band.png)
#
# **그림 900.** `sionna_p4000000000_mini5pro_r30_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 9.2 | 8.7 | 89.8 | −0.6 | 442.6 ⚠튐 | 2.41 | −108.01 | 0.030 |
# | −30° | 887 Hz | 88.6 | 8.7 | 23.9 | +45.3 | 183.8 | 1.00 | −162.82 | 16.335 |

# %% [markdown]
# ### 절 8.40 `sionna_p4000000000_mini5pro_r60_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r60_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r60_n8192_d1__map.png)
#
# **그림 901.** `sionna_p4000000000_mini5pro_r60_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r60_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r60_n8192_d1__band.png)
#
# **그림 902.** `sionna_p4000000000_mini5pro_r60_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 87.8 | 8.7 | 20.3 | +43.6 | 549.0 | 2.99 | −180.22 | 0.000 |
# | −30° | 887 Hz | 87.2 | 8.7 | 22.4 | +45.2 | 183.8 | 1.00 | −175.09 | 40.613 |

# %% [markdown]
# ### 절 8.41 `sionna_p4000000000_phys_r120_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r120_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r120_n8192_d1__map.png)
#
# **그림 903.** `sionna_p4000000000_phys_r120_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r120_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r120_n8192_d1__band.png)
#
# **그림 904.** `sionna_p4000000000_phys_r120_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 87.0 | +0.3 | 380.7 ⚠튐 | 3.01 | −166.22 | 0.000 |
# | −30° | 1102 Hz | 13.5 | 12.6 | 82.8 | +4.7 | 126.1 ⚠튐 | 0.99 | −171.15 | 0.007 |
# | −60° | 636 Hz | 61.8 | 12.6 | 70.3 | +23.7 | 126.1 | 0.99 | −174.20 | 0.008 |

# %% [markdown]
# ### 절 8.42 `sionna_p4000000000_phys_r30_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r30_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r30_n8192_d1__map.png)
#
# **그림 905.** `sionna_p4000000000_phys_r30_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r30_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r30_n8192_d1__band.png)
#
# **그림 906.** `sionna_p4000000000_phys_r30_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 87.4 | +0.0 | 55.8 ⚠튐 | 0.44 | −108.19 | 0.010 |
# | −30° | 1102 Hz | 14.0 | 12.6 | 84.1 | +7.8 | 380.7 ⚠튐 | 3.01 | −145.07 | 0.029 |
# | −60° | 636 Hz | 17.3 | 12.6 | 86.2 | +8.3 | 126.1 | 0.99 | −141.04 | 0.130 |

# %% [markdown]
# ### 절 8.43 `sionna_p4000000000_phys_r60_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r60_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r60_n8192_d1__map.png)
#
# **그림 907.** `sionna_p4000000000_phys_r60_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r60_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r60_n8192_d1__band.png)
#
# **그림 908.** `sionna_p4000000000_phys_r60_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 87.1 | +0.1 | 21.8 ⚠튐 | 0.17 | −123.04 | 0.001 |
# | −30° | 1102 Hz | 14.9 | 12.6 | 85.0 | +6.7 | 252.2 ⚠튐 | 1.99 | −157.65 | 0.033 |
# | −60° | 636 Hz | 21.3 | 12.6 | 90.5 | +8.0 | 126.1 ⚠튐 | 0.99 | −156.98 | 0.022 |

# %% [markdown]
# ### 절 8.44 `sionna_p4000000000_r120_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_d1__map.png)
#
# **그림 909.** `sionna_p4000000000_r120_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_d1__band.png)
#
# **그림 910.** `sionna_p4000000000_r120_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.1 | −0.0 | 46.1 ⚠튐 | 0.36 | −125.29 | 0.004 |
# | −30° | 1102 Hz | 81.3 | 12.6 | 10.9 | +40.5 | 126.1 | 0.99 | −180.62 | 13.973 |
# | −60° | 636 Hz | 87.2 | 12.6 | 16.8 | +39.9 | 126.1 | 0.99 | −173.11 | 76.135 |

# %% [markdown]
# ### 절 8.45 `sionna_p4000000000_r120_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_d3__map.png)
#
# **그림 911.** `sionna_p4000000000_r120_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_d3__band.png)
#
# **그림 912.** `sionna_p4000000000_r120_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 81.4 | 12.6 | 10.8 | +40.4 | 126.1 | 0.99 | −180.36 | 13.421 |

# %% [markdown]
# ### 절 8.46 `sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 913.** `sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 914.** `sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 75.7 | 12.6 | 11.1 | +39.7 | 252.2 | 1.99 | −182.14 | 19.432 |

# %% [markdown]
# ### 절 8.47 `sionna_p4000000000_r240_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 240 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r240_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r240_n8192_d1__map.png)
#
# **그림 915.** `sionna_p4000000000_r240_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r240_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r240_n8192_d1__band.png)
#
# **그림 916.** `sionna_p4000000000_r240_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 92.1 | 12.5 | 6.7 | +54.0 | 506.8 | 4.00 | −193.59 | 0.000 |
# | −30° | 1102 Hz | 78.7 | 12.6 | 7.5 | +42.3 | 126.1 | 0.99 | −192.11 | 37.535 |

# %% [markdown]
# ### 절 8.48 `sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 240 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 917.** `sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 918.** `sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 77.8 | 12.6 | 14.6 | +37.4 | 126.1 | 0.99 | −194.68 | 53.333 |

# %% [markdown]
# ### 절 8.49 `sionna_p4000000000_r30_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_d1__map.png)
#
# **그림 919.** `sionna_p4000000000_r30_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_d1__band.png)
#
# **그림 920.** `sionna_p4000000000_r30_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 84.7 | −1.3 | 143.1 ⚠튐 | 1.13 | −104.37 | 0.031 |
# | −30° | 1102 Hz | 80.5 | 12.6 | 3.1 | +46.8 | 126.1 | 0.99 | −151.91 | 26.775 |
# | −60° | 636 Hz | 89.7 | 12.6 | 13.7 | +43.2 | 126.1 | 0.99 | −146.86 | 12.765 |

# %% [markdown]
# ### 절 8.50 `sionna_p4000000000_r30_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_d3__map.png)
#
# **그림 921.** `sionna_p4000000000_r30_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_d3__band.png)
#
# **그림 922.** `sionna_p4000000000_r30_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 80.1 | 12.6 | 3.6 | +46.4 | 126.1 | 0.99 | −152.30 | 23.558 |

# %% [markdown]
# ### 절 8.51 `sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 923.** `sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 924.** `sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 79.2 | 12.6 | 3.4 | +48.6 | 126.1 | 0.99 | −152.87 | 19.312 |

# %% [markdown]
# ### 절 8.52 `sionna_p4000000000_r480_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 480 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r480_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r480_n8192_d1__map.png)
#
# **그림 925.** `sionna_p4000000000_r480_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r480_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r480_n8192_d1__band.png)
#
# **그림 926.** `sionna_p4000000000_r480_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | ○ 안 움직임 | — | — | — | — | — | — | — |
# | −30° | 1102 Hz | ◐ 덜 참(2,905/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 8.53 `sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 480 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 927.** `sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 928.** `sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ◐ 덜 참(2,994/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 8.54 `sionna_p4000000000_r60_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r60_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r60_n8192_d1__map.png)
#
# **그림 929.** `sionna_p4000000000_r60_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r60_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r60_n8192_d1__band.png)
#
# **그림 930.** `sionna_p4000000000_r60_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 87.0 | +0.2 | 38.8 ⚠튐 | 0.31 | −115.00 | 0.011 |
# | −30° | 1102 Hz | 84.1 | 12.6 | 9.4 | +41.2 | 126.1 | 0.99 | −167.89 | 75.109 |
# | −60° | 636 Hz | 83.8 | 12.6 | 18.2 | +43.0 | 126.1 | 0.99 | −162.20 | 41.385 |

# %% [markdown]
# ### 절 8.55 `sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 931.** `sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 932.** `sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 81.8 | 12.6 | 7.0 | +44.6 | 126.1 | 0.99 | −167.60 | 88.001 |

# %% [markdown]
# ### 절 8.56 `sionna_p4000000000_s1000plus_r120_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r120_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r120_n8192_d1__map.png)
#
# **그림 933.** `sionna_p4000000000_s1000plus_r120_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r120_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r120_n8192_d1__band.png)
#
# **그림 934.** `sionna_p4000000000_s1000plus_r120_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 54.2 | 10.9 | 43.8 | +25.4 | 746.0 | 5.01 | −183.36 | 0.057 |
# | −30° | 1802 Hz | 49.6 | 10.8 | 32.9 | +23.1 | 150.2 | 1.01 | −177.98 | 0.594 |

# %% [markdown]
# ### 절 8.57 `sionna_p4000000000_s1000plus_r30_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r30_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r30_n8192_d1__map.png)
#
# **그림 935.** `sionna_p4000000000_s1000plus_r30_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r30_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r30_n8192_d1__band.png)
#
# **그림 936.** `sionna_p4000000000_s1000plus_r30_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 37.6 | 10.9 | 33.3 | +29.5 | 743.5 | 4.99 | −156.02 | 0.009 |
# | −30° | 1802 Hz | 45.6 | 10.8 | 5.1 | +36.2 | 147.7 | 0.99 | −149.83 | 0.936 |

# %% [markdown]
# ### 절 8.58 `sionna_p4000000000_s1000plus_r60_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r60_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r60_n8192_d1__map.png)
#
# **그림 937.** `sionna_p4000000000_s1000plus_r60_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r60_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r60_n8192_d1__band.png)
#
# **그림 938.** `sionna_p4000000000_s1000plus_r60_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 46.4 | 10.9 | 41.9 | +29.9 | 595.8 | 4.00 | −169.66 | 0.018 |
# | −30° | 1802 Hz | 41.3 | 10.8 | 18.6 | +32.9 | 147.7 | 0.99 | −165.46 | 0.281 |
