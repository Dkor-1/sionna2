# %% [markdown]
# # 리포트 65 — 평판·큐브·우리 격자를 같은 동작점에서 갈아끼우면 요구 이득이 이만큼 달라진다
#
# > ### 한 일
# > **같은 기하·같은 검출기·같은 동작점에서 표적만 세 모형으로 갈아끼우고, 자세평균을 맞춘 뒤 남는 요구 추가이득을 추정량별로 적었다.**
#
# ### 결과
# 1. 세 모형은 자세무관 평판 σ -12.81 dBsm [^1] (3GPP, M1) · 정육면체(M2) · 우리 SBR+PO 격자(M3) 다.
# 2. 자세 앙상블은 셀당 1080 [^2]자세 전수, (기체×밴드) 셀은 21 [^3]개이고 재현편차는 0.00 dB [^4] 다.
# 3. 낙차의 소유자는 정육면체다 — 자유공간에서 최대가 M2 인 셀이 21 [^5]개, 최소가 M1 인 셀이 21 [^6]개로 전수다.
# 4. 크기는 **추정량이 정한다** — 검출기가 읽는 p10 에서 맞추면 낙차가 2.30 dB [^7] 로 줄고 세 팔의 순서가 뒤집혀 M1 이 가장 어려운 팔이 된다.
# 5. 각 다양성이 낙차를 줄인다 — 각 다양성이 0 인 자유공간에서 29.30 dB [^8], 가장 큰 앙상블에서 10.09 dB [^9] 다.

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 갈아끼우는 것 | 기하·검출기·동작점을 고정하고 표적 모형만 셋으로 바꾼다 — 그래서 남는 차이는 표적 모형의 몫이다 |
# | 자세 앙상블 | 셀당 자세 전수를 돌리고 자세평균을 맞춘 뒤 남는 **요구 추가이득**을 읽는다 |
# | 추정량 | 선형평균(이 실험의 규약) · 중앙값 · dB 평균 · p10(검출기가 읽는 분위수) 넷을 나란히 싣는다 |
# | 문턱 규약 | 잡음전력 기지 이상문턱이다. CA-CFAR 문턱은 세 팔에 같은 오프셋을 주므로 모형 간 차이는 문턱 규약에 불변이다 |
#
# ### 재현
#
# ```bash
# cd /home/yunjung/workspace/sionna2
# PYTHONPATH=src ~/.venvs/py312/bin/python src/build_part10_results.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/tm_result.json`, `outputs/tm_attack.json` |
# | 소요 | σ 격자 · 검지거리 4단계 · 검증 · 스윕을 합쳐 7.8 h [^10] (GPU 2 [^11]장). 이 빌더 자신은 CPU 수 초다 |
#
# ### 앞 편에서
#
# | 어디서 | 무엇을 알고 와야 하나 |
# |---|---|
# | [편 60 «앵커 σ 위의 R90 은 3.69~11.10…»](60_r90.ipynb) | 우리 격자 위의 검출거리와 순위 |
# | [편 53 «운용 형상에서 경험 Pfa 를 재니 명목값의…»](53_cfar-calib.ipynb) | 교정된 오경보율 위의 절대 소요이득 |
#
# ---

# %% [markdown]
# ## 표적만 세 모형으로 갈아끼운다
#
# 같은 기하·같은 검출기·같은 동작점에서 표적만 셋으로 갈아끼운다 — 자세무관 평판 σ -12.81 dBsm [^1] (3GPP, M1) · 정육면체(M2) · 우리 SBR+PO 격자(M3).
#
# 자세 앙상블은 셀당 1080 [^2]자세 전수, (기체×밴드) 셀은 21 [^3]개이고, 자세평균을 맞춘 뒤 남는 **요구 추가이득**을 추정량별로 적는다(재현편차 0.00 dB [^4]).

# %% [markdown]
# | 무엇을 맞추나 | M1 평판 [dB] | M2 정육면체 [dB] | M3 우리 격자 [dB] |
# |---|---|---|---|
# | 선형평균 — 이 실험의 규약 | +0.00 [^12] | +29.30 [^13] | +7.52 [^14] |
# | 중앙값 | +0.00 [^15] | +16.01 [^16] | +4.78 [^17] |
# | dB 평균 | +0.00 [^18] | +14.65 [^19] | +4.66 [^20] |
# | p10 — 검출기가 읽는 분위수 | +0.00 [^21] | -2.20 [^22] | -2.08 [^23] |

# %% [markdown]
# ## 낙차의 소유자는 정육면체다
#
# 자유공간에서 최대가 M2 인 셀이 21 [^5]개, 최소가 M1 인 셀이 21 [^6]개로 전수이고, M3 몫은 다섯 앙상블에서 20.2% [^24] ~ 33.0% [^25] 다.
#
# 각 다양성이 그 낙차를 줄인다 — 각 다양성이 0 인 자유공간(N_eff 1.0 [^26])에서 29.30 dB [^8], 각 다양성이 가장 큰 앙상블(N_eff 3.78 [^27])에서 10.09 dB [^9] 다.

# %% [markdown]
# ## 크기는 추정량이 정한다
#
# ⚠ 검출기가 읽는 p10 에서 맞추면 낙차가 2.30 dB [^7] 로 줄고 세 팔의 순서가 뒤집혀 M1 이 가장 어려운 팔이 된다.
#
# 문턱은 잡음전력 기지 이상문턱이고 CA-CFAR 문턱은 세 팔에 같은 오프셋을 주므로, 교정표는 세 팔의 절대 소요이득만 옮긴다([^28]).

# %% [markdown]
# ## 이 표에 구 대조군은 없다
#
# 구는 **부피를 맞게 고르면** σ 의 절대 레벨을 맞출 수 있는 단순 모형이면서 자세에 따른 변화를 0 으로 낸다. 레벨에서 우리 메쉬를 앞선 그 구는 논문이 적어 둔 상자 치수로 잡은 부피이고, 메쉬 부피로 잡으면 두 잣대 모두에서 우리 메쉬보다 나쁘다.
#
# 그래서 이 표의 낙차는 «자세 구조를 얼마나 담는가» 의 낙차로 읽는다. 구 팔을 넣는 일은 다음 단계에 있다.

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 표적모형 민감도의 M3 팔을 재생성 격자로 다시 푼다 | 우리 팔의 요구 추가이득 7.52 dB [^29] 와 낙차 몫 25.7% [^30] 가 현재 메쉬 위에 선다 | `scratchpad/tm_result.py` |
# | 표적모형에 **구 팔(M4)** 을 더한다 | 레벨만 맞추는 모형과 자세 구조를 담는 모형의 검출 낙차가 갈라진다 | `scratchpad/tm_result.py` → [편 27 «메쉬가 사는 축은 절대 크기가 아니라 각도 구…»](27_box-sphere-control.ipynb) |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 30개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/tm_result.json` | `protocol.operating_point.sigma_reference_dbsm` | -12.81 |
# | [^2] | `outputs/tm_result.json` | `statistics.n_aspect_realisations_per_cell` | 1080 |
# | [^3] | `outputs/tm_result.json` | `statistics.n_drone_band_cells` | 21 |
# | [^4] | `outputs/tm_attack.json` | `meta.reproduction.E0_extra_gain_max_abs_dev_db` | 0 |
# | [^5] | `outputs/tm_attack.json` | `Q3_staleness.argmax_argmin_counts.E0_freespace.argmax_counts.M2` | 21 |
# | [^6] | `outputs/tm_attack.json` | `Q3_staleness.argmax_argmin_counts.E0_freespace.argmin_counts.M1` | 21 |
# | [^7] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.p10.spread_mean` | 2.303 |
# | [^8] | `outputs/tm_result.json` | `verdicts.Q3_environment_dependence.pure_pattern_spread_db_by_env.E0_freespace` | 29.3 |
# | [^9] | `outputs/tm_result.json` | `verdicts.Q3_environment_dependence.pure_pattern_spread_db_by_env.E2b_outdoor_shadowed` | 10.09 |
# | [^10] | `outputs/report05_derived.json` | `runtime.total_h` | 7.773 |
# | [^11] | `outputs/report13_freespace.json` | `meta.gpus` | 2 |
# | [^12] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.mean_lin.per_model_extra_gain_db.M1` | 1.275e-06 |
# | [^13] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.mean_lin.per_model_extra_gain_db.M2` | 29.3 |
# | [^14] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.mean_lin.per_model_extra_gain_db.M3` | 7.52 |
# | [^15] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.median.per_model_extra_gain_db.M1` | 1.275e-06 |
# | [^16] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.median.per_model_extra_gain_db.M2` | 16.01 |
# | [^17] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.median.per_model_extra_gain_db.M3` | 4.784 |
# | [^18] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.mean_db.per_model_extra_gain_db.M1` | 1.275e-06 |
# | [^19] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.mean_db.per_model_extra_gain_db.M2` | 14.65 |
# | [^20] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.mean_db.per_model_extra_gain_db.M3` | 4.663 |
# | [^21] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.p10.per_model_extra_gain_db.M1` | 1.275e-06 |
# | [^22] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.p10.per_model_extra_gain_db.M2` | -2.199 |
# | [^23] | `outputs/tm_attack.json` | `Q1_normalisation.recomputed_spread_db_by_matching_estimator.p10.per_model_extra_gain_db.M3` | -2.075 |
# | [^24] | `outputs/tm_attack.json` | `Q3_staleness.argmax_argmin_counts.E2_outdoor_canyon.m3_share_of_spread` | 0.2016 |
# | [^25] | `outputs/tm_attack.json` | `Q3_staleness.argmax_argmin_counts.E1_chamber_floor.m3_share_of_spread` | 0.3296 |
# | [^26] | `outputs/tm_result.json` | `verdicts.Q3_environment_dependence.predictor.E0_freespace.n_eff_pairs` | 1 |
# | [^27] | `outputs/tm_result.json` | `verdicts.Q3_environment_dependence.predictor.E2b_outdoor_shadowed.n_eff_pairs` | 3.777 |
# | [^28] | `outputs/tm_result.json` | `protocol.pfa_convention` | (3항목 묶음) |
# | [^29] | `outputs/tm_attack.json` | `Q3_staleness.m3_own_number.base_db` | 7.52 |
# | [^30] | `outputs/tm_attack.json` | `Q3_staleness.argmax_argmin_counts.E0_freespace.m3_share_of_spread` | 0.2566 |
