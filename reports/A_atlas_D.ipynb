# %% [markdown]
# # 도감 D — 방위 — 정면 말고 45° 에서 본 판
#
# [← 도감 지도](A_atlas.ipynb) 로 돌아간다. 이 편은 도감의 **절 6** 하나다 — 주제마다 파일을 나눴다.

# %% [markdown]
# ---
#
# ## 절 6. 방위 — 정면 말고 45° 에서 본 판
#
# > **묻는 것** — 지금까지의 결론이 방위 한 자리(정면)에서만 서는 것인가 — 45° 옆에서도 같은 말을 하나.
#
# 팔 35 개 · 칸 119 개 · 그림 76 장. 그림 파일은 전부 `outputs/figures/atlas/04azimuth__…` 로 시작한다.

# %% [markdown]
# ![azimuth — 04azimuth__000-overview-rhythm.png](../outputs/figures/atlas/04azimuth__000-overview-rhythm.png)
#
# **그림 1577.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![azimuth — 04azimuth__01-compare-tile-30-p1.png](../outputs/figures/atlas/04azimuth__01-compare-tile-30-p1.png)
#
# **그림 1578.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![azimuth — 04azimuth__02-compare-stack-p1.png](../outputs/figures/atlas/04azimuth__02-compare-stack-p1.png)
#
# **그림 1579.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![azimuth — 04azimuth__02-compare-stack-p2.png](../outputs/figures/atlas/04azimuth__02-compare-stack-p2.png)
#
# **그림 1580.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![azimuth — 04azimuth__02-compare-stack-p3.png](../outputs/figures/atlas/04azimuth__02-compare-stack-p3.png)
#
# **그림 1581.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![azimuth — 04azimuth__02-compare-stack-p4.png](../outputs/figures/atlas/04azimuth__02-compare-stack-p4.png)
#
# **그림 1582.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 6.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 350 RTK ≈ 20.1 · DJI Matrice 4E ≈ 12.6 · DJI Mavic 4 Pro ≈ 13.4 · DJI Mini 5 Pro ≈ 8.7 · DJI Phantom 4 ≈ 8.7 · DJI S1000+ ≈ 10.8 · Holybro X500 V2 ≈ 8.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −15° | −30° | −45° | −60° | −75° | −90° |
# |---|---|---|---|---|---|---|---|---|---|
# | `ours_mini5pro_r15_n8192_az22.5` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 67 | 73 | 84 | 77 | 69 | 60 | — |
# | `ours_mini5pro_r15_n8192_az45` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 71 | 70 | 86 | 76 | 62 | 69 | — |
# | `ours_mini5pro_r15_n8192_az67.5` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 68 | 66 | 84 | 79 | 58 | 69 | — |
# | `ours_ptd_r15_n8192_az22.5` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 87 | — | — | — | — |
# | `ours_r15_n8192_az15` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 90 | — | — | — | — |
# | `ours_r15_n8192_az15_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 91 | — | — | — | — |
# | `ours_r15_n8192_az22.5` | DJI Matrice 4E · 126.667 Hz | 15 m | 61 | 66 | 87 | 53 | 54 | 82 | — |
# | `ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 56 | 68 | 87 | 51 | 60 | 84 | — |
# | `ours_r15_n8192_az30` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 88 | — | — | — | — |
# | `ours_r15_n8192_az30_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 85 | — | — | — | — |
# | `ours_r15_n8192_az45` | DJI Matrice 4E · 126.667 Hz | 15 m | 50 | 66 | 87 | 48 | 51 | 58 | 65\* |
# | `ours_r15_n8192_az45_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 54 | 66 | 86 | 51 | 51 | 67 | — |
# | `ours_r15_n8192_az60` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 89 | — | — | — | — |
# | `ours_r15_n8192_az60_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 86 | — | — | — | — |
# | `ours_r15_n8192_az67.5` | DJI Matrice 4E · 126.667 Hz | 15 m | 55 | 60 | 87 | 51 | 54 | 76 | — |
# | `ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 56 | 64 | 85 | 49 | 60 | 83 | — |
# | `ours_r15_n8192_az75` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 85 | — | — | — | — |
# | `ours_r15_n8192_az75_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 87 | — | — | — | — |
# | `ours_r15_n8192_az90` | DJI Matrice 4E · 126.667 Hz | 15 m | 47 | — | 84 | — | 54 | — | — |
# | `ours_r15_n8192_az90_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 47 | 70 | 85 | 49 | 62 | 66 | — |
# | `ours_r30_n8192_az45_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 30 m | 54 | — | 86 | — | — | — | — |
# | `ours_r30_n8192_az90_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 30 m | 47 | — | 85 | — | — | — | — |
# | `ours_r60_n8192_az45_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 60 m | 54 | — | 86 | — | — | — | — |
# | `ours_r60_n8192_az90_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 60 m | 47 | — | 85 | — | — | — | — |
# | `ours_s1000plus_r15_n8192_az22.5` | DJI S1000+ · 148.9 Hz | 15 m | 50 | 59 | 76 | 64 | 74 | 93 | — |
# | `ours_s1000plus_r15_n8192_az45` | DJI S1000+ · 148.9 Hz | 15 m | 48 | 60 | 70 | 50 | 66 | 82 | — |
# | `ours_s1000plus_r15_n8192_az67.5` | DJI S1000+ · 148.9 Hz | 15 m | 51 | 58 | 76 | 58 | 75 | 93 | — |
# | `sionna_p4000000000_phys_r15_n8192_az45_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | 14 | — | 28 | — | 14\* |
# | `sionna_p4000000000_r15_n8192_az22.5_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 84 | — | 84 | — | 88 | — | — |
# | `sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 84 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_az45_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 82 | — | 84 | — | 89 | — | 98\* |
# | `sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 82 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_az67.5_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 84 | — | 84 | — | 91 | — | — |
# | `sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 85 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_az90_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 83 | — | 80 | — | 4 | — | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 6.2 `ours_mini5pro_r15_n8192_az22.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 22.5° · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_mini5pro_r15_n8192_az22.5__map.png)
#
# **그림 1583.** `ours_mini5pro_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_mini5pro_r15_n8192_az22.5__band.png)
#
# **그림 1584.** `ours_mini5pro_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 66.9 | 8.7 | 4.4 | +49.1 | 183.8 | 1.00 | −73.34 | 0.937 |
# | −15° | 990 Hz | 73.2 | 8.6 | 14.2 | +45.0 | 183.8 | 1.00 | −75.29 | 0.821 |
# | −30° | 887 Hz | 84.3 | 8.7 | 19.6 | +45.1 | 367.6 | 2.00 | −75.64 | 1.152 |
# | −45° | 725 Hz | 77.4 | 8.7 | 4.1 | +50.2 | 183.8 | 1.00 | −71.25 | 10.397 |
# | −60° | 512 Hz | 68.9 | 8.7 | 1.3 | — | 183.8 | 1.00 | −67.27 | 2.131 |
# | −75° | 265 Hz | 59.6 | 8.7 | 51.7 | — | 181.4 | 0.99 | −82.59 | 0.041 |

# %% [markdown]
# ### 절 6.3 `ours_mini5pro_r15_n8192_az45`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 45° · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_az45 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_mini5pro_r15_n8192_az45__map.png)
#
# **그림 1585.** `ours_mini5pro_r15_n8192_az45` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_az45 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_mini5pro_r15_n8192_az45__band.png)
#
# **그림 1586.** `ours_mini5pro_r15_n8192_az45` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 70.9 | 8.7 | 5.0 | +50.4 | 367.6 | 2.00 | −73.73 | 0.454 |
# | −15° | 990 Hz | 70.3 | 8.6 | 16.3 | +41.0 | 183.8 | 1.00 | −75.80 | 1.283 |
# | −30° | 887 Hz | 86.4 | 8.7 | 21.3 | +43.4 | 365.2 | 1.99 | −74.46 | 1.471 |
# | −45° | 725 Hz | 76.2 | 8.7 | 6.3 | +52.3 | 367.6 | 2.00 | −73.62 | 17.807 |
# | −60° | 512 Hz | 61.9 | 8.7 | 1.9 | — | 183.8 | 1.00 | −69.46 | 7.291 |
# | −75° | 265 Hz | 68.9 | 8.7 | 5.4 | — | 183.8 | 1.00 | −72.91 | 1.677 |

# %% [markdown]
# ### 절 6.4 `ours_mini5pro_r15_n8192_az67.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 67.5° · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_az67.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_mini5pro_r15_n8192_az67.5__map.png)
#
# **그림 1587.** `ours_mini5pro_r15_n8192_az67.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_az67.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_mini5pro_r15_n8192_az67.5__band.png)
#
# **그림 1588.** `ours_mini5pro_r15_n8192_az67.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 68.0 | 8.7 | 4.1 | +50.4 | 551.4 | 3.01 | −72.55 | 2.362 |
# | −15° | 990 Hz | 66.2 | 8.6 | 21.1 | +40.9 | 549.0 | 2.99 | −76.82 | 0.432 |
# | −30° | 887 Hz | 83.8 | 8.7 | 18.0 | +45.2 | 549.0 | 2.99 | −74.96 | 2.681 |
# | −45° | 725 Hz | 78.7 | 8.7 | 10.1 | +46.1 | 183.8 | 1.00 | −74.22 | 0.900 |
# | −60° | 512 Hz | 58.1 | 8.7 | 1.4 | — | 183.8 | 1.00 | −68.71 | 1.501 |
# | −75° | 265 Hz | 69.0 | 8.7 | 18.2 | — | 183.8 | 1.00 | −77.58 | 5.654 |

# %% [markdown]
# ### 절 6.5 `ours_ptd_r15_n8192_az22.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_ptd_r15_n8192_az22.5__map.png)
#
# **그림 1589.** `ours_ptd_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_ptd_r15_n8192_az22.5__band.png)
#
# **그림 1590.** `ours_ptd_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 87.2 | 12.6 | 18.9 | +41.4 | 126.1 | 0.99 | −69.01 | 5.157 |

# %% [markdown]
# ### 절 6.6 `ours_r15_n8192_az15`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 15° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az15 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az15__map.png)
#
# **그림 1591.** `ours_r15_n8192_az15` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az15 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az15__band.png)
#
# **그림 1592.** `ours_r15_n8192_az15` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 89.7 | 12.6 | 13.2 | +45.0 | 126.1 | 0.99 | −67.78 | 6.763 |

# %% [markdown]
# ### 절 6.7 `ours_r15_n8192_az15_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 15° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az15_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az15_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1593.** `ours_r15_n8192_az15_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az15_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az15_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1594.** `ours_r15_n8192_az15_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 91.4 | 12.6 | 18.5 | +43.7 | 126.1 | 0.99 | −68.47 | 5.560 |

# %% [markdown]
# ### 절 6.8 `ours_r15_n8192_az22.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az22.5__map.png)
#
# **그림 1595.** `ours_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az22.5__band.png)
#
# **그림 1596.** `ours_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 61.3 | 12.5 | 4.7 | +46.1 | 126.1 | 0.99 | −70.03 | 0.615 |
# | −15° | 1230 Hz | 65.5 | 12.6 | 9.3 | +40.9 | 126.1 | 0.99 | −68.92 | 1.004 |
# | −30° | 1102 Hz | 87.3 | 12.6 | 18.8 | +41.4 | 126.1 | 0.99 | −69.00 | 3.744 |
# | −45° | 900 Hz | 52.6 | 12.5 | 2.6 | +44.9 | 126.1 | 0.99 | −66.66 | 5.327 |
# | −60° | 636 Hz | 53.8 | 12.6 | 1.0 | +53.6 | 126.1 | 0.99 | −64.84 | 47.919 |
# | −75° | 330 Hz | 82.3 | 12.6 | 1.2 | — | 126.1 | 0.99 | −60.39 | 5.661 |

# %% [markdown]
# ### 절 6.9 `ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1597.** `ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1598.** `ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 55.7 | 12.5 | 4.2 | +47.0 | 126.1 | 0.99 | −70.38 | 0.607 |
# | −15° | 1230 Hz | 67.5 | 12.6 | 9.6 | +41.9 | 126.1 | 0.99 | −68.36 | 1.397 |
# | −30° | 1102 Hz | 86.6 | 12.6 | 17.4 | +42.6 | 126.1 | 0.99 | −68.97 | 2.067 |
# | −45° | 900 Hz | 51.3 | 12.5 | 2.5 | +46.1 | 126.1 | 0.99 | −66.64 | 12.894 |
# | −60° | 636 Hz | 59.6 | 12.6 | 1.0 | +51.8 | 126.1 | 0.99 | −64.49 | 10.819 |
# | −75° | 330 Hz | 83.9 | 12.6 | 1.7 | — | 126.1 | 0.99 | −61.46 | 5.544 |

# %% [markdown]
# ### 절 6.10 `ours_r15_n8192_az30`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 30° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az30 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az30__map.png)
#
# **그림 1599.** `ours_r15_n8192_az30` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az30 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az30__band.png)
#
# **그림 1600.** `ours_r15_n8192_az30` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 87.9 | 12.6 | 18.4 | +41.7 | 126.1 | 0.99 | −69.44 | 1.527 |

# %% [markdown]
# ### 절 6.11 `ours_r15_n8192_az30_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 30° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az30_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az30_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1601.** `ours_r15_n8192_az30_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az30_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az30_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1602.** `ours_r15_n8192_az30_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 84.6 | 12.6 | 10.3 | +42.8 | 126.1 | 0.99 | −68.05 | 4.279 |

# %% [markdown]
# ### 절 6.12 `ours_r15_n8192_az45`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az45 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az45__map.png)
#
# **그림 1603.** `ours_r15_n8192_az45` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az45 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az45__band.png)
#
# **그림 1604.** `ours_r15_n8192_az45` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 50.3 | 12.5 | 3.5 | +48.0 | 126.1 | 0.99 | −69.85 | 4.172 |
# | −15° | 1230 Hz | 66.2 | 12.6 | 12.5 | +38.7 | 126.1 | 0.99 | −69.94 | 2.790 |
# | −30° | 1102 Hz | 86.8 | 12.6 | 14.6 | +41.3 | 126.1 | 0.99 | −68.75 | 32.727 |
# | −45° | 900 Hz | 48.4 | 12.5 | 1.9 | +46.5 | 126.1 | 0.99 | −66.60 | 12.244 |
# | −60° | 636 Hz | 51.0 | 12.6 | 0.7 | +53.5 | 126.1 | 0.99 | −62.61 | 12.066 |
# | −75° | 330 Hz | 57.7 | 12.6 | 0.3 | — | 126.1 | 0.99 | −58.80 | 2.759 |
# | −90°\* | 0 Hz | 64.9 | 12.6 | 100.0 | — | 126.1 | 0.99 | −81.56 | 0.009 |

# %% [markdown]
# ### 절 6.13 `ours_r15_n8192_az45_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az45_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az45_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1605.** `ours_r15_n8192_az45_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az45_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az45_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1606.** `ours_r15_n8192_az45_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 53.5 | 12.5 | 3.5 | +47.2 | 126.1 | 0.99 | −69.72 | 5.607 |
# | −15° | 1230 Hz | 66.2 | 12.6 | 11.0 | +39.7 | 128.5 | 1.01 | −69.08 | 1.929 |
# | −30° | 1102 Hz | 85.5 | 12.6 | 14.0 | +41.9 | 126.1 | 0.99 | −68.42 | 5.801 |
# | −45° | 900 Hz | 51.3 | 12.5 | 2.5 | +44.7 | 126.1 | 0.99 | −66.45 | 37.822 |
# | −60° | 636 Hz | 50.7 | 12.6 | 0.8 | +53.0 | 252.2 | 1.99 | −63.01 | 6.785 |
# | −75° | 330 Hz | 67.4 | 12.6 | 0.7 | — | 126.1 | 0.99 | −60.98 | 1.633 |

# %% [markdown]
# ### 절 6.14 `ours_r15_n8192_az60`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 60° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az60 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az60__map.png)
#
# **그림 1607.** `ours_r15_n8192_az60` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az60 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az60__band.png)
#
# **그림 1608.** `ours_r15_n8192_az60` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 89.4 | 12.6 | 12.3 | +43.2 | 252.2 | 1.99 | −67.51 | 9.457 |

# %% [markdown]
# ### 절 6.15 `ours_r15_n8192_az60_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 60° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az60_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az60_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1609.** `ours_r15_n8192_az60_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az60_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az60_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1610.** `ours_r15_n8192_az60_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 85.7 | 12.6 | 13.9 | +42.3 | 254.6 | 2.01 | −68.71 | 17.238 |

# %% [markdown]
# ### 절 6.16 `ours_r15_n8192_az67.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az67.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az67.5__map.png)
#
# **그림 1611.** `ours_r15_n8192_az67.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az67.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az67.5__band.png)
#
# **그림 1612.** `ours_r15_n8192_az67.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 54.7 | 12.5 | 3.6 | +47.8 | 252.2 | 1.99 | −69.77 | 1.268 |
# | −15° | 1230 Hz | 60.1 | 12.6 | 15.1 | +38.2 | 252.2 | 1.99 | −70.87 | 0.862 |
# | −30° | 1102 Hz | 86.7 | 12.6 | 11.5 | +44.2 | 252.2 | 1.99 | −67.51 | 7.060 |
# | −45° | 900 Hz | 50.8 | 12.5 | 1.2 | +47.0 | 126.1 | 0.99 | −64.66 | 9.215 |
# | −60° | 636 Hz | 54.1 | 12.6 | 0.5 | +55.4 | 126.1 | 0.99 | −61.48 | 5.335 |
# | −75° | 330 Hz | 76.5 | 12.6 | 1.4 | — | 126.1 | 0.99 | −62.30 | 1.431 |

# %% [markdown]
# ### 절 6.17 `ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1613.** `ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1614.** `ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 56.2 | 12.5 | 3.9 | +45.9 | 252.2 | 1.99 | −69.36 | 1.657 |
# | −15° | 1230 Hz | 64.5 | 12.6 | 14.6 | +38.7 | 254.6 | 2.01 | −70.20 | 1.003 |
# | −30° | 1102 Hz | 84.8 | 12.6 | 12.1 | +42.2 | 252.2 | 1.99 | −68.05 | 10.216 |
# | −45° | 900 Hz | 49.0 | 12.5 | 1.3 | +49.0 | 254.6 | 2.01 | −65.27 | 16.790 |
# | −60° | 636 Hz | 60.0 | 12.6 | 0.7 | +56.6 | 380.7 | 3.01 | −62.45 | 7.186 |
# | −75° | 330 Hz | 83.4 | 12.6 | 1.6 | — | 126.1 | 0.99 | −61.19 | 1.611 |

# %% [markdown]
# ### 절 6.18 `ours_r15_n8192_az75`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 75° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az75 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az75__map.png)
#
# **그림 1615.** `ours_r15_n8192_az75` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az75 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az75__band.png)
#
# **그림 1616.** `ours_r15_n8192_az75` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 84.6 | 12.6 | 13.1 | +39.9 | 126.1 | 0.99 | −68.22 | 3.679 |

# %% [markdown]
# ### 절 6.19 `ours_r15_n8192_az75_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 75° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az75_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az75_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1617.** `ours_r15_n8192_az75_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az75_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az75_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1618.** `ours_r15_n8192_az75_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 87.0 | 12.6 | 13.2 | +42.7 | 126.1 | 0.99 | −67.59 | 1.773 |

# %% [markdown]
# ### 절 6.20 `ours_r15_n8192_az90`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az90 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az90__map.png)
#
# **그림 1619.** `ours_r15_n8192_az90` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az90 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az90__band.png)
#
# **그림 1620.** `ours_r15_n8192_az90` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 46.8 | 12.5 | 3.3 | +46.3 | 378.3 | 2.99 | −71.16 | 0.070 |
# | −30° | 1102 Hz | 84.5 | 12.6 | 14.1 | +40.8 | 254.6 | 2.01 | −68.77 | 0.842 |
# | −60° | 636 Hz | 53.7 | 12.6 | 1.1 | +51.8 | 254.6 | 2.01 | −64.09 | 3.458 |

# %% [markdown]
# ### 절 6.21 `ours_r15_n8192_az90_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az90_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az90_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1621.** `ours_r15_n8192_az90_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az90_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az90_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1622.** `ours_r15_n8192_az90_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 47.3 | 12.5 | 4.2 | +44.6 | 504.4 | 3.98 | −71.21 | 0.071 |
# | −15° | 1230 Hz | 69.8 | 12.6 | 10.6 | +41.7 | 126.1 | 0.99 | −69.06 | 0.152 |
# | −30° | 1102 Hz | 84.7 | 12.6 | 10.8 | +42.8 | 126.1 | 0.99 | −67.79 | 1.071 |
# | −45° | 900 Hz | 49.3 | 12.5 | 2.5 | +45.8 | 126.1 | 0.99 | −68.37 | 33.755 |
# | −60° | 636 Hz | 61.9 | 12.6 | 1.4 | +52.3 | 126.1 | 0.99 | −64.69 | 7.069 |
# | −75° | 330 Hz | 65.8 | 12.6 | 0.4 | — | 126.1 | 0.99 | −58.51 | 3.052 |

# %% [markdown]
# ### 절 6.22 `ours_r30_n8192_az45_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r30_n8192_az45_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r30_n8192_az45_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1623.** `ours_r30_n8192_az45_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r30_n8192_az45_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r30_n8192_az45_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1624.** `ours_r30_n8192_az45_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 53.5 | 12.5 | 3.5 | +47.2 | 126.1 | 0.99 | −69.69 | 5.969 |
# | −30° | 1102 Hz | 85.5 | 12.6 | 14.1 | +41.9 | 126.1 | 0.99 | −68.40 | 5.314 |

# %% [markdown]
# ### 절 6.23 `ours_r30_n8192_az90_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r30_n8192_az90_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r30_n8192_az90_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1625.** `ours_r30_n8192_az90_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r30_n8192_az90_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r30_n8192_az90_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1626.** `ours_r30_n8192_az90_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 47.1 | 12.5 | 4.2 | +44.7 | 504.4 | 3.98 | −71.21 | 0.071 |
# | −30° | 1102 Hz | 84.6 | 12.6 | 11.0 | +42.6 | 126.1 | 0.99 | −67.81 | 1.090 |

# %% [markdown]
# ### 절 6.24 `ours_r60_n8192_az45_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r60_n8192_az45_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r60_n8192_az45_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1627.** `ours_r60_n8192_az45_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r60_n8192_az45_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r60_n8192_az45_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1628.** `ours_r60_n8192_az45_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 53.5 | 12.5 | 3.6 | +47.2 | 126.1 | 0.99 | −69.67 | 6.158 |
# | −30° | 1102 Hz | 85.5 | 12.6 | 14.1 | +42.0 | 126.1 | 0.99 | −68.38 | 5.105 |

# %% [markdown]
# ### 절 6.25 `ours_r60_n8192_az90_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r60_n8192_az90_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r60_n8192_az90_mfixbatteryi5_blperairframe__map.png)
#
# **그림 1629.** `ours_r60_n8192_az90_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r60_n8192_az90_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r60_n8192_az90_mfixbatteryi5_blperairframe__band.png)
#
# **그림 1630.** `ours_r60_n8192_az90_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 47.0 | 12.5 | 4.2 | +44.7 | 504.4 | 3.98 | −71.21 | 0.070 |
# | −30° | 1102 Hz | 84.6 | 12.6 | 11.1 | +42.5 | 126.1 | 0.99 | −67.82 | 1.101 |

# %% [markdown]
# ### 절 6.26 `ours_s1000plus_r15_n8192_az22.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 22.5° · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_s1000plus_r15_n8192_az22.5__map.png)
#
# **그림 1631.** `ours_s1000plus_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_s1000plus_r15_n8192_az22.5__band.png)
#
# **그림 1632.** `ours_s1000plus_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 49.9 | 10.9 | 3.3 | +40.4 | 297.9 | 2.00 | −64.03 | 0.736 |
# | −15° | 2010 Hz | 58.7 | 10.8 | 27.0 | +27.0 | 297.9 | 2.00 | −67.43 | 0.112 |
# | −30° | 1802 Hz | 75.7 | 10.8 | 8.4 | +35.9 | 297.9 | 2.00 | −62.77 | 0.277 |
# | −45° | 1471 Hz | 64.0 | 10.9 | 1.4 | +43.6 | 150.2 | 1.01 | −59.12 | 1.240 |
# | −60° | 1040 Hz | 74.1 | 10.9 | 1.3 | +49.7 | 297.9 | 2.00 | −57.11 | 1.542 |
# | −75° | 538 Hz | 93.0 | 10.8 | 2.1 | +56.3 | 297.9 | 2.00 | −53.66 | 1.383 |

# %% [markdown]
# ### 절 6.27 `ours_s1000plus_r15_n8192_az45`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 45° · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192_az45 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_s1000plus_r15_n8192_az45__map.png)
#
# **그림 1633.** `ours_s1000plus_r15_n8192_az45` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192_az45 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_s1000plus_r15_n8192_az45__band.png)
#
# **그림 1634.** `ours_s1000plus_r15_n8192_az45` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 47.5 | 10.9 | 4.3 | +38.1 | 297.9 | 2.00 | −65.58 | 7.867 |
# | −15° | 2010 Hz | 59.7 | 10.8 | 14.0 | +31.5 | 297.9 | 2.00 | −64.33 | 1.880 |
# | −30° | 1802 Hz | 70.1 | 10.8 | 11.4 | +34.7 | 147.7 | 0.99 | −63.14 | 3.055 |
# | −45° | 1471 Hz | 50.2 | 10.9 | 2.5 | +39.8 | 448.1 | 3.01 | −62.10 | 26.447 |
# | −60° | 1040 Hz | 66.4 | 10.9 | 0.8 | +49.4 | 147.7 | 0.99 | −56.11 | 5.307 |
# | −75° | 538 Hz | 82.1 | 10.8 | 1.3 | +53.3 | 147.7 | 0.99 | −55.07 | 48.689 |

# %% [markdown]
# ### 절 6.28 `ours_s1000plus_r15_n8192_az67.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 67.5° · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192_az67.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_s1000plus_r15_n8192_az67.5__map.png)
#
# **그림 1635.** `ours_s1000plus_r15_n8192_az67.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192_az67.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_s1000plus_r15_n8192_az67.5__band.png)
#
# **그림 1636.** `ours_s1000plus_r15_n8192_az67.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 50.6 | 10.9 | 2.5 | +39.4 | 297.9 | 2.00 | −63.56 | 0.380 |
# | −15° | 2010 Hz | 58.4 | 10.8 | 21.6 | +29.2 | 743.5 | 4.99 | −66.40 | 0.070 |
# | −30° | 1802 Hz | 76.0 | 10.8 | 7.4 | +37.7 | 297.9 | 2.00 | −62.57 | 0.534 |
# | −45° | 1471 Hz | 58.1 | 10.9 | 1.9 | +40.2 | 297.9 | 2.00 | −59.51 | 0.822 |
# | −60° | 1040 Hz | 74.6 | 10.9 | 1.0 | +47.7 | 297.9 | 2.00 | −56.48 | 1.330 |
# | −75° | 538 Hz | 93.0 | 10.8 | 2.0 | +54.9 | 297.9 | 2.00 | −53.96 | 1.295 |

# %% [markdown]
# ### 절 6.29 `sionna_p4000000000_phys_r15_n8192_az45_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_az45_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_phys_r15_n8192_az45_d1__map.png)
#
# **그림 1637.** `sionna_p4000000000_phys_r15_n8192_az45_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_az45_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_phys_r15_n8192_az45_d1__band.png)
#
# **그림 1638.** `sionna_p4000000000_phys_r15_n8192_az45_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.9 | 12.5 | 82.6 | +5.1 | 126.1 | 0.99 | −120.28 | 1.062 |
# | −30° | 1102 Hz | 14.5 | 12.6 | 64.6 | +15.0 | 128.5 | 1.01 | −135.82 | 94.260 |
# | −60° | 636 Hz | 28.4 | 12.6 | 38.7 | +22.7 | 126.1 | 0.99 | −131.84 | 53.667 |
# | −90°\* | 0 Hz | 14.3 | 12.6 | 100.0 | — | 191.6 ⚠튐 | 1.51 | −118.38 | 0.001 |

# %% [markdown]
# ### 절 6.30 `sionna_p4000000000_r15_n8192_az22.5_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az22.5_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az22.5_d1__map.png)
#
# **그림 1639.** `sionna_p4000000000_r15_n8192_az22.5_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az22.5_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az22.5_d1__band.png)
#
# **그림 1640.** `sionna_p4000000000_r15_n8192_az22.5_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 84.4 | 12.5 | 8.5 | +46.7 | 126.1 | 0.99 | −148.46 | 0.269 |
# | −30° | 1102 Hz | 83.8 | 12.6 | 2.0 | +52.7 | 126.1 | 0.99 | −135.19 | 16.877 |
# | −60° | 636 Hz | 87.6 | 12.6 | 4.0 | +54.4 | 126.1 | 0.99 | −129.40 | 23.463 |

# %% [markdown]
# ### 절 6.31 `sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 1641.** `sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 1642.** `sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 84.0 | 12.6 | 2.1 | +53.3 | 126.1 | 0.99 | −135.78 | 17.596 |

# %% [markdown]
# ### 절 6.32 `sionna_p4000000000_r15_n8192_az45_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az45_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az45_d1__map.png)
#
# **그림 1643.** `sionna_p4000000000_r15_n8192_az45_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az45_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az45_d1__band.png)
#
# **그림 1644.** `sionna_p4000000000_r15_n8192_az45_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 82.0 | 12.5 | 4.9 | +45.3 | 126.1 | 0.99 | −145.41 | 0.309 |
# | −30° | 1102 Hz | 84.4 | 12.6 | 1.2 | +53.0 | 128.5 | 1.01 | −133.57 | 66.207 |
# | −60° | 636 Hz | 88.7 | 12.6 | 1.2 | +56.4 | 126.1 | 0.99 | −125.65 | 16.414 |
# | −90°\* | 0 Hz | 98.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.72 | 1.665 |

# %% [markdown]
# ### 절 6.33 `sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 1645.** `sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 1646.** `sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 82.0 | 12.6 | 1.4 | +52.1 | 126.1 | 0.99 | −134.62 | 56.551 |

# %% [markdown]
# ### 절 6.34 `sionna_p4000000000_r15_n8192_az67.5_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az67.5_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az67.5_d1__map.png)
#
# **그림 1647.** `sionna_p4000000000_r15_n8192_az67.5_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az67.5_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az67.5_d1__band.png)
#
# **그림 1648.** `sionna_p4000000000_r15_n8192_az67.5_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 84.4 | 12.5 | 3.2 | +46.9 | 128.5 | 1.01 | −142.84 | 2.457 |
# | −30° | 1102 Hz | 84.0 | 12.6 | 0.7 | +54.3 | 252.2 | 1.99 | −133.08 | 44.034 |
# | −60° | 636 Hz | 91.4 | 12.6 | 1.2 | +59.1 | 380.7 | 3.01 | −124.49 | 25.586 |

# %% [markdown]
# ### 절 6.35 `sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 1649.** `sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 1650.** `sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 85.4 | 12.6 | 1.3 | +53.7 | 252.2 | 1.99 | −134.39 | 33.216 |

# %% [markdown]
# ### 절 6.36 `sionna_p4000000000_r15_n8192_az90_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az90_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az90_d1__map.png)
#
# **그림 1651.** `sionna_p4000000000_r15_n8192_az90_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az90_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az90_d1__band.png)
#
# **그림 1652.** `sionna_p4000000000_r15_n8192_az90_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 83.1 | 12.5 | 3.1 | +48.0 | 126.1 | 0.99 | −144.53 | 0.161 |
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.2 | +53.4 | 126.1 | 0.99 | −134.74 | 2.092 |
# | −60° | 636 Hz | 4.2 | 12.6 | 36.5 | +40.8 | 126.1 | 0.99 | −127.24 | 90.403 |
