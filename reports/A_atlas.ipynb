# %% [markdown]
# # 부록 A — 마이크로도플러 아틀라스 · 목차
#
# > 앙각 스윕 원장에는 **팔 122 개 · 칸 349 개**가 들어 있는데, 지금까지 그림으로 나온 것은 덱이 고른 몇 팔뿐이었다. `benchmark/build_md_atlas.py` 가 그 전부를 **그림 273 장**으로 구웠고, 이 문서는 그것을 주제별로 세워 놓은 **목차**다. 여기서 그림을 고르고, 팔 이름을 읽는 법을 익히고, 어디를 믿으면 안 되는지 확인한다.
#
# 이 부록은 **권 번호 체계 밖**이다 — 결론을 주장하는 문서가 아니라 원장을 찾아보는 문서라, 파일 이름이 `A_` 로 시작하고 리포트 색인에 안 걸린다. 전체 목차는 [reports/README.md](README.md) 다.
#
# | 무엇 | 어디 |
# |---|---|
# | 원장 | `outputs/elevation_sweep_md.json` · `outputs/elevation_sweep_md.npz` |
# | 그림 | `outputs/figures/atlas/` — 273 장 |
# | 색인(기계용) | `outputs/md_atlas_index.json` — 이 문서의 모든 수가 여기서 온다 |
# | 구운 때 | 2026-08-16 11:52:47 |
# | 잰 자리 | 반송파 3.5 GHz · PRF 19,700 Hz · 기본 표적 `matrice4e` |
#
# ```bash
# PYTHONPATH=src:benchmark ~/.venvs/py312/bin/python benchmark/build_md_atlas.py
# PYTHONPATH=src ~/.venvs/py312/bin/python benchmark/build_atlas_toc.py   # 이 문서
# ```

# %% [markdown]
# ---
#
# ## 절 1. 이 문서를 읽는 법
#
# ### 그림은 두 종류다
#
# 팔 하나에 그림이 **두 장** 붙는다. 한 장은 «무늬가 어떻게 생겼나», 다른 한 장은 «그 무늬가 규칙적인가» 를 본다. 주제마다 그 위에 **비교판**이 한두 장 더 얹힌다 — 여러 팔을 한 장에 모아 어디를 열어 볼지 정하는 판이다.
#
# **(가) 맵** — 파일 이름이 `…__map.png` 로 끝난다.
#
# - 가로가 **시간**(20 ms 부터 60 ms 창), 세로가 **도플러**(움직이는 것이 주파수를 얼마나 밀었나)다.
# - 규칙적으로 지나가는 밝은 덩어리가 **날개**다. 날개가 시선을 스칠 때마다 한 번씩 번쩍하고, 그 번쩍이 일정한 간격으로 늘어서면 «회전하는 것이 달려 있다» 는 뜻이다.
# - 흰 점선은 **날개끝 상한**(f_tip) — 날개 끝이 낼 수 있는 가장 빠른 도플러다. 물리적으로 그 선 위에는 날개가 만든 것이 있을 수 없다.
# - 위 줄은 **받은 그대로**, 아래 줄은 **정지 성분(시계열 평균)을 뺀** 판이다. 위 줄 한가운데 가로로 진하게 눕는 띠가 동체 · 붙박이 반사이고, 아래 줄은 그것을 빼고 «움직이는 것만» 남긴 판이다. ⭐세기를 말하는 수는 전부 아래 줄에서 잰다.
# - 구석의 작은 수는 **«날개 박자에 붙은 에너지 몫[%]»** 이다 — 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배 자리(±8 Hz)에 앉은 몫. 백색잡음이면 얼마가 나오는지는 **칸마다 다르다**(DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8) — 그림·표가 그 칸의 널을 함께 적으니 «13» 하나를 모든 팔에 대지 마라.
# - ⚠**천장 100 은 실제 자료에서 도달 불가다.** 실제 로터는 rpm 이 조금씩 흩어져 선이 번지고 창 반폭이 8 Hz 로 고정이라 높은 배음일수록 창 밖으로 샌다. 눈금 실측(`grid_convergence_check.json`)의 «백색 12.12 % · 이상 로터 100.00 % (빗살 77 개)» 에서 100 % 를 낸 «이상 로터» 는 **rpm 산포가 0 인 합성 신호**다 — 실물이 아니다. 그러니 100 을 «완벽한 로터» 로 읽지 말고, 눈금의 위쪽 끝이라고만 읽는다.
# - ⭐⚠**그 몫이 낮다고 «날개가 안 보인다» 는 뜻이 아니다.** 이 수는 상한 **위**에 남은 것만 본다. 그런데 몫이 낮은 칸은 대개 «위가 조용해서» 가 아니라 **«위가 잡동사니로 가득 차서»** 낮다 — 이 원장에서 직접 재 보면 그렇다: 리듬 몫이 20 % 미만인 칸 89 개는 움직이는 에너지의 **중앙값 86 %**가 상한 위에 있고, 20 % 이상인 칸 215 개는 **9 %** 뿐이다(−90° 제외). 즉 «무늬가 상한 아래로 얌전히 들어앉아서 몫이 낮다» 는 설명은 **거꾸로**다(2026-08-15 정정 — 그전 판에 그렇게 적혀 있었다).
# - 그래서 구석에는 **짝 잣대**를 함께 적는다 — «in-band comb [dB]» 는 상한 **아래**(2·박자 ~ 상한)에서 «정수배 자리 ÷ 그 사이 자리» 전력비다. 백색잡음 ≈ 0 dB. 리듬 몫이 0 인데 이 수가 +40 dB 면 «날개가 없다» 가 아니라 **«이 잣대가 못 읽는 자리다»** 라는 뜻이다. 날개가 보이나는 결국 **맵 자체**와 이 수로 판단한다.
# - ⚠**패널마다 자기 최댓값을 기준으로 색을 칠한다.** 색이 진하다고 세기가 센 것이 아니다 — 이 그림은 **모양을 읽는 그림**이지 세기를 읽는 그림이 아니다.
#
# **(나) 대역 에너지** — 파일 이름이 `…__band.png` 로 끝난다.
#
# - 날개끝 상한의 0.35~1.0 배 띠(«날개 대역»)의 전력이 시간에 따라 어떻게 뛰는지, 그 **리듬의 스펙트럼**이다. 맵의 줄무늬가 정말 규칙적으로 뛰는가를 직접 묻는 판이다.
# - 가로는 **초당 몇 번 뛰나**(변조율 [Hz]), 세로는 그 선의 세기다. 왼쪽이 넓은 범위(100~1,000 Hz), 오른쪽이 첫 선들의 확대다.
# - 세로 점선이 **예측 박자의 정수배**다 — 날개 수 × 호버 rpm ÷ 60. 곡선의 봉우리가 그 점선에 올라앉으면 «예측한 그대로 돈다», 점선을 비껴 서면 «다른 것이 뛰고 있다», 봉우리 없이 잔디밭이면 «리듬이 없다» 이다.
# - 곡선 하나가 앙각 하나다. ⚠여기서도 **곡선마다 자기 최댓값**으로 눕혔다 — 곡선 사이 높이 비교는 뜻이 없다.
#
# ### 표의 표기
#
# | 표기 | 뜻 |
# |---|---|
# | `—` | 원장에 그 칸이 없다(안 돌린 자리) |
# | `∅` | 돌리기는 했는데 **아무것도 안 돌아왔다**(에코가 통째로 0) |
# | `◐` | ⭐**자세가 덜 찼다** — 병합이 아직 절반이라 잣대를 내지 않는다 (절 14.1b) |
# | `○` | **움직이는 것이 없다** — AC/DC 가 반올림 바닥 아래라 잣대를 내지 않는다 (절 14.1c) |
# | `*` | 앙각 −90° — 날개끝 상한이 0 이라 «상한 위» 잣대가 **퇴화**한다 (절 13.1 을 보라) |
# | `⚠튐` | 자세 몇 개가 통째로 튀어 그 «박자» 가 회전이 아니다 (절 13.8) |
#
# 팔 이름이 낯설면 **절 12 «팔 이름 읽는 법»** 을 먼저 봐도 된다 — `_phys` · `_swR1D0E0F1` · `_partsprop` 같은 토막이 각각 무슨 뜻인지 표로 있다. 어디를 믿으면 안 되는지는 **절 13** 에 모아 뒀다.
#
# ### 집 규칙
#
# - 마이크로도플러 표현은 **STFT 만** 쓴다(재할당 · WVD 같은 다른 표현은 안 쓴다) — `src/md_mapstyle.py` 의 `flash_spec`: 블레이드 주기의 0.45 배 조각 · hop 2 · 8× 제로패딩.
# - ⭐레벨(dB)·리듬 몫·박자는 전부 정지 성분(시계열 평균) 제거 후에 잰다.
# - 맵은 20 ms 부터 60 ms 창. 패널마다 자기 최댓값으로 정규화한다.
# - 그림 안 글자는 영어, 본문은 한국어다. 각도는 «−30°» 로 적는다.

# %% [markdown]
# ---
#
# ## 절 2. 주제 아홉 가지
#
# 원장의 팔은 **이름 규칙**으로 아홉 주제에 갈린다 — 하드코딩한 목록이 아니라 이름에서 유도하므로, 새 팔이 생기면 자동으로 제자리에 붙는다.
#
# | 절 | 주제 | 무엇을 묻나 | 팔 | 칸 | 그림 |
# |---|---|---|---|---|---|
# | 3 | **기본 엔진** (`01base`) | 엔진과 광선 예산만 바꾸면 날개 무늬가 달라지나 | 22 | 105 | 49 |
# | 4 | **스위치** (`02switch`) | 굴절 · 회절 · 모서리 회절 · 확산 반사 중 **무엇을 켜면** 날개 리듬이 백색 수준으로 주저앉나 | 38 | 83 | 82 |
# | 5 | **기체 3 종** (`03airframe`) | 표적 기체를 바꾸면 그림의 박자가 **그 기체의 박자**로 따라가나 | 8 | 40 | 19 |
# | 6 | **방위** (`04azimuth`) | 지금까지의 결론이 방위 한 자리(정면)에서만 서는 것인가 | 14 | 29 | 31 |
# | 7 | **부품 분해** (`05parts`) | 무늬를 만드는 것은 프로펠러인가 동체인가 | 3 | 9 | 8 |
# | 8 | **거리** (`06range`) | 15 m 에서 30 m 로 물러나면 날개 무늬가 남나 | 30 | 64 | 66 |
# | 9 | **PTD** (`07ptd`) | 우리 팔의 모서리 회절(PTD 프린지)을 켜면 무늬가 달라지나 | 4 | 10 | 10 |
# | 10 | **격자** (`08grid`) | 표면 격자를 λ/12 에서 λ/24 로 조이면 잣대가 얼마나 움직이나 | 2 | 8 | 6 |
# | 11 | **평면파** (`09planewave`) | 직하방의 잔여가 근접장 **곡률** 탓인가 | 1 | 1 | 2 |
#
# 합계 — 팔 122 · 칸 349 · 그림 273.

# %% [markdown]
# ---
#
# ## 절 3. 기본 엔진 — 엔진·광선예산·자세수, ⚠거리도 10 m·15 m 로 섞여 있다
#
# > **묻는 것** — 엔진과 광선 예산만 바꾸면 날개 무늬가 달라지나 — 그리고 얼마나 부어야 달라지기를 멈추나.
#
# 팔 22 개 · 칸 105 개 · 그림 49 장. 그림 파일은 전부 `outputs/figures/atlas/01base__…` 로 시작한다.

# %% [markdown]
# ![base engines — 01base__000-overview-rhythm.png](../outputs/figures/atlas/01base__000-overview-rhythm.png)
#
# **그림 1.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![base engines — 01base__01-compare-tile-30-p1.png](../outputs/figures/atlas/01base__01-compare-tile-30-p1.png)
#
# **그림 2.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p1.png](../outputs/figures/atlas/01base__02-compare-stack-p1.png)
#
# **그림 3.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p2.png](../outputs/figures/atlas/01base__02-compare-stack-p2.png)
#
# **그림 4.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![base engines — 01base__02-compare-stack-p3.png](../outputs/figures/atlas/01base__02-compare-stack-p3.png)
#
# **그림 5.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 3.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −15° | −30° | −45° | −60° | −75° | −90° |
# |---|---|---|---|---|---|---|---|---|---|
# | `ours` | DJI Matrice 4E · 126.667 Hz | 10 m | 58 | 62 | 83 | 51 | 48 | 50 | 73\* |
# | `ours_free_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 63 | 72 | 83 | 49 | 52 | 48 | 56\* |
# | `ours_r15_n32768` | DJI Matrice 4E · 126.667 Hz | 15 m | 63 | — | 86 | — | 46 | — | — |
# | `ours_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 63 | 73 | 83 | 50 | 53 | 46 | 65\* |
# | `sionna` | DJI Matrice 4E · 126.667 Hz | 10 m | 91 | 73 | 76 | 82 | 80 | 92 | 95\* |
# | `sionna_p1000000000` | DJI Matrice 4E · 126.667 Hz | 10 m | 12 | 80 | 78 | 83 | 84 | 93 | 98\* |
# | `sionna_p250000000` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | 73 | 82 | 83 | 82 | 92 | 97\* |
# | `sionna_p250000000_phys` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | 14 | 15 | 15 | 18 | 13 | 12\* |
# | `sionna_p4000000000` | DJI Matrice 4E · 126.667 Hz | 10 m | 11 | 74 | — | 83 | 89 | ◐ | — |
# | `sionna_p4000000000_phys_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 10 m | 16 | 13 | 13 | 12 | 15 | 13 | 17\* |
# | `sionna_p4000000000_phys_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | 12 | 12 | 14 | 15 | 12 | 14\* |
# | `sionna_p4000000000_phys_r15_n8192_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | 12 | 12 | 14 | 15 | 12 | 14\* |
# | `sionna_p4000000000_r15_n32768_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 82 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | 81 | 80 | 84 | 87 | 95 | 98\* |
# | `sionna_p4000000000_r15_n8192_shell0.5mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 80 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 80 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 74 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | 77 | 75 | — | 87 | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | 77 | — | 87 | — | — |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 78 | — | — | — | — |
# | `sionna_p4000000000_r15_n8192_shell1.5mm_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 80 | — | — | — | — |
# | `sionna_phys` | DJI Matrice 4E · 126.667 Hz | 10 m | 14 | 18 | 52 | 40 | 61 | 58 | 45\* |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 3.2 `ours`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 10 m · 자세 4,096 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours micro-Doppler maps](../outputs/figures/atlas/01base__ours__map.png)
#
# **그림 6.** `ours` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours__band.png)
#
# **그림 7.** `ours` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 58.0 | 12.6 | 2.3 | +48.9 | 127.2 | 1.00 | −69.77 | 2.853 |
# | −15° | 1230 Hz | 62.3 | 12.7 | 15.7 | +39.7 | 127.2 | 1.00 | −70.81 | 1.077 |
# | −30° | 1102 Hz | 82.6 | 12.6 | 11.2 | +43.9 | 127.2 | 1.00 | −68.50 | 27.583 |
# | −45° | 900 Hz | 51.2 | 12.5 | 2.2 | +46.4 | 127.2 | 1.00 | −67.08 | 13.592 |
# | −60° | 636 Hz | 47.7 | 12.6 | 1.3 | +46.6 | 127.2 | 1.00 | −65.37 | 94.911 |
# | −75° | 330 Hz | 50.2 | 12.6 | 0.3 | — | 127.2 | 1.00 | −58.00 | 8.233 |
# | −90°\* | 0 Hz | 73.4 | 12.6 | 100.0 | — | 127.2 | 1.00 | −79.96 | 0.015 |

# %% [markdown]
# ### 절 3.3 `ours_free_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO), 동체 «면» 을 빼서 가림을 없앤 대조군** · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_free_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/01base__ours_free_r15_n8192__map.png)
#
# **그림 8.** `ours_free_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_free_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_free_r15_n8192__band.png)
#
# **그림 9.** `ours_free_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.3 | 12.5 | 2.7 | +47.8 | 126.1 | 0.99 | −70.40 | 94.752 |
# | −15° | 1230 Hz | 72.2 | 12.6 | 19.3 | +39.7 | 126.1 | 0.99 | −71.17 | 70.136 |
# | −30° | 1102 Hz | 82.9 | 12.6 | 10.2 | +42.8 | 126.1 | 0.99 | −68.81 | 90.229 |
# | −45° | 900 Hz | 48.7 | 12.5 | 1.8 | +47.3 | 126.1 | 0.99 | −67.07 | 94.491 |
# | −60° | 636 Hz | 52.4 | 12.6 | 1.7 | +45.0 | 126.1 | 0.99 | −65.99 | 72.063 |
# | −75° | 330 Hz | 47.7 | 12.6 | 0.2 | — | 126.1 | 0.99 | −57.74 | 86.885 |
# | −90°\* | 0 Hz | 55.6 | 12.6 | 100.0 | — | 126.1 | 0.99 | −82.59 | 0.019 |

# %% [markdown]
# ### 절 3.4 `ours_r15_n32768`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 32,768 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n32768 micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n32768__map.png)
#
# **그림 10.** `ours_r15_n32768` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n32768 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n32768__band.png)
#
# **그림 11.** `ours_r15_n32768` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.0 | 12.5 | 3.5 | +47.9 | 127.1 | 1.00 | −70.86 | 2.294 |
# | −30° | 1102 Hz | 85.6 | 12.6 | 13.5 | +42.8 | 127.1 | 1.00 | −68.98 | 23.713 |
# | −60° | 636 Hz | 46.0 | 12.6 | 1.0 | +52.6 | 253.6 | 2.00 | −64.36 | 89.509 |

# %% [markdown]
# ### 절 3.5 `ours_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/01base__ours_r15_n8192__map.png)
#
# **그림 12.** `ours_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/01base__ours_r15_n8192__band.png)
#
# **그림 13.** `ours_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.3 | 12.5 | 2.7 | +47.8 | 126.1 | 0.99 | −70.40 | 2.563 |
# | −15° | 1230 Hz | 72.7 | 12.6 | 17.2 | +40.5 | 126.1 | 0.99 | −71.05 | 1.040 |
# | −30° | 1102 Hz | 83.3 | 12.6 | 10.6 | +42.9 | 126.1 | 0.99 | −69.11 | 27.399 |
# | −45° | 900 Hz | 49.7 | 12.5 | 1.8 | +47.1 | 126.1 | 0.99 | −67.19 | 13.227 |
# | −60° | 636 Hz | 52.8 | 12.6 | 1.8 | +45.4 | 126.1 | 0.99 | −66.04 | 79.883 |
# | −75° | 330 Hz | 46.3 | 12.6 | 0.2 | — | 126.1 | 0.99 | −57.71 | 8.826 |
# | −90°\* | 0 Hz | 64.9 | 12.6 | 100.0 | — | 126.1 | 0.99 | −81.56 | 0.009 |

# %% [markdown]
# ### 절 3.6 `sionna`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 1,111 만 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna micro-Doppler maps](../outputs/figures/atlas/01base__sionna__map.png)
#
# **그림 14.** `sionna` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna__band.png)
#
# **그림 15.** `sionna` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 91.3 | 12.6 | 29.0 | +43.5 | 635.8 | 5.02 | −143.21 | 0.000 |
# | −15° | 1230 Hz | 72.9 | 12.7 | 40.0 | +35.8 | 127.2 | 1.00 | −144.82 | 0.993 |
# | −30° | 1102 Hz | 75.7 | 12.6 | 8.8 | +41.8 | 254.3 | 2.01 | −136.79 | 59.980 |
# | −45° | 900 Hz | 82.1 | 12.5 | 25.3 | +41.5 | 127.2 | 1.00 | −136.46 | 8.459 |
# | −60° | 636 Hz | 80.3 | 12.6 | 28.5 | +41.7 | 127.2 | 1.00 | −132.70 | 27.510 |
# | −75° | 330 Hz | 91.7 | 12.6 | 47.1 | — | 127.2 | 1.00 | −131.67 | 32.443 |
# | −90°\* | 0 Hz | 95.3 | 12.6 | 100.0 | — | 127.2 | 1.00 | −132.21 | 49.365 |

# %% [markdown]
# ### 절 3.7 `sionna_p1000000000`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 10 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p1000000000 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p1000000000__map.png)
#
# **그림 16.** `sionna_p1000000000` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p1000000000 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p1000000000__band.png)
#
# **그림 17.** `sionna_p1000000000` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.6 | 87.4 | −2.7 | 24.5 ⚠튐 | 0.19 | −93.58 | 0.041 |
# | −15° | 1230 Hz | 80.5 | 12.7 | 8.5 | +42.5 | 127.2 | 1.00 | −138.66 | 0.294 |
# | −30° | 1102 Hz | 77.6 | 12.6 | 1.4 | +50.4 | 127.2 | 1.00 | −129.61 | 95.050 |
# | −45° | 900 Hz | 82.6 | 12.5 | 1.6 | +54.3 | 127.2 | 1.00 | −124.25 | 44.202 |
# | −60° | 636 Hz | 84.2 | 12.6 | 3.6 | +44.9 | 254.3 | 2.01 | −123.60 | 26.701 |
# | −75° | 330 Hz | 93.4 | 12.6 | 1.5 | — | 127.2 | 1.00 | −115.62 | 25.441 |
# | −90°\* | 0 Hz | 98.4 | 12.6 | 100.0 | — | 127.2 | 1.00 | −126.52 | 3.070 |

# %% [markdown]
# ### 절 3.8 `sionna_p250000000`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 2.5 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p250000000 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p250000000__map.png)
#
# **그림 18.** `sionna_p250000000` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p250000000 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p250000000__band.png)
#
# **그림 19.** `sionna_p250000000` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.6 | 87.0 | +0.0 | 29.3 ⚠튐 | 0.23 | −99.31 | 0.011 |
# | −15° | 1230 Hz | 73.2 | 12.7 | 30.9 | +37.3 | 127.2 | 1.00 | −145.66 | 0.212 |
# | −30° | 1102 Hz | 82.4 | 12.6 | 5.1 | +47.2 | 127.2 | 1.00 | −134.32 | 71.499 |
# | −45° | 900 Hz | 82.9 | 12.5 | 7.4 | +47.9 | 127.2 | 1.00 | −130.98 | 20.179 |
# | −60° | 636 Hz | 82.2 | 12.6 | 18.5 | +44.5 | 127.2 | 1.00 | −130.76 | 7.827 |
# | −75° | 330 Hz | 91.7 | 12.6 | 5.8 | — | 127.2 | 1.00 | −122.40 | 16.838 |
# | −90°\* | 0 Hz | 97.0 | 12.6 | 100.0 | — | 254.3 | 2.01 | −129.81 | 6.832 |

# %% [markdown]
# ### 절 3.9 `sionna_p250000000_phys`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 2.5 억 발 · 반사 깊이 3 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p250000000_phys micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p250000000_phys__map.png)
#
# **그림 20.** `sionna_p250000000_phys` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p250000000_phys blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p250000000_phys__band.png)
#
# **그림 21.** `sionna_p250000000_phys` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.6 | 87.1 | −2.4 | 450.0 ⚠튐 | 3.55 | −94.81 | 0.018 |
# | −15° | 1230 Hz | 14.2 | 12.7 | 85.4 | +6.0 | 78.3 ⚠튐 | 0.62 | −127.27 | 0.094 |
# | −30° | 1102 Hz | 15.0 | 12.6 | 82.0 | +7.7 | 254.3 | 2.01 | −127.28 | 0.155 |
# | −45° | 900 Hz | 15.4 | 12.5 | 79.5 | +10.9 | 254.3 | 2.01 | −125.22 | 0.046 |
# | −60° | 636 Hz | 17.6 | 12.6 | 87.6 | +7.5 | 127.2 | 1.00 | −123.08 | 0.935 |
# | −75° | 330 Hz | 12.9 | 12.6 | 96.4 | — | 127.2 ⚠튐 | 1.00 | −111.90 | 0.054 |
# | −90°\* | 0 Hz | 12.4 | 12.6 | 100.0 | — | 39.1 ⚠튐 | 0.31 | −100.07 | 0.014 |

# %% [markdown]
# ### 절 3.10 `sionna_p4000000000`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000__map.png)
#
# **그림 22.** `sionna_p4000000000` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000__band.png)
#
# **그림 23.** `sionna_p4000000000` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 11.4 | 12.6 | 86.4 | +0.9 | 58.7 ⚠튐 | 0.46 | −90.44 | 0.084 |
# | −15° | 1230 Hz | 74.3 | 12.7 | 3.5 | +44.4 | 127.2 | 1.00 | −135.75 | 0.178 |
# | −45° | 900 Hz | 82.7 | 12.5 | 0.5 | +59.3 | 127.2 | 1.00 | −118.98 | 34.594 |
# | −60° | 636 Hz | 88.8 | 12.6 | 1.5 | +50.8 | 127.2 | 1.00 | −117.92 | 20.061 |
# | −75° | 330 Hz | ◐ 덜 참(2,048/4,096 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 3.11 `sionna_p4000000000_phys_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_phys_n8192_d1__map.png)
#
# **그림 24.** `sionna_p4000000000_phys_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_phys_n8192_d1__band.png)
#
# **그림 25.** `sionna_p4000000000_phys_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.0 | 12.5 | 71.8 | +10.8 | 254.6 | 2.01 | −87.88 | 0.087 |
# | −15° | 1230 Hz | 13.1 | 12.6 | 87.2 | −0.1 | 252.2 ⚠튐 | 1.99 | −117.00 | 0.133 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 83.3 | +8.6 | 252.2 | 1.99 | −118.38 | 0.293 |
# | −45° | 900 Hz | 12.2 | 12.5 | 90.0 | +2.4 | 506.8 ⚠튐 | 4.00 | −100.13 | 0.109 |
# | −60° | 636 Hz | 14.8 | 12.6 | 84.9 | +7.6 | 126.1 | 0.99 | −116.19 | 1.095 |
# | −75° | 330 Hz | 12.6 | 12.6 | 93.8 | — | 126.1 ⚠튐 | 0.99 | −104.63 | 0.122 |
# | −90°\* | 0 Hz | 16.6 | 12.6 | 100.0 | — | 254.6 ⚠튐 | 2.01 | −110.64 | 0.004 |

# %% [markdown]
# ### 절 3.12 `sionna_p4000000000_phys_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_d1__map.png)
#
# **그림 26.** `sionna_p4000000000_phys_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_d1__band.png)
#
# **그림 27.** `sionna_p4000000000_phys_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.0 | 12.5 | 86.4 | −2.1 | 82.4 ⚠튐 | 0.65 | −94.84 | 0.053 |
# | −15° | 1230 Hz | 11.9 | 12.6 | 87.8 | −0.5 | 143.1 ⚠튐 | 1.13 | −115.02 | 0.758 |
# | −30° | 1102 Hz | 12.5 | 12.6 | 85.8 | +6.3 | 252.2 | 1.99 | −126.60 | 0.077 |
# | −45° | 900 Hz | 13.8 | 12.5 | 78.1 | +11.8 | 506.8 | 4.00 | −126.90 | 0.126 |
# | −60° | 636 Hz | 14.9 | 12.6 | 86.7 | +7.0 | 126.1 | 0.99 | −125.88 | 1.013 |
# | −75° | 330 Hz | 12.4 | 12.6 | 96.2 | — | 126.1 ⚠튐 | 0.99 | −110.96 | 0.081 |
# | −90°\* | 0 Hz | 14.3 | 12.6 | 100.0 | — | 194.0 ⚠튐 | 1.53 | −118.37 | 0.001 |

# %% [markdown]
# ### 절 3.13 `sionna_p4000000000_phys_r15_n8192_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_d2 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_d2__map.png)
#
# **그림 28.** `sionna_p4000000000_phys_r15_n8192_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_d2 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_phys_r15_n8192_d2__band.png)
#
# **그림 29.** `sionna_p4000000000_phys_r15_n8192_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.8 | 12.5 | 86.6 | −2.5 | 123.7 ⚠튐 | 0.98 | −94.42 | 0.058 |
# | −15° | 1230 Hz | 12.1 | 12.6 | 87.7 | −0.5 | 143.1 ⚠튐 | 1.13 | −114.58 | 0.838 |
# | −30° | 1102 Hz | 12.4 | 12.6 | 86.0 | +6.1 | 252.2 | 1.99 | −126.14 | 0.086 |
# | −45° | 900 Hz | 13.8 | 12.5 | 78.4 | +11.7 | 252.2 | 1.99 | −126.57 | 0.136 |
# | −60° | 636 Hz | 15.0 | 12.6 | 86.7 | +7.1 | 126.1 | 0.99 | −125.87 | 1.003 |
# | −75° | 330 Hz | 12.4 | 12.6 | 96.1 | — | 126.1 ⚠튐 | 0.99 | −110.85 | 0.083 |
# | −90°\* | 0 Hz | 14.3 | 12.6 | 100.0 | — | 160.0 ⚠튐 | 1.26 | −118.38 | 0.001 |

# %% [markdown]
# ### 절 3.14 `sionna_p4000000000_r15_n32768_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 32,768 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n32768_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n32768_d1__map.png)
#
# **그림 30.** `sionna_p4000000000_r15_n32768_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n32768_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n32768_d1__band.png)
#
# **그림 31.** `sionna_p4000000000_r15_n32768_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 82.5 | 12.6 | 0.8 | +55.1 | 127.1 | 1.00 | −134.57 | 64.136 |

# %% [markdown]
# ### 절 3.15 `sionna_p4000000000_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_d1__map.png)
#
# **그림 32.** `sionna_p4000000000_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_d1__band.png)
#
# **그림 33.** `sionna_p4000000000_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 86.2 | −0.8 | 84.9 ⚠튐 | 0.67 | −94.30 | 0.078 |
# | −15° | 1230 Hz | 81.3 | 12.6 | 6.5 | +45.4 | 126.1 | 0.99 | −145.33 | 0.226 |
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 58.125 |
# | −45° | 900 Hz | 84.1 | 12.5 | 0.9 | +54.1 | 126.1 | 0.99 | −129.61 | 25.376 |
# | −60° | 636 Hz | 86.6 | 12.6 | 3.3 | +48.3 | 126.1 | 0.99 | −129.72 | 12.742 |
# | −75° | 330 Hz | 95.2 | 12.6 | 0.8 | — | 126.1 | 0.99 | −119.73 | 20.050 |
# | −90°\* | 0 Hz | 98.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.72 | 1.665 |

# %% [markdown]
# ### 절 3.16 `sionna_p4000000000_r15_n8192_shell0.5mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.5mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.5mm_d1__map.png)
#
# **그림 34.** `sionna_p4000000000_r15_n8192_shell0.5mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.5mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.5mm_d1__band.png)
#
# **그림 35.** `sionna_p4000000000_r15_n8192_shell0.5mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 87.769 |

# %% [markdown]
# ### 절 3.17 `sionna_p4000000000_r15_n8192_shell0.75mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_d1__map.png)
#
# **그림 36.** `sionna_p4000000000_r15_n8192_shell0.75mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_d1__band.png)
#
# **그림 37.** `sionna_p4000000000_r15_n8192_shell0.75mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 85.386 |

# %% [markdown]
# ### 절 3.18 `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1__map.png)
#
# **그림 38.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1__band.png)
#
# **그림 39.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 73.8 | 12.6 | 3.1 | +44.1 | 126.1 | 0.99 | −157.74 | 19.840 |

# %% [markdown]
# ### 절 3.19 `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1__map.png)
#
# **그림 40.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1__band.png)
#
# **그림 41.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 86.2 | −0.8 | 84.9 ⚠튐 | 0.67 | −94.30 | 0.078 |
# | −15° | 1230 Hz | 76.9 | 12.6 | 22.0 | +36.7 | 126.1 | 0.99 | −158.40 | 0.419 |
# | −30° | 1102 Hz | 75.3 | 12.6 | 2.9 | +45.0 | 126.1 | 0.99 | −152.65 | 40.065 |
# | −60° | 636 Hz | 86.9 | 12.6 | 2.7 | +50.0 | 126.1 | 0.99 | −144.44 | 20.496 |

# %% [markdown]
# ### 절 3.20 `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1__map.png)
#
# **그림 42.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1__band.png)
#
# **그림 43.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 86.2 | −0.8 | 84.9 ⚠튐 | 0.67 | −94.30 | 0.078 |
# | −30° | 1102 Hz | 76.7 | 12.6 | 2.8 | +45.8 | 126.1 | 0.99 | −148.68 | 57.034 |
# | −60° | 636 Hz | 86.9 | 12.6 | 2.7 | +50.0 | 126.1 | 0.99 | −140.47 | 47.800 |

# %% [markdown]
# ### 절 3.21 `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1__map.png)
#
# **그림 44.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1__band.png)
#
# **그림 45.** `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 77.7 | 12.6 | 2.7 | +46.4 | 126.1 | 0.99 | −145.85 | 67.063 |

# %% [markdown]
# ### 절 3.22 `sionna_p4000000000_r15_n8192_shell1.5mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell1.5mm_d1 micro-Doppler maps](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell1.5mm_d1__map.png)
#
# **그림 46.** `sionna_p4000000000_r15_n8192_shell1.5mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_shell1.5mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_p4000000000_r15_n8192_shell1.5mm_d1__band.png)
#
# **그림 47.** `sionna_p4000000000_r15_n8192_shell1.5mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 78.282 |

# %% [markdown]
# ### 절 3.23 `sionna_phys`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 4,096 개 · 광선 1,111 만 발 · 반사 깊이 3 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_phys micro-Doppler maps](../outputs/figures/atlas/01base__sionna_phys__map.png)
#
# **그림 48.** `sionna_phys` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_phys blade-band rhythm spectrum](../outputs/figures/atlas/01base__sionna_phys__band.png)
#
# **그림 49.** `sionna_phys` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.0 | 12.6 | 83.1 | +1.4 | 420.6 ⚠튐 | 3.32 | −131.99 | 0.000 |
# | −15° | 1230 Hz | 17.7 | 12.7 | 83.1 | +7.6 | 24.5 ⚠튐 | 0.19 | −133.57 | 0.230 |
# | −30° | 1102 Hz | 51.6 | 12.6 | 69.9 | +18.2 | 254.3 | 2.01 | −136.58 | 0.011 |
# | −45° | 900 Hz | 40.4 | 12.5 | 46.1 | +21.0 | 127.2 | 1.00 | −131.88 | 0.032 |
# | −60° | 636 Hz | 60.7 | 12.6 | 88.0 | +19.9 | 127.2 | 1.00 | −132.14 | 88.149 |
# | −75° | 330 Hz | 58.3 | 12.6 | 82.3 | — | 127.2 | 1.00 | −131.35 | 0.043 |
# | −90°\* | 0 Hz | 45.0 | 12.6 | 100.0 | — | 254.3 | 2.01 | −130.92 | 0.000 |

# %% [markdown]
# ---
#
# ## 절 4. 스위치 — 굴절·회절·모서리·확산을 켜고 끈 조합
#
# > **묻는 것** — 굴절 · 회절 · 모서리 회절 · 확산 반사 중 **무엇을 켜면** 날개 리듬이 백색 수준으로 주저앉나.
#
# 팔 38 개 · 칸 83 개 · 그림 82 장. 그림 파일은 전부 `outputs/figures/atlas/02switch__…` 로 시작한다.

# %% [markdown]
# ![physics switches — 02switch__000-overview-rhythm.png](../outputs/figures/atlas/02switch__000-overview-rhythm.png)
#
# **그림 50.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![physics switches — 02switch__01-compare-tile+0-p1.png](../outputs/figures/atlas/02switch__01-compare-tile+0-p1.png)
#
# **그림 51.** 앙각이 **0° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![physics switches — 02switch__01-compare-tile-30-p1.png](../outputs/figures/atlas/02switch__01-compare-tile-30-p1.png)
#
# **그림 52.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![physics switches — 02switch__01-compare-tile-30-p2.png](../outputs/figures/atlas/02switch__01-compare-tile-30-p2.png)
#
# **그림 53.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p1.png](../outputs/figures/atlas/02switch__02-compare-stack-p1.png)
#
# **그림 54.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p2.png](../outputs/figures/atlas/02switch__02-compare-stack-p2.png)
#
# **그림 55.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 4.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −15° | −30° | −45° | −60° | −75° | −90° |
# |---|---|---|---|---|---|---|---|---|---|
# | `sionna_p4000000000_onlydepth3_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | 81 | — | 32 | — | 98\* |
# | `sionna_p4000000000_onlydiffr_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | 12 | 12 | 13 | 14 | 13 | 13\* |
# | `sionna_p4000000000_onlyedge_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | 80 | — | 87 | — | 98\* |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | 71 | — | 59 | — | — |
# | `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | ○ | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 53 | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r120_n8192` | DJI Matrice 4E · 126.667 Hz | 120 m | 44 | — | 66 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | 61 | 62 | 65 | 64 | 57 | 62\* |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 65 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 64 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 64 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | 40 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 41 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r240_n8192` | DJI Matrice 4E · 126.667 Hz | 240 m | 56 | — | 69 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r30_n8192` | DJI Matrice 4E · 126.667 Hz | 30 m | 13 | — | 64 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r60_n8192` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | 70 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` | DJI S1000+ · 148.9 Hz | 15 m | 30 | — | 36 | — | 66 | — | — |
# | `sionna_p4000000000_stockdef_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | ∅ | ∅ | ∅ | ∅ | ∅ | ∅ |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | ∅ | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | ∅ | — | — | — | — |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 12 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 11 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 11 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 12 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 11 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 12 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 11 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | ∅ | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | 49 | 71 | 61 | 59 | 54 | 46\* |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 62 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1` | DJI S1000+ · 148.9 Hz | 15 m | 30 | 26 | 36 | 51 | 66 | 18 | 14\* |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 12 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 12 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 12 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 13 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 12 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 12 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 13 | — | — | — | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 4.2 `sionna_p4000000000_onlydepth3_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: 깊이 3 만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlydepth3_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlydepth3_r15_n8192__map.png)
#
# **그림 56.** `sionna_p4000000000_onlydepth3_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlydepth3_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlydepth3_r15_n8192__band.png)
#
# **그림 57.** `sionna_p4000000000_onlydepth3_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 86.8 | +1.2 | 77.6 | 0.61 | −92.61 | 0.116 |
# | −30° | 1102 Hz | 80.6 | 12.6 | 1.2 | +52.1 | 126.1 | 0.99 | −135.74 | 71.930 |
# | −60° | 636 Hz | 32.4 | 12.6 | 11.5 | +27.2 | 126.1 | 0.99 | −129.63 | 13.894 |
# | −90°\* | 0 Hz | 98.2 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.74 | 1.683 |

# %% [markdown]
# ### 절 4.3 `sionna_p4000000000_onlydiffr_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 회절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlydiffr_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlydiffr_r15_n8192__map.png)
#
# **그림 58.** `sionna_p4000000000_onlydiffr_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlydiffr_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlydiffr_r15_n8192__band.png)
#
# **그림 59.** `sionna_p4000000000_onlydiffr_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.2 | 12.5 | 86.4 | −1.8 | 84.9 ⚠튐 | 0.67 | −93.05 | 0.080 |
# | −15° | 1230 Hz | 11.9 | 12.6 | 87.6 | −0.6 | 198.8 ⚠튐 | 1.57 | −111.60 | 1.721 |
# | −30° | 1102 Hz | 11.7 | 12.6 | 81.1 | +9.1 | 252.2 | 1.99 | −124.74 | 0.118 |
# | −45° | 900 Hz | 13.2 | 12.5 | 58.5 | +16.4 | 252.2 | 1.99 | −124.38 | 0.219 |
# | −60° | 636 Hz | 13.5 | 12.6 | 70.8 | +11.6 | 128.5 | 1.01 | −123.53 | 1.496 |
# | −75° | 330 Hz | 13.0 | 12.6 | 91.7 | — | 126.1 | 0.99 | −108.24 | 0.154 |
# | −90°\* | 0 Hz | 12.9 | 12.6 | 100.0 | — | 150.3 ⚠튐 | 1.19 | −109.44 | 0.008 |

# %% [markdown]
# ### 절 4.4 `sionna_p4000000000_onlyedge_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 모서리 회절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyedge_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyedge_r15_n8192__map.png)
#
# **그림 60.** `sionna_p4000000000_onlyedge_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyedge_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyedge_r15_n8192__band.png)
#
# **그림 61.** `sionna_p4000000000_onlyedge_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 86.2 | −0.8 | 84.9 ⚠튐 | 0.67 | −94.30 | 0.078 |
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 58.125 |
# | −60° | 636 Hz | 86.6 | 12.6 | 3.3 | +48.3 | 126.1 | 0.99 | −129.72 | 12.742 |
# | −90°\* | 0 Hz | 98.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.72 | 1.665 |

# %% [markdown]
# ### 절 4.5 `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192__map.png)
#
# **그림 62.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192__band.png)
#
# **그림 63.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.7 | 8.7 | 89.7 | −0.8 | 522.4 ⚠튐 | 2.85 | −103.51 | 0.021 |
# | −30° | 887 Hz | 71.0 | 8.7 | 39.7 | +36.2 | 181.4 | 0.99 | −150.99 | 61.137 |
# | −60° | 512 Hz | 59.2 | 8.7 | 22.1 | — | 183.8 | 1.00 | −138.29 | 22.591 |

# %% [markdown]
# ### 절 4.6 `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 장면: **프로펠러를 뺀 나머지** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192__map.png)
#
# **그림 64.** `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192__band.png)
#
# **그림 65.** `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | ○ 안 움직임 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.7 `sionna_p4000000000_onlyrefr_partsprop_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 장면: **프로펠러만** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_partsprop_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_partsprop_r15_n8192__map.png)
#
# **그림 66.** `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_partsprop_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_partsprop_r15_n8192__band.png)
#
# **그림 67.** `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 53.0 | 12.5 | 42.8 | +29.4 | 126.1 | 0.99 | −148.84 | 91.485 |

# %% [markdown]
# ### 절 4.8 `sionna_p4000000000_onlyrefr_r120_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r120_n8192__map.png)
#
# **그림 68.** `sionna_p4000000000_onlyrefr_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r120_n8192__band.png)
#
# **그림 69.** `sionna_p4000000000_onlyrefr_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 43.9 | 12.5 | 45.2 | +28.5 | 380.7 | 3.01 | −189.23 | 0.000 |
# | −30° | 1102 Hz | 66.2 | 12.6 | 28.1 | +28.5 | 126.1 | 0.99 | −180.91 | 7.368 |

# %% [markdown]
# ### 절 4.9 `sionna_p4000000000_onlyrefr_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192__map.png)
#
# **그림 70.** `sionna_p4000000000_onlyrefr_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192__band.png)
#
# **그림 71.** `sionna_p4000000000_onlyrefr_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.3 | 12.5 | 85.2 | +0.3 | 21.8 ⚠튐 | 0.17 | −96.87 | 0.043 |
# | −15° | 1230 Hz | 61.3 | 12.6 | 42.5 | +28.6 | 126.1 | 0.99 | −148.22 | 0.932 |
# | −30° | 1102 Hz | 62.1 | 12.6 | 11.5 | +37.5 | 126.1 | 0.99 | −141.03 | 38.442 |
# | −45° | 900 Hz | 64.9 | 12.5 | 15.8 | +37.1 | 126.1 | 0.99 | −135.69 | 51.197 |
# | −60° | 636 Hz | 64.0 | 12.6 | 44.6 | +28.9 | 128.5 | 1.01 | −136.12 | 21.238 |
# | −75° | 330 Hz | 57.1 | 12.6 | 12.8 | — | 126.1 | 0.99 | −129.71 | 11.642 |
# | −90°\* | 0 Hz | 61.8 | 12.6 | 100.0 | — | 123.7 | 0.98 | −137.23 | 19.329 |

# %% [markdown]
# ### 절 4.10 `sionna_p4000000000_onlyrefr_r15_n8192_az22.5`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5__map.png)
#
# **그림 72.** `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5__band.png)
#
# **그림 73.** `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 64.9 | 12.6 | 14.3 | +37.4 | 126.1 | 0.99 | −140.46 | 28.992 |

# %% [markdown]
# ### 절 4.11 `sionna_p4000000000_onlyrefr_r15_n8192_az45`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az45 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45__map.png)
#
# **그림 74.** `sionna_p4000000000_onlyrefr_r15_n8192_az45` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az45 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45__band.png)
#
# **그림 75.** `sionna_p4000000000_onlyrefr_r15_n8192_az45` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 64.2 | 12.6 | 12.3 | +38.2 | 128.5 | 1.01 | −140.48 | 63.099 |

# %% [markdown]
# ### 절 4.12 `sionna_p4000000000_onlyrefr_r15_n8192_az67.5`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az67.5 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5__map.png)
#
# **그림 76.** `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az67.5 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5__band.png)
#
# **그림 77.** `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 63.9 | 12.6 | 7.2 | +39.9 | 252.2 | 1.99 | −138.86 | 60.959 |

# %% [markdown]
# ### 절 4.13 `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm__map.png)
#
# **그림 78.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm__band.png)
#
# **그림 79.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 87.1 | +0.3 | 53.3 ⚠튐 | 0.42 | −104.13 | 0.008 |
# | −30° | 1102 Hz | 39.7 | 12.6 | 77.1 | +19.6 | 254.6 | 2.01 | −160.42 | 15.925 |

# %% [markdown]
# ### 절 4.14 `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm__map.png)
#
# **그림 80.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm__band.png)
#
# **그림 81.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 41.0 | 12.6 | 61.3 | +22.7 | 126.1 | 0.99 | −155.27 | 39.360 |

# %% [markdown]
# ### 절 4.15 `sionna_p4000000000_onlyrefr_r240_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 240 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r240_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r240_n8192__map.png)
#
# **그림 82.** `sionna_p4000000000_onlyrefr_r240_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r240_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r240_n8192__band.png)
#
# **그림 83.** `sionna_p4000000000_onlyrefr_r240_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 56.1 | 12.5 | 89.7 | +24.4 | 506.8 | 4.00 | −193.91 | 0.000 |
# | −30° | 1102 Hz | 68.8 | 12.6 | 43.5 | +28.2 | 126.1 | 0.99 | −193.18 | 65.250 |

# %% [markdown]
# ### 절 4.16 `sionna_p4000000000_onlyrefr_r30_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r30_n8192__map.png)
#
# **그림 84.** `sionna_p4000000000_onlyrefr_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r30_n8192__band.png)
#
# **그림 85.** `sionna_p4000000000_onlyrefr_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 87.4 | +0.0 | 55.8 ⚠튐 | 0.44 | −108.44 | 0.012 |
# | −30° | 1102 Hz | 63.6 | 12.6 | 29.3 | +33.0 | 126.1 | 0.99 | −156.64 | 34.444 |

# %% [markdown]
# ### 절 4.17 `sionna_p4000000000_onlyrefr_r60_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r60_n8192__map.png)
#
# **그림 86.** `sionna_p4000000000_onlyrefr_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r60_n8192__band.png)
#
# **그림 87.** `sionna_p4000000000_onlyrefr_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 86.7 | −0.1 | 21.8 ⚠튐 | 0.17 | −121.01 | 0.003 |
# | −30° | 1102 Hz | 69.7 | 12.6 | 38.8 | +31.0 | 126.1 | 0.99 | −169.73 | 18.103 |

# %% [markdown]
# ### 절 4.18 `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192__map.png)
#
# **그림 88.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192__band.png)
#
# **그림 89.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 30.3 | 10.9 | 62.4 | +22.0 | 746.0 | 5.01 | −140.95 | 0.004 |
# | −30° | 1802 Hz | 36.5 | 10.8 | 14.0 | +30.2 | 147.7 | 0.99 | −136.81 | 0.281 |
# | −60° | 1040 Hz | 65.7 | 10.9 | 22.2 | +32.5 | 147.7 | 0.99 | −127.39 | 0.300 |

# %% [markdown]
# ### 절 4.19 `sionna_p4000000000_stockdef_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: **PathSolver 순정 기본값**(굴절 켬 · 회절 끔 · 모서리 끔 · 확산 끔) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_stockdef_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_stockdef_r15_n8192__map.png)
#
# **그림 90.** `sionna_p4000000000_stockdef_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_stockdef_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_stockdef_r15_n8192__band.png)
#
# **그림 91.** `sionna_p4000000000_stockdef_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.2 | 12.5 | 86.2 | +0.9 | 84.9 ⚠튐 | 0.67 | −94.77 | 0.070 |
# | −15° | 1230 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −30° | 1102 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −45° | 900 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −75° | 330 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −90° | 0 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.20 `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R0D0E0F0` = 넷 다 끔(정반사·LOS 는 켬) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d1__map.png)
#
# **그림 92.** `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d1__band.png)
#
# **그림 93.** `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.21 `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D0E0F0` = 넷 다 끔(정반사·LOS 는 켬) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d3__map.png)
#
# **그림 94.** `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d3__band.png)
#
# **그림 95.** `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.22 `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R0D1E0F0` = 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d1__map.png)
#
# **그림 96.** `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d1__band.png)
#
# **그림 97.** `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.6 | 12.6 | 88.9 | −0.5 | 417.1 ⚠튐 | 3.29 | −125.17 | 0.109 |

# %% [markdown]
# ### 절 4.23 `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D1E0F0` = 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d3__map.png)
#
# **그림 98.** `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d3__band.png)
#
# **그림 99.** `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.2 | 12.6 | 89.1 | +1.5 | 344.3 ⚠튐 | 2.72 | −123.70 | 0.152 |

# %% [markdown]
# ### 절 4.24 `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D1E0F1` = 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F1_r15_n8192_d3__map.png)
#
# **그림 100.** `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F1_r15_n8192_d3__band.png)
#
# **그림 101.** `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.3 | 12.6 | 83.1 | +9.1 | 252.2 | 1.99 | −123.44 | 0.160 |

# %% [markdown]
# ### 절 4.25 `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R0D1E1F0` = 회절 + 모서리 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d1__map.png)
#
# **그림 102.** `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d1__band.png)
#
# **그림 103.** `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.6 | 12.6 | 89.0 | −0.3 | 417.1 ⚠튐 | 3.29 | −125.14 | 0.109 |

# %% [markdown]
# ### 절 4.26 `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D1E1F0` = 회절 + 모서리 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d3__map.png)
#
# **그림 104.** `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d3__band.png)
#
# **그림 105.** `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.2 | 12.6 | 89.1 | +1.3 | 344.3 ⚠튐 | 2.72 | −123.71 | 0.152 |

# %% [markdown]
# ### 절 4.27 `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d1__map.png)
#
# **그림 106.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d1__band.png)
#
# **그림 107.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.7 | 12.6 | 81.0 | +9.1 | 252.2 | 1.99 | −124.73 | 0.118 |

# %% [markdown]
# ### 절 4.28 `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d3__map.png)
#
# **그림 108.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d3__band.png)
#
# **그림 109.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.3 | 12.6 | 83.2 | +9.0 | 252.2 | 1.99 | −123.42 | 0.161 |

# %% [markdown]
# ### 절 4.29 `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D0E0F0` = 굴절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F0_r15_n8192_d1__map.png)
#
# **그림 110.** `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F0_r15_n8192_d1__band.png)
#
# **그림 111.** `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.30 `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1__map.png)
#
# **그림 112.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1__band.png)
#
# **그림 113.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.7 | 8.7 | 89.7 | −0.8 | 522.4 ⚠튐 | 2.85 | −103.51 | 0.021 |
# | −15° | 990 Hz | 49.2 | 8.6 | 52.2 | +28.7 | 367.6 | 2.00 | −156.78 | 2.917 |
# | −30° | 887 Hz | 71.0 | 8.7 | 39.7 | +36.2 | 181.4 | 0.99 | −150.99 | 61.137 |
# | −45° | 725 Hz | 60.7 | 8.7 | 14.3 | +39.3 | 183.8 | 1.00 | −140.58 | 26.336 |
# | −60° | 512 Hz | 59.2 | 8.7 | 22.1 | — | 183.8 | 1.00 | −138.29 | 22.591 |
# | −75° | 265 Hz | 54.4 | 8.7 | 34.7 | — | 183.8 | 1.00 | −139.55 | 6.400 |
# | −90°\* | 0 Hz | 45.7 | 8.7 | 100.0 | — | 183.8 | 1.00 | −144.05 | 3.457 |

# %% [markdown]
# ### 절 4.31 `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_d3__map.png)
#
# **그림 114.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_d3__band.png)
#
# **그림 115.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 61.6 | 12.6 | 11.8 | +37.5 | 126.1 | 0.99 | −140.96 | 31.974 |

# %% [markdown]
# ### 절 4.32 `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1__map.png)
#
# **그림 116.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1__band.png)
#
# **그림 117.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 30.3 | 10.9 | 62.4 | +22.0 | 746.0 | 5.01 | −140.95 | 0.004 |
# | −15° | 2010 Hz | 25.6 | 10.8 | 48.1 | +20.7 | 147.7 | 0.99 | −138.74 | 0.153 |
# | −30° | 1802 Hz | 36.5 | 10.8 | 14.0 | +30.2 | 147.7 | 0.99 | −136.81 | 0.281 |
# | −45° | 1471 Hz | 51.4 | 10.9 | 12.7 | +32.0 | 147.7 | 0.99 | −129.87 | 0.308 |
# | −60° | 1040 Hz | 65.7 | 10.9 | 22.2 | +32.5 | 147.7 | 0.99 | −127.39 | 0.300 |
# | −75° | 538 Hz | 18.4 | 10.8 | 89.9 | +14.1 | 150.2 | 1.01 | −114.00 | 3.813 |
# | −90°\* | 0 Hz | 13.5 | 10.8 | 100.0 | — | 55.7 ⚠튐 | 0.37 | −115.00 | 0.012 |

# %% [markdown]
# ### 절 4.33 `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D1E0F0` = 굴절 + 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d1__map.png)
#
# **그림 118.** `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d1__band.png)
#
# **그림 119.** `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.1 | 12.6 | 88.8 | +0.5 | 419.5 ⚠튐 | 3.31 | −126.73 | 0.076 |

# %% [markdown]
# ### 절 4.34 `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D1E0F0` = 굴절 + 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d3__map.png)
#
# **그림 120.** `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d3__band.png)
#
# **그림 121.** `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.0 | 12.6 | 88.4 | +0.8 | 497.1 ⚠튐 | 3.92 | −124.50 | 0.127 |

# %% [markdown]
# ### 절 4.35 `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D1E0F1` = 굴절 + 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F1_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d1__map.png)
#
# **그림 122.** `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F1_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d1__band.png)
#
# **그림 123.** `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.3 | 12.6 | 85.7 | +6.3 | 252.2 | 1.99 | −126.56 | 0.078 |

# %% [markdown]
# ### 절 4.36 `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D1E0F1` = 굴절 + 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d3__map.png)
#
# **그림 124.** `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d3__band.png)
#
# **그림 125.** `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.6 | 12.6 | 86.4 | +4.7 | 254.6 | 2.01 | −124.41 | 0.128 |

# %% [markdown]
# ### 절 4.37 `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D1E1F0` = 굴절 + 회절 + 모서리 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d1__map.png)
#
# **그림 126.** `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d1__band.png)
#
# **그림 127.** `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.1 | 12.6 | 88.8 | +0.8 | 419.5 ⚠튐 | 3.31 | −126.80 | 0.074 |

# %% [markdown]
# ### 절 4.38 `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D1E1F0` = 굴절 + 회절 + 모서리 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d3__map.png)
#
# **그림 128.** `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d3__band.png)
#
# **그림 129.** `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.0 | 12.6 | 88.3 | +0.8 | 497.1 ⚠튐 | 3.92 | −124.50 | 0.127 |

# %% [markdown]
# ### 절 4.39 `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_d3__map.png)
#
# **그림 130.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_d3__band.png)
#
# **그림 131.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.6 | 12.6 | 86.3 | +4.6 | 254.6 | 2.01 | −124.42 | 0.128 |

# %% [markdown]
# ---
#
# ## 절 5. 기체 3 종 — 박자가 기체마다 다르다
#
# > **묻는 것** — 표적 기체를 바꾸면 그림의 박자가 **그 기체의 박자**로 따라가나 — 분류 축이 성립하나.
#
# 팔 8 개 · 칸 40 개 · 그림 19 장. 그림 파일은 전부 `outputs/figures/atlas/03airframe__…` 로 시작한다.

# %% [markdown]
# ![airframes — 03airframe__000-overview-rhythm.png](../outputs/figures/atlas/03airframe__000-overview-rhythm.png)
#
# **그림 132.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![airframes — 03airframe__01-compare-tile-30-p1.png](../outputs/figures/atlas/03airframe__01-compare-tile-30-p1.png)
#
# **그림 133.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![airframes — 03airframe__02-compare-stack-p1.png](../outputs/figures/atlas/03airframe__02-compare-stack-p1.png)
#
# **그림 134.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 5.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −15° | −30° | −45° | −60° | −75° | −90° |
# |---|---|---|---|---|---|---|---|---|---|
# | `ours_mini5pro_r15_n8192` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 66 | 66 | 83 | 72 | 59 | 58 | 61\* |
# | `ours_s1000plus_r15_n8192` | DJI S1000+ · 148.9 Hz | 15 m | 53 | 49 | 70 | 49 | 81 | 82 | 99\* |
# | `sionna_p4000000000_mini5pro_r15_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | 80 | 89 | 94 | 90 | 93 | 96\* |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | — | — | 84 | — | — | — | — |
# | `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | 11 | — | 14 | — | — |
# | `sionna_p4000000000_phys_s1000plus_r15_n8192_d1` | DJI S1000+ · 148.9 Hz | 15 m | 12 | 11 | 11 | 12 | 17 | 17 | 18\* |
# | `sionna_p4000000000_s1000plus_r15_n8192_d1` | DJI S1000+ · 148.9 Hz | 15 m | 28 | 24 | 36 | 62 | 90 | 19 | 23\* |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` | DJI S1000+ · 148.9 Hz | 15 m | — | — | 23 | — | — | — | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 5.2 `ours_mini5pro_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192__map.png)
#
# **그림 135.** `ours_mini5pro_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192__band.png)
#
# **그림 136.** `ours_mini5pro_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.9 | +47.5 | 183.8 | 1.00 | −74.44 | 2.970 |
# | −15° | 990 Hz | 65.8 | 8.6 | 34.6 | +35.5 | 367.6 | 2.00 | −79.60 | 1.044 |
# | −30° | 887 Hz | 83.0 | 8.7 | 32.7 | +39.8 | 183.8 | 1.00 | −77.61 | 1.864 |
# | −45° | 725 Hz | 72.3 | 8.7 | 5.4 | +46.3 | 183.8 | 1.00 | −72.62 | 1.598 |
# | −60° | 512 Hz | 58.8 | 8.7 | 1.4 | — | 183.8 | 1.00 | −68.34 | 3.678 |
# | −75° | 265 Hz | 57.5 | 8.7 | 3.4 | — | 183.8 | 1.00 | −72.32 | 0.291 |
# | −90°\* | 0 Hz | 61.3 | 8.7 | 100.0 | — | 183.8 | 1.00 | −86.18 | 0.143 |

# %% [markdown]
# ### 절 5.3 `ours_s1000plus_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192__map.png)
#
# **그림 137.** `ours_s1000plus_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192__band.png)
#
# **그림 138.** `ours_s1000plus_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 52.7 | 10.9 | 4.5 | +38.6 | 147.7 | 0.99 | −65.73 | 0.145 |
# | −15° | 2010 Hz | 49.4 | 10.8 | 12.5 | +31.8 | 150.2 | 1.01 | −65.66 | 0.219 |
# | −30° | 1802 Hz | 70.4 | 10.8 | 14.1 | +32.4 | 147.7 | 0.99 | −65.22 | 2.496 |
# | −45° | 1471 Hz | 49.4 | 10.9 | 2.1 | +41.2 | 150.2 | 1.01 | −61.48 | 3.480 |
# | −60° | 1040 Hz | 80.6 | 10.9 | 1.9 | +43.7 | 147.7 | 0.99 | −57.39 | 4.913 |
# | −75° | 538 Hz | 82.5 | 10.8 | 1.0 | +51.6 | 150.2 | 1.01 | −54.62 | 50.095 |
# | −90°\* | 0 Hz | 99.4 | 10.8 | 100.0 | — | 147.7 | 0.99 | −54.93 | 0.371 |

# %% [markdown]
# ### 절 5.4 `sionna_p4000000000_mini5pro_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_d1__map.png)
#
# **그림 139.** `sionna_p4000000000_mini5pro_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_d1__band.png)
#
# **그림 140.** `sionna_p4000000000_mini5pro_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.7 | 8.7 | 89.8 | +0.0 | 365.2 ⚠튐 | 1.99 | −97.66 | 0.082 |
# | −15° | 990 Hz | 80.4 | 8.6 | 22.5 | +42.9 | 183.8 | 1.00 | −156.43 | 1.806 |
# | −30° | 887 Hz | 88.7 | 8.7 | 11.4 | +47.0 | 183.8 | 1.00 | −147.28 | 6.671 |
# | −45° | 725 Hz | 93.7 | 8.7 | 2.9 | +53.5 | 183.8 | 1.00 | −134.18 | 24.613 |
# | −60° | 512 Hz | 89.7 | 8.7 | 2.2 | — | 183.8 | 1.00 | −131.13 | 13.645 |
# | −75° | 265 Hz | 93.2 | 8.7 | 7.7 | — | 183.8 | 1.00 | −134.52 | 4.102 |
# | −90°\* | 0 Hz | 96.5 | 8.7 | 100.0 | — | 367.6 | 2.00 | −143.67 | 0.351 |

# %% [markdown]
# ### 절 5.5 `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1__map.png)
#
# **그림 141.** `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1__band.png)
#
# **그림 142.** `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 84.2 | 8.7 | 12.9 | +40.6 | 183.8 | 1.00 | −162.27 | 7.599 |

# %% [markdown]
# ### 절 5.6 `sionna_p4000000000_phys_mini5pro_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_mini5pro_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_phys_mini5pro_r15_n8192_d1__map.png)
#
# **그림 143.** `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_mini5pro_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_phys_mini5pro_r15_n8192_d1__band.png)
#
# **그림 144.** `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.3 | 8.7 | 88.1 | +2.3 | 367.6 ⚠튐 | 2.00 | −101.46 | 0.032 |
# | −30° | 887 Hz | 11.3 | 8.7 | 89.5 | +5.8 | 367.6 ⚠튐 | 2.00 | −135.64 | 0.014 |
# | −60° | 512 Hz | 14.3 | 8.7 | 73.6 | — | 183.8 | 1.00 | −132.64 | 0.026 |

# %% [markdown]
# ### 절 5.7 `sionna_p4000000000_phys_s1000plus_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_s1000plus_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_phys_s1000plus_r15_n8192_d1__map.png)
#
# **그림 145.** `sionna_p4000000000_phys_s1000plus_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_s1000plus_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_phys_s1000plus_r15_n8192_d1__band.png)
#
# **그림 146.** `sionna_p4000000000_phys_s1000plus_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 11.9 | 10.9 | 78.4 | +0.2 | 60.5 ⚠튐 | 0.41 | −96.06 | 7.486 |
# | −15° | 2010 Hz | 11.2 | 10.8 | 77.9 | +1.5 | 249.5 | 1.68 | −119.11 | 0.162 |
# | −30° | 1802 Hz | 11.2 | 10.8 | 78.8 | +4.6 | 145.3 | 0.98 | −122.87 | 1.813 |
# | −45° | 1471 Hz | 12.5 | 10.9 | 69.0 | +13.4 | 150.2 | 1.01 | −122.74 | 0.272 |
# | −60° | 1040 Hz | 17.1 | 10.9 | 65.9 | +16.2 | 297.9 | 2.00 | −121.24 | 0.198 |
# | −75° | 538 Hz | 16.7 | 10.8 | 89.6 | +12.9 | 297.9 | 2.00 | −113.12 | 1.263 |
# | −90°\* | 0 Hz | 17.8 | 10.8 | 100.0 | — | 685.4 ⚠튐 | 4.60 | −114.08 | 0.001 |

# %% [markdown]
# ### 절 5.8 `sionna_p4000000000_s1000plus_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_d1__map.png)
#
# **그림 147.** `sionna_p4000000000_s1000plus_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_d1__band.png)
#
# **그림 148.** `sionna_p4000000000_s1000plus_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 27.9 | 10.9 | 39.6 | +26.7 | 891.3 | 5.99 | −141.11 | 0.004 |
# | −15° | 2010 Hz | 24.0 | 10.8 | 22.7 | +25.2 | 147.7 | 0.99 | −138.15 | 0.138 |
# | −30° | 1802 Hz | 36.3 | 10.8 | 3.6 | +39.6 | 147.7 | 0.99 | −133.30 | 0.640 |
# | −45° | 1471 Hz | 61.5 | 10.9 | 1.5 | +47.0 | 150.2 | 1.01 | −123.53 | 1.212 |
# | −60° | 1040 Hz | 90.0 | 10.9 | 2.8 | +47.4 | 147.7 | 0.99 | −120.94 | 1.359 |
# | −75° | 538 Hz | 18.7 | 10.8 | 63.2 | +23.7 | 150.2 | 1.01 | −111.62 | 4.675 |
# | −90°\* | 0 Hz | 22.6 | 10.8 | 100.0 | — | 147.7 | 0.99 | −107.47 | 0.066 |

# %% [markdown]
# ### 절 5.9 `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1__map.png)
#
# **그림 149.** `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1__band.png)
#
# **그림 150.** `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 23.2 | 10.8 | 51.9 | +26.8 | 743.5 | 4.99 | −144.95 | 0.046 |

# %% [markdown]
# ---
#
# ## 절 6. 방위 — 정면 말고 45° 에서 본 판
#
# > **묻는 것** — 지금까지의 결론이 방위 한 자리(정면)에서만 서는 것인가 — 45° 옆에서도 같은 말을 하나.
#
# 팔 14 개 · 칸 29 개 · 그림 31 장. 그림 파일은 전부 `outputs/figures/atlas/04azimuth__…` 로 시작한다.

# %% [markdown]
# ![azimuth — 04azimuth__000-overview-rhythm.png](../outputs/figures/atlas/04azimuth__000-overview-rhythm.png)
#
# **그림 151.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![azimuth — 04azimuth__01-compare-tile-30-p1.png](../outputs/figures/atlas/04azimuth__01-compare-tile-30-p1.png)
#
# **그림 152.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![azimuth — 04azimuth__02-compare-stack-p1.png](../outputs/figures/atlas/04azimuth__02-compare-stack-p1.png)
#
# **그림 153.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 6.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −30° | −60° | −90° |
# |---|---|---|---|---|---|---|
# | `ours_mini5pro_r15_n8192_az22.5` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 67 | 84 | — | — |
# | `ours_ptd_r15_n8192_az22.5` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 87 | — | — |
# | `ours_r15_n8192_az15` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 90 | — | — |
# | `ours_r15_n8192_az22.5` | DJI Matrice 4E · 126.667 Hz | 15 m | 61 | 87 | 54 | — |
# | `ours_r15_n8192_az30` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 88 | — | — |
# | `ours_r15_n8192_az45` | DJI Matrice 4E · 126.667 Hz | 15 m | 50 | 87 | 51 | 65\* |
# | `ours_r15_n8192_az60` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 89 | — | — |
# | `ours_r15_n8192_az67.5` | DJI Matrice 4E · 126.667 Hz | 15 m | 55 | 87 | 54 | — |
# | `ours_r15_n8192_az75` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 85 | — | — |
# | `ours_r15_n8192_az90` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 84 | — | — |
# | `ours_s1000plus_r15_n8192_az22.5` | DJI S1000+ · 148.9 Hz | 15 m | 50 | 76 | — | — |
# | `sionna_p4000000000_phys_r15_n8192_az45_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | 14 | 28 | 14\* |
# | `sionna_p4000000000_r15_n8192_az22.5_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 84 | — | — |
# | `sionna_p4000000000_r15_n8192_az45_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 82 | 84 | 89 | 98\* |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 6.2 `ours_mini5pro_r15_n8192_az22.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 22.5° · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_mini5pro_r15_n8192_az22.5__map.png)
#
# **그림 154.** `ours_mini5pro_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_mini5pro_r15_n8192_az22.5__band.png)
#
# **그림 155.** `ours_mini5pro_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 66.9 | 8.7 | 4.4 | +49.1 | 183.8 | 1.00 | −73.34 | 0.937 |
# | −30° | 887 Hz | 84.3 | 8.7 | 19.6 | +45.1 | 367.6 | 2.00 | −75.64 | 1.152 |

# %% [markdown]
# ### 절 6.3 `ours_ptd_r15_n8192_az22.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_ptd_r15_n8192_az22.5__map.png)
#
# **그림 156.** `ours_ptd_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_ptd_r15_n8192_az22.5__band.png)
#
# **그림 157.** `ours_ptd_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 87.2 | 12.6 | 18.9 | +41.4 | 126.1 | 0.99 | −69.01 | 5.157 |

# %% [markdown]
# ### 절 6.4 `ours_r15_n8192_az15`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 15° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az15 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az15__map.png)
#
# **그림 158.** `ours_r15_n8192_az15` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az15 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az15__band.png)
#
# **그림 159.** `ours_r15_n8192_az15` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 89.7 | 12.6 | 13.2 | +45.0 | 126.1 | 0.99 | −67.78 | 6.763 |

# %% [markdown]
# ### 절 6.5 `ours_r15_n8192_az22.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az22.5__map.png)
#
# **그림 160.** `ours_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az22.5__band.png)
#
# **그림 161.** `ours_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 61.3 | 12.5 | 4.7 | +46.1 | 126.1 | 0.99 | −70.03 | 0.615 |
# | −30° | 1102 Hz | 87.3 | 12.6 | 18.8 | +41.4 | 126.1 | 0.99 | −69.00 | 3.744 |
# | −60° | 636 Hz | 53.8 | 12.6 | 1.0 | +53.6 | 126.1 | 0.99 | −64.84 | 47.919 |

# %% [markdown]
# ### 절 6.6 `ours_r15_n8192_az30`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 30° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az30 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az30__map.png)
#
# **그림 162.** `ours_r15_n8192_az30` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az30 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az30__band.png)
#
# **그림 163.** `ours_r15_n8192_az30` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 87.9 | 12.6 | 18.4 | +41.7 | 126.1 | 0.99 | −69.44 | 1.527 |

# %% [markdown]
# ### 절 6.7 `ours_r15_n8192_az45`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az45 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az45__map.png)
#
# **그림 164.** `ours_r15_n8192_az45` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az45 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az45__band.png)
#
# **그림 165.** `ours_r15_n8192_az45` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 50.3 | 12.5 | 3.5 | +48.0 | 126.1 | 0.99 | −69.85 | 4.172 |
# | −30° | 1102 Hz | 86.8 | 12.6 | 14.6 | +41.3 | 126.1 | 0.99 | −68.75 | 32.727 |
# | −60° | 636 Hz | 51.0 | 12.6 | 0.7 | +53.5 | 126.1 | 0.99 | −62.61 | 12.066 |
# | −90°\* | 0 Hz | 64.9 | 12.6 | 100.0 | — | 126.1 | 0.99 | −81.56 | 0.009 |

# %% [markdown]
# ### 절 6.8 `ours_r15_n8192_az60`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 60° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az60 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az60__map.png)
#
# **그림 166.** `ours_r15_n8192_az60` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az60 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az60__band.png)
#
# **그림 167.** `ours_r15_n8192_az60` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 89.4 | 12.6 | 12.3 | +43.2 | 252.2 | 1.99 | −67.51 | 9.457 |

# %% [markdown]
# ### 절 6.9 `ours_r15_n8192_az67.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az67.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az67.5__map.png)
#
# **그림 168.** `ours_r15_n8192_az67.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az67.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az67.5__band.png)
#
# **그림 169.** `ours_r15_n8192_az67.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 54.7 | 12.5 | 3.6 | +47.8 | 252.2 | 1.99 | −69.77 | 1.268 |
# | −30° | 1102 Hz | 86.7 | 12.6 | 11.5 | +44.2 | 252.2 | 1.99 | −67.51 | 7.060 |
# | −60° | 636 Hz | 54.1 | 12.6 | 0.5 | +55.4 | 126.1 | 0.99 | −61.48 | 5.335 |

# %% [markdown]
# ### 절 6.10 `ours_r15_n8192_az75`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 75° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az75 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az75__map.png)
#
# **그림 170.** `ours_r15_n8192_az75` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az75 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az75__band.png)
#
# **그림 171.** `ours_r15_n8192_az75` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 84.6 | 12.6 | 13.1 | +39.9 | 126.1 | 0.99 | −68.22 | 3.679 |

# %% [markdown]
# ### 절 6.11 `ours_r15_n8192_az90`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_az90 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az90__map.png)
#
# **그림 172.** `ours_r15_n8192_az90` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_az90 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_r15_n8192_az90__band.png)
#
# **그림 173.** `ours_r15_n8192_az90` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 84.5 | 12.6 | 14.1 | +40.8 | 254.6 | 2.01 | −68.77 | 0.842 |

# %% [markdown]
# ### 절 6.12 `ours_s1000plus_r15_n8192_az22.5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 방위 22.5° · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/04azimuth__ours_s1000plus_r15_n8192_az22.5__map.png)
#
# **그림 174.** `ours_s1000plus_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__ours_s1000plus_r15_n8192_az22.5__band.png)
#
# **그림 175.** `ours_s1000plus_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 49.9 | 10.9 | 3.3 | +40.4 | 297.9 | 2.00 | −64.03 | 0.736 |
# | −30° | 1802 Hz | 75.7 | 10.8 | 8.4 | +35.9 | 297.9 | 2.00 | −62.77 | 0.277 |

# %% [markdown]
# ### 절 6.13 `sionna_p4000000000_phys_r15_n8192_az45_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_az45_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_phys_r15_n8192_az45_d1__map.png)
#
# **그림 176.** `sionna_p4000000000_phys_r15_n8192_az45_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r15_n8192_az45_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_phys_r15_n8192_az45_d1__band.png)
#
# **그림 177.** `sionna_p4000000000_phys_r15_n8192_az45_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.9 | 12.5 | 82.6 | +5.1 | 126.1 | 0.99 | −120.28 | 1.062 |
# | −30° | 1102 Hz | 14.5 | 12.6 | 64.6 | +15.0 | 128.5 | 1.01 | −135.82 | 94.260 |
# | −60° | 636 Hz | 28.4 | 12.6 | 38.7 | +22.7 | 126.1 | 0.99 | −131.84 | 53.667 |
# | −90°\* | 0 Hz | 14.3 | 12.6 | 100.0 | — | 191.6 ⚠튐 | 1.51 | −118.38 | 0.001 |

# %% [markdown]
# ### 절 6.14 `sionna_p4000000000_r15_n8192_az22.5_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az22.5_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az22.5_d1__map.png)
#
# **그림 178.** `sionna_p4000000000_r15_n8192_az22.5_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az22.5_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az22.5_d1__band.png)
#
# **그림 179.** `sionna_p4000000000_r15_n8192_az22.5_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 83.8 | 12.6 | 2.0 | +52.7 | 126.1 | 0.99 | −135.19 | 16.877 |

# %% [markdown]
# ### 절 6.15 `sionna_p4000000000_r15_n8192_az45_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az45_d1 micro-Doppler maps](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az45_d1__map.png)
#
# **그림 180.** `sionna_p4000000000_r15_n8192_az45_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r15_n8192_az45_d1 blade-band rhythm spectrum](../outputs/figures/atlas/04azimuth__sionna_p4000000000_r15_n8192_az45_d1__band.png)
#
# **그림 181.** `sionna_p4000000000_r15_n8192_az45_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 82.0 | 12.5 | 4.9 | +45.3 | 126.1 | 0.99 | −145.41 | 0.309 |
# | −30° | 1102 Hz | 84.4 | 12.6 | 1.2 | +53.0 | 128.5 | 1.01 | −133.57 | 66.207 |
# | −60° | 636 Hz | 88.7 | 12.6 | 1.2 | +56.4 | 126.1 | 0.99 | −125.65 | 16.414 |
# | −90°\* | 0 Hz | 98.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.72 | 1.665 |

# %% [markdown]
# ---
#
# ## 절 7. 부품 분해 — 프로펠러만 / 동체만
#
# > **묻는 것** — 무늬를 만드는 것은 프로펠러인가 동체인가 — 프로펠러만 남기면 무엇이 남나.
#
# 팔 3 개 · 칸 9 개 · 그림 8 장. 그림 파일은 전부 `outputs/figures/atlas/05parts__…` 로 시작한다.

# %% [markdown]
# ![scene parts — 05parts__000-overview-rhythm.png](../outputs/figures/atlas/05parts__000-overview-rhythm.png)
#
# **그림 182.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![scene parts — 05parts__02-compare-stack-p1.png](../outputs/figures/atlas/05parts__02-compare-stack-p1.png)
#
# **그림 183.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 7.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −30° | −60° | −90° |
# |---|---|---|---|---|---|---|
# | `sionna_p4000000000_partsnoprop_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | ○ | — | — | — |
# | `sionna_p4000000000_partsprop_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 90 | 82 | 86 | 99\* |
# | `sionna_p4000000000_phys_partsprop_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | 14 | 19 | 23\* |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 7.2 `sionna_p4000000000_partsnoprop_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 장면: **프로펠러를 뺀 나머지** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_partsnoprop_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/05parts__sionna_p4000000000_partsnoprop_r15_n8192_d1__map.png)
#
# **그림 184.** `sionna_p4000000000_partsnoprop_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_partsnoprop_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/05parts__sionna_p4000000000_partsnoprop_r15_n8192_d1__band.png)
#
# **그림 185.** `sionna_p4000000000_partsnoprop_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | ○ 안 움직임 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 7.3 `sionna_p4000000000_partsprop_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 장면: **프로펠러만** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_partsprop_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/05parts__sionna_p4000000000_partsprop_r15_n8192_d1__map.png)
#
# **그림 186.** `sionna_p4000000000_partsprop_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_partsprop_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/05parts__sionna_p4000000000_partsprop_r15_n8192_d1__band.png)
#
# **그림 187.** `sionna_p4000000000_partsprop_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 89.7 | 12.5 | 8.1 | +48.4 | 126.1 | 0.99 | −146.68 | 23.348 |
# | −30° | 1102 Hz | 81.5 | 12.6 | 1.2 | +51.8 | 126.1 | 0.99 | −135.47 | 94.697 |
# | −60° | 636 Hz | 86.0 | 12.6 | 3.1 | +48.3 | 126.1 | 0.99 | −129.55 | 80.685 |
# | −90°\* | 0 Hz | 99.2 | 12.6 | 100.0 | — | 126.1 | 0.99 | −132.67 | 0.263 |

# %% [markdown]
# ### 절 7.4 `sionna_p4000000000_phys_partsprop_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 장면: **프로펠러만** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_partsprop_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/05parts__sionna_p4000000000_phys_partsprop_r15_n8192_d1__map.png)
#
# **그림 188.** `sionna_p4000000000_phys_partsprop_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_partsprop_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/05parts__sionna_p4000000000_phys_partsprop_r15_n8192_d1__band.png)
#
# **그림 189.** `sionna_p4000000000_phys_partsprop_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 80.0 | +7.4 | 126.1 | 0.99 | −119.05 | 97.933 |
# | −30° | 1102 Hz | 14.2 | 12.6 | 81.1 | +10.6 | 126.1 | 0.99 | −130.53 | 99.874 |
# | −60° | 636 Hz | 19.1 | 12.6 | 75.5 | +12.6 | 126.1 | 0.99 | −129.06 | 88.826 |
# | −90°\* | 0 Hz | 23.0 | 12.6 | 100.0 | — | 208.5 | 1.65 | −122.57 | 18.965 |

# %% [markdown]
# ---
#
# ## 절 8. 거리 — 15 m 아닌 판(30 m)
#
# > **묻는 것** — 15 m 에서 30 m 로 물러나면 날개 무늬가 남나.
#
# 팔 30 개 · 칸 64 개 · 그림 66 장. 그림 파일은 전부 `outputs/figures/atlas/06range__…` 로 시작한다.

# %% [markdown]
# ![range — 06range__000-overview-rhythm.png](../outputs/figures/atlas/06range__000-overview-rhythm.png)
#
# **그림 190.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![range — 06range__01-compare-tile-30-p1.png](../outputs/figures/atlas/06range__01-compare-tile-30-p1.png)
#
# **그림 191.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p1.png](../outputs/figures/atlas/06range__02-compare-stack-p1.png)
#
# **그림 192.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p2.png](../outputs/figures/atlas/06range__02-compare-stack-p2.png)
#
# **그림 193.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p3.png](../outputs/figures/atlas/06range__02-compare-stack-p3.png)
#
# **그림 194.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![range — 06range__02-compare-stack-p4.png](../outputs/figures/atlas/06range__02-compare-stack-p4.png)
#
# **그림 195.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 8.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −30° | −60° |
# |---|---|---|---|---|---|
# | `ours_mini5pro_r120_n8192` | DJI Mini 5 Pro · 183.333 Hz | 120 m | 66 | 83 | — |
# | `ours_mini5pro_r30_n8192` | DJI Mini 5 Pro · 183.333 Hz | 30 m | 66 | 83 | — |
# | `ours_mini5pro_r60_n8192` | DJI Mini 5 Pro · 183.333 Hz | 60 m | 66 | 83 | — |
# | `ours_ptd_r120_n8192` | DJI Matrice 4E · 126.667 Hz | 120 m | — | 83 | — |
# | `ours_ptd_r30_n8192` | DJI Matrice 4E · 126.667 Hz | 30 m | — | 83 | — |
# | `ours_ptd_r60_n8192` | DJI Matrice 4E · 126.667 Hz | 60 m | — | 83 | — |
# | `ours_r120_n8192` | DJI Matrice 4E · 126.667 Hz | 120 m | 64 | 83 | 53 |
# | `ours_r240_n8192` | DJI Matrice 4E · 126.667 Hz | 240 m | 64 | 83 | — |
# | `ours_r30_n8192` | DJI Matrice 4E · 126.667 Hz | 30 m | 64 | 83 | 53 |
# | `ours_r480_n8192` | DJI Matrice 4E · 126.667 Hz | 480 m | 64 | 83 | — |
# | `ours_r60_n8192` | DJI Matrice 4E · 126.667 Hz | 60 m | 64 | 83 | 53 |
# | `ours_s1000plus_r120_n8192` | DJI S1000+ · 148.9 Hz | 120 m | 51 | 75 | — |
# | `ours_s1000plus_r30_n8192` | DJI S1000+ · 148.9 Hz | 30 m | 52 | 74 | — |
# | `ours_s1000plus_r60_n8192` | DJI S1000+ · 148.9 Hz | 60 m | 51 | 75 | — |
# | `sionna_p4000000000_mini5pro_r120_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 120 m | 86 | 83 | — |
# | `sionna_p4000000000_mini5pro_r30_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 30 m | 9 | 89 | — |
# | `sionna_p4000000000_mini5pro_r60_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 60 m | 88 | 87 | — |
# | `sionna_p4000000000_phys_r120_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 120 m | 12 | 14 | 62 |
# | `sionna_p4000000000_phys_r30_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 30 m | 13 | 14 | 17 |
# | `sionna_p4000000000_phys_r60_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | 15 | 21 |
# | `sionna_p4000000000_r120_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 120 m | 12 | 81 | 87 |
# | `sionna_p4000000000_r120_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 120 m | — | 81 | — |
# | `sionna_p4000000000_r240_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 240 m | 92 | 79 | — |
# | `sionna_p4000000000_r30_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 30 m | 12 | 80 | 90 |
# | `sionna_p4000000000_r30_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 30 m | — | 80 | — |
# | `sionna_p4000000000_r480_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 480 m | ○ | ◐ | — |
# | `sionna_p4000000000_r60_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 60 m | 12 | 84 | 84 |
# | `sionna_p4000000000_s1000plus_r120_n8192_d1` | DJI S1000+ · 148.9 Hz | 120 m | 54 | 50 | — |
# | `sionna_p4000000000_s1000plus_r30_n8192_d1` | DJI S1000+ · 148.9 Hz | 30 m | 38 | 46 | — |
# | `sionna_p4000000000_s1000plus_r60_n8192_d1` | DJI S1000+ · 148.9 Hz | 60 m | 46 | 41 | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 8.2 `ours_mini5pro_r120_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r120_n8192__map.png)
#
# **그림 196.** `ours_mini5pro_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r120_n8192__band.png)
#
# **그림 197.** `ours_mini5pro_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.8 | +47.5 | 183.8 | 1.00 | −74.42 | 3.007 |
# | −30° | 887 Hz | 83.1 | 8.7 | 33.0 | +39.7 | 183.8 | 1.00 | −77.68 | 1.754 |

# %% [markdown]
# ### 절 8.3 `ours_mini5pro_r30_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r30_n8192__map.png)
#
# **그림 198.** `ours_mini5pro_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r30_n8192__band.png)
#
# **그림 199.** `ours_mini5pro_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.8 | +47.5 | 183.8 | 1.00 | −74.43 | 2.991 |
# | −30° | 887 Hz | 83.0 | 8.7 | 32.9 | +39.7 | 183.8 | 1.00 | −77.65 | 1.799 |

# %% [markdown]
# ### 절 8.4 `ours_mini5pro_r60_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_mini5pro_r60_n8192__map.png)
#
# **그림 200.** `ours_mini5pro_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_mini5pro_r60_n8192__band.png)
#
# **그림 201.** `ours_mini5pro_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.8 | +47.5 | 183.8 | 1.00 | −74.42 | 3.002 |
# | −30° | 887 Hz | 83.0 | 8.7 | 33.0 | +39.7 | 183.8 | 1.00 | −77.67 | 1.769 |

# %% [markdown]
# ### 절 8.5 `ours_ptd_r120_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_ptd_r120_n8192__map.png)
#
# **그림 202.** `ours_ptd_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_ptd_r120_n8192__band.png)
#
# **그림 203.** `ours_ptd_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 82.8 | 12.6 | 9.2 | +43.6 | 126.1 | 0.99 | −68.82 | 58.206 |

# %% [markdown]
# ### 절 8.6 `ours_ptd_r30_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_ptd_r30_n8192__map.png)
#
# **그림 204.** `ours_ptd_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_ptd_r30_n8192__band.png)
#
# **그림 205.** `ours_ptd_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 83.0 | 12.6 | 9.8 | +43.3 | 126.1 | 0.99 | −68.95 | 55.259 |

# %% [markdown]
# ### 절 8.7 `ours_ptd_r60_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_ptd_r60_n8192__map.png)
#
# **그림 206.** `ours_ptd_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_ptd_r60_n8192__band.png)
#
# **그림 207.** `ours_ptd_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 82.9 | 12.6 | 9.4 | +43.5 | 126.1 | 0.99 | −68.86 | 57.194 |

# %% [markdown]
# ### 절 8.8 `ours_r120_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r120_n8192__map.png)
#
# **그림 208.** `ours_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r120_n8192__band.png)
#
# **그림 209.** `ours_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.8 | 12.5 | 2.6 | +48.2 | 126.1 | 0.99 | −70.42 | 2.689 |
# | −30° | 1102 Hz | 82.9 | 12.6 | 9.2 | +43.7 | 126.1 | 0.99 | −68.81 | 30.645 |
# | −60° | 636 Hz | 53.2 | 12.6 | 1.8 | +45.1 | 126.1 | 0.99 | −66.05 | 57.685 |

# %% [markdown]
# ### 절 8.9 `ours_r240_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 240 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r240_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r240_n8192__map.png)
#
# **그림 210.** `ours_r240_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r240_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r240_n8192__band.png)
#
# **그림 211.** `ours_r240_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.8 | 12.5 | 2.6 | +48.2 | 126.1 | 0.99 | −70.42 | 2.697 |
# | −30° | 1102 Hz | 82.9 | 12.6 | 9.1 | +43.7 | 126.1 | 0.99 | −68.79 | 30.834 |

# %% [markdown]
# ### 절 8.10 `ours_r30_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r30_n8192__map.png)
#
# **그림 212.** `ours_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r30_n8192__band.png)
#
# **그림 213.** `ours_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.6 | 12.5 | 2.6 | +48.0 | 126.1 | 0.99 | −70.41 | 2.636 |
# | −30° | 1102 Hz | 83.1 | 12.6 | 9.8 | +43.4 | 126.1 | 0.99 | −68.94 | 29.374 |
# | −60° | 636 Hz | 53.0 | 12.6 | 1.8 | +45.2 | 126.1 | 0.99 | −66.05 | 66.847 |

# %% [markdown]
# ### 절 8.11 `ours_r480_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 480 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r480_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r480_n8192__map.png)
#
# **그림 214.** `ours_r480_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r480_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r480_n8192__band.png)
#
# **그림 215.** `ours_r480_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.8 | 12.5 | 2.6 | +48.2 | 126.1 | 0.99 | −70.42 | 2.702 |
# | −30° | 1102 Hz | 82.9 | 12.6 | 9.1 | +43.7 | 126.1 | 0.99 | −68.78 | 30.926 |

# %% [markdown]
# ### 절 8.12 `ours_r60_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_r60_n8192__map.png)
#
# **그림 216.** `ours_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_r60_n8192__band.png)
#
# **그림 217.** `ours_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 63.7 | 12.5 | 2.6 | +48.1 | 126.1 | 0.99 | −70.41 | 2.671 |
# | −30° | 1102 Hz | 83.0 | 12.6 | 9.4 | +43.6 | 126.1 | 0.99 | −68.85 | 30.246 |
# | −60° | 636 Hz | 53.1 | 12.6 | 1.8 | +45.2 | 126.1 | 0.99 | −66.05 | 60.631 |

# %% [markdown]
# ### 절 8.13 `ours_s1000plus_r120_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 120 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r120_n8192__map.png)
#
# **그림 218.** `ours_s1000plus_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r120_n8192__band.png)
#
# **그림 219.** `ours_s1000plus_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 50.7 | 10.9 | 5.0 | +37.9 | 147.7 | 0.99 | −66.11 | 0.118 |
# | −30° | 1802 Hz | 75.3 | 10.8 | 16.1 | +33.2 | 147.7 | 0.99 | −64.25 | 3.925 |

# %% [markdown]
# ### 절 8.14 `ours_s1000plus_r30_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 30 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r30_n8192__map.png)
#
# **그림 220.** `ours_s1000plus_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r30_n8192__band.png)
#
# **그림 221.** `ours_s1000plus_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 52.3 | 10.9 | 4.9 | +38.4 | 147.7 | 0.99 | −65.96 | 0.126 |
# | −30° | 1802 Hz | 73.7 | 10.8 | 15.3 | +33.0 | 147.7 | 0.99 | −64.53 | 3.305 |

# %% [markdown]
# ### 절 8.15 `ours_s1000plus_r60_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 60 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/06range__ours_s1000plus_r60_n8192__map.png)
#
# **그림 222.** `ours_s1000plus_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/06range__ours_s1000plus_r60_n8192__band.png)
#
# **그림 223.** `ours_s1000plus_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 51.3 | 10.9 | 5.0 | +38.1 | 147.7 | 0.99 | −66.07 | 0.120 |
# | −30° | 1802 Hz | 74.8 | 10.8 | 15.8 | +33.1 | 147.7 | 0.99 | −64.32 | 3.720 |

# %% [markdown]
# ### 절 8.16 `sionna_p4000000000_mini5pro_r120_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r120_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r120_n8192_d1__map.png)
#
# **그림 224.** `sionna_p4000000000_mini5pro_r120_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r120_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r120_n8192_d1__band.png)
#
# **그림 225.** `sionna_p4000000000_mini5pro_r120_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 86.2 | 8.7 | 14.0 | +52.6 | 183.8 | 1.00 | −187.23 | 0.000 |
# | −30° | 887 Hz | 82.9 | 8.7 | 24.0 | +44.5 | 183.8 | 1.00 | −188.14 | 28.471 |

# %% [markdown]
# ### 절 8.17 `sionna_p4000000000_mini5pro_r30_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r30_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r30_n8192_d1__map.png)
#
# **그림 226.** `sionna_p4000000000_mini5pro_r30_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r30_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r30_n8192_d1__band.png)
#
# **그림 227.** `sionna_p4000000000_mini5pro_r30_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 9.2 | 8.7 | 89.8 | −0.6 | 442.6 ⚠튐 | 2.41 | −108.01 | 0.030 |
# | −30° | 887 Hz | 88.6 | 8.7 | 23.9 | +45.3 | 183.8 | 1.00 | −162.82 | 16.335 |

# %% [markdown]
# ### 절 8.18 `sionna_p4000000000_mini5pro_r60_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r60_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r60_n8192_d1__map.png)
#
# **그림 228.** `sionna_p4000000000_mini5pro_r60_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r60_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_mini5pro_r60_n8192_d1__band.png)
#
# **그림 229.** `sionna_p4000000000_mini5pro_r60_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 87.8 | 8.7 | 20.3 | +43.6 | 549.0 | 2.99 | −180.22 | 0.000 |
# | −30° | 887 Hz | 87.2 | 8.7 | 22.4 | +45.2 | 183.8 | 1.00 | −175.09 | 40.613 |

# %% [markdown]
# ### 절 8.19 `sionna_p4000000000_phys_r120_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r120_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r120_n8192_d1__map.png)
#
# **그림 230.** `sionna_p4000000000_phys_r120_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r120_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r120_n8192_d1__band.png)
#
# **그림 231.** `sionna_p4000000000_phys_r120_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 87.0 | +0.3 | 380.7 ⚠튐 | 3.01 | −166.22 | 0.000 |
# | −30° | 1102 Hz | 13.5 | 12.6 | 82.8 | +4.7 | 126.1 ⚠튐 | 0.99 | −171.15 | 0.007 |
# | −60° | 636 Hz | 61.8 | 12.6 | 70.3 | +23.7 | 126.1 | 0.99 | −174.20 | 0.008 |

# %% [markdown]
# ### 절 8.20 `sionna_p4000000000_phys_r30_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r30_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r30_n8192_d1__map.png)
#
# **그림 232.** `sionna_p4000000000_phys_r30_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r30_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r30_n8192_d1__band.png)
#
# **그림 233.** `sionna_p4000000000_phys_r30_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 87.4 | +0.0 | 55.8 ⚠튐 | 0.44 | −108.19 | 0.010 |
# | −30° | 1102 Hz | 14.0 | 12.6 | 84.1 | +7.8 | 380.7 ⚠튐 | 3.01 | −145.07 | 0.029 |
# | −60° | 636 Hz | 17.3 | 12.6 | 86.2 | +8.3 | 126.1 | 0.99 | −141.04 | 0.130 |

# %% [markdown]
# ### 절 8.21 `sionna_p4000000000_phys_r60_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_r60_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r60_n8192_d1__map.png)
#
# **그림 234.** `sionna_p4000000000_phys_r60_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_r60_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_phys_r60_n8192_d1__band.png)
#
# **그림 235.** `sionna_p4000000000_phys_r60_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 87.1 | +0.1 | 21.8 ⚠튐 | 0.17 | −123.04 | 0.001 |
# | −30° | 1102 Hz | 14.9 | 12.6 | 85.0 | +6.7 | 252.2 ⚠튐 | 1.99 | −157.65 | 0.033 |
# | −60° | 636 Hz | 21.3 | 12.6 | 90.5 | +8.0 | 126.1 ⚠튐 | 0.99 | −156.98 | 0.022 |

# %% [markdown]
# ### 절 8.22 `sionna_p4000000000_r120_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_d1__map.png)
#
# **그림 236.** `sionna_p4000000000_r120_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_d1__band.png)
#
# **그림 237.** `sionna_p4000000000_r120_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.1 | −0.0 | 46.1 ⚠튐 | 0.36 | −125.29 | 0.004 |
# | −30° | 1102 Hz | 81.3 | 12.6 | 10.9 | +40.5 | 126.1 | 0.99 | −180.62 | 13.973 |
# | −60° | 636 Hz | 87.2 | 12.6 | 16.8 | +39.9 | 126.1 | 0.99 | −173.11 | 76.135 |

# %% [markdown]
# ### 절 8.23 `sionna_p4000000000_r120_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_d3__map.png)
#
# **그림 238.** `sionna_p4000000000_r120_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r120_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r120_n8192_d3__band.png)
#
# **그림 239.** `sionna_p4000000000_r120_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 81.4 | 12.6 | 10.8 | +40.4 | 126.1 | 0.99 | −180.36 | 13.421 |

# %% [markdown]
# ### 절 8.24 `sionna_p4000000000_r240_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 240 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r240_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r240_n8192_d1__map.png)
#
# **그림 240.** `sionna_p4000000000_r240_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r240_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r240_n8192_d1__band.png)
#
# **그림 241.** `sionna_p4000000000_r240_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 92.1 | 12.5 | 6.7 | +54.0 | 506.8 | 4.00 | −193.59 | 0.000 |
# | −30° | 1102 Hz | 78.7 | 12.6 | 7.5 | +42.3 | 126.1 | 0.99 | −192.11 | 37.535 |

# %% [markdown]
# ### 절 8.25 `sionna_p4000000000_r30_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_d1__map.png)
#
# **그림 242.** `sionna_p4000000000_r30_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_d1__band.png)
#
# **그림 243.** `sionna_p4000000000_r30_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 84.7 | −1.3 | 143.1 ⚠튐 | 1.13 | −104.37 | 0.031 |
# | −30° | 1102 Hz | 80.5 | 12.6 | 3.1 | +46.8 | 126.1 | 0.99 | −151.91 | 26.775 |
# | −60° | 636 Hz | 89.7 | 12.6 | 13.7 | +43.2 | 126.1 | 0.99 | −146.86 | 12.765 |

# %% [markdown]
# ### 절 8.26 `sionna_p4000000000_r30_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_d3__map.png)
#
# **그림 244.** `sionna_p4000000000_r30_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r30_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r30_n8192_d3__band.png)
#
# **그림 245.** `sionna_p4000000000_r30_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 80.1 | 12.6 | 3.6 | +46.4 | 126.1 | 0.99 | −152.30 | 23.558 |

# %% [markdown]
# ### 절 8.27 `sionna_p4000000000_r480_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 480 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r480_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r480_n8192_d1__map.png)
#
# **그림 246.** `sionna_p4000000000_r480_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r480_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r480_n8192_d1__band.png)
#
# **그림 247.** `sionna_p4000000000_r480_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | ○ 안 움직임 | — | — | — | — | — | — | — |
# | −30° | 1102 Hz | ◐ 덜 참(2,905/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 8.28 `sionna_p4000000000_r60_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_r60_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_r60_n8192_d1__map.png)
#
# **그림 248.** `sionna_p4000000000_r60_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_r60_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_r60_n8192_d1__band.png)
#
# **그림 249.** `sionna_p4000000000_r60_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 87.0 | +0.2 | 38.8 ⚠튐 | 0.31 | −115.00 | 0.011 |
# | −30° | 1102 Hz | 84.1 | 12.6 | 9.4 | +41.2 | 126.1 | 0.99 | −167.89 | 75.109 |
# | −60° | 636 Hz | 83.8 | 12.6 | 18.2 | +43.0 | 126.1 | 0.99 | −162.20 | 41.385 |

# %% [markdown]
# ### 절 8.29 `sionna_p4000000000_s1000plus_r120_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r120_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r120_n8192_d1__map.png)
#
# **그림 250.** `sionna_p4000000000_s1000plus_r120_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r120_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r120_n8192_d1__band.png)
#
# **그림 251.** `sionna_p4000000000_s1000plus_r120_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 54.2 | 10.9 | 43.8 | +25.4 | 746.0 | 5.01 | −183.36 | 0.057 |
# | −30° | 1802 Hz | 49.6 | 10.8 | 32.9 | +23.1 | 150.2 | 1.01 | −177.98 | 0.594 |

# %% [markdown]
# ### 절 8.30 `sionna_p4000000000_s1000plus_r30_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r30_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r30_n8192_d1__map.png)
#
# **그림 252.** `sionna_p4000000000_s1000plus_r30_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r30_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r30_n8192_d1__band.png)
#
# **그림 253.** `sionna_p4000000000_s1000plus_r30_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 37.6 | 10.9 | 33.3 | +29.5 | 743.5 | 4.99 | −156.02 | 0.009 |
# | −30° | 1802 Hz | 45.6 | 10.8 | 5.1 | +36.2 | 147.7 | 0.99 | −149.83 | 0.936 |

# %% [markdown]
# ### 절 8.31 `sionna_p4000000000_s1000plus_r60_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r60_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r60_n8192_d1__map.png)
#
# **그림 254.** `sionna_p4000000000_s1000plus_r60_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r60_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/06range__sionna_p4000000000_s1000plus_r60_n8192_d1__band.png)
#
# **그림 255.** `sionna_p4000000000_s1000plus_r60_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 46.4 | 10.9 | 41.9 | +29.9 | 595.8 | 4.00 | −169.66 | 0.018 |
# | −30° | 1802 Hz | 41.3 | 10.8 | 18.6 | +32.9 | 147.7 | 0.99 | −165.46 | 0.281 |

# %% [markdown]
# ---
#
# ## 절 9. PTD — 모서리 보정을 켠 판
#
# > **묻는 것** — 우리 팔의 모서리 회절(PTD 프린지)을 켜면 무늬가 달라지나.
#
# 팔 4 개 · 칸 10 개 · 그림 10 장. 그림 파일은 전부 `outputs/figures/atlas/07ptd__…` 로 시작한다.

# %% [markdown]
# ![PTD edges — 07ptd__000-overview-rhythm.png](../outputs/figures/atlas/07ptd__000-overview-rhythm.png)
#
# **그림 256.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![PTD edges — 07ptd__01-compare-tile-30-p1.png](../outputs/figures/atlas/07ptd__01-compare-tile-30-p1.png)
#
# **그림 257.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ### 절 9.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −15° | −30° | −45° | −60° | −75° | −90° |
# |---|---|---|---|---|---|---|---|---|---|
# | `ours_ptd_mini5pro_r15_n8192` | DJI Mini 5 Pro · 183.333 Hz | 15 m | — | — | 83 | — | — | — | — |
# | `ours_ptd_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 63 | 73 | 83 | 50 | 53 | 46 | 65\* |
# | `ours_ptd_r15_n8192_div24` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | 62 | — | — | — | — |
# | `ours_ptd_s1000plus_r15_n8192` | DJI S1000+ · 148.9 Hz | 15 m | — | — | 70 | — | — | — | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 9.2 `ours_ptd_mini5pro_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_ptd_mini5pro_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/07ptd__ours_ptd_mini5pro_r15_n8192__map.png)
#
# **그림 258.** `ours_ptd_mini5pro_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_mini5pro_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/07ptd__ours_ptd_mini5pro_r15_n8192__band.png)
#
# **그림 259.** `ours_ptd_mini5pro_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 83.0 | 8.7 | 32.7 | +39.8 | 183.8 | 1.00 | −77.61 | 2.054 |

# %% [markdown]
# ### 절 9.3 `ours_ptd_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/07ptd__ours_ptd_r15_n8192__map.png)
#
# **그림 260.** `ours_ptd_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/07ptd__ours_ptd_r15_n8192__band.png)
#
# **그림 261.** `ours_ptd_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 62.9 | 12.5 | 2.7 | +48.0 | 126.1 | 0.99 | −70.38 | 2.487 |
# | −15° | 1230 Hz | 72.7 | 12.6 | 17.2 | +40.5 | 126.1 | 0.99 | −71.06 | 1.322 |
# | −30° | 1102 Hz | 83.2 | 12.6 | 10.7 | +42.9 | 126.1 | 0.99 | −69.12 | 51.752 |
# | −45° | 900 Hz | 49.7 | 12.5 | 1.8 | +47.1 | 126.1 | 0.99 | −67.19 | 34.578 |
# | −60° | 636 Hz | 52.8 | 12.6 | 1.8 | +45.4 | 254.6 | 2.01 | −66.04 | 51.424 |
# | −75° | 330 Hz | 46.3 | 12.6 | 0.2 | — | 126.1 | 0.99 | −57.71 | 11.916 |
# | −90°\* | 0 Hz | 64.9 | 12.6 | 100.0 | — | 126.1 | 0.99 | −81.56 | 0.009 |

# %% [markdown]
# ### 절 9.4 `ours_ptd_r15_n8192_div24`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/24 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_ptd_r15_n8192_div24 micro-Doppler maps](../outputs/figures/atlas/07ptd__ours_ptd_r15_n8192_div24__map.png)
#
# **그림 262.** `ours_ptd_r15_n8192_div24` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_r15_n8192_div24 blade-band rhythm spectrum](../outputs/figures/atlas/07ptd__ours_ptd_r15_n8192_div24__band.png)
#
# **그림 263.** `ours_ptd_r15_n8192_div24` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 61.6 | 12.6 | 1.4 | +47.5 | 126.1 | 0.99 | −69.50 | 15.626 |

# %% [markdown]
# ### 절 9.5 `ours_ptd_s1000plus_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 모서리 회절(PTD 프린지) **켬** · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_ptd_s1000plus_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/07ptd__ours_ptd_s1000plus_r15_n8192__map.png)
#
# **그림 264.** `ours_ptd_s1000plus_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_ptd_s1000plus_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/07ptd__ours_ptd_s1000plus_r15_n8192__band.png)
#
# **그림 265.** `ours_ptd_s1000plus_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 70.4 | 10.8 | 14.1 | +32.4 | 147.7 | 0.99 | −65.22 | 3.478 |

# %% [markdown]
# ---
#
# ## 절 10. 격자 — λ/12 대신 더 촘촘한 격자
#
# > **묻는 것** — 표면 격자를 λ/12 에서 λ/24 로 조이면 잣대가 얼마나 움직이나 — **판정 문턱을 정하는 판**이다.
#
# 팔 2 개 · 칸 8 개 · 그림 6 장. 그림 파일은 전부 `outputs/figures/atlas/08grid__…` 로 시작한다.

# %% [markdown]
# ![grid — 08grid__000-overview-rhythm.png](../outputs/figures/atlas/08grid__000-overview-rhythm.png)
#
# **그림 266.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![grid — 08grid__02-compare-stack-p1.png](../outputs/figures/atlas/08grid__02-compare-stack-p1.png)
#
# **그림 267.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 10.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −15° | −30° | −45° | −60° | −75° | −90° |
# |---|---|---|---|---|---|---|---|---|---|
# | `ours_r15_n8192_div24` | DJI Matrice 4E · 126.667 Hz | 15 m | 52 | 73 | 62 | 37 | 69 | 44 | 81\* |
# | `ours_r15_n8192_div48` | DJI Matrice 4E · 126.667 Hz | 15 m | — | 55 | — | — | — | — | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 10.2 `ours_r15_n8192_div24`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/24 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_div24 micro-Doppler maps](../outputs/figures/atlas/08grid__ours_r15_n8192_div24__map.png)
#
# **그림 268.** `ours_r15_n8192_div24` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_div24 blade-band rhythm spectrum](../outputs/figures/atlas/08grid__ours_r15_n8192_div24__band.png)
#
# **그림 269.** `ours_r15_n8192_div24` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 51.5 | 12.5 | 1.5 | +47.7 | 126.1 | 0.99 | −74.26 | 4.722 |
# | −15° | 1230 Hz | 72.8 | 12.6 | 4.6 | +44.6 | 126.1 | 0.99 | −72.36 | 0.535 |
# | −30° | 1102 Hz | 61.5 | 12.6 | 1.4 | +47.5 | 126.1 | 0.99 | −69.48 | 36.370 |
# | −45° | 900 Hz | 36.8 | 12.5 | 0.3 | +51.7 | 126.1 | 0.99 | −67.10 | 8.823 |
# | −60° | 636 Hz | 68.8 | 12.6 | 0.5 | +49.4 | 126.1 | 0.99 | −66.06 | 44.660 |
# | −75° | 330 Hz | 43.8 | 12.6 | 0.0 | — | 126.1 | 0.99 | −57.81 | 8.991 |
# | −90°\* | 0 Hz | 81.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −87.18 | 0.002 |

# %% [markdown]
# ### 절 10.3 `ours_r15_n8192_div48`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/48 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_div48 micro-Doppler maps](../outputs/figures/atlas/08grid__ours_r15_n8192_div48__map.png)
#
# **그림 270.** `ours_r15_n8192_div48` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_div48 blade-band rhythm spectrum](../outputs/figures/atlas/08grid__ours_r15_n8192_div48__band.png)
#
# **그림 271.** `ours_r15_n8192_div48` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | 55.0 | 12.6 | 0.7 | +50.2 | 126.1 | 0.99 | −72.48 | 0.522 |

# %% [markdown]
# ---
#
# ## 절 11. 평면파 — 구면파 대신 평면파로 조명한 판
#
# > **묻는 것** — 직하방의 잔여가 근접장 **곡률** 탓인가 — 평면파로 바꾸면 사라지나.
#
# 팔 1 개 · 칸 1 개 · 그림 2 장. 그림 파일은 전부 `outputs/figures/atlas/09planewave__…` 로 시작한다.

# %% [markdown]
# ### 절 11.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | −90° |
# |---|---|---|---|
# | `ours_r15_n8192_pw` | DJI Matrice 4E · 126.667 Hz | 15 m | 59\* |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 11.2 `ours_r15_n8192_pw`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 조명: **평면파**(구면파 아님) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![ours_r15_n8192_pw micro-Doppler maps](../outputs/figures/atlas/09planewave__ours_r15_n8192_pw__map.png)
#
# **그림 272.** `ours_r15_n8192_pw` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_r15_n8192_pw blade-band rhythm spectrum](../outputs/figures/atlas/09planewave__ours_r15_n8192_pw__band.png)
#
# **그림 273.** `ours_r15_n8192_pw` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −90°\* | 0 Hz | 58.6 | 12.6 | 100.0 | — | 126.1 | 0.99 | −82.21 | 0.007 |

# %% [markdown]
# ---
#
# ## 절 12. 팔 이름 읽는 법
#
# 팔 이름은 «무엇을 바꾼 판인가» 를 밑줄로 이어 붙인 것이다. 그림 파일 이름이 `<주제번호><주제>__<팔 이름>__map.png` 라서, **이 표만 있으면 파일 이름만 보고 그 판이 무엇인지 안다**.
#
# ⭐읽는 요령은 **없는 토막이 곧 기본값**이라는 것이다 — `_r15` 가 없으면 15 m 가 아니라 옛 기본 10 m 이고, `_n8192` 가 없으면 자세가 4,096 이다. 그래서 아래 표에는 «토막이 없으면 무엇인가» 칸을 함께 뒀다.
#
# | 토막 | 뜻 | 토막이 없으면 | 이 토막을 단 팔 |
# |---|---|---|---|
# | `ours` | 우리 커널(SBR+PO) — 동체를 넣어 **가림이 있는** 판 | — | 37 |
# | `ours_free` | 우리 커널이되 **동체 «면» 만 빼서** 가림을 없앤 대조군 (꼭짓점 · bbox · 광선 격자는 그대로라 «동체가 막느냐» 하나만 갈린다) | — | 1 |
# | `sionna` | Sionna RT 의 `PathSolver` 팔 | — | 84 |
# | `p<N>` | 광선 수(`--spp`). `p4000000000` = 40 억 발 | 규칙값 (R/3)²×1M | 82 |
# | `phys` | PathSolver 물리를 **전부 켠다** — 굴절 · 회절 · 모서리 회절 | 셋 다 끔 | 12 |
# | `swR#D#E#F#` | 스위치를 **비트로 직접** 준 판. `R` 굴절 · `D` 회절 · `E` 모서리 회절 · `F` 확산 반사, `1` 이 켬. 예 `swR1D0E0F1` = 굴절 + 확산 반사. ⚠소스 실측으로 `E` 는 `D=1` 일 때만 뜻이 있다. ⭐**이 네 비트에 정반사·직선경로(LOS)는 없다** — 생성기가 `los=True, specular_reflection=True` 를 하드코딩하므로 둘은 54 팔 전부에서 **항상 켜져 있다**. 그러니 `swR0D0E0F0` 도 «전부 끔» 이 아니다 | — | 20 |
# | `stockdef` | PathSolver 를 **순정 기본값 그대로** — 굴절 켬 · 회절 끔 · 모서리 끔 · 깊이 3 · 확산 끔. 우리 «끔» 판과도 «켬» 판과도 다른 제3 의 조합 | — | 1 |
# | `only<x>` | 스위치를 **하나만** 켠 판 — `onlyrefr` 굴절 · `onlydiffr` 회절 · `onlyedge` 모서리 회절 · `onlydepth3` 깊이 3. `phys` 는 넷을 한꺼번에 켜서 무엇이 무엇을 했는지 귀속이 안 된다 | — | 17 |
# | `d<N>` | PathSolver 반사 깊이(`--max-depth`). 물리 스위치와 깊이를 **가르는** 축 | 옛 규칙(물리 켜면 3, 아니면 1) | 60 |
# | `parts<…>` | 장면에 넣을 부품 그룹. `partsprop` = 프로펠러만 · `partsnoprop` = 프로펠러를 뺀 나머지(0° 붕괴가 «기근이냐 익사냐») | 기체 전체 | 5 |
# | 기체 태그 | 표적 기체를 바꾼 판 — `mini5pro` · `s1000plus`. ⚠**박자와 날개끝 상한이 함께 바뀐다** | 원장 기본 `matrice4e` | 28 |
# | `az<N>` | 방위각[°]. `az45` = 45° 옆에서 본 판 | 원장 기본 0° | 17 |
# | `r<N>` | 구면 반경[m]. `r15` = 15 m · `r30` = 30 m | 옛 기본 10 m(원거리장 경계 안쪽) | 114 |
# | `n<N>` | 슬로타임 자세 수. `n8192` = 8,192 자세(박자 FFT 분해능 = PRF/N) | 원장 기본 4,096 | 115 |
# | `div<N>` | 우리 커널 표면 격자 간격 λ/N. `div24` = λ/24 (PathSolver 에 없는 축) | 규약값 λ/12 | 3 |
# | `ptd` | 우리 팔의 **모서리 회절(PTD 프린지)** 켬 | 끔 | 8 |
# | `pw` | **평면파** 조명(구면파 대신 · 무한 거리 등가) | 구면파 | 1 |
#
# **읽어 보기**
#
# | 팔 이름 | 읽으면 |
# |---|---|
# | `sionna_p4000000000_phys_r15_n8192_d1` | PathSolver · 광선 40 억 · 물리 전부 켬 · 15 m · 자세 8,192 · 반사 깊이 1 |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` | PathSolver · 광선 40 억 · 굴절 + 확산 반사만 · **표적이 Mini 5 Pro**(박자 183.33 Hz) · 15 m · 자세 8,192 · 깊이 1 |
# | `ours_free_r15_n8192` | 우리 커널이되 **동체 면을 뺀** 대조군 · 15 m · 자세 8,192 |
# | `ours` | 우리 커널 · 토막이 하나도 없으니 **전부 기본값** — 10 m · 자세 4,096 · 격자 λ/12 |
#
# **팔 → 주제 찾아보기**
#
# | 팔 | 주제 | 그림 파일 앞머리 |
# |---|---|---|
# | `ours` | 기본 엔진 | `01base__ours__` |
# | `ours_free_r15_n8192` | 기본 엔진 | `01base__ours_free_r15_n8192__` |
# | `ours_mini5pro_r120_n8192` | 거리 | `06range__ours_mini5pro_r120_n8192__` |
# | `ours_mini5pro_r15_n8192` | 기체 3 종 | `03airframe__ours_mini5pro_r15_n8192__` |
# | `ours_mini5pro_r15_n8192_az22.5` | 방위 | `04azimuth__ours_mini5pro_r15_n8192_az22.5__` |
# | `ours_mini5pro_r30_n8192` | 거리 | `06range__ours_mini5pro_r30_n8192__` |
# | `ours_mini5pro_r60_n8192` | 거리 | `06range__ours_mini5pro_r60_n8192__` |
# | `ours_ptd_mini5pro_r15_n8192` | PTD | `07ptd__ours_ptd_mini5pro_r15_n8192__` |
# | `ours_ptd_r120_n8192` | 거리 | `06range__ours_ptd_r120_n8192__` |
# | `ours_ptd_r15_n8192` | PTD | `07ptd__ours_ptd_r15_n8192__` |
# | `ours_ptd_r15_n8192_az22.5` | 방위 | `04azimuth__ours_ptd_r15_n8192_az22.5__` |
# | `ours_ptd_r15_n8192_div24` | PTD | `07ptd__ours_ptd_r15_n8192_div24__` |
# | `ours_ptd_r30_n8192` | 거리 | `06range__ours_ptd_r30_n8192__` |
# | `ours_ptd_r60_n8192` | 거리 | `06range__ours_ptd_r60_n8192__` |
# | `ours_ptd_s1000plus_r15_n8192` | PTD | `07ptd__ours_ptd_s1000plus_r15_n8192__` |
# | `ours_r120_n8192` | 거리 | `06range__ours_r120_n8192__` |
# | `ours_r15_n32768` | 기본 엔진 | `01base__ours_r15_n32768__` |
# | `ours_r15_n8192` | 기본 엔진 | `01base__ours_r15_n8192__` |
# | `ours_r15_n8192_az15` | 방위 | `04azimuth__ours_r15_n8192_az15__` |
# | `ours_r15_n8192_az22.5` | 방위 | `04azimuth__ours_r15_n8192_az22.5__` |
# | `ours_r15_n8192_az30` | 방위 | `04azimuth__ours_r15_n8192_az30__` |
# | `ours_r15_n8192_az45` | 방위 | `04azimuth__ours_r15_n8192_az45__` |
# | `ours_r15_n8192_az60` | 방위 | `04azimuth__ours_r15_n8192_az60__` |
# | `ours_r15_n8192_az67.5` | 방위 | `04azimuth__ours_r15_n8192_az67.5__` |
# | `ours_r15_n8192_az75` | 방위 | `04azimuth__ours_r15_n8192_az75__` |
# | `ours_r15_n8192_az90` | 방위 | `04azimuth__ours_r15_n8192_az90__` |
# | `ours_r15_n8192_div24` | 격자 | `08grid__ours_r15_n8192_div24__` |
# | `ours_r15_n8192_div48` | 격자 | `08grid__ours_r15_n8192_div48__` |
# | `ours_r15_n8192_pw` | 평면파 | `09planewave__ours_r15_n8192_pw__` |
# | `ours_r240_n8192` | 거리 | `06range__ours_r240_n8192__` |
# | `ours_r30_n8192` | 거리 | `06range__ours_r30_n8192__` |
# | `ours_r480_n8192` | 거리 | `06range__ours_r480_n8192__` |
# | `ours_r60_n8192` | 거리 | `06range__ours_r60_n8192__` |
# | `ours_s1000plus_r120_n8192` | 거리 | `06range__ours_s1000plus_r120_n8192__` |
# | `ours_s1000plus_r15_n8192` | 기체 3 종 | `03airframe__ours_s1000plus_r15_n8192__` |
# | `ours_s1000plus_r15_n8192_az22.5` | 방위 | `04azimuth__ours_s1000plus_r15_n8192_az22.5__` |
# | `ours_s1000plus_r30_n8192` | 거리 | `06range__ours_s1000plus_r30_n8192__` |
# | `ours_s1000plus_r60_n8192` | 거리 | `06range__ours_s1000plus_r60_n8192__` |
# | `sionna` | 기본 엔진 | `01base__sionna__` |
# | `sionna_p1000000000` | 기본 엔진 | `01base__sionna_p1000000000__` |
# | `sionna_p250000000` | 기본 엔진 | `01base__sionna_p250000000__` |
# | `sionna_p250000000_phys` | 기본 엔진 | `01base__sionna_p250000000_phys__` |
# | `sionna_p4000000000` | 기본 엔진 | `01base__sionna_p4000000000__` |
# | `sionna_p4000000000_mini5pro_r120_n8192_d1` | 거리 | `06range__sionna_p4000000000_mini5pro_r120_n8192_d1__` |
# | `sionna_p4000000000_mini5pro_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_mini5pro_r15_n8192_d1__` |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1__` |
# | `sionna_p4000000000_mini5pro_r30_n8192_d1` | 거리 | `06range__sionna_p4000000000_mini5pro_r30_n8192_d1__` |
# | `sionna_p4000000000_mini5pro_r60_n8192_d1` | 거리 | `06range__sionna_p4000000000_mini5pro_r60_n8192_d1__` |
# | `sionna_p4000000000_onlydepth3_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlydepth3_r15_n8192__` |
# | `sionna_p4000000000_onlydiffr_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlydiffr_r15_n8192__` |
# | `sionna_p4000000000_onlyedge_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyedge_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_partsprop_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_r120_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r120_n8192__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm__` |
# | `sionna_p4000000000_onlyrefr_r240_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r240_n8192__` |
# | `sionna_p4000000000_onlyrefr_r30_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r30_n8192__` |
# | `sionna_p4000000000_onlyrefr_r60_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r60_n8192__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192__` |
# | `sionna_p4000000000_partsnoprop_r15_n8192_d1` | 부품 분해 | `05parts__sionna_p4000000000_partsnoprop_r15_n8192_d1__` |
# | `sionna_p4000000000_partsprop_r15_n8192_d1` | 부품 분해 | `05parts__sionna_p4000000000_partsprop_r15_n8192_d1__` |
# | `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_phys_mini5pro_r15_n8192_d1__` |
# | `sionna_p4000000000_phys_n8192_d1` | 기본 엔진 | `01base__sionna_p4000000000_phys_n8192_d1__` |
# | `sionna_p4000000000_phys_partsprop_r15_n8192_d1` | 부품 분해 | `05parts__sionna_p4000000000_phys_partsprop_r15_n8192_d1__` |
# | `sionna_p4000000000_phys_r120_n8192_d1` | 거리 | `06range__sionna_p4000000000_phys_r120_n8192_d1__` |
# | `sionna_p4000000000_phys_r15_n8192_az45_d1` | 방위 | `04azimuth__sionna_p4000000000_phys_r15_n8192_az45_d1__` |
# | `sionna_p4000000000_phys_r15_n8192_d1` | 기본 엔진 | `01base__sionna_p4000000000_phys_r15_n8192_d1__` |
# | `sionna_p4000000000_phys_r15_n8192_d2` | 기본 엔진 | `01base__sionna_p4000000000_phys_r15_n8192_d2__` |
# | `sionna_p4000000000_phys_r30_n8192_d1` | 거리 | `06range__sionna_p4000000000_phys_r30_n8192_d1__` |
# | `sionna_p4000000000_phys_r60_n8192_d1` | 거리 | `06range__sionna_p4000000000_phys_r60_n8192_d1__` |
# | `sionna_p4000000000_phys_s1000plus_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_phys_s1000plus_r15_n8192_d1__` |
# | `sionna_p4000000000_r120_n8192_d1` | 거리 | `06range__sionna_p4000000000_r120_n8192_d1__` |
# | `sionna_p4000000000_r120_n8192_d3` | 거리 | `06range__sionna_p4000000000_r120_n8192_d3__` |
# | `sionna_p4000000000_r15_n32768_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n32768_d1__` |
# | `sionna_p4000000000_r15_n8192_az22.5_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az22.5_d1__` |
# | `sionna_p4000000000_r15_n8192_az45_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az45_d1__` |
# | `sionna_p4000000000_r15_n8192_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.5mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.5mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell1.5mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell1.5mm_d1__` |
# | `sionna_p4000000000_r240_n8192_d1` | 거리 | `06range__sionna_p4000000000_r240_n8192_d1__` |
# | `sionna_p4000000000_r30_n8192_d1` | 거리 | `06range__sionna_p4000000000_r30_n8192_d1__` |
# | `sionna_p4000000000_r30_n8192_d3` | 거리 | `06range__sionna_p4000000000_r30_n8192_d3__` |
# | `sionna_p4000000000_r480_n8192_d1` | 거리 | `06range__sionna_p4000000000_r480_n8192_d1__` |
# | `sionna_p4000000000_r60_n8192_d1` | 거리 | `06range__sionna_p4000000000_r60_n8192_d1__` |
# | `sionna_p4000000000_s1000plus_r120_n8192_d1` | 거리 | `06range__sionna_p4000000000_s1000plus_r120_n8192_d1__` |
# | `sionna_p4000000000_s1000plus_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_s1000plus_r15_n8192_d1__` |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1__` |
# | `sionna_p4000000000_s1000plus_r30_n8192_d1` | 거리 | `06range__sionna_p4000000000_s1000plus_r30_n8192_d1__` |
# | `sionna_p4000000000_s1000plus_r60_n8192_d1` | 거리 | `06range__sionna_p4000000000_s1000plus_r60_n8192_d1__` |
# | `sionna_p4000000000_stockdef_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_stockdef_r15_n8192__` |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D1E0F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d1__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_d3__` |
# | `sionna_phys` | 기본 엔진 | `01base__sionna_phys__` |

# %% [markdown]
# ---
#
# ## 절 13. ⚠읽을 때 주의
#
# ### 13.1 앙각 −90° 는 잣대가 퇴화한다
#
# 직하방에서는 날개가 도는 면이 시선과 **수직**이라 날개끝 상한 f_tip 이 0 Hz 다(f_tip ∝ cos el). 상한이 0 이면 «상한 **위**» 가 전 대역이 되어, 리듬 몫이 «날개가 만들 수 없는 자리에 무엇이 남았나» 를 재는 잣대이기를 그만둔다 — 그냥 전 대역의 빗살 정도를 재는 수가 된다. 그림에서는 그 칸 제목에 `*` 가 붙고 각주가 달린다. 표에서도 `*` 다. 이 원장에서 그런 칸은 **32 개**다.
#
# 대역 에너지 그림도 마찬가지다 — −90° 는 날개 대역 자체가 정의되지 않아 **0° 의 대역을 빌려** 그린다. 참값이 «선 없음» 인 자리라서, 거기서 빗살이 서면 그것이 곧 인공물이라는 뜻이다. 범례에 «band borrowed from 0°» 로 적혀 있다.
#
# ### 13.2 ⛔팔 사이의 **절대 세기**를 비교하지 마라
#
# 우리 커널과 PathSolver 는 **눈금이 다르다** — 같은 표적을 같은 자리에서 재도 «전력 −70 dB» 와 «−94 dB» 는 세기의 비교가 아니다. 광선 예산 · 격자 · 정규화가 엔진마다 다르게 들어간 수라, 두 팔의 dB 를 빼는 순간 그 차이는 물리가 아니라 구현의 차이가 된다.
#
# **그래서 이 아틀라스는 «모양» 과 «구조» 로만 말한다** — 맵은 패널마다 자기 최댓값으로 정규화하고, 팔을 가로지르는 비교는 리듬 몫[%] · 박자[Hz] · 박자 ÷ 예측 처럼 **눈금에 무관한 수**로만 한다. 같은 팔 안에서 앙각끼리 dB 를 비교하는 것은 된다(같은 눈금이다).
#
# ### 13.3 격자 흔들림 밴드 안이면 판정 불가
#
# 표면 격자를 λ/12 에서 λ/24 로 조이기만 해도 잣대가 움직인다. 그 폭이 **리듬 몫 21.8 %p · 움직이는 전력 3.86 dB** 다(`outputs/grid_convergence_check.json`, 앙각 네 점에서 잰 최대값).
#
# ⭐그러므로 **두 팔의 차이가 리듬 몫 21.8 %p 안이면 «차이가 있다» 고 말할 수 없다.** 예를 들어 58 과 63 의 차이는 판정 불가이고, 83 과 13 의 차이는 밴드 밖이라 살아 있다. 이 표의 수를 어디에 인용하든 «λ/12 한정» 을 함께 적는다.
#
# ### 13.4 한 원장에 **거리가 다른 팔**이 섞여 있다
#
# 이 원장의 기준 거리는 15 m 인데, 팔 80 개만 거기에 있다. `_r` 토막이 없는 팔 8 개는 옛 기본 **10 m** 에서 잰 것이고 — 원거리장 경계 2D²/λ ≈ 14.08 m 의 **안쪽**(근접장)이다 — `_r30` 팔 10 개는 30 m 다. **거리가 다른 팔을 나란히 놓을 때는 그 사실을 반드시 적는다.** 주제별 요약 표에 거리 열을 둔 이유다.
#
# | 거리 | 팔 수 | 어느 팔인가 |
# |---|---|---|
# | **10 m** | 8 | `ours` · `sionna` · `sionna_p1000000000` · `sionna_p250000000` · `sionna_p250000000_phys` · `sionna_p4000000000` · `sionna_p4000000000_phys_n8192_d1` · `sionna_phys` |
# | **15 m** | 80 | 기준 거리 — 나머지 팔 전부 |
# | **30 m** | 10 | `ours_mini5pro_r30_n8192` · `ours_ptd_r30_n8192` · `ours_r30_n8192` · `ours_s1000plus_r30_n8192` · `sionna_p4000000000_mini5pro_r30_n8192_d1` · `sionna_p4000000000_onlyrefr_r30_n8192` · `sionna_p4000000000_phys_r30_n8192_d1` · `sionna_p4000000000_r30_n8192_d1` · `sionna_p4000000000_r30_n8192_d3` · `sionna_p4000000000_s1000plus_r30_n8192_d1` |
# | **60 m** | 9 | `ours_mini5pro_r60_n8192` · `ours_ptd_r60_n8192` · `ours_r60_n8192` · `ours_s1000plus_r60_n8192` · `sionna_p4000000000_mini5pro_r60_n8192_d1` · `sionna_p4000000000_onlyrefr_r60_n8192` · `sionna_p4000000000_phys_r60_n8192_d1` · `sionna_p4000000000_r60_n8192_d1` · `sionna_p4000000000_s1000plus_r60_n8192_d1` |
# | **120 m** | 10 | `ours_mini5pro_r120_n8192` · `ours_ptd_r120_n8192` · `ours_r120_n8192` · `ours_s1000plus_r120_n8192` · `sionna_p4000000000_mini5pro_r120_n8192_d1` · `sionna_p4000000000_onlyrefr_r120_n8192` · `sionna_p4000000000_phys_r120_n8192_d1` · `sionna_p4000000000_r120_n8192_d1` · `sionna_p4000000000_r120_n8192_d3` · `sionna_p4000000000_s1000plus_r120_n8192_d1` |
# | **240 m** | 3 | `ours_r240_n8192` · `sionna_p4000000000_onlyrefr_r240_n8192` · `sionna_p4000000000_r240_n8192_d1` |
# | **480 m** | 2 | `ours_r480_n8192` · `sionna_p4000000000_r480_n8192_d1` |
#
# ### 13.5 ⭐**근접장은 기체마다 다른 자리에서 시작한다**
#
# 원거리장 경계는 2D²/λ 다 — D 가 표적 크기라, **기체가 커지면 경계가 멀어진다.** 기본 기체(matrice4e) 기준의 14.08 m 하나를 모든 팔에 대면 틀린다. 기체별로 다시 계산하면 이렇다(원장과 같은 규약 — 메쉬 3D 대각).
#
# | 기체 | 표적 크기 D | 원거리장 경계 2D²/λ | 이 원장의 팔이 선 거리 | 판정 |
# |---|---|---|---|---|
# | DJI Matrice 4E | 0.78 m | **14.08 m** | 10 m · 15 m · 30 m · 60 m · 120 m · 240 m · 480 m | ⚠10 m 는 **안쪽**(근접장, 경계의 0.71 배) |
# | DJI Mini 5 Pro | 0.45 m | **4.79 m** | 15 m · 30 m · 60 m · 120 m | 전부 밖(원거리장) |
# | DJI S1000+ | 1.92 m | **85.95 m** | 15 m · 30 m · 60 m · 120 m | ⚠15 m 는 **안쪽**(근접장, 경계의 0.17 배) · 30 m 는 **안쪽**(근접장, 경계의 0.35 배) · 60 m 는 **안쪽**(근접장, 경계의 0.70 배) |
#
# ⚠**그래서 «15 m 면 원거리장» 이 아니다.** 근접장에 선 팔이 **20 개**다 — `ours` · `ours_ptd_s1000plus_r15_n8192` · `ours_s1000plus_r15_n8192` · `ours_s1000plus_r15_n8192_az22.5` · `ours_s1000plus_r30_n8192` · `ours_s1000plus_r60_n8192` · `sionna` · `sionna_p1000000000` ….
#
# 근접장에서는 파면이 표적 위에서 휘어 날개끝과 동체가 서로 다른 위상 기울기를 받는다. 그러니 그런 팔의 dB 는 물론 **리듬 몫도** 엔진 차이로 읽으면 안 된다 — «한 축만 다른 짝» 이라고 부르기 전에 이 표를 먼저 본다.
#
# ### 13.6 기체 태그가 붙은 팔은 박자가 다르다
#
# ⚠이름에 `mini5pro` · `s1000plus` 가 박힌 팔은 표적이 바뀐 판이라 **예측 박자가 다르다** — 날개 수 × 호버 rpm ÷ 60 이라 기체마다 다른 수가 나온다. 원장 `_meta.f_flash_hz` 는 기본 기체(matrice4e) 값이라 그대로 쓰면 그 팔의 점선이 전부 엉뚱한 자리에 선다.
#
# | 기체 | 박자 | 이 원장의 팔 |
# |---|---|---|
# | DJI Matrice 4E | 126.667 Hz | 94 |
# | DJI Mini 5 Pro | 183.333 Hz | 14 |
# | DJI S1000+ | 148.9 Hz | 14 |
#
# 이 아틀라스의 그림은 팔마다 `src/drones.py` 에서 박자를 다시 계산해 점선을 세웠다 — 절 14.3 의 자기검사가 그것을 확인한다.
#
# ### 13.7 ⭐리듬 몫의 **널도 기체마다 다르다**
#
# 백색잡음이면 리듬 몫이 얼마로 나오나 — DJI Matrice 4E ≈ 12.6 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8. 창 폭(±8 Hz)을 박자로 나눈 값이 곧 널이라, 박자가 빠른 기체일수록 낮다. 그러므로 «13 아래면 리듬 없음» 은 기본 기체에서만 맞는 말이다. 표와 그림은 **그 칸의 널**을 함께 적는다.
#
# ### 13.8 **몇 자세가 튄 칸**의 박자는 박자가 아니다
#
# |AC| 의 최대 ÷ 중앙(= 튐 지표)이 100 을 넘는 칸이 **61 개**다. 자세 몇 개가 통째로 다른 값이면 맵은 그 자리에 세로 줄 하나만 남기고 나머지가 바닥색으로 깔리고(패널마다 자기 최댓값으로 정규화하므로), 그때 잡히는 «박자» 는 회전이 아니라 **그 튐들의 간격**이다. 표·그림에 «⚡ 큰 자세»·«(spiky)» 로 적었다. 예측의 0.5 배 미만처럼 이상한 배수가 나오면 먼저 이 깃발을 본다. ⚠이 잣대는 «얼마나 큰가» 만 잰다 — «얼마나 혼자인가» 는 바로 아래 절이다.
#
# ### 13.9 ⭐자세 **하나**가 헤드라인을 끄는 칸 3 개
#
# 2026-08-16 에 «−60° 에서 반사 깊이 3 이면 리듬 몫이 86.6 → 32.4 % 로 무너진다» 는 판정이 **자세 8,192 개 중 하나** 때문이었다. 그 자세를 이웃 평균으로 갈아 끼우면 두 판이 85.5 대 85.2 % 로 같다. 그래서 튐 진단을 **모든 칸에 상시로** 돌린다 — 그 칸에서 가장 큰 자세 하나를 이웃 평균으로 갈아 끼우고 헤드라인 넷(리듬 몫 · 빗살 대비 · 요동 전력 · 상한 위 몫)을 다시 재서, 움직인 폭이 ① 죄 없는 자세 12 개·둘째 자세를 같은 방법으로 갈아 끼웠을 때보다 꼬리 울타리 밖으로 크고 ② 그 앙각의 **격자 산포 밴드**보다 크면 «튐» 이다. 문턱은 둘 다 원장에서 읽어 온다(`outputs/outlier_census_0816.json` · 밴드 `benchmark/depth_axis_verdict_0816.py`).
#
# - ⚑ **sionna_phys** -15° — 자세 하나(#3195)가 격자 밴드보다 크게 헤드라인을 움직인다: 리듬 몫 +30%p > 격자밴드 0.1%p (299.7 배) · 쏠림 6667× · 요동 전력 -10.8dB > 격자밴드 1.31dB (8.2 배) · 쏠림 3301× · 빗살 대비 +16.3dB > 격자밴드 4.1dB (4.0 배) · 쏠림 403× · 상한 위 몫 -20.5%p > 격자밴드 12.5549%p (1.6 배) · 쏠림 933×
# - ⚑ **sionna_phys** -30° — 자세 하나(#2505)가 격자 밴드보다 크게 헤드라인을 움직인다: 빗살 대비 +8.77dB > 격자밴드 4.6dB (1.9 배) · 쏠림 216×
# - ⚑ **sionna_p4000000000_onlydepth3_r15_n8192** -60° — 자세 하나(#3399)가 격자 밴드보다 크게 헤드라인을 움직인다: 리듬 몫 +54%p > 격자밴드 16%p (3.4 배) · 쏠림 15534× · 요동 전력 -0.146dB > 격자밴드 0.02dB (7.3 배) · 쏠림 1046× · 빗살 대비 +20.9dB > 격자밴드 4dB (5.2 배) · 쏠림 2888×
#
# - ⌗ **덜 찍힌 플래시 40 개** — ⭐**튐이 아니다.** 진짜 날개 플래시가 **한 표본 폭**으로 찍힌 것이다(에코는 날개끝 상한으로 대역제한이라 플래시의 최소 폭이 0° 에서 7.7 표본이어야 한다). 고칠 곳은 그 칸이 아니라 **표집**이고, 그 칸의 «상한 위 몫 · 빗살 대비» 를 인용할 때는 그 단서를 함께 적는다.
# - ◈ **경계 칸 6 개** — 쏠림의 분모가 «죄 없는 자세 12 개의 최댓값» 이라 어느 12 개를 뽑느냐에 등급이 걸린다. 중앙값 대조군으로 다시 재서 판정이 갈리면 이 깃발을 세우고, 감식 원장(`outputs/outlier_census_0816.json`)의 등급도 나란히 적는다.
#
# ⛔**깃발이 떴다고 그 칸을 자동으로 버리지 마라.** 뜻은 «이 수는 자세 하나에 걸려 있으니 그 자세를 열어 보라» 이지 «틀렸다» 가 아니다 — 로터가 시선과 딱 맞는 순간의 **진짜 정반사 플래시**도 이렇게 보인다. 그래서 «얼마나 큰가»(최대÷중앙)는 등급에 안 쓰고, «날개가 지나갈 때마다 다시 서나 · 이웃 자세와 이어지나 · 갈아 끼우면 헤드라인이 움직이나» 로만 판정한다.
#
# ### 13.10 박자와 맵은 **다른 구간**에서 잰 수다
#
# ⚠박자는 **전 구간**(자세 전부)으로 재고, 맵 그림은 20~80 ms 창만 그린다 — 같은 상자의 두 수가 다른 구간에서 나온 수다. 같은 상자 안에 있어도 «맵에 보이는 것» 과 «박자 수치» 는 같은 창의 이야기가 아니다.
#
# ### 13.11 ⭐아직 **못 고친 것** — 알고 쓰라고 적어 둔다
#
# - **덜 찬 칸 2 개의 참값** — 원장을 다시 병합해야 나온다. 이 문서는 원장을 읽기만 한다. 세 칸 중 둘은 자세가 뭉텅이로 빠져 «0 을 걷어내고 다시 재는» 길도 없다(균일 표본이 아니다).
# - **주제 분류(`topic_of`)가 아직 이름 토막으로 거리를 본다** — 그래서 `_r` 토막이 없는 10 m 옛 팔이 «기본 엔진» 주제에 남아 있다. 원장 `range_m` 으로 바꾸면 그 팔들이 거리 주제로 옮겨가 그림 파일 이름이 전부 바뀌므로, 주제를 다시 짤 때 함께 고친다 — 그 사이의 안전장치가 절 13.4 의 거리 표와 그림 속 거리 라벨이다.
# - **맵은 패널마다 자기 최댓값으로 밝기를 맞춘다** — 그래서 거리와 세기를 그림에서 읽을 수 없다. 공통 눈금을 쓰면 눈금이 다른 두 엔진을 한 색역에 올리는 더 큰 거짓이 되므로 그대로 두었다.
# - **리듬 몫의 창 반폭은 8 Hz 고정** — `build_deck_maps.structure_bars` 와 정의를 맞추려고 그대로 두었다. 그 대가로 높은 배음일수록 창 밖으로 새어 100 이 도달 불가다.
#
# 수리의 «전 → 후» 수치는 `outputs/atlas_falsify.json` 에 있다 (`benchmark/audit_atlas_repair.py`).

# %% [markdown]
# ---
#
# ## 절 14. 누락 검사
#
# > **원장 349 칸 가운데 그림이 없는 칸은 0 개다.**
#
# 세는 법 — 팔 하나의 맵 그림은 **그 팔이 가진 앙각을 가로로 늘어놓은 격자**라, 칸 하나가 열 하나다. 그래서 «칸에 그림이 있나» 는 «그 칸이 어느 맵의 열로 그려졌나» 로 센다. 색인을 믿지 않고 원장 npz 의 키에서 팔과 앙각을 다시 뽑아 맞췄다.
#
# | 검사 | 결과 |
# |---|---|
# | 원장 팔 · 칸 | 122 팔 · 349 칸 (원장 `rows` 349 행과 일치) |
# | 그림 열이 없는 칸 | **0 개** |
# | 색인에만 있고 원장에 없는 팔 | 0 개 |
# | 원장에만 있고 색인에 없는 팔 | 0 개 |
# | 색인이 가리키는데 디스크에 없는 그림 파일 | 0 개 |
#
# 빠진 칸이 없으므로 아래에 목록이 없다. 대신 «그림은 있는데 볼 것이 없는 칸» 과 «애초에 원장에 없는 자리» 를 남긴다 — 찾다가 허탕치는 자리는 그 둘이다.
#
# ### 14.1 그림은 있는데 **아무것도 안 돌아온** 칸 (9 개)
#
# 원장의 시계열이 통째로 0 인 칸이다(원장 `level_db` 도 −6000 이라는 표식이 붙는다 — 잰 세기가 아니라 **«없음» 표식**이다). 맵은 그려지지만 패널에 «nothing came back» 이라고 적히고, 대역 에너지 그림에는 그 앙각의 곡선이 **아예 안 그려진다** — 0 을 dB 로 바꾸면 −∞ 라 보이지 않는 선이 범례에만 남기 때문이다.
#
# ⚠**왜 비었나 를 스위치 탓으로만 적으면 틀린다.** 생성기 `benchmark/elevation_sweep_md.py` 는 `los=True, specular_reflection=True` 를 **하드코딩**하고 굴절·회절·모서리·확산만 `--sw` 로 켜고 끈다. 즉 `swR0D0E0F0` 도 «전부 끔» 이 아니라 «정반사와 직선경로는 켜 둔 채 나머지 넷을 끈» 판이다. 그런데도 표적 경유 경로가 0 개라는 것이 사실이다 (원장 실측 −30°: `swR0D0E0F0` 경로 0 · `swR1D0E0F0`(굴절만) 0 · `swR0D1E0F0`(회절만) 8).
#
# | 팔 | 앙각 | 왜 |
# |---|---|---|
# | `sionna_p4000000000_stockdef_r15_n8192` | −15° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −30° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −45° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −60° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −75° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −90° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` | −30° | 굴절 · 회절 · 모서리 · 확산을 끈 조합 — **정반사·LOS 는 켜져 있는데도** 표적 경유 경로가 0 개다 |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` | −30° | 굴절 · 회절 · 모서리 · 확산을 끈 조합 — **정반사·LOS 는 켜져 있는데도** 표적 경유 경로가 0 개다 |
# | `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` | −30° | 굴절만 켠 조합(정반사·LOS 는 켬)이 이 앙각에서 경로를 못 찾았다 |
#
# ### 14.1b ⭐**아직 덜 찬** 칸 (2 개) — 수를 내지 않는다
#
# 원장 `n_missing` 열이 «이 칸은 자세가 덜 찼다» 고 적어 둔 칸이다(또는 시계열 안에 «정확히 0» 인 표본이 섞여 있는 칸). 실험이 도는 중이라 병합이 아직 절반인 것이다.
#
# ⭐**왜 수를 내면 안 되나** — 빠진 자세 자리가 0 으로 채워져 있어서, 0 채움이 스펙트럼을 PRF/2 · PRF/4 자리에 **복제**한다. 그 복제본이 «날개끝 상한 위» 에 앉아 그 대역의 에너지를 거의 다 차지하고, 그래서 리듬 몫이 0 % 로 주저앉는다 — **물리가 아니라 결측 자국**이다. 맵에는 날개 무늬가 또렷한데 구석에 «0 %» 가 적히는 모순이 그렇게 생겼다(2026-08-15 정정 전 판이 그랬다).
#
# ⚠**«0 을 빼고 다시 재면 되지 않나»** — 안 된다. 세 칸 가운데 빠진 자리가 균일한 칸은 하나뿐이고(한 칸 걸러 하나), 나머지 둘은 자세가 뭉텅이로 빠져 (4 개 중 2·3번째, 8 개 중 5~8번째) **균일 표본이 아니다** — 그런 자료의 스펙트럼은 정의되지 않는다. 고치는 길은 하나뿐이다: **원장을 다시 병합한다.**
#
# | 팔 | 앙각 | 들어온 자세 | 빠진 자세 | 거리 |
# |---|---|---|---|---|
# | `sionna_p4000000000` | −75° | 2,048 | 2,048 | 10.0 m |
# | `sionna_p4000000000_r480_n8192_d1` | −30° | 2,905 | 5,287 | 480.0 m |
#
# ⚠**원장 병합이 낡았다** — `outputs/elev_sweep_shards/` 에 원장보다 새로운 샤드가 55 개 있다. 다시 병합하면 이 칸들이 채워질 수 있다(이 아틀라스는 원장만 읽으므로 병합은 스윕 쪽 일이다).
#
# ### 14.1c **움직이는 것이 없는** 칸 (3 개)
#
# 시계열이 사실상 상수인 칸이다 — AC/DC 가 배정밀도 반올림 바닥(1e-12) 아래다. 프로펠러를 뺀 대조군이 그렇다: 돌아가는 것이 없으니 흔들릴 것도 없다.
#
# ⭐그런 칸에서 뽑은 «박자» 는 **1 ULP(마지막 자리 한 칸)를 흔든 자리**라 재현되지 않는다 — 계산 순서를 조금만 바꿔도 봉우리가 다른 자리로 옮겨간다. 그래서 수를 내지 않는다(정정 전 판은 «beat 204 Hz = 1.61x · 움직이는 전력 −384 dB» 라고 적었다. −384 dB 는 물리량이 아니다).
#
# | 팔 | 앙각 | AC/DC |
# |---|---|---|
# | `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` | 0° | 3.1e-32 |
# | `sionna_p4000000000_partsnoprop_r15_n8192_d1` | 0° | 7.542e-33 |
# | `sionna_p4000000000_r480_n8192_d1` | 0° | 6.323e-33 |
#
#
# ### 14.2 애초에 **원장에 없는 자리** (505 칸)
#
# 7 점 격자(0° · −15° … −90°)를 다 채웠다면 122 × 7 = 854 칸일 텐데 원장에는 349 칸이 있다. 나머지 505 칸은 **안 돌린 자리**다 — 그림이 빠진 것이 아니라 계산이 없다. 표와 지도에서 `—` 로 나온다.
#
# 대부분은 설계가 그랬다 — 스위치 조합 판은 «어느 스위치가 리듬을 죽이나» 하나만 물으려고 −30° 한 점에서만 돌렸고, 방위 · 부품 판은 네 점(0° · −30° · −60° · −90°), 격자 판은 위쪽 네 점(0° ~ −45°)만 돌렸다. 거리 판은 정면 한 점이고, 평면파 판은 직하방 한 점이다.
#
# ⚠**설계 격자 어디에도 안 맞는 팔이 있다.** 위 네 가지(7 점 · 성긴 4 점 · 촘촘한 4 점 · 1 점) 중 어느 것도 아닌 앙각 구성이다 — 왜 그 칸만 비었는지는 원장에 적혀 있지 않다. 그 자리를 인용하려면 다시 돌려야 한다.
#
# | 팔 | 있는 앙각 | 없는 앙각 |
# |---|---|---|
# | `ours_mini5pro_r120_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_mini5pro_r15_n8192_az22.5` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_mini5pro_r30_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_mini5pro_r60_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r120_n8192` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n32768` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_az22.5` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_az67.5` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r240_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r30_n8192` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r480_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r60_n8192` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_s1000plus_r120_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_s1000plus_r15_n8192_az22.5` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_s1000plus_r30_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_s1000plus_r60_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000` | 0° · −15° · −45° · −60° · −75° | **−30° · −90°** |
# | `sionna_p4000000000_mini5pro_r120_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_mini5pro_r30_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_mini5pro_r60_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r120_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r240_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r30_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r60_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_phys_r120_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_phys_r30_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_phys_r60_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r120_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` | 0° · −15° · −30° · −60° | **−45° · −75° · −90°** |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r240_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_r30_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r480_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_r60_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_s1000plus_r120_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_s1000plus_r30_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_s1000plus_r60_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
#
# **전체 목록** — 원장에 칸이 덜 찬 팔 98 개(나머지 24 개는 7 점을 다 채웠다).
#
# | 팔 | 없는 앙각 |
# |---|---|
# | `ours_mini5pro_r120_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r15_n8192_az22.5` | −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r30_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r60_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_mini5pro_r15_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r120_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r15_n8192_az22.5` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r15_n8192_div24` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r30_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r60_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_s1000plus_r15_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r120_n8192` | −15° · −45° · −75° · −90° |
# | `ours_r15_n32768` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_az15` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az22.5` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_az30` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az45` | −15° · −45° · −75° |
# | `ours_r15_n8192_az60` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az67.5` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_az75` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az90` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_div48` | 0° · −30° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_pw` | 0° · −15° · −30° · −45° · −60° · −75° |
# | `ours_r240_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r30_n8192` | −15° · −45° · −75° · −90° |
# | `ours_r480_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r60_n8192` | −15° · −45° · −75° · −90° |
# | `ours_s1000plus_r120_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r15_n8192_az22.5` | −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r30_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r60_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000` | −30° · −90° |
# | `sionna_p4000000000_mini5pro_r120_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_mini5pro_r30_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_mini5pro_r60_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlydepth3_r15_n8192` | −15° · −45° · −75° |
# | `sionna_p4000000000_onlyedge_r15_n8192` | −15° · −45° · −75° |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r120_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r240_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r30_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r60_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_partsnoprop_r15_n8192_d1` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_partsprop_r15_n8192_d1` | −15° · −45° · −75° |
# | `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_phys_partsprop_r15_n8192_d1` | −15° · −45° · −75° |
# | `sionna_p4000000000_phys_r120_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_phys_r15_n8192_az45_d1` | −15° · −45° · −75° |
# | `sionna_p4000000000_phys_r30_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_phys_r60_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r120_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r120_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n32768_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_az22.5_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_az45_d1` | −15° · −45° · −75° |
# | `sionna_p4000000000_r15_n8192_shell0.5mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` | −45° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell1.5mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r240_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r30_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r30_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r480_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r60_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r120_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r30_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r60_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
#
# ### 14.3 자기검사
#
# | 검사 | 통과 | 실측 |
# |---|---|---|
# | 기체별 박자·날개끝 상한을 `src/drones.py` 에서 다시 계산해 색인과 대조 ⚠(같은 식·같은 입력이라 **항진명제**다 — 아래 원장 대조가 진짜 검사다) | ✅ | 팔 122 개 전부 일치 |
# | ⭐원장이 **스스로 잰** 박자(`track.beat_hz`)가 우리가 세운 예측 박자의 정수배 ±3 % 안에 든다 — 색인과 무관한 독립 증거 | ✅ | 맞음 264 칸 · 어긋남 40 칸 (가장 먼 칸 sionna_p4000000000@+0 58.15 Hz = 0.46x) |
# | 기체 태그 팔의 박자가 원장 기본값과 **다르다**(그대로 썼으면 틀렸을 자리) | ✅ | mini5pro 183.333 Hz · s1000plus 148.9 Hz ↔ 원장 기본 126.67 Hz |
# | ⭐수를 낼 자격이 없는 칸(덜 참 · 안 움직임 · 에코 없음)에 **잣대가 하나도 안 실렸다** | ✅ | 덜 참 2 · 안 움직임 3 · 에코 없음 9 칸, 새어 나온 수 0 개 |
# | 원장 병합이 최신이다 — 샤드 파일 가운데 원장보다 새 것이 없다 | ❌ | ⚠원장보다 새 샤드 55 개 — 병합이 낡았다(예: `ours_mini5pro_r120_n8192_el-30_01.npz`) |
# | 원장 칸 수와 색인 칸 수가 같다 | ✅ | 원장 npz 349 · 원장 rows 349 · 색인 349 |
# | 색인이 가리키는 그림 파일이 전부 디스크에 있다 | ✅ | 그림 273 장 · 빠진 파일 0 개 |
# | 원장에 있는데 그림 열이 없는 칸이 없다 | ✅ | 빠진 칸 0 개 |
#
# | | |
# |---|---|
# | 출력 | `reports/A_atlas.ipynb` |
# | 읽는 것 | `outputs/md_atlas_index.json` · `outputs/elevation_sweep_md.{json,npz}` · `outputs/grid_convergence_check.json` · `src/drones.py` |
# | 만든 곳 | `benchmark/build_atlas_toc.py` (그림은 `benchmark/build_md_atlas.py`) |
# | 소요 | CPU 로 수 초. GPU 를 안 쓴다 |
