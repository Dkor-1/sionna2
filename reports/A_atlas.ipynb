# %% [markdown]
# # 부록 A — 마이크로도플러 아틀라스 · 목차
#
# > 앙각 스윕 원장에는 **팔 445 개 · 칸 1433 개**가 들어 있는데, 지금까지 그림으로 나온 것은 덱이 고른 몇 팔뿐이었다. `benchmark/build_md_atlas.py` 가 그 전부를 **그림 961 장**으로 구웠고, 이 문서는 그것을 주제별로 세워 놓은 **목차**다. 여기서 그림을 고르고, 팔 이름을 읽는 법을 익히고, 어디를 믿으면 안 되는지 확인한다.
#
# 이 부록은 **권 번호 체계 밖**이다 — 결론을 주장하는 문서가 아니라 원장을 찾아보는 문서라, 파일 이름이 `A_` 로 시작하고 리포트 색인에 안 걸린다. 전체 목차는 [reports/README.md](README.md) 다.
#
# | 무엇 | 어디 |
# |---|---|
# | 원장 | `outputs/elevation_sweep_md.json` · `outputs/elevation_sweep_md.npz` |
# | 그림 | `outputs/figures/atlas/` — 961 장 |
# | 색인(기계용) | `outputs/md_atlas_index.json` — 이 문서의 모든 수가 여기서 온다 |
# | 구운 때 | 2026-09-03 05:19:11 |
# | 잰 자리 | 반송파 3.5 GHz · PRF 19,700 Hz · 기본 표적 `matrice4e` |
#
# ```bash
# PYTHONPATH=src:benchmark ~/.venvs/py312/bin/python benchmark/build_md_atlas.py
# PYTHONPATH=src ~/.venvs/py312/bin/python benchmark/build_atlas_toc.py   # 이 문서
# ```

# %% [markdown]
# ---
#
# ## 절 1. 이 문서를 읽는 법
#
# ### 그림은 두 종류다
#
# 팔 하나에 그림이 **두 장** 붙는다. 한 장은 «무늬가 어떻게 생겼나», 다른 한 장은 «그 무늬가 규칙적인가» 를 본다. 주제마다 그 위에 **비교판**이 한두 장 더 얹힌다 — 여러 팔을 한 장에 모아 어디를 열어 볼지 정하는 판이다.
#
# **(가) 맵** — 파일 이름이 `…__map.png` 로 끝난다.
#
# - 가로가 **시간**(20 ms 부터 60 ms 창), 세로가 **도플러**(움직이는 것이 주파수를 얼마나 밀었나)다.
# - 규칙적으로 지나가는 밝은 덩어리가 **날개**다. 날개가 시선을 스칠 때마다 한 번씩 번쩍하고, 그 번쩍이 일정한 간격으로 늘어서면 «회전하는 것이 달려 있다» 는 뜻이다.
# - 흰 점선은 **날개끝 상한**(f_tip) — 날개 끝이 낼 수 있는 가장 빠른 도플러다. 물리적으로 그 선 위에는 날개가 만든 것이 있을 수 없다.
# - 위 줄은 **받은 그대로**, 아래 줄은 **정지 성분(시계열 평균)을 뺀** 판이다. 위 줄 한가운데 가로로 진하게 눕는 띠가 동체 · 붙박이 반사이고, 아래 줄은 그것을 빼고 «움직이는 것만» 남긴 판이다. ⭐세기를 말하는 수는 전부 아래 줄에서 잰다.
# - 구석의 작은 수는 **«날개 박자에 붙은 에너지 몫[%]»** 이다 — 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배 자리(±8 Hz)에 앉은 몫. 백색잡음이면 얼마가 나오는지는 **칸마다 다르다**(DJI Matrice 4E ≈ 12.6 · DJI Mavic 4 Pro ≈ 13.5 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8) — 그림·표가 그 칸의 널을 함께 적으니 «13» 하나를 모든 팔에 대지 마라.
# - ⚠**천장 100 은 실제 자료에서 도달 불가다.** 실제 로터는 rpm 이 조금씩 흩어져 선이 번지고 창 반폭이 8 Hz 로 고정이라 높은 배음일수록 창 밖으로 샌다. 눈금 실측(`grid_convergence_check.json`)의 «백색 12.12 % · 이상 로터 100.00 % (빗살 77 개)» 에서 100 % 를 낸 «이상 로터» 는 **rpm 산포가 0 인 합성 신호**다 — 실물이 아니다. 그러니 100 을 «완벽한 로터» 로 읽지 말고, 눈금의 위쪽 끝이라고만 읽는다.
# - ⭐⚠**그 몫이 낮다고 «날개가 안 보인다» 는 뜻이 아니다.** 이 수는 상한 **위**에 남은 것만 본다. 그런데 몫이 낮은 칸은 대개 «위가 조용해서» 가 아니라 **«위가 잡동사니로 가득 차서»** 낮다 — 이 원장에서 직접 재 보면 그렇다: 리듬 몫이 20 % 미만인 칸 475 개는 움직이는 에너지의 **중앙값 85 %**가 상한 위에 있고, 20 % 이상인 칸 799 개는 **8 %** 뿐이다(−90° 제외). 즉 «무늬가 상한 아래로 얌전히 들어앉아서 몫이 낮다» 는 설명은 **거꾸로**다(2026-08-15 정정 — 그전 판에 그렇게 적혀 있었다).
# - 그래서 구석에는 **짝 잣대**를 함께 적는다 — «in-band comb [dB]» 는 상한 **아래**(2·박자 ~ 상한)에서 «정수배 자리 ÷ 그 사이 자리» 전력비다. 백색잡음 ≈ 0 dB. 리듬 몫이 0 인데 이 수가 +40 dB 면 «날개가 없다» 가 아니라 **«이 잣대가 못 읽는 자리다»** 라는 뜻이다. 날개가 보이나는 결국 **맵 자체**와 이 수로 판단한다.
# - ⚠**패널마다 자기 최댓값을 기준으로 색을 칠한다.** 색이 진하다고 세기가 센 것이 아니다 — 이 그림은 **모양을 읽는 그림**이지 세기를 읽는 그림이 아니다.
#
# **(나) 대역 에너지** — 파일 이름이 `…__band.png` 로 끝난다.
#
# - 날개끝 상한의 0.35~1.0 배 띠(«날개 대역»)의 전력이 시간에 따라 어떻게 뛰는지, 그 **리듬의 스펙트럼**이다. 맵의 줄무늬가 정말 규칙적으로 뛰는가를 직접 묻는 판이다.
# - 가로는 **초당 몇 번 뛰나**(변조율 [Hz]), 세로는 그 선의 세기다. 왼쪽이 넓은 범위(100~1,000 Hz), 오른쪽이 첫 선들의 확대다.
# - 세로 점선이 **예측 박자의 정수배**다 — 날개 수 × 호버 rpm ÷ 60. 곡선의 봉우리가 그 점선에 올라앉으면 «예측한 그대로 돈다», 점선을 비껴 서면 «다른 것이 뛰고 있다», 봉우리 없이 잔디밭이면 «리듬이 없다» 이다.
# - 곡선 하나가 앙각 하나다. ⚠여기서도 **곡선마다 자기 최댓값**으로 눕혔다 — 곡선 사이 높이 비교는 뜻이 없다.
#
# ### 표의 표기
#
# | 표기 | 뜻 |
# |---|---|
# | `—` | 원장에 그 칸이 없다(안 돌린 자리) |
# | `∅` | 돌리기는 했는데 **아무것도 안 돌아왔다**(에코가 통째로 0) |
# | `◐` | ⭐**자세가 덜 찼다** — 병합이 아직 절반이라 잣대를 내지 않는다 (절 14.1b) |
# | `○` | **움직이는 것이 없다** — AC/DC 가 반올림 바닥 아래라 잣대를 내지 않는다 (절 14.1c) |
# | `*` | 앙각 −90° — 날개끝 상한이 0 이라 «상한 위» 잣대가 **퇴화**한다 (절 13.1 을 보라) |
# | `⚠튐` | 자세 몇 개가 통째로 튀어 그 «박자» 가 회전이 아니다 (절 13.8) |
#
# 팔 이름이 낯설면 **절 12 «팔 이름 읽는 법»** 을 먼저 봐도 된다 — `_phys` · `_swR1D0E0F1` · `_partsprop` 같은 토막이 각각 무슨 뜻인지 표로 있다. 어디를 믿으면 안 되는지는 **절 13** 에 모아 뒀다.
#
# ### 집 규칙
#
# - 마이크로도플러 표현은 **STFT 만** 쓴다(재할당 · WVD 같은 다른 표현은 안 쓴다) — `src/md_mapstyle.py` 의 `flash_spec`: 블레이드 주기의 0.45 배 조각 · hop 2 · 8× 제로패딩.
# - ⭐레벨(dB)·리듬 몫·박자는 전부 정지 성분(시계열 평균) 제거 후에 잰다.
# - 맵은 20 ms 부터 60 ms 창. 패널마다 자기 최댓값으로 정규화한다.
# - 그림 안 글자는 영어, 본문은 한국어다. 각도는 «−30°» 로 적는다.

# %% [markdown]
# ---
#
# ## 절 2. 주제 아홉 가지
#
# 원장의 팔은 **이름 규칙**으로 아홉 주제에 갈린다 — 하드코딩한 목록이 아니라 이름에서 유도하므로, 새 팔이 생기면 자동으로 제자리에 붙는다.
#
# | 절 | 주제 | 무엇을 묻나 | 팔 | 칸 | 그림 |
# |---|---|---|---|---|---|
# | 3 | **기본 엔진** (`01base`) | 엔진과 광선 예산만 바꾸면 날개 무늬가 달라지나 | 61 | 249 | 133 |
# | 4 | **스위치** (`02switch`) | 굴절 · 회절 · 모서리 회절 · 확산 반사 중 **무엇을 켜면** 날개 리듬이 백색 수준으로 주저앉나 | 247 | 756 | 526 |
# | 5 | **기체 3 종** (`03airframe`) | 표적 기체를 바꾸면 그림의 박자가 **그 기체의 박자**로 따라가나 | 33 | 167 | 73 |
# | 6 | **방위** (`04azimuth`) | 지금까지의 결론이 방위 한 자리(정면)에서만 서는 것인가 | 35 | 103 | 76 |
# | 7 | **부품 분해** (`05parts`) | 무늬를 만드는 것은 프로펠러인가 동체인가 | 3 | 9 | 8 |
# | 8 | **거리** (`06range`) | 15 m 에서 30 m 로 물러나면 날개 무늬가 남나 | 57 | 119 | 122 |
# | 9 | **PTD** (`07ptd`) | 우리 팔의 모서리 회절(PTD 프린지)을 켜면 무늬가 달라지나 | 4 | 10 | 10 |
# | 10 | **격자** (`08grid`) | 표면 격자를 λ/12 에서 λ/24 로 조이면 잣대가 얼마나 움직이나 | 4 | 19 | 11 |
# | 11 | **평면파** (`09planewave`) | 직하방의 잔여가 근접장 **곡률** 탓인가 | 1 | 1 | 2 |
#
# 합계 — 팔 445 · 칸 1433 · 그림 961.

# %% [markdown]
# ## 이 도감은 여러 편으로 나뉜다
#
# | 편 | 주제 | 파일 |
# |---|---|---|
# | A | 기본 엔진 — 엔진·광선예산·자세수, ⚠거리도 10 m·15 m 로 섞여 있다 | [A_atlas_A.ipynb](A_atlas_A.ipynb) |
# | B | 스위치 — 굴절·회절·모서리·확산을 켜고 끈 조합 | [A_atlas_B.ipynb](A_atlas_B.ipynb) |
# | C | 기체 3 종 — 박자가 기체마다 다르다 | [A_atlas_C.ipynb](A_atlas_C.ipynb) |
# | D | 방위 — 정면 말고 45° 에서 본 판 | [A_atlas_D.ipynb](A_atlas_D.ipynb) |
# | E | 부품 분해 — 프로펠러만 / 동체만 | [A_atlas_E.ipynb](A_atlas_E.ipynb) |
# | F | 거리 — 15 m 아닌 판(30 m) | [A_atlas_F.ipynb](A_atlas_F.ipynb) |
# | G | PTD — 모서리 보정을 켠 판 | [A_atlas_G.ipynb](A_atlas_G.ipynb) |
# | H | 격자 — λ/12 대신 더 촘촘한 격자 | [A_atlas_H.ipynb](A_atlas_H.ipynb) |
# | I | 평면파 — 구면파 대신 평면파로 조명한 판 | [A_atlas_I.ipynb](A_atlas_I.ipynb) |
#
# ⭐그림이 수백 장이라 한 파일에 담으면 열기가 무겁다. 주제 하나만 볼 사람이 전체를 받지 않아도 되게 나눴다(2026-09-03).

# %% [markdown]
# ---
#
# ## 절 12. 팔 이름 읽는 법
#
# 팔 이름은 «무엇을 바꾼 판인가» 를 밑줄로 이어 붙인 것이다. 그림 파일 이름이 `<주제번호><주제>__<팔 이름>__map.png` 라서, **이 표만 있으면 파일 이름만 보고 그 판이 무엇인지 안다**.
#
# ⭐읽는 요령은 **없는 토막이 곧 기본값**이라는 것이다 — `_r15` 가 없으면 15 m 가 아니라 옛 기본 10 m 이고, `_n8192` 가 없으면 자세가 4,096 이다. 그래서 아래 표에는 «토막이 없으면 무엇인가» 칸을 함께 뒀다.
#
# | 토막 | 뜻 | 토막이 없으면 | 이 토막을 단 팔 |
# |---|---|---|---|
# | `ours` | 우리 커널(SBR+PO) — 동체를 넣어 **가림이 있는** 판 | — | 129 |
# | `ours_free` | 우리 커널이되 **동체 «면» 만 빼서** 가림을 없앤 대조군 (꼭짓점 · bbox · 광선 격자는 그대로라 «동체가 막느냐» 하나만 갈린다) | — | 1 |
# | `sionna` | Sionna RT 의 `PathSolver` 팔 | — | 315 |
# | `p<N>` | 광선 수(`--spp`). `p4000000000` = 40 억 발 | 규칙값 (R/3)²×1M | 310 |
# | `phys` | PathSolver 물리를 **전부 켠다** — 굴절 · 회절 · 모서리 회절 | 셋 다 끔 | 13 |
# | `swR#D#E#F#` | 스위치를 **비트로 직접** 준 판. `R` 굴절 · `D` 회절 · `E` 모서리 회절 · `F` 확산 반사, `1` 이 켬. 예 `swR1D0E0F1` = 굴절 + 확산 반사. ⚠소스 실측으로 `E` 는 `D=1` 일 때만 뜻이 있다. ⭐**이 네 비트에 정반사·직선경로(LOS)는 없다** — 생성기가 `los=True, specular_reflection=True` 를 하드코딩하므로 둘은 54 팔 전부에서 **항상 켜져 있다**. 그러니 `swR0D0E0F0` 도 «전부 끔» 이 아니다 | — | 202 |
# | `stockdef` | PathSolver 를 **순정 기본값 그대로** — 굴절 켬 · 회절 끔 · 모서리 끔 · 깊이 3 · 확산 끔. 우리 «끔» 판과도 «켬» 판과도 다른 제3 의 조합 | — | 1 |
# | `only<x>` | 스위치를 **하나만** 켠 판 — `onlyrefr` 굴절 · `onlydiffr` 회절 · `onlyedge` 모서리 회절 · `onlydepth3` 깊이 3. `phys` 는 넷을 한꺼번에 켜서 무엇이 무엇을 했는지 귀속이 안 된다 | — | 44 |
# | `d<N>` | PathSolver 반사 깊이(`--max-depth`). 물리 스위치와 깊이를 **가르는** 축 | 옛 규칙(물리 켜면 3, 아니면 1) | 261 |
# | `parts<…>` | 장면에 넣을 부품 그룹. `partsprop` = 프로펠러만 · `partsnoprop` = 프로펠러를 뺀 나머지(0° 붕괴가 «기근이냐 익사냐») | 기체 전체 | 5 |
# | 기체 태그 | 표적 기체를 바꾼 판 — `mini5pro` · `s1000plus`. ⚠**박자와 날개끝 상한이 함께 바뀐다** | 원장 기본 `matrice4e` | 132 |
# | `az<N>` | 방위각[°]. `az45` = 45° 옆에서 본 판 | 원장 기본 0° | 70 |
# | `r<N>` | 구면 반경[m]. `r15` = 15 m · `r30` = 30 m | 옛 기본 10 m(원거리장 경계 안쪽) | 416 |
# | `n<N>` | 슬로타임 자세 수. `n8192` = 8,192 자세(박자 FFT 분해능 = PRF/N) | 원장 기본 4,096 | 438 |
# | `div<N>` | 우리 커널 표면 격자 간격 λ/N. `div24` = λ/24 (PathSolver 에 없는 축) | 규약값 λ/12 | 5 |
# | `ptd` | 우리 팔의 **모서리 회절(PTD 프린지)** 켬 | 끔 | 8 |
# | `pw` | **평면파** 조명(구면파 대신 · 무한 거리 등가) | 구면파 | 1 |
#
# **읽어 보기**
#
# | 팔 이름 | 읽으면 |
# |---|---|
# | `sionna_p4000000000_phys_r15_n8192_d1` | PathSolver · 광선 40 억 · 물리 전부 켬 · 15 m · 자세 8,192 · 반사 깊이 1 |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` | PathSolver · 광선 40 억 · 굴절 + 확산 반사만 · **표적이 Mini 5 Pro**(박자 183.33 Hz) · 15 m · 자세 8,192 · 깊이 1 |
# | `ours_free_r15_n8192` | 우리 커널이되 **동체 면을 뺀** 대조군 · 15 m · 자세 8,192 |
# | `ours` | 우리 커널 · 토막이 하나도 없으니 **전부 기본값** — 10 m · 자세 4,096 · 격자 λ/12 |
#
# **팔 → 주제 찾아보기**
#
# | 팔 | 주제 | 그림 파일 앞머리 |
# |---|---|---|
# | `ours` | 기본 엔진 | `01base__ours__` |
# | `ours_free_r15_n8192` | 기본 엔진 | `01base__ours_free_r15_n8192__` |
# | `ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_mavic4pro_r15_n8192` | 기체 3 종 | `03airframe__ours_mavic4pro_r15_n8192__` |
# | `ours_mavic4pro_r15_n8192_mfixbatteryi5` | 기체 3 종 | `03airframe__ours_mavic4pro_r15_n8192_mfixbatteryi5__` |
# | `ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe__` |
# | `ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe__` |
# | `ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe__` |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe__` |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__` |
# | `ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_mini5pro_r120_n8192` | 거리 | `06range__ours_mini5pro_r120_n8192__` |
# | `ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_mini5pro_r15_n8192` | 기체 3 종 | `03airframe__ours_mini5pro_r15_n8192__` |
# | `ours_mini5pro_r15_n8192_az22.5` | 방위 | `04azimuth__ours_mini5pro_r15_n8192_az22.5__` |
# | `ours_mini5pro_r15_n8192_az45` | 방위 | `04azimuth__ours_mini5pro_r15_n8192_az45__` |
# | `ours_mini5pro_r15_n8192_az67.5` | 방위 | `04azimuth__ours_mini5pro_r15_n8192_az67.5__` |
# | `ours_mini5pro_r15_n8192_mfixbatteryi5` | 기체 3 종 | `03airframe__ours_mini5pro_r15_n8192_mfixbatteryi5__` |
# | `ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe__` |
# | `ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe__` |
# | `ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__` |
# | `ours_mini5pro_r240_n8192` | 거리 | `06range__ours_mini5pro_r240_n8192__` |
# | `ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_mini5pro_r30_n8192` | 거리 | `06range__ours_mini5pro_r30_n8192__` |
# | `ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_mini5pro_r60_n8192` | 거리 | `06range__ours_mini5pro_r60_n8192__` |
# | `ours_n8192_rep1_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_n8192_rep1_mfixbatteryi5_blperairframe__` |
# | `ours_ptd_mini5pro_r15_n8192` | PTD | `07ptd__ours_ptd_mini5pro_r15_n8192__` |
# | `ours_ptd_r120_n8192` | 거리 | `06range__ours_ptd_r120_n8192__` |
# | `ours_ptd_r15_n8192` | PTD | `07ptd__ours_ptd_r15_n8192__` |
# | `ours_ptd_r15_n8192_az22.5` | 방위 | `04azimuth__ours_ptd_r15_n8192_az22.5__` |
# | `ours_ptd_r15_n8192_div24` | PTD | `07ptd__ours_ptd_r15_n8192_div24__` |
# | `ours_ptd_r30_n8192` | 거리 | `06range__ours_ptd_r30_n8192__` |
# | `ours_ptd_r60_n8192` | 거리 | `06range__ours_ptd_r60_n8192__` |
# | `ours_ptd_s1000plus_r15_n8192` | PTD | `07ptd__ours_ptd_s1000plus_r15_n8192__` |
# | `ours_r120_n8192` | 거리 | `06range__ours_r120_n8192__` |
# | `ours_r120_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r120_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n32768` | 기본 엔진 | `01base__ours_r15_n32768__` |
# | `ours_r15_n8192` | 기본 엔진 | `01base__ours_r15_n8192__` |
# | `ours_r15_n8192_az15` | 방위 | `04azimuth__ours_r15_n8192_az15__` |
# | `ours_r15_n8192_az15_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r15_n8192_az15_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_az22.5` | 방위 | `04azimuth__ours_r15_n8192_az22.5__` |
# | `ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_az30` | 방위 | `04azimuth__ours_r15_n8192_az30__` |
# | `ours_r15_n8192_az30_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r15_n8192_az30_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_az45` | 방위 | `04azimuth__ours_r15_n8192_az45__` |
# | `ours_r15_n8192_az45_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r15_n8192_az45_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_az60` | 방위 | `04azimuth__ours_r15_n8192_az60__` |
# | `ours_r15_n8192_az60_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r15_n8192_az60_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_az67.5` | 방위 | `04azimuth__ours_r15_n8192_az67.5__` |
# | `ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_az75` | 방위 | `04azimuth__ours_r15_n8192_az75__` |
# | `ours_r15_n8192_az75_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r15_n8192_az75_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_az90` | 방위 | `04azimuth__ours_r15_n8192_az90__` |
# | `ours_r15_n8192_az90_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r15_n8192_az90_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_div24` | 격자 | `08grid__ours_r15_n8192_div24__` |
# | `ours_r15_n8192_div24_shift0.5` | 격자 | `08grid__ours_r15_n8192_div24_shift0.5__` |
# | `ours_r15_n8192_div48` | 격자 | `08grid__ours_r15_n8192_div48__` |
# | `ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_fs2_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_fs2_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_mfixbatteryi5_blperairframe_div24` | 격자 | `08grid__ours_r15_n8192_mfixbatteryi5_blperairframe_div24__` |
# | `ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_ps2_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_ps2_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_pw` | 평면파 | `09planewave__ours_r15_n8192_pw__` |
# | `ours_r15_n8192_rep1_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rep1_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rep2_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rep2_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe__` |
# | `ours_r15_n8192_shift0.37x-0.19` | 기본 엔진 | `01base__ours_r15_n8192_shift0.37x-0.19__` |
# | `ours_r15_n8192_shift0.5` | 기본 엔진 | `01base__ours_r15_n8192_shift0.5__` |
# | `ours_r15_n8192_shift1` | 기본 엔진 | `01base__ours_r15_n8192_shift1__` |
# | `ours_r240_n8192` | 거리 | `06range__ours_r240_n8192__` |
# | `ours_r240_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r240_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_r30_n8192` | 거리 | `06range__ours_r30_n8192__` |
# | `ours_r30_n8192_az45_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r30_n8192_az45_mfixbatteryi5_blperairframe__` |
# | `ours_r30_n8192_az90_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r30_n8192_az90_mfixbatteryi5_blperairframe__` |
# | `ours_r30_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r30_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_r45_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r45_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_r480_n8192` | 거리 | `06range__ours_r480_n8192__` |
# | `ours_r480_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r480_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_r60_n8192` | 거리 | `06range__ours_r60_n8192__` |
# | `ours_r60_n8192_az45_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r60_n8192_az45_mfixbatteryi5_blperairframe__` |
# | `ours_r60_n8192_az90_mfixbatteryi5_blperairframe` | 방위 | `04azimuth__ours_r60_n8192_az90_mfixbatteryi5_blperairframe__` |
# | `ours_r60_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r60_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe__` |
# | `ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe__` |
# | `ours_r90_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r90_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe__` |
# | `ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe__` |
# | `ours_s1000plus_r120_n8192` | 거리 | `06range__ours_s1000plus_r120_n8192__` |
# | `ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_s1000plus_r15_n8192` | 기체 3 종 | `03airframe__ours_s1000plus_r15_n8192__` |
# | `ours_s1000plus_r15_n8192_az22.5` | 방위 | `04azimuth__ours_s1000plus_r15_n8192_az22.5__` |
# | `ours_s1000plus_r15_n8192_az45` | 방위 | `04azimuth__ours_s1000plus_r15_n8192_az45__` |
# | `ours_s1000plus_r15_n8192_az67.5` | 방위 | `04azimuth__ours_s1000plus_r15_n8192_az67.5__` |
# | `ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe__` |
# | `ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe__` |
# | `ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__` |
# | `ours_s1000plus_r240_n8192` | 거리 | `06range__ours_s1000plus_r240_n8192__` |
# | `ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_s1000plus_r30_n8192` | 거리 | `06range__ours_s1000plus_r30_n8192__` |
# | `ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe` | 거리 | `06range__ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe__` |
# | `ours_s1000plus_r60_n8192` | 거리 | `06range__ours_s1000plus_r60_n8192__` |
# | `sionna` | 기본 엔진 | `01base__sionna__` |
# | `sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` | 기체 3 종 | `03airframe__sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p1000000000` | 기본 엔진 | `01base__sionna_p1000000000__` |
# | `sionna_p1000000000_swR1D1E1F1_r15_n8192_d1` | 스위치 | `02switch__sionna_p1000000000_swR1D1E1F1_r15_n8192_d1__` |
# | `sionna_p1000000000_swR1D1E1F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p1000000000_swR1D1E1F1_r15_n8192_d3__` |
# | `sionna_p250000000` | 기본 엔진 | `01base__sionna_p250000000__` |
# | `sionna_p250000000_phys` | 기본 엔진 | `01base__sionna_p250000000_phys__` |
# | `sionna_p4000000000` | 기본 엔진 | `01base__sionna_p4000000000__` |
# | `sionna_p4000000000_mavic4pro_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_mavic4pro_r15_n8192_d1__` |
# | `sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_mini5pro_r120_n8192_d1` | 거리 | `06range__sionna_p4000000000_mini5pro_r120_n8192_d1__` |
# | `sionna_p4000000000_mini5pro_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_mini5pro_r15_n8192_d1__` |
# | `sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1__` |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1__` |
# | `sionna_p4000000000_mini5pro_r30_n8192_d1` | 거리 | `06range__sionna_p4000000000_mini5pro_r30_n8192_d1__` |
# | `sionna_p4000000000_mini5pro_r60_n8192_d1` | 거리 | `06range__sionna_p4000000000_mini5pro_r60_n8192_d1__` |
# | `sionna_p4000000000_onlydepth3_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlydepth3_r15_n8192__` |
# | `sionna_p4000000000_onlydiffr_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlydiffr_r15_n8192__` |
# | `sionna_p4000000000_onlyedge_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyedge_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r120_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r120_n8192__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r240_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r240_n8192__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r30_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r30_n8192__` |
# | `sionna_p4000000000_onlyrefr_mini5pro_r60_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_mini5pro_r60_n8192__` |
# | `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_partsprop_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_r120_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r120_n8192__` |
# | `sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az90` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_az90__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm__` |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm__` |
# | `sionna_p4000000000_onlyrefr_r240_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r240_n8192__` |
# | `sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_r30_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r30_n8192__` |
# | `sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_r60_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r60_n8192__` |
# | `sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r120_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r120_n8192__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r240_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r240_n8192__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r30_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r30_n8192__` |
# | `sionna_p4000000000_onlyrefr_s1000plus_r60_n8192` | 스위치 | `02switch__sionna_p4000000000_onlyrefr_s1000plus_r60_n8192__` |
# | `sionna_p4000000000_partsnoprop_r15_n8192_d1` | 부품 분해 | `05parts__sionna_p4000000000_partsnoprop_r15_n8192_d1__` |
# | `sionna_p4000000000_partsprop_r15_n8192_d1` | 부품 분해 | `05parts__sionna_p4000000000_partsprop_r15_n8192_d1__` |
# | `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_phys_mini5pro_r15_n8192_d1__` |
# | `sionna_p4000000000_phys_n8192_d1` | 기본 엔진 | `01base__sionna_p4000000000_phys_n8192_d1__` |
# | `sionna_p4000000000_phys_partsprop_r15_n8192_d1` | 부품 분해 | `05parts__sionna_p4000000000_phys_partsprop_r15_n8192_d1__` |
# | `sionna_p4000000000_phys_r120_n8192_d1` | 거리 | `06range__sionna_p4000000000_phys_r120_n8192_d1__` |
# | `sionna_p4000000000_phys_r15_n8192_az45_d1` | 방위 | `04azimuth__sionna_p4000000000_phys_r15_n8192_az45_d1__` |
# | `sionna_p4000000000_phys_r15_n8192_d1` | 기본 엔진 | `01base__sionna_p4000000000_phys_r15_n8192_d1__` |
# | `sionna_p4000000000_phys_r15_n8192_d2` | 기본 엔진 | `01base__sionna_p4000000000_phys_r15_n8192_d2__` |
# | `sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1` | 기본 엔진 | `01base__sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_phys_r30_n8192_d1` | 거리 | `06range__sionna_p4000000000_phys_r30_n8192_d1__` |
# | `sionna_p4000000000_phys_r60_n8192_d1` | 거리 | `06range__sionna_p4000000000_phys_r60_n8192_d1__` |
# | `sionna_p4000000000_phys_s1000plus_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_phys_s1000plus_r15_n8192_d1__` |
# | `sionna_p4000000000_r120_n8192_d1` | 거리 | `06range__sionna_p4000000000_r120_n8192_d1__` |
# | `sionna_p4000000000_r120_n8192_d3` | 거리 | `06range__sionna_p4000000000_r120_n8192_d3__` |
# | `sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1` | 거리 | `06range__sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r15_n32768_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n32768_d1__` |
# | `sionna_p4000000000_r15_n8192_az22.5_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az22.5_d1__` |
# | `sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r15_n8192_az45_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az45_d1__` |
# | `sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r15_n8192_az67.5_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az67.5_d1__` |
# | `sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r15_n8192_az90_d1` | 방위 | `04azimuth__sionna_p4000000000_r15_n8192_az90_d1__` |
# | `sionna_p4000000000_r15_n8192_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_d1__` |
# | `sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.5mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.5mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1__` |
# | `sionna_p4000000000_r15_n8192_shell1.5mm_d1` | 기본 엔진 | `01base__sionna_p4000000000_r15_n8192_shell1.5mm_d1__` |
# | `sionna_p4000000000_r240_n8192_d1` | 거리 | `06range__sionna_p4000000000_r240_n8192_d1__` |
# | `sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1` | 거리 | `06range__sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r30_n8192_d1` | 거리 | `06range__sionna_p4000000000_r30_n8192_d1__` |
# | `sionna_p4000000000_r30_n8192_d3` | 거리 | `06range__sionna_p4000000000_r30_n8192_d3__` |
# | `sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1` | 거리 | `06range__sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r480_n8192_d1` | 거리 | `06range__sionna_p4000000000_r480_n8192_d1__` |
# | `sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1` | 거리 | `06range__sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_r60_n8192_d1` | 거리 | `06range__sionna_p4000000000_r60_n8192_d1__` |
# | `sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1` | 거리 | `06range__sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_s1000plus_r120_n8192_d1` | 거리 | `06range__sionna_p4000000000_s1000plus_r120_n8192_d1__` |
# | `sionna_p4000000000_s1000plus_r15_n8192_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_s1000plus_r15_n8192_d1__` |
# | `sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1__` |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1__` |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` | 기체 3 종 | `03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1__` |
# | `sionna_p4000000000_s1000plus_r30_n8192_d1` | 거리 | `06range__sionna_p4000000000_s1000plus_r30_n8192_d1__` |
# | `sionna_p4000000000_s1000plus_r60_n8192_d1` | 거리 | `06range__sionna_p4000000000_s1000plus_r60_n8192_d1__` |
# | `sionna_p4000000000_stockdef_r15_n8192` | 스위치 | `02switch__sionna_p4000000000_stockdef_r15_n8192__` |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D1E0F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d1__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3__` |
# | `sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d1__` |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_d3__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | 스위치 | `02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__` |
# | `sionna_phys` | 기본 엔진 | `01base__sionna_phys__` |
# | `sionna_r15_n8192_mfixbatteryi5_blperairframe` | 기본 엔진 | `01base__sionna_r15_n8192_mfixbatteryi5_blperairframe__` |

# %% [markdown]
# ---
#
# ## 절 13. ⚠읽을 때 주의
#
# ### 13.1 앙각 −90° 는 잣대가 퇴화한다
#
# 직하방에서는 날개가 도는 면이 시선과 **수직**이라 날개끝 상한 f_tip 이 0 Hz 다(f_tip ∝ cos el). 상한이 0 이면 «상한 **위**» 가 전 대역이 되어, 리듬 몫이 «날개가 만들 수 없는 자리에 무엇이 남았나» 를 재는 잣대이기를 그만둔다 — 그냥 전 대역의 빗살 정도를 재는 수가 된다. 그림에서는 그 칸 제목에 `*` 가 붙고 각주가 달린다. 표에서도 `*` 다. 이 원장에서 그런 칸은 **116 개**다.
#
# 대역 에너지 그림도 마찬가지다 — −90° 는 날개 대역 자체가 정의되지 않아 **0° 의 대역을 빌려** 그린다. 참값이 «선 없음» 인 자리라서, 거기서 빗살이 서면 그것이 곧 인공물이라는 뜻이다. 범례에 «band borrowed from 0°» 로 적혀 있다.
#
# ### 13.2 ⛔팔 사이의 **절대 세기**를 비교하지 마라
#
# 우리 커널과 PathSolver 는 **눈금이 다르다** — 같은 표적을 같은 자리에서 재도 «전력 −70 dB» 와 «−94 dB» 는 세기의 비교가 아니다. 광선 예산 · 격자 · 정규화가 엔진마다 다르게 들어간 수라, 두 팔의 dB 를 빼는 순간 그 차이는 물리가 아니라 구현의 차이가 된다.
#
# **그래서 이 아틀라스는 «모양» 과 «구조» 로만 말한다** — 맵은 패널마다 자기 최댓값으로 정규화하고, 팔을 가로지르는 비교는 리듬 몫[%] · 박자[Hz] · 박자 ÷ 예측 처럼 **눈금에 무관한 수**로만 한다. 같은 팔 안에서 앙각끼리 dB 를 비교하는 것은 된다(같은 눈금이다).
#
# ### 13.3 격자 흔들림 밴드 안이면 판정 불가
#
# 표면 격자를 λ/12 에서 λ/24 로 조이기만 해도 잣대가 움직인다. 그 폭이 **리듬 몫 21.8 %p · 움직이는 전력 3.86 dB** 다(`outputs/grid_convergence_check.json`, 앙각 네 점에서 잰 최대값).
#
# ⭐그러므로 **두 팔의 차이가 리듬 몫 21.8 %p 안이면 «차이가 있다» 고 말할 수 없다.** 예를 들어 58 과 63 의 차이는 판정 불가이고, 83 과 13 의 차이는 밴드 밖이라 살아 있다. 이 표의 수를 어디에 인용하든 «λ/12 한정» 을 함께 적는다.
#
# ### 13.4 한 원장에 **거리가 다른 팔**이 섞여 있다
#
# 이 원장의 기준 거리는 15 m 인데, 팔 306 개만 거기에 있다. `_r` 토막이 없는 팔 29 개는 옛 기본 **10 m** 에서 잰 것이고 — 원거리장 경계 2D²/λ ≈ 14.08 m 의 **안쪽**(근접장)이다 — `_r30` 팔 28 개는 30 m 다. **거리가 다른 팔을 나란히 놓을 때는 그 사실을 반드시 적는다.** 주제별 요약 표에 거리 열을 둔 이유다.
#
# | 거리 | 팔 수 | 어느 팔인가 |
# |---|---|---|
# | **10 m** | 29 | `ours` · `ours_n8192_rep1_mfixbatteryi5_blperairframe` · `sionna` · `sionna_p1000000000` · `sionna_p250000000` · `sionna_p250000000_phys` · `sionna_p4000000000` · `sionna_p4000000000_phys_n8192_d1` · `sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` · `sionna_phys` |
# | **15 m** | 306 | 기준 거리 — 나머지 팔 전부 |
# | **30 m** | 28 | `ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe` · `ours_mini5pro_r30_n8192` · `ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe` · `ours_ptd_r30_n8192` · `ours_r30_n8192` · `ours_r30_n8192_az45_mfixbatteryi5_blperairframe` · `ours_r30_n8192_az90_mfixbatteryi5_blperairframe` · `ours_r30_n8192_mfixbatteryi5_blperairframe` · `ours_s1000plus_r30_n8192` · `ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_mini5pro_r30_n8192_d1` · `sionna_p4000000000_onlyrefr_mini5pro_r30_n8192` · `sionna_p4000000000_onlyrefr_r30_n8192` · `sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_onlyrefr_s1000plus_r30_n8192` · `sionna_p4000000000_phys_r30_n8192_d1` · `sionna_p4000000000_r30_n8192_d1` · `sionna_p4000000000_r30_n8192_d3` · `sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1` · `sionna_p4000000000_s1000plus_r30_n8192_d1` · `sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` |
# | **45 m** | 5 | `ours_r45_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` |
# | **60 m** | 30 | `ours_mini5pro_r60_n8192` · `ours_ptd_r60_n8192` · `ours_r60_n8192` · `ours_r60_n8192_az45_mfixbatteryi5_blperairframe` · `ours_r60_n8192_az90_mfixbatteryi5_blperairframe` · `ours_r60_n8192_mfixbatteryi5_blperairframe` · `ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe` · `ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe` · `ours_s1000plus_r60_n8192` · `sionna_p4000000000_mini5pro_r60_n8192_d1` · `sionna_p4000000000_onlyrefr_mini5pro_r60_n8192` · `sionna_p4000000000_onlyrefr_r60_n8192` · `sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_onlyrefr_s1000plus_r60_n8192` · `sionna_p4000000000_phys_r60_n8192_d1` · `sionna_p4000000000_r60_n8192_d1` · `sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1` · `sionna_p4000000000_s1000plus_r60_n8192_d1` · `sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` |
# | **90 m** | 11 | `ours_r90_n8192_mfixbatteryi5_blperairframe` · `ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe` · `ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe` · `sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` · `sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` |
# | **120 m** | 18 | `ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe` · `ours_mini5pro_r120_n8192` · `ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe` · `ours_ptd_r120_n8192` · `ours_r120_n8192` · `ours_r120_n8192_mfixbatteryi5_blperairframe` · `ours_s1000plus_r120_n8192` · `ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_mini5pro_r120_n8192_d1` · `sionna_p4000000000_onlyrefr_mini5pro_r120_n8192` · `sionna_p4000000000_onlyrefr_r120_n8192` · `sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_onlyrefr_s1000plus_r120_n8192` · `sionna_p4000000000_phys_r120_n8192_d1` · `sionna_p4000000000_r120_n8192_d1` · `sionna_p4000000000_r120_n8192_d3` · `sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1` · `sionna_p4000000000_s1000plus_r120_n8192_d1` |
# | **240 m** | 13 | `ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe` · `ours_mini5pro_r240_n8192` · `ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe` · `ours_r240_n8192` · `ours_r240_n8192_mfixbatteryi5_blperairframe` · `ours_s1000plus_r240_n8192` · `ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_onlyrefr_mini5pro_r240_n8192` · `sionna_p4000000000_onlyrefr_r240_n8192` · `sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_onlyrefr_s1000plus_r240_n8192` · `sionna_p4000000000_r240_n8192_d1` · `sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1` |
# | **480 m** | 5 | `ours_r480_n8192` · `ours_r480_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe` · `sionna_p4000000000_r480_n8192_d1` · `sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1` |
#
# ### 13.5 ⭐**근접장은 기체마다 다른 자리에서 시작한다**
#
# 원거리장 경계는 2D²/λ 다 — D 가 표적 크기라, **기체가 커지면 경계가 멀어진다.** 기본 기체(matrice4e) 기준의 14.08 m 하나를 모든 팔에 대면 틀린다. 기체별로 다시 계산하면 이렇다(원장과 같은 규약 — 메쉬 3D 대각).
#
# | 기체 | 표적 크기 D | 원거리장 경계 2D²/λ | 이 원장의 팔이 선 거리 | 판정 |
# |---|---|---|---|---|
# | DJI Matrice 4E | 0.78 m | **14.10 m** | 10 m · 15 m · 30 m · 45 m · 60 m · 90 m · 120 m · 240 m · 480 m | ⚠10 m 는 **안쪽**(근접장, 경계의 0.71 배) |
# | DJI Mavic 4 Pro | 0.77 m | **13.77 m** | 15 m · 30 m · 120 m · 240 m | 전부 밖(원거리장) |
# | DJI Mini 5 Pro | 0.45 m | **4.82 m** | 15 m · 30 m · 60 m · 120 m · 240 m | 전부 밖(원거리장) |
# | DJI S1000+ | 1.92 m | **85.94 m** | 15 m · 30 m · 60 m · 120 m · 240 m | ⚠15 m 는 **안쪽**(근접장, 경계의 0.17 배) · 30 m 는 **안쪽**(근접장, 경계의 0.35 배) · 60 m 는 **안쪽**(근접장, 경계의 0.70 배) |
#
# ⚠**그래서 «15 m 면 원거리장» 이 아니다.** 근접장에 선 팔이 **71 개**다 — `ours` · `ours_n8192_rep1_mfixbatteryi5_blperairframe` · `ours_ptd_s1000plus_r15_n8192` · `ours_s1000plus_r15_n8192` · `ours_s1000plus_r15_n8192_az22.5` · `ours_s1000plus_r15_n8192_az45` · `ours_s1000plus_r15_n8192_az67.5` · `ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` ….
#
# 근접장에서는 파면이 표적 위에서 휘어 날개끝과 동체가 서로 다른 위상 기울기를 받는다. 그러니 그런 팔의 dB 는 물론 **리듬 몫도** 엔진 차이로 읽으면 안 된다 — «한 축만 다른 짝» 이라고 부르기 전에 이 표를 먼저 본다.
#
# ### 13.6 기체 태그가 붙은 팔은 박자가 다르다
#
# ⚠이름에 `mini5pro` · `s1000plus` 가 박힌 팔은 표적이 바뀐 판이라 **예측 박자가 다르다** — 날개 수 × 호버 rpm ÷ 60 이라 기체마다 다른 수가 나온다. 원장 `_meta.f_flash_hz` 는 기본 기체(matrice4e) 값이라 그대로 쓰면 그 팔의 점선이 전부 엉뚱한 자리에 선다.
#
# | 기체 | 박자 | 이 원장의 팔 |
# |---|---|---|
# | DJI Matrice 4E | 126.667 Hz | 313 |
# | DJI Mini 5 Pro | 183.333 Hz | 51 |
# | DJI S1000+ | 148.9 Hz | 49 |
# | DJI Mavic 4 Pro | 120 Hz | 32 |
#
# 이 아틀라스의 그림은 팔마다 `src/drones.py` 에서 박자를 다시 계산해 점선을 세웠다 — 절 14.3 의 자기검사가 그것을 확인한다.
#
# ### 13.7 ⭐리듬 몫의 **널도 기체마다 다르다**
#
# 백색잡음이면 리듬 몫이 얼마로 나오나 — DJI Matrice 4E ≈ 12.6 · DJI Mavic 4 Pro ≈ 13.5 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8. 창 폭(±8 Hz)을 박자로 나눈 값이 곧 널이라, 박자가 빠른 기체일수록 낮다. 그러므로 «13 아래면 리듬 없음» 은 기본 기체에서만 맞는 말이다. 표와 그림은 **그 칸의 널**을 함께 적는다.
#
# ### 13.8 **몇 자세가 튄 칸**의 박자는 박자가 아니다
#
# |AC| 의 최대 ÷ 중앙(= 튐 지표)이 100 을 넘는 칸이 **256 개**다. 자세 몇 개가 통째로 다른 값이면 맵은 그 자리에 세로 줄 하나만 남기고 나머지가 바닥색으로 깔리고(패널마다 자기 최댓값으로 정규화하므로), 그때 잡히는 «박자» 는 회전이 아니라 **그 튐들의 간격**이다. 표·그림에 «⚡ 큰 자세»·«(spiky)» 로 적었다. 예측의 0.5 배 미만처럼 이상한 배수가 나오면 먼저 이 깃발을 본다. ⚠이 잣대는 «얼마나 큰가» 만 잰다 — «얼마나 혼자인가» 는 바로 아래 절이다.
#
# ### 13.9 ⭐자세 **하나**가 헤드라인을 끄는 칸 11 개
#
# 2026-08-16 에 «−60° 에서 반사 깊이 3 이면 리듬 몫이 86.6 → 32.4 % 로 무너진다» 는 판정이 **자세 8,192 개 중 하나** 때문이었다. 그 자세를 이웃 평균으로 갈아 끼우면 두 판이 85.5 대 85.2 % 로 같다. 그래서 튐 진단을 **모든 칸에 상시로** 돌린다 — 그 칸에서 가장 큰 자세 하나를 이웃 평균으로 갈아 끼우고 헤드라인 넷(리듬 몫 · 빗살 대비 · 요동 전력 · 상한 위 몫)을 다시 재서, 움직인 폭이 ① 죄 없는 자세 12 개·둘째 자세를 같은 방법으로 갈아 끼웠을 때보다 꼬리 울타리 밖으로 크고 ② 그 앙각의 **격자 산포 밴드**보다 크면 «튐» 이다. 문턱은 둘 다 원장에서 읽어 온다(`outputs/outlier_census_0816.json` · 밴드 `benchmark/depth_axis_verdict_0816.py`).
#
# - ⚑ **sionna_phys** -15° — 자세 하나(#3195)가 격자 밴드보다 크게 헤드라인을 움직인다: 리듬 몫 +30%p > 격자밴드 0.1%p (299.7 배) · 쏠림 6667× · 요동 전력 -10.8dB > 격자밴드 1.31dB (8.2 배) · 쏠림 3301× · 빗살 대비 +16.3dB > 격자밴드 4.1dB (4.0 배) · 쏠림 403× · 상한 위 몫 -20.5%p > 격자밴드 12.5549%p (1.6 배) · 쏠림 933×
# - ⚑ **sionna_phys** -30° — 자세 하나(#2505)가 격자 밴드보다 크게 헤드라인을 움직인다: 빗살 대비 +8.77dB > 격자밴드 4.6dB (1.9 배) · 쏠림 216×
# - ⚑ **sionna_p4000000000_onlydepth3_r15_n8192** -60° — 자세 하나(#3399)가 격자 밴드보다 크게 헤드라인을 움직인다: 리듬 몫 +54%p > 격자밴드 16%p (3.4 배) · 쏠림 15534× · 요동 전력 -0.146dB > 격자밴드 0.02dB (7.3 배) · 쏠림 1046× · 빗살 대비 +20.9dB > 격자밴드 4dB (5.2 배) · 쏠림 2888×
# - ⚑ **sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2** -30° — 자세 하나(#2228)가 격자 밴드보다 크게 헤드라인을 움직인다: 요동 전력 -0.375dB > 격자밴드 0.37dB (1.0 배) · 쏠림 852× · 빗살 대비 +8.33dB > 격자밴드 4.6dB (1.8 배) · 쏠림 6091×
# - ⚑ **sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2** +0° — 자세 하나(#1649)가 격자 밴드보다 크게 헤드라인을 움직인다: 리듬 몫 +30.2%p > 격자밴드 11.8%p (2.6 배) · 쏠림 57963360× · 요동 전력 -52.8dB > 격자밴드 3.86dB (13.7 배) · 쏠림 11714118612× · 빗살 대비 -5.38dB > 격자밴드 0.1dB (53.8 배) · 쏠림 6709392× · 상한 위 몫 -82.1%p > 격자밴드 12.5549%p (6.5 배) · 쏠림 599397188×
# - ⚑ **sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2** -30° — 자세 하나(#8082)가 격자 밴드보다 크게 헤드라인을 움직인다: 요동 전력 -0.892dB > 격자밴드 0.37dB (2.4 배) · 쏠림 2185×
# - ⚑ **sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2** +0° — 자세 하나(#4426)가 격자 밴드보다 크게 헤드라인을 움직인다: 빗살 대비 -3.26dB > 격자밴드 0.1dB (32.6 배) · 쏠림 1122×
# - ⚑ **sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2** +0° — 자세 하나(#1649)가 격자 밴드보다 크게 헤드라인을 움직인다: 요동 전력 -12.4dB > 격자밴드 3.86dB (3.2 배) · 쏠림 16334×
# - ⚑ **sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2** +0° — 자세 하나(#6912)가 격자 밴드보다 크게 헤드라인을 움직인다: 리듬 몫 +37.6%p > 격자밴드 11.8%p (3.2 배) · 쏠림 721868× · 요동 전력 -48.5dB > 격자밴드 3.86dB (12.6 배) · 쏠림 244108324× · 빗살 대비 +25.4dB > 격자밴드 0.1dB (254.0 배) · 쏠림 385603× · 상한 위 몫 -15.8%p > 격자밴드 12.5549%p (1.3 배) · 쏠림 2506581×
# - ⚑ **sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2** +0° — 자세 하나(#2293)가 격자 밴드보다 크게 헤드라인을 움직인다: 리듬 몫 +21.7%p > 격자밴드 11.8%p (1.8 배) · 쏠림 27127× · 빗살 대비 +12.3dB > 격자밴드 0.1dB (123.5 배) · 쏠림 25061× · 상한 위 몫 -75.9%p > 격자밴드 12.5549%p (6.0 배) · 쏠림 6002×
# - ⚑ **sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2** -90° — 자세 하나(#7254)가 격자 밴드보다 크게 헤드라인을 움직인다: 요동 전력 -10.1dB > 격자밴드 5.62dB (1.8 배) · 쏠림 7288×
#
# - ⌗ **덜 찍힌 플래시 201 개** — ⭐**튐이 아니다.** 진짜 날개 플래시가 **한 표본 폭**으로 찍힌 것이다(에코는 날개끝 상한으로 대역제한이라 플래시의 최소 폭이 0° 에서 7.7 표본이어야 한다). 고칠 곳은 그 칸이 아니라 **표집**이고, 그 칸의 «상한 위 몫 · 빗살 대비» 를 인용할 때는 그 단서를 함께 적는다.
# - ◈ **경계 칸 20 개** — 쏠림의 분모가 «죄 없는 자세 12 개의 최댓값» 이라 어느 12 개를 뽑느냐에 등급이 걸린다. 중앙값 대조군으로 다시 재서 판정이 갈리면 이 깃발을 세우고, 감식 원장(`outputs/outlier_census_0816.json`)의 등급도 나란히 적는다.
#
# ⛔**깃발이 떴다고 그 칸을 자동으로 버리지 마라.** 뜻은 «이 수는 자세 하나에 걸려 있으니 그 자세를 열어 보라» 이지 «틀렸다» 가 아니다 — 로터가 시선과 딱 맞는 순간의 **진짜 정반사 플래시**도 이렇게 보인다. 그래서 «얼마나 큰가»(최대÷중앙)는 등급에 안 쓰고, «날개가 지나갈 때마다 다시 서나 · 이웃 자세와 이어지나 · 갈아 끼우면 헤드라인이 움직이나» 로만 판정한다.
#
# ### 13.10 박자와 맵은 **다른 구간**에서 잰 수다
#
# ⚠박자는 **전 구간**(자세 전부)으로 재고, 맵 그림은 20~80 ms 창만 그린다 — 같은 상자의 두 수가 다른 구간에서 나온 수다. 같은 상자 안에 있어도 «맵에 보이는 것» 과 «박자 수치» 는 같은 창의 이야기가 아니다.
#
# ### 13.11 ⭐아직 **못 고친 것** — 알고 쓰라고 적어 둔다
#
# - **덜 찬 칸 32 개의 참값** — 원장을 다시 병합해야 나온다. 이 문서는 원장을 읽기만 한다. 그 가운데 31 칸은 자세가 뭉텅이로 빠져 «0 을 걷어내고 다시 재는» 길도 없다(균일 표본이 아니다).
# - **주제 분류(`topic_of`)가 아직 이름 토막으로 거리를 본다** — 그래서 `_r` 토막이 없는 10 m 옛 팔이 «기본 엔진» 주제에 남아 있다. 원장 `range_m` 으로 바꾸면 그 팔들이 거리 주제로 옮겨가 그림 파일 이름이 전부 바뀌므로, 주제를 다시 짤 때 함께 고친다 — 그 사이의 안전장치가 절 13.4 의 거리 표와 그림 속 거리 라벨이다.
# - **맵은 패널마다 자기 최댓값으로 밝기를 맞춘다** — 그래서 거리와 세기를 그림에서 읽을 수 없다. 공통 눈금을 쓰면 눈금이 다른 두 엔진을 한 색역에 올리는 더 큰 거짓이 되므로 그대로 두었다.
# - **리듬 몫의 창 반폭은 8 Hz 고정** — `build_deck_maps.structure_bars` 와 정의를 맞추려고 그대로 두었다. 그 대가로 높은 배음일수록 창 밖으로 새어 100 이 도달 불가다.
#
# 수리의 «전 → 후» 수치는 `outputs/atlas_falsify.json` 에 있다 (`benchmark/audit_atlas_repair.py`).

# %% [markdown]
# ---
#
# ## 절 14. 누락 검사
#
# > **원장 1433 칸 가운데 그림이 없는 칸은 0 개다.**
#
# 세는 법 — 팔 하나의 맵 그림은 **그 팔이 가진 앙각을 가로로 늘어놓은 격자**라, 칸 하나가 열 하나다. 그래서 «칸에 그림이 있나» 는 «그 칸이 어느 맵의 열로 그려졌나» 로 센다. 색인을 믿지 않고 원장 npz 의 키에서 팔과 앙각을 다시 뽑아 맞췄다.
#
# | 검사 | 결과 |
# |---|---|
# | 원장 팔 · 칸 | 445 팔 · 1433 칸 (원장 `rows` 1433 행과 일치) |
# | 그림 열이 없는 칸 | **0 개** |
# | 색인에만 있고 원장에 없는 팔 | 0 개 |
# | 원장에만 있고 색인에 없는 팔 | 0 개 |
# | 색인이 가리키는데 디스크에 없는 그림 파일 | 0 개 |
#
# 빠진 칸이 없으므로 아래에 목록이 없다. 대신 «그림은 있는데 볼 것이 없는 칸» 과 «애초에 원장에 없는 자리» 를 남긴다 — 찾다가 허탕치는 자리는 그 둘이다.
#
# ### 14.1 그림은 있는데 **아무것도 안 돌아온** 칸 (9 개)
#
# 원장의 시계열이 통째로 0 인 칸이다(원장 `level_db` 도 −6000 이라는 표식이 붙는다 — 잰 세기가 아니라 **«없음» 표식**이다). 맵은 그려지지만 패널에 «nothing came back» 이라고 적히고, 대역 에너지 그림에는 그 앙각의 곡선이 **아예 안 그려진다** — 0 을 dB 로 바꾸면 −∞ 라 보이지 않는 선이 범례에만 남기 때문이다.
#
# ⚠**왜 비었나 를 스위치 탓으로만 적으면 틀린다.** 생성기 `benchmark/elevation_sweep_md.py` 는 `los=True, specular_reflection=True` 를 **하드코딩**하고 굴절·회절·모서리·확산만 `--sw` 로 켜고 끈다. 즉 `swR0D0E0F0` 도 «전부 끔» 이 아니라 «정반사와 직선경로는 켜 둔 채 나머지 넷을 끈» 판이다. 그런데도 표적 경유 경로가 0 개라는 것이 사실이다 (원장 실측 −30°: `swR0D0E0F0` 경로 0 · `swR1D0E0F0`(굴절만) 0 · `swR0D1E0F0`(회절만) 8).
#
# | 팔 | 앙각 | 왜 |
# |---|---|---|
# | `sionna_p4000000000_stockdef_r15_n8192` | −15° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −30° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −45° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −60° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −75° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_stockdef_r15_n8192` | −90° | PathSolver 순정 기본값 조합(정반사·굴절 켬)이 이 앙각에서 표적 경유 경로를 하나도 못 찾았다 |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` | −30° | 굴절 · 회절 · 모서리 · 확산을 끈 조합 — **정반사·LOS 는 켜져 있는데도** 표적 경유 경로가 0 개다 |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` | −30° | 굴절 · 회절 · 모서리 · 확산을 끈 조합 — **정반사·LOS 는 켜져 있는데도** 표적 경유 경로가 0 개다 |
# | `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` | −30° | 굴절만 켠 조합(정반사·LOS 는 켬)이 이 앙각에서 경로를 못 찾았다 |
#
# ### 14.1b ⭐**아직 덜 찬** 칸 (32 개) — 수를 내지 않는다
#
# 원장 `n_missing` 열이 «이 칸은 자세가 덜 찼다» 고 적어 둔 칸이다(또는 시계열 안에 «정확히 0» 인 표본이 섞여 있는 칸). 실험이 도는 중이라 병합이 아직 절반인 것이다.
#
# ⭐**왜 수를 내면 안 되나** — 빠진 자세 자리가 0 으로 채워져 있어서, 0 채움이 스펙트럼을 PRF/2 · PRF/4 자리에 **복제**한다. 그 복제본이 «날개끝 상한 위» 에 앉아 그 대역의 에너지를 거의 다 차지하고, 그래서 리듬 몫이 0 % 로 주저앉는다 — **물리가 아니라 결측 자국**이다. 맵에는 날개 무늬가 또렷한데 구석에 «0 %» 가 적히는 모순이 그렇게 생겼다(2026-08-15 정정 전 판이 그랬다).
#
# ⚠**«0 을 빼고 다시 재면 되지 않나»** — 안 된다. 덜 찬 32 칸 가운데 빠진 자리가 균일한 칸은 하나뿐이고(한 칸 걸러 하나), 나머지 31 칸은 자세가 뭉텅이로 빠져 (4 개 중 2·3번째, 8 개 중 5~8번째) **균일 표본이 아니다** — 그런 자료의 스펙트럼은 정의되지 않는다. 고치는 길은 하나뿐이다: **원장을 다시 병합한다.**
#
# | 팔 | 앙각 | 들어온 자세 | 빠진 자세 | 거리 |
# |---|---|---|---|---|
# | `ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_r15_n8192_shift1` | −15° | 512 | 7,680 | 15.0 m |
# | `sionna_p4000000000` | −75° | 2,048 | 2,048 | 10.0 m |
# | `sionna_p4000000000_onlyrefr_mini5pro_r240_n8192` | −30° | 695 | 7,497 | 240.0 m |
# | `sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe` | −30° | 2,199 | 5,993 | 240.0 m |
# | `sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe` | −30° | 862 | 7,330 | 480.0 m |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | 0° | 4,096 | 4,096 | 15.0 m |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_mini5pro_r15_n8192_mfixbatteryi5` | −60° | 4,096 | 4,096 | 15.0 m |
# | `ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | −30° | 4,096 | 4,096 | 15.0 m |
# | `sionna_p4000000000_r480_n8192_d1` | −30° | 2,905 | 5,287 | 480.0 m |
# | `sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1` | −30° | 2,994 | 5,198 | 480.0 m |
#
# ⚠**원장 병합이 낡았다** — `outputs/elev_sweep_shards/` 에 원장보다 새로운 샤드가 407 개 있다. 다시 병합하면 이 칸들이 채워질 수 있다(이 아틀라스는 원장만 읽으므로 병합은 스윕 쪽 일이다).
#
# ### 14.1c **움직이는 것이 없는** 칸 (3 개)
#
# 시계열이 사실상 상수인 칸이다 — AC/DC 가 배정밀도 반올림 바닥(1e-12) 아래다. 프로펠러를 뺀 대조군이 그렇다: 돌아가는 것이 없으니 흔들릴 것도 없다.
#
# ⭐그런 칸에서 뽑은 «박자» 는 **1 ULP(마지막 자리 한 칸)를 흔든 자리**라 재현되지 않는다 — 계산 순서를 조금만 바꿔도 봉우리가 다른 자리로 옮겨간다. 그래서 수를 내지 않는다(정정 전 판은 «beat 204 Hz = 1.61x · 움직이는 전력 −384 dB» 라고 적었다. −384 dB 는 물리량이 아니다).
#
# | 팔 | 앙각 | AC/DC |
# |---|---|---|
# | `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` | 0° | 3.1e-32 |
# | `sionna_p4000000000_partsnoprop_r15_n8192_d1` | 0° | 7.542e-33 |
# | `sionna_p4000000000_r480_n8192_d1` | 0° | 6.323e-33 |
#
#
# ### 14.2 애초에 **원장에 없는 자리** (1770 칸)
#
# 7 점 격자(0° · −15° … −90°)를 다 채웠다면 445 × 7 = 3115 칸일 텐데 원장에는 1433 칸이 있다. 나머지 1770 칸은 **안 돌린 자리**다 — 그림이 빠진 것이 아니라 계산이 없다. 표와 지도에서 `—` 로 나온다.
#
# 대부분은 설계가 그랬다 — 스위치 조합 판은 «어느 스위치가 리듬을 죽이나» 하나만 물으려고 −30° 한 점에서만 돌렸고, 방위 · 부품 판은 네 점(0° · −30° · −60° · −90°), 격자 판은 위쪽 네 점(0° ~ −45°)만 돌렸다. 거리 판은 정면 한 점이고, 평면파 판은 직하방 한 점이다.
#
# ⚠**설계 격자 어디에도 안 맞는 팔이 있다.** 위 네 가지(7 점 · 성긴 4 점 · 촘촘한 4 점 · 1 점) 중 어느 것도 아닌 앙각 구성이다 — 왜 그 칸만 비었는지는 원장에 적혀 있지 않다. 그 자리를 인용하려면 다시 돌려야 한다.
#
# | 팔 | 있는 앙각 | 없는 앙각 |
# |---|---|---|
# | `ours_mavic4pro_r15_n8192` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_mavic4pro_r15_n8192_mfixbatteryi5` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_mini5pro_r120_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_mini5pro_r15_n8192_az22.5` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_mini5pro_r15_n8192_az45` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_mini5pro_r15_n8192_az67.5` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_mini5pro_r15_n8192_mfixbatteryi5` | 0° · −15° · −30° · −45° · −60° | **−75° · −90°** |
# | `ours_mini5pro_r30_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_mini5pro_r60_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_n8192_rep1_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r120_n8192` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n32768` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_az22.5` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_az45_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_az67.5` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_az90` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_az90_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_fs2_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_ps2_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r15_n8192_rep1_mfixbatteryi5_blperairframe` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_r15_n8192_rep2_mfixbatteryi5_blperairframe` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` | 0° · −30° · −45° · −60° | **−15° · −75° · −90°** |
# | `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | 0° · −30° · −45° · −60° | **−15° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | 0° · −30° · −45° · −60° · −90° | **−15° · −75°** |
# | `ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r240_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r30_n8192` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r30_n8192_az45_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r30_n8192_az90_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r480_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r60_n8192` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `ours_r60_n8192_az45_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r60_n8192_az90_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_s1000plus_r120_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_s1000plus_r15_n8192_az22.5` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_s1000plus_r15_n8192_az45` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_s1000plus_r15_n8192_az67.5` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `ours_s1000plus_r30_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `ours_s1000plus_r60_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` | −52° · −68° · −82° | **0° · −15° · −30° · −45° · −60° · −75° · −90°** |
# | `sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` | −52° · −68° · −82° | **0° · −15° · −30° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000` | 0° · −15° · −45° · −60° · −75° | **−30° · −90°** |
# | `sionna_p4000000000_mavic4pro_r15_n8192_d1` | −30° · −60° | **0° · −15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_mini5pro_r120_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_mini5pro_r30_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_mini5pro_r60_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192` | −30° · −60° | **0° · −15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` | 0° · −30° · −52° · −60° · −68° · −82° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r120_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` | −15° · −30° · −60° | **0° · −45° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45` | −15° · −30° · −60° | **0° · −45° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` | −15° · −30° · −60° | **0° · −45° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r240_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r30_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_r60_n8192` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` | 0° · −30° · −52° · −60° · −68° · −82° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_phys_r120_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_phys_r30_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_phys_r60_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r120_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r15_n8192_az22.5_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r15_n8192_az67.5_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r15_n8192_az90_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` | 0° · −15° · −30° · −60° | **−45° · −75° · −90°** |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r240_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_r30_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_r480_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_r60_n8192_d1` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_s1000plus_r120_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_s1000plus_r30_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_s1000plus_r60_n8192_d1` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | 0° · −30° | **−15° · −45° · −60° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | 0° · −15° · −30° · −45° · −60° · −75° | **−90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | 0° · −30° · −60° | **−15° · −45° · −75° · −90°** |
# | `sionna_r15_n8192_mfixbatteryi5_blperairframe` | −15° · −45° · −75° | **0° · −30° · −60° · −90°** |
#
# **전체 목록** — 원장에 칸이 덜 찬 팔 387 개(나머지 58 개는 7 점을 다 채웠다).
#
# | 팔 | 없는 앙각 |
# |---|---|
# | `ours_mavic4pro_r120_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_mavic4pro_r15_n8192` | −90° |
# | `ours_mavic4pro_r15_n8192_mfixbatteryi5` | −90° |
# | `ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | −15° · −45° · −75° |
# | `ours_mavic4pro_r240_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_mavic4pro_r30_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r120_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r120_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r15_n8192_az22.5` | −90° |
# | `ours_mini5pro_r15_n8192_az45` | −90° |
# | `ours_mini5pro_r15_n8192_az67.5` | −90° |
# | `ours_mini5pro_r15_n8192_mfixbatteryi5` | −75° · −90° |
# | `ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | −15° · −45° · −75° |
# | `ours_mini5pro_r240_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r240_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r30_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r30_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_mini5pro_r60_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_n8192_rep1_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_ptd_mini5pro_r15_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r120_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r15_n8192_az22.5` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r15_n8192_div24` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r30_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_r60_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_ptd_s1000plus_r15_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r120_n8192` | −15° · −45° · −75° · −90° |
# | `ours_r120_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n32768` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_az15` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az15_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az22.5` | −90° |
# | `ours_r15_n8192_az22.5_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az30` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az30_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az45_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az60` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az60_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az67.5` | −90° |
# | `ours_r15_n8192_az67.5_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az75` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az75_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_az90` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_az90_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_bs0.4_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_bs0.6_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_bs0.8_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_div24_shift0.5` | 0° · −30° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_div48` | 0° · −30° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_fs1.4_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_fs2_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_prf157600_mfixbatteryi5_blperairframe` | −15° · −45° · −75° |
# | `ours_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | −15° · −45° · −75° |
# | `ours_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | −15° · −45° · −75° |
# | `ours_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_ps0.7_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_ps1.4_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_ps2_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_pw` | 0° · −15° · −30° · −45° · −60° · −75° |
# | `ours_r15_n8192_rep1_mfixbatteryi5_blperairframe` | −90° |
# | `ours_r15_n8192_rep2_mfixbatteryi5_blperairframe` | −90° |
# | `ours_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` | −15° · −75° · −90° |
# | `ours_r15_n8192_rotlegacys1_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotlegacys2_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | −15° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | −15° · −75° |
# | `ours_r15_n8192_rotoutdoor_v2s1_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoor_v2s2_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoor_v2s3_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoor_v2s4_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoor_v2s5_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoors1_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoors2_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoors3_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_rotoutdoors4_mfixbatteryi5_blperairframe` | −15° · −45° · −75° · −90° |
# | `ours_r15_n8192_shift0.37x-0.19` | 0° · −30° · −45° · −60° · −75° · −90° |
# | `ours_r15_n8192_shift0.5` | −60° · −75° · −90° |
# | `ours_r15_n8192_shift1` | 0° · −30° · −45° · −60° · −75° · −90° |
# | `ours_r240_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r240_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r30_n8192` | −15° · −45° · −75° · −90° |
# | `ours_r30_n8192_az45_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r30_n8192_az90_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r480_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r480_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_r60_n8192` | −15° · −45° · −75° · −90° |
# | `ours_r60_n8192_az45_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r60_n8192_az90_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r60_n8192_prf39400_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r60_n8192_prf78800_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r90_n8192_prf39400_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_r90_n8192_prf78800_mfixbatteryi5_blperairframe` | −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r120_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r120_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r15_n8192_az22.5` | −90° |
# | `ours_s1000plus_r15_n8192_az45` | −90° |
# | `ours_s1000plus_r15_n8192_az67.5` | −90° |
# | `ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | −15° · −45° · −75° |
# | `ours_s1000plus_r240_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r240_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r30_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r30_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `ours_s1000plus_r60_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p1000000000_swR1D1E1F1_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p1000000000_swR1D1E1F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000` | −30° · −90° |
# | `sionna_p4000000000_mavic4pro_r15_n8192_d1` | 0° · −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_mini5pro_r120_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_mini5pro_r30_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_mini5pro_r60_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlydepth3_r15_n8192` | −15° · −45° · −75° |
# | `sionna_p4000000000_onlyedge_r15_n8192` | −15° · −45° · −75° |
# | `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192` | 0° · −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_mini5pro_r120_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_mini5pro_r240_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_mini5pro_r30_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_mini5pro_r60_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r120_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` | 0° · −45° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45` | 0° · −45° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` | 0° · −45° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az90` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r240_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r30_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r60_n8192` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_s1000plus_r120_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_s1000plus_r240_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_s1000plus_r30_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_onlyrefr_s1000plus_r60_n8192` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_partsnoprop_r15_n8192_d1` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_partsprop_r15_n8192_d1` | −15° · −45° · −75° |
# | `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_phys_partsprop_r15_n8192_d1` | −15° · −45° · −75° |
# | `sionna_p4000000000_phys_r120_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_phys_r15_n8192_az45_d1` | −15° · −45° · −75° |
# | `sionna_p4000000000_phys_r15_n8192_shell0.75mm_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_phys_r30_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_phys_r60_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r120_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r120_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r120_n8192_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n32768_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_az22.5_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_az45_d1` | −15° · −45° · −75° |
# | `sionna_p4000000000_r15_n8192_az45_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_az67.5_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_az90_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.5mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.5mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop0.9mm_d1` | −45° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop1.43mm_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell0.75mm_prop2mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r15_n8192_shell1.5mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r240_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r240_n8192_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r30_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r30_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r30_n8192_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r480_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r480_n8192_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_r60_n8192_d1` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_r60_n8192_mfixbatteryi5_blperairframe_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r120_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r30_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_s1000plus_r60_n8192_d1` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` | 0° · −15° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | −15° · −30° · −45° · −60° · −75° · −90° |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | −15° · −45° · −75° |
# | `sionna_r15_n8192_mfixbatteryi5_blperairframe` | 0° · −30° · −60° · −90° |
#
# ### 14.3 자기검사
#
# | 검사 | 통과 | 실측 |
# |---|---|---|
# | 기체별 박자·날개끝 상한을 `src/drones.py` 에서 다시 계산해 색인과 대조 ⚠(같은 식·같은 입력이라 **항진명제**다 — 아래 원장 대조가 진짜 검사다) | ✅ | 팔 445 개 전부 일치 |
# | ⭐원장이 **스스로 잰** 박자(`track.beat_hz`)가 우리가 세운 예측 박자의 정수배 ±3 % 안에 든다 — 색인과 무관한 독립 증거 | ❌ | 맞음 1014 칸 · 어긋남 260 칸 (가장 먼 칸 sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2@-60 63.34 Hz = 0.50x) |
# | 기체 태그 팔의 박자가 원장 기본값과 **다르다**(그대로 썼으면 틀렸을 자리) | ✅ | mavic4pro 120 Hz · mini5pro 183.333 Hz · s1000plus 148.9 Hz ↔ 원장 기본 126.67 Hz |
# | ⭐수를 낼 자격이 없는 칸(덜 참 · 안 움직임 · 에코 없음)에 **잣대가 하나도 안 실렸다** | ✅ | 덜 참 32 · 안 움직임 3 · 에코 없음 9 칸, 새어 나온 수 0 개 |
# | 원장 병합이 최신이다 — 샤드 파일 가운데 원장보다 새 것이 없다 | ❌ | ⚠원장보다 새 샤드 407 개 — 병합이 낡았다(예: `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe_el+0_01.npz`) |
# | 원장 칸 수와 색인 칸 수가 같다 | ✅ | 원장 npz 1433 · 원장 rows 1433 · 색인 1433 |
# | 색인이 가리키는 그림 파일이 전부 디스크에 있다 | ✅ | 그림 961 장 · 빠진 파일 0 개 |
# | 원장에 있는데 그림 열이 없는 칸이 없다 | ✅ | 빠진 칸 0 개 |
#
# | | |
# |---|---|
# | 출력 | `reports/A_atlas.ipynb` |
# | 읽는 것 | `outputs/md_atlas_index.json` · `outputs/elevation_sweep_md.{json,npz}` · `outputs/grid_convergence_check.json` · `src/drones.py` |
# | 만든 곳 | `benchmark/build_atlas_toc.py` (그림은 `benchmark/build_md_atlas.py`) |
# | 소요 | CPU 로 수 초. GPU 를 안 쓴다 |

# %% [markdown]
# ---
#
# ## 조각에서 이어붙인 절
#
# 아래 절 15~14 는 `reports/_parts/` 의 조각을 그대로 이어 붙인 것이다 — 같은 물음(무엇이 무늬를 정하나)에 답하기 때문이다. 각주는 이 편 안에서 다시 번호가 매겨졌다.
#
# ⭐ 이 절들을 손으로 고치지 마라. 고칠 곳은 그 조각을 만든 `src/build_partNN_*.py` 이고, 고친 뒤 `src/build_volumes.py` 를 다시 돌리면 여기가 따라 바뀐다.
