# %% [markdown]
# # 도감 B — 스위치 — 굴절·회절·모서리·확산을 켜고 끈 조합
#
# [← 도감 지도](A_atlas.ipynb) 로 돌아간다. 이 편은 도감의 **절 4** 하나다 — 주제마다 파일을 나눴다.

# %% [markdown]
# ---
#
# ## 절 4. 스위치 — 굴절·회절·모서리·확산을 켜고 끈 조합
#
# > **묻는 것** — 굴절 · 회절 · 모서리 회절 · 확산 반사 중 **무엇을 켜면** 날개 리듬이 백색 수준으로 주저앉나.
#
# 팔 247 개 · 칸 756 개 · 그림 526 장. 그림 파일은 전부 `outputs/figures/atlas/02switch__…` 로 시작한다.

# %% [markdown]
# ![physics switches — 02switch__000-overview-rhythm.png](../outputs/figures/atlas/02switch__000-overview-rhythm.png)
#
# **그림 134.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![physics switches — 02switch__01-compare-tile+0-p1.png](../outputs/figures/atlas/02switch__01-compare-tile+0-p1.png)
#
# **그림 135.** 앙각이 **0° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![physics switches — 02switch__01-compare-tile+0-p2.png](../outputs/figures/atlas/02switch__01-compare-tile+0-p2.png)
#
# **그림 136.** 앙각이 **0° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![physics switches — 02switch__01-compare-tile-30-p1.png](../outputs/figures/atlas/02switch__01-compare-tile-30-p1.png)
#
# **그림 137.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![physics switches — 02switch__01-compare-tile-30-p2.png](../outputs/figures/atlas/02switch__01-compare-tile-30-p2.png)
#
# **그림 138.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![physics switches — 02switch__01-compare-tile-30-p3.png](../outputs/figures/atlas/02switch__01-compare-tile-30-p3.png)
#
# **그림 139.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p1.png](../outputs/figures/atlas/02switch__02-compare-stack-p1.png)
#
# **그림 140.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p2.png](../outputs/figures/atlas/02switch__02-compare-stack-p2.png)
#
# **그림 141.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p3.png](../outputs/figures/atlas/02switch__02-compare-stack-p3.png)
#
# **그림 142.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p4.png](../outputs/figures/atlas/02switch__02-compare-stack-p4.png)
#
# **그림 143.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p5.png](../outputs/figures/atlas/02switch__02-compare-stack-p5.png)
#
# **그림 144.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p6.png](../outputs/figures/atlas/02switch__02-compare-stack-p6.png)
#
# **그림 145.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p7.png](../outputs/figures/atlas/02switch__02-compare-stack-p7.png)
#
# **그림 146.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p8.png](../outputs/figures/atlas/02switch__02-compare-stack-p8.png)
#
# **그림 147.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p9.png](../outputs/figures/atlas/02switch__02-compare-stack-p9.png)
#
# **그림 148.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p10.png](../outputs/figures/atlas/02switch__02-compare-stack-p10.png)
#
# **그림 149.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p11.png](../outputs/figures/atlas/02switch__02-compare-stack-p11.png)
#
# **그림 150.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p12.png](../outputs/figures/atlas/02switch__02-compare-stack-p12.png)
#
# **그림 151.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p13.png](../outputs/figures/atlas/02switch__02-compare-stack-p13.png)
#
# **그림 152.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p14.png](../outputs/figures/atlas/02switch__02-compare-stack-p14.png)
#
# **그림 153.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p15.png](../outputs/figures/atlas/02switch__02-compare-stack-p15.png)
#
# **그림 154.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p16.png](../outputs/figures/atlas/02switch__02-compare-stack-p16.png)
#
# **그림 155.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p17.png](../outputs/figures/atlas/02switch__02-compare-stack-p17.png)
#
# **그림 156.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p18.png](../outputs/figures/atlas/02switch__02-compare-stack-p18.png)
#
# **그림 157.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p19.png](../outputs/figures/atlas/02switch__02-compare-stack-p19.png)
#
# **그림 158.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p20.png](../outputs/figures/atlas/02switch__02-compare-stack-p20.png)
#
# **그림 159.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p21.png](../outputs/figures/atlas/02switch__02-compare-stack-p21.png)
#
# **그림 160.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p22.png](../outputs/figures/atlas/02switch__02-compare-stack-p22.png)
#
# **그림 161.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p23.png](../outputs/figures/atlas/02switch__02-compare-stack-p23.png)
#
# **그림 162.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p24.png](../outputs/figures/atlas/02switch__02-compare-stack-p24.png)
#
# **그림 163.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p25.png](../outputs/figures/atlas/02switch__02-compare-stack-p25.png)
#
# **그림 164.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![physics switches — 02switch__02-compare-stack-p26.png](../outputs/figures/atlas/02switch__02-compare-stack-p26.png)
#
# **그림 165.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 4.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mavic 4 Pro ≈ 13.5 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −4° | −8° | −11° | −15° | −30° | −45° | −52° | −60° | −68° | −75° | −82° | −90° |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# | `sionna_p1000000000_swR1D1E1F1_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 14 | — | — | — | — | — | — | — |
# | `sionna_p1000000000_swR1D1E1F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 15 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlydepth3_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 81 | — | — | 32 | — | — | — | 98\* |
# | `sionna_p4000000000_onlydiffr_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | 12 | 12 | 13 | — | 14 | — | 13 | — | 13\* |
# | `sionna_p4000000000_onlyedge_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 80 | — | — | 87 | — | — | — | 98\* |
# | `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192` | DJI Mavic 4 Pro · 120 Hz | 15 m | — | — | — | — | — | 69 | — | — | 73 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 15 m | 13 | — | — | — | 55 | 73 | 70 | 63 | 71 | 69 | 65 | 60 | 70\* |
# | `sionna_p4000000000_onlyrefr_mini5pro_r120_n8192` | DJI Mini 5 Pro · 183.333 Hz | 120 m | — | — | — | — | — | 76 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | — | — | — | 71 | — | 57 | 59 | 58 | — | 56 | — |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5` | DJI Mini 5 Pro · 183.333 Hz | 15 m | — | — | — | — | — | 64 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45` | DJI Mini 5 Pro · 183.333 Hz | 15 m | — | — | — | — | — | 73 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | 46 | 74 | 58 | 58 | 59 | 57 | 52 | 58 | 39\* |
# | `sionna_p4000000000_onlyrefr_mini5pro_r240_n8192` | DJI Mini 5 Pro · 183.333 Hz | 240 m | — | — | — | — | — | ◐ | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_mini5pro_r30_n8192` | DJI Mini 5 Pro · 183.333 Hz | 30 m | — | — | — | — | — | 66 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_mini5pro_r60_n8192` | DJI Mini 5 Pro · 183.333 Hz | 60 m | — | — | — | — | — | 66 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | ○ | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 53 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r120_n8192` | DJI Matrice 4E · 126.667 Hz | 120 m | 44 | — | — | — | — | 66 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 120 m | — | — | — | — | — | 64 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | 52 | 58 | 56 | 61 | 62 | 65 | 64 | 64 | 11 | 57 | 62 | 62\* |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | 61 | 65 | — | — | 61 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 69 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | 66 | 64 | — | — | 58 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 62 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | 51 | 64 | — | — | 61 | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 67 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_az90` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 65 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | 61 | 59 | 64 | 65 | 62 | 62 | 52 | 57 | 57\* |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 62 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 40 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 41 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r240_n8192` | DJI Matrice 4E · 126.667 Hz | 240 m | 56 | — | — | — | — | 69 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 240 m | — | — | — | — | — | ◐ | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r30_n8192` | DJI Matrice 4E · 126.667 Hz | 30 m | 13 | — | — | — | — | 64 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 30 m | — | — | — | — | — | 65 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 480 m | — | — | — | — | — | ◐ | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r60_n8192` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | — | — | — | 70 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe` | DJI Matrice 4E · 126.667 Hz | 60 m | — | — | — | — | — | 62 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_s1000plus_r120_n8192` | DJI S1000+ · 148.9 Hz | 120 m | — | — | — | — | — | 42 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` | DJI S1000+ · 148.9 Hz | 15 m | 30 | — | — | — | — | 36 | — | 56 | 66 | 55 | — | 12 | — |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5` | DJI S1000+ · 148.9 Hz | 15 m | — | — | — | — | — | 29 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45` | DJI S1000+ · 148.9 Hz | 15 m | — | — | — | — | — | 53 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` | DJI S1000+ · 148.9 Hz | 15 m | 34 | — | — | — | 27 | 43 | 51 | 53 | 57 | 51 | 19 | 70 | 82\* |
# | `sionna_p4000000000_onlyrefr_s1000plus_r240_n8192` | DJI S1000+ · 148.9 Hz | 240 m | — | — | — | — | — | 52 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_s1000plus_r30_n8192` | DJI S1000+ · 148.9 Hz | 30 m | — | — | — | — | — | 52 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_onlyrefr_s1000plus_r60_n8192` | DJI S1000+ · 148.9 Hz | 60 m | — | — | — | — | — | 46 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_stockdef_r15_n8192` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | ∅ | ∅ | ∅ | — | ∅ | — | ∅ | — | ∅ |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | ∅ | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | ∅ | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 13 | — | — | — | — | 81 | — | — | 95 | — | — | — | 99\* |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 13 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | 15 | — | — | 27 | — | — | — | 72\* |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | 90 | — | — | 90 | — | — | — | 97\* |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | — | — | — | 14 | — | — | 35 | — | — | — | 43\* |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 80 | — | — | 93 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 80 | — | — | 93 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 80 | — | — | 93 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 80 | — | — | 93 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 80 | — | — | 93 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 85 | — | — | — | — | 84 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 78 | — | — | — | — | 81 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 72 | — | — | — | — | 85 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 78 | — | — | — | — | 82 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 78 | — | — | 89 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 79 | — | — | 91 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 79 | — | — | 90 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 12 | — | — | 13 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 82 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 82 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 81 | — | — | 90 | — | — | — | 98\* |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 13 | — | — | 13 | — | — | — | 6\* |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 41 | — | — | 38 | — | — | — | 54\* |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 17 | — | — | 20 | — | — | — | 31\* |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | — | 78 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 75 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 11 | — | — | — | — | 94 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 92 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 99 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 98 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | 76 | 81 | 86 | — | 90 | — | 95 | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | 76 | 81 | 86 | — | 90 | — | 95 | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | 76 | 81 | 86 | — | 90 | — | 95 | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 81 | — | — | 90 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 81 | — | — | 90 | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 19 | — | — | 17 | — | — | — | 64\* |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 30 m | 74 | — | — | — | — | 81 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 30 m | 77 | — | — | — | — | 81 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 30 m | 12 | — | — | — | 75 | 79 | 85 | — | 89 | — | 93 | — | 97\* |
# | `sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 45 m | 12 | — | — | — | 77 | 79 | 82 | — | 90 | — | 96 | — | 97\* |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 79 | — | — | — | — | 82 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 78 | — | — | — | — | 80 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 12 | — | — | — | 78 | 81 | 86 | — | 87 | — | 93 | — | 98\* |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | — | — | — | 38 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 12 | — | — | — | — | 23 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 90 m | 89 | — | — | — | 79 | 79 | 83 | — | 88 | — | 95 | — | 96\* |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 90 m | 12 | — | — | — | — | 34 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 90 m | 12 | — | — | — | — | 20 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 31 | — | — | — | — | 40 | — | — | 88 | — | — | — | 100\* |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 26 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 12 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 9 | — | — | — | — | 8 | — | — | 11 | — | — | — | 69\* |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 11 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 11 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 11 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | 15 | — | — | 15 | — | — | — | 35\* |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 15 | — | — | — | — | 16 | — | — | 14 | — | — | — | 23\* |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | 9 | — | — | 11 | — | — | — | 9\* |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | — | — | — | 8 | — | — | 10 | — | — | — | 8\* |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 15 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 12 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 19 | — | — | — | — | 15 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 27 | — | — | — | — | 16 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 15 | — | — | — | — | 12 | — | — | 13 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | — | 12 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 11 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 15 | — | — | — | — | 13 | — | — | 13 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 15 | — | — | — | — | 13 | — | — | 15 | — | — | — | 12\* |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 13 | — | — | 12 | — | — | — | 12\* |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 13 | — | — | 12 | — | — | — | 12\* |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 13 | — | — | 12 | — | — | — | 13\* |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 19 | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | — | 14 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 18 | — | — | — | — | 17 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 15 | — | — | — | 12 | 13 | 13 | — | 15 | — | 12 | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 15 | — | — | — | 12 | 13 | 13 | — | 15 | — | 12 | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 15 | — | — | — | 12 | 13 | 13 | — | 15 | — | 12 | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 15 | — | — | — | — | 13 | — | — | 15 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 15 | — | — | — | — | 13 | — | — | 15 | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 13 | — | — | 12 | — | — | — | 13\* |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 30 m | 14 | — | — | — | — | 21 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 30 m | 16 | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 30 m | 12 | — | — | — | 12 | 12 | 13 | — | 14 | — | 13 | — | 13\* |
# | `sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 45 m | 13 | — | — | — | 13 | 13 | 14 | — | 14 | — | 14 | — | 13\* |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 18 | — | — | — | — | 81 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | — | — | 13 | 17 | 14 | — | 14 | — | 13 | — | 12\* |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 90 m | 23 | — | — | — | 13 | 14 | 14 | — | 14 | — | 16 | — | 12\* |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 90 m | 13 | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 90 m | 13 | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 11 | — | — | — | — | 10 | — | — | 11 | — | — | — | 53\* |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 12 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 11 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 12 | — | — | — | — | 11 | — | — | 10 | — | — | — | 33\* |
# | `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | ∅ | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 12 | — | — | — | — | 73 | — | — | 71 | — | — | — | 70\* |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 15 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 13 | — | — | — | — | 17 | — | — | 21 | — | — | — | 36\* |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | — | — | 49 | 71 | 61 | — | 59 | — | 54 | — | 46\* |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | 73 | — | — | 60 | — | — | — | 39\* |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | 16 | — | — | 19 | — | — | — | 18\* |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 12 | — | — | — | — | 63 | — | — | 63 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 12 | — | — | — | — | 63 | — | — | 63 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 12 | — | — | — | — | 63 | — | — | 63 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 12 | — | — | — | — | 63 | — | — | 63 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 12 | — | — | — | — | 63 | — | — | 63 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 50 | — | — | — | — | 68 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 50 | — | — | — | — | 60 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 52 | — | — | — | — | 65 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 39 | — | — | — | — | 62 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 62 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 13 | — | — | 13 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 59 | — | — | 63 | — | — | — | 57\* |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 11 | — | — | 13 | — | — | — | 10\* |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | — | 37 | — | — | 35 | — | — | — | 40\* |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 19 | — | — | 21 | — | — | — | 15\* |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | 59 | 59 | 64 | — | 63 | — | 52 | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | 59 | 59 | 64 | — | 63 | — | 52 | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | 59 | 59 | 64 | — | 63 | — | 52 | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 59 | — | — | 63 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 59 | — | — | 63 | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 17 | — | — | 17 | — | — | — | 26\* |
# | `sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 61 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 30 m | 12 | — | — | — | 58 | 65 | 60 | — | 61 | — | 59 | — | 52\* |
# | `sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 45 m | 12 | — | — | — | 64 | 65 | 63 | — | 61 | — | 58 | — | 51\* |
# | `sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 12 | — | — | — | 60 | 61 | 60 | — | 60 | — | 54 | — | 46\* |
# | `sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 90 m | 51 | — | — | — | 73 | 56 | 65 | — | 60 | — | 62 | — | 54\* |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1` | DJI S1000+ · 148.9 Hz | 15 m | 30 | — | — | — | 26 | 36 | 51 | — | 66 | — | 18 | — | 14\* |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 34 | — | — | — | — | 43 | — | — | 58 | — | — | — | 82\* |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 38 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 17 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 9 | — | — | — | — | 8 | — | — | 9 | — | — | — | 38\* |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 12 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 13 | — | — | — | — | 17 | — | — | 16 | — | — | — | 32\* |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Mavic 4 Pro · 120 Hz | 15 m | 13 | — | — | — | — | 19 | — | — | 14 | — | — | — | 17\* |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | 10 | — | — | 15 | — | — | — | 8\* |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | 8 | — | — | 10 | — | — | — | 9\* |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 10 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 22 | — | — | — | — | 17 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 30 | — | — | — | — | 16 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 14 | — | — | — | — | 15 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` | DJI Matrice 4E · 126.667 Hz | 15 m | — | — | — | — | — | 13 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 16 | — | — | — | — | 13 | — | — | 13 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 16 | — | — | — | — | 13 | — | — | 16 | — | — | — | 13\* |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 12 | — | — | 12 | — | — | — | 12\* |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 13 | — | — | 14 | — | — | — | 12\* |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 13 | — | — | — | — | 13 | — | — | 12 | — | — | — | 13\* |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 16 | — | — | — | 13 | 13 | 13 | — | 16 | — | 13 | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 16 | — | — | — | 13 | 13 | 13 | — | 16 | — | 13 | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 16 | — | — | — | 13 | 13 | 13 | — | 16 | — | 13 | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 16 | — | — | — | — | 13 | — | — | 16 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 16 | — | — | — | — | 13 | — | — | 16 | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 15 m | 12 | — | — | — | — | 12 | — | — | 12 | — | — | — | 13\* |
# | `sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 30 m | 14 | — | — | — | 13 | 12 | 15 | — | 18 | — | 15 | — | 12\* |
# | `sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 45 m | 16 | — | — | — | 13 | 17 | 20 | — | 17 | — | 20 | — | 13\* |
# | `sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 60 m | 13 | — | — | — | 13 | 21 | 22 | — | 24 | — | 42 | — | 12\* |
# | `sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` | DJI Matrice 4E · 126.667 Hz | 90 m | 23 | — | — | — | 13 | 54 | 44 | — | 17 | — | 28 | — | 13\* |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 11 | — | — | — | — | 10 | — | — | 10 | — | — | — | 28\* |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 11 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 10 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` | DJI S1000+ · 148.9 Hz | 15 m | 11 | — | — | — | — | 11 | — | — | 11 | — | — | — | 18\* |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 4.2 `sionna_p1000000000_swR1D1E1F1_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 10 억 발 · 반사 깊이 1 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p1000000000_swR1D1E1F1_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p1000000000_swR1D1E1F1_r15_n8192_d1__map.png)
#
# **그림 166.** `sionna_p1000000000_swR1D1E1F1_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p1000000000_swR1D1E1F1_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p1000000000_swR1D1E1F1_r15_n8192_d1__band.png)
#
# **그림 167.** `sionna_p1000000000_swR1D1E1F1_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 14.0 | 12.6 | 82.4 | +6.5 | 254.6 | 2.01 | −131.85 | 0.071 |

# %% [markdown]
# ### 절 4.3 `sionna_p1000000000_swR1D1E1F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 10 억 발 · 반사 깊이 3 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p1000000000_swR1D1E1F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p1000000000_swR1D1E1F1_r15_n8192_d3__map.png)
#
# **그림 168.** `sionna_p1000000000_swR1D1E1F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p1000000000_swR1D1E1F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p1000000000_swR1D1E1F1_r15_n8192_d3__band.png)
#
# **그림 169.** `sionna_p1000000000_swR1D1E1F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 14.6 | 12.6 | 84.7 | +4.9 | 254.6 | 2.01 | −130.51 | 0.096 |

# %% [markdown]
# ### 절 4.4 `sionna_p4000000000_onlydepth3_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: 깊이 3 만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlydepth3_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlydepth3_r15_n8192__map.png)
#
# **그림 170.** `sionna_p4000000000_onlydepth3_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlydepth3_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlydepth3_r15_n8192__band.png)
#
# **그림 171.** `sionna_p4000000000_onlydepth3_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 86.8 | +1.2 | 77.6 | 0.61 | −92.61 | 0.116 |
# | −30° | 1102 Hz | 80.6 | 12.6 | 1.2 | +52.1 | 126.1 | 0.99 | −135.74 | 71.930 |
# | −60° | 636 Hz | 32.4 | 12.6 | 11.5 | +27.2 | 126.1 | 0.99 | −129.63 | 13.894 |
# | −90°\* | 0 Hz | 98.2 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.74 | 1.683 |

# %% [markdown]
# ### 절 4.5 `sionna_p4000000000_onlydiffr_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 회절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlydiffr_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlydiffr_r15_n8192__map.png)
#
# **그림 172.** `sionna_p4000000000_onlydiffr_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlydiffr_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlydiffr_r15_n8192__band.png)
#
# **그림 173.** `sionna_p4000000000_onlydiffr_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.2 | 12.5 | 86.4 | −1.8 | 84.9 ⚠튐 | 0.67 | −93.05 | 0.080 |
# | −15° | 1230 Hz | 11.9 | 12.6 | 87.6 | −0.6 | 198.8 ⚠튐 | 1.57 | −111.60 | 1.721 |
# | −30° | 1102 Hz | 11.7 | 12.6 | 81.1 | +9.1 | 252.2 | 1.99 | −124.74 | 0.118 |
# | −45° | 900 Hz | 13.2 | 12.5 | 58.5 | +16.4 | 252.2 | 1.99 | −124.38 | 0.219 |
# | −60° | 636 Hz | 13.5 | 12.6 | 70.8 | +11.6 | 128.5 | 1.01 | −123.53 | 1.496 |
# | −75° | 330 Hz | 13.0 | 12.6 | 91.7 | — | 126.1 | 0.99 | −108.24 | 0.154 |
# | −90°\* | 0 Hz | 12.9 | 12.6 | 100.0 | — | 150.3 ⚠튐 | 1.19 | −109.44 | 0.008 |

# %% [markdown]
# ### 절 4.6 `sionna_p4000000000_onlyedge_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 모서리 회절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyedge_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyedge_r15_n8192__map.png)
#
# **그림 174.** `sionna_p4000000000_onlyedge_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyedge_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyedge_r15_n8192__band.png)
#
# **그림 175.** `sionna_p4000000000_onlyedge_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 86.2 | −0.8 | 84.9 ⚠튐 | 0.67 | −94.30 | 0.078 |
# | −30° | 1102 Hz | 80.5 | 12.6 | 1.1 | +52.0 | 126.1 | 0.99 | −135.66 | 58.125 |
# | −60° | 636 Hz | 86.6 | 12.6 | 3.3 | +48.3 | 126.1 | 0.99 | −129.72 | 12.742 |
# | −90°\* | 0 Hz | 98.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.72 | 1.665 |

# %% [markdown]
# ### 절 4.7 `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192__map.png)
#
# **그림 176.** `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192__band.png)
#
# **그림 177.** `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1018 Hz | 69.2 | 13.5 | 9.4 | +34.8 | 121.3 | 1.01 | −141.09 | 12.494 |
# | −60° | 588 Hz | 72.7 | 13.5 | 41.8 | +24.8 | 118.9 | 0.99 | −135.97 | 14.180 |

# %% [markdown]
# ### 절 4.8 `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 178.** `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 179.** `sionna_p4000000000_onlyrefr_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 12.9 | 13.5 | 88.1 | −0.3 | 424.6 ⚠튐 | 3.54 | −98.16 | 0.018 |
# | −15° | 1135 Hz | 55.0 | 13.4 | 34.3 | +28.2 | 121.3 | 1.01 | −149.92 | 0.737 |
# | −30° | 1018 Hz | 72.8 | 13.5 | 9.9 | +36.8 | 121.3 | 1.01 | −141.62 | 10.683 |
# | −45° | 831 Hz | 70.2 | 13.5 | 18.8 | +33.7 | 118.9 | 0.99 | −137.77 | 11.851 |
# | −52° | 724 Hz | 63.3 | 13.4 | 32.8 | +28.0 | 118.9 | 0.99 | −138.25 | 36.229 |
# | −60° | 588 Hz | 70.8 | 13.5 | 61.6 | +24.9 | 118.9 | 0.99 | −138.12 | 11.804 |
# | −68° | 440 Hz | 68.7 | 13.4 | 34.5 | +31.0 | 240.2 | 2.00 | −135.12 | 12.701 |
# | −75° | 304 Hz | 65.2 | 13.4 | 16.2 | — | 118.9 | 0.99 | −131.24 | 19.107 |
# | −82° | 164 Hz | 59.8 | 13.4 | 18.8 | — | 118.9 | 0.99 | −131.76 | 15.798 |
# | −90°\* | 0 Hz | 70.1 | 13.4 | 100.0 | — | 240.2 | 2.00 | −137.58 | 0.282 |

# %% [markdown]
# ### 절 4.9 `sionna_p4000000000_onlyrefr_mini5pro_r120_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r120_n8192__map.png)
#
# **그림 180.** `sionna_p4000000000_onlyrefr_mini5pro_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r120_n8192__band.png)
#
# **그림 181.** `sionna_p4000000000_onlyrefr_mini5pro_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 75.8 | 8.7 | 38.4 | +36.3 | 367.6 | 2.00 | −189.07 | 6.848 |

# %% [markdown]
# ### 절 4.10 `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192__map.png)
#
# **그림 182.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192__band.png)
#
# **그림 183.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.7 | 8.7 | 89.7 | −0.8 | 522.4 ⚠튐 | 2.85 | −103.51 | 0.021 |
# | −30° | 887 Hz | 71.0 | 8.7 | 39.7 | +36.2 | 181.4 | 0.99 | −150.99 | 61.137 |
# | −52° | 631 Hz | 57.0 | 8.7 | 22.8 | +33.6 | 183.8 | 1.00 | −140.77 | 7.286 |
# | −60° | 512 Hz | 59.2 | 8.7 | 22.1 | — | 183.8 | 1.00 | −138.29 | 22.591 |
# | −68° | 384 Hz | 58.5 | 8.6 | 27.1 | — | 183.8 | 1.00 | −138.32 | 9.985 |
# | −82° | 143 Hz | 55.9 | 8.7 | 99.4 | — | 183.8 | 1.00 | −143.13 | 3.575 |

# %% [markdown]
# ### 절 4.11 `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 22.5° · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5__map.png)
#
# **그림 184.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5__band.png)
#
# **그림 185.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 64.4 | 8.7 | 34.7 | +36.7 | 367.6 | 2.00 | −150.09 | 13.728 |

# %% [markdown]
# ### 절 4.12 `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 45° · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45__map.png)
#
# **그림 186.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45__band.png)
#
# **그림 187.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_az45` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 72.9 | 8.7 | 12.8 | +40.6 | 183.8 | 1.00 | −146.36 | 9.225 |

# %% [markdown]
# ### 절 4.13 `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 188.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 189.** `sionna_p4000000000_onlyrefr_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.5 | 8.7 | 89.6 | +0.6 | 527.2 ⚠튐 | 2.88 | −104.18 | 0.018 |
# | −15° | 990 Hz | 46.1 | 8.6 | 59.9 | +28.1 | 367.6 | 2.00 | −157.04 | 2.596 |
# | −30° | 887 Hz | 73.9 | 8.7 | 45.8 | +36.1 | 183.8 | 1.00 | −151.87 | 84.250 |
# | −45° | 725 Hz | 57.8 | 8.7 | 22.2 | +38.0 | 183.8 | 1.00 | −142.49 | 15.371 |
# | −52° | 631 Hz | 57.6 | 8.7 | 29.0 | +33.5 | 183.8 | 1.00 | −141.79 | 6.173 |
# | −60° | 512 Hz | 59.0 | 8.7 | 19.4 | — | 183.8 | 1.00 | −137.79 | 25.009 |
# | −68° | 384 Hz | 57.3 | 8.6 | 22.7 | — | 183.8 | 1.00 | −137.71 | 13.628 |
# | −75° | 265 Hz | 52.3 | 8.7 | 30.4 | — | 183.8 | 1.00 | −138.93 | 6.668 |
# | −82° | 143 Hz | 57.6 | 8.7 | 99.5 | — | 365.2 | 1.99 | −142.83 | 3.622 |
# | −90°\* | 0 Hz | 39.2 | 8.7 | 100.0 | — | 367.6 | 2.00 | −144.17 | 2.563 |

# %% [markdown]
# ### 절 4.14 `sionna_p4000000000_onlyrefr_mini5pro_r240_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 240 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r240_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r240_n8192__map.png)
#
# **그림 190.** `sionna_p4000000000_onlyrefr_mini5pro_r240_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r240_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r240_n8192__band.png)
#
# **그림 191.** `sionna_p4000000000_onlyrefr_mini5pro_r240_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | ◐ 덜 참(695/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.15 `sionna_p4000000000_onlyrefr_mini5pro_r30_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r30_n8192__map.png)
#
# **그림 192.** `sionna_p4000000000_onlyrefr_mini5pro_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r30_n8192__band.png)
#
# **그림 193.** `sionna_p4000000000_onlyrefr_mini5pro_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 65.9 | 8.7 | 45.9 | +35.6 | 367.6 | 2.00 | −165.48 | 10.318 |

# %% [markdown]
# ### 절 4.16 `sionna_p4000000000_onlyrefr_mini5pro_r60_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r60_n8192__map.png)
#
# **그림 194.** `sionna_p4000000000_onlyrefr_mini5pro_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_mini5pro_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_mini5pro_r60_n8192__band.png)
#
# **그림 195.** `sionna_p4000000000_onlyrefr_mini5pro_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 66.1 | 8.7 | 40.4 | +33.5 | 183.8 | 1.00 | −177.32 | 9.495 |

# %% [markdown]
# ### 절 4.17 `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 장면: **프로펠러를 뺀 나머지** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192__map.png)
#
# **그림 196.** `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192__band.png)
#
# **그림 197.** `sionna_p4000000000_onlyrefr_partsnoprop_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | ○ 안 움직임 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.18 `sionna_p4000000000_onlyrefr_partsprop_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 장면: **프로펠러만** · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_partsprop_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_partsprop_r15_n8192__map.png)
#
# **그림 198.** `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_partsprop_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_partsprop_r15_n8192__band.png)
#
# **그림 199.** `sionna_p4000000000_onlyrefr_partsprop_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 53.0 | 12.5 | 42.8 | +29.4 | 126.1 | 0.99 | −148.84 | 91.485 |

# %% [markdown]
# ### 절 4.19 `sionna_p4000000000_onlyrefr_r120_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r120_n8192__map.png)
#
# **그림 200.** `sionna_p4000000000_onlyrefr_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r120_n8192__band.png)
#
# **그림 201.** `sionna_p4000000000_onlyrefr_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 43.9 | 12.5 | 45.2 | +28.5 | 380.7 | 3.01 | −189.23 | 0.000 |
# | −30° | 1102 Hz | 66.2 | 12.6 | 28.1 | +28.5 | 126.1 | 0.99 | −180.91 | 7.368 |

# %% [markdown]
# ### 절 4.20 `sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 202.** `sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 203.** `sionna_p4000000000_onlyrefr_r120_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 64.5 | 12.6 | 46.5 | +29.9 | 126.1 | 0.99 | −183.24 | 11.653 |

# %% [markdown]
# ### 절 4.21 `sionna_p4000000000_onlyrefr_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192__map.png)
#
# **그림 204.** `sionna_p4000000000_onlyrefr_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192__band.png)
#
# **그림 205.** `sionna_p4000000000_onlyrefr_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.3 | 12.5 | 85.2 | +0.3 | 21.8 ⚠튐 | 0.17 | −96.87 | 0.043 |
# | −4° | 1270 Hz | 51.7 | 12.6 | 40.3 | +31.7 | 126.1 | 0.99 | −148.49 | 4.440 |
# | −8° | 1260 Hz | 58.5 | 12.7 | 58.1 | +26.0 | 128.5 | 1.01 | −149.44 | 1.430 |
# | −11° | 1250 Hz | 55.9 | 12.7 | 64.2 | +25.8 | 126.1 | 0.99 | −149.49 | 2.151 |
# | −15° | 1230 Hz | 61.3 | 12.6 | 42.5 | +28.6 | 126.1 | 0.99 | −148.22 | 0.932 |
# | −30° | 1102 Hz | 62.1 | 12.6 | 11.5 | +37.5 | 126.1 | 0.99 | −141.03 | 38.442 |
# | −45° | 900 Hz | 64.9 | 12.5 | 15.8 | +37.1 | 126.1 | 0.99 | −135.69 | 51.197 |
# | −52° | 784 Hz | 64.5 | 12.5 | 13.7 | +34.7 | 254.6 | 2.01 | −133.03 | 36.974 |
# | −60° | 636 Hz | 64.0 | 12.6 | 44.6 | +28.9 | 128.5 | 1.01 | −136.12 | 21.238 |
# | −68° | 477 Hz | 11.1 | 12.6 | 93.4 | +7.6 | 126.1 ⚠튐 | 0.99 | −116.99 | 89.406 |
# | −75° | 330 Hz | 57.1 | 12.6 | 12.8 | — | 126.1 | 0.99 | −129.71 | 11.642 |
# | −82° | 177 Hz | 62.5 | 12.6 | 33.0 | — | 126.1 | 0.99 | −132.80 | 7.976 |
# | −90°\* | 0 Hz | 61.8 | 12.6 | 100.0 | — | 123.7 | 0.98 | −137.23 | 19.329 |

# %% [markdown]
# ### 절 4.22 `sionna_p4000000000_onlyrefr_r15_n8192_az22.5`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5__map.png)
#
# **그림 206.** `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5__band.png)
#
# **그림 207.** `sionna_p4000000000_onlyrefr_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | 60.7 | 12.6 | 34.0 | +30.5 | 126.1 | 0.99 | −146.79 | 4.991 |
# | −30° | 1102 Hz | 64.9 | 12.6 | 14.3 | +37.4 | 126.1 | 0.99 | −140.46 | 28.992 |
# | −60° | 636 Hz | 61.1 | 12.6 | 21.8 | +37.5 | 126.1 | 0.99 | −134.45 | 83.851 |

# %% [markdown]
# ### 절 4.23 `sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe__map.png)
#
# **그림 208.** `sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe__band.png)
#
# **그림 209.** `sionna_p4000000000_onlyrefr_r15_n8192_az22.5_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 68.6 | 12.6 | 20.4 | +38.1 | 126.1 | 0.99 | −141.44 | 17.701 |

# %% [markdown]
# ### 절 4.24 `sionna_p4000000000_onlyrefr_r15_n8192_az45`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az45 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45__map.png)
#
# **그림 210.** `sionna_p4000000000_onlyrefr_r15_n8192_az45` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az45 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45__band.png)
#
# **그림 211.** `sionna_p4000000000_onlyrefr_r15_n8192_az45` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | 66.0 | 12.6 | 35.0 | +29.7 | 128.5 | 1.01 | −145.98 | 1.897 |
# | −30° | 1102 Hz | 64.2 | 12.6 | 12.3 | +38.2 | 128.5 | 1.01 | −140.48 | 63.099 |
# | −60° | 636 Hz | 57.8 | 12.6 | 19.2 | +34.6 | 126.1 | 0.99 | −133.60 | 45.675 |

# %% [markdown]
# ### 절 4.25 `sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe__map.png)
#
# **그림 212.** `sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe__band.png)
#
# **그림 213.** `sionna_p4000000000_onlyrefr_r15_n8192_az45_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 61.7 | 12.6 | 7.8 | +38.7 | 126.1 | 0.99 | −139.14 | 29.056 |

# %% [markdown]
# ### 절 4.26 `sionna_p4000000000_onlyrefr_r15_n8192_az67.5`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az67.5 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5__map.png)
#
# **그림 214.** `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az67.5 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5__band.png)
#
# **그림 215.** `sionna_p4000000000_onlyrefr_r15_n8192_az67.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −15° | 1230 Hz | 51.2 | 12.6 | 30.0 | +29.3 | 126.1 | 0.99 | −147.61 | 4.103 |
# | −30° | 1102 Hz | 63.9 | 12.6 | 7.2 | +39.9 | 252.2 | 1.99 | −138.86 | 60.959 |
# | −60° | 636 Hz | 60.7 | 12.6 | 13.9 | +37.9 | 380.7 | 3.01 | −132.05 | 23.324 |

# %% [markdown]
# ### 절 4.27 `sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe__map.png)
#
# **그림 216.** `sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe__band.png)
#
# **그림 217.** `sionna_p4000000000_onlyrefr_r15_n8192_az67.5_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 67.0 | 12.6 | 10.6 | +40.1 | 252.2 | 1.99 | −140.42 | 80.354 |

# %% [markdown]
# ### 절 4.28 `sionna_p4000000000_onlyrefr_r15_n8192_az90`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az90 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az90__map.png)
#
# **그림 218.** `sionna_p4000000000_onlyrefr_r15_n8192_az90` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_az90 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_az90__band.png)
#
# **그림 219.** `sionna_p4000000000_onlyrefr_r15_n8192_az90` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 64.9 | 12.6 | 7.5 | +38.5 | 126.1 | 0.99 | −138.49 | 4.966 |

# %% [markdown]
# ### 절 4.29 `sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 220.** `sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 221.** `sionna_p4000000000_onlyrefr_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 85.3 | −0.1 | 106.7 ⚠튐 | 0.84 | −97.77 | 0.035 |
# | −15° | 1230 Hz | 61.2 | 12.6 | 49.1 | +28.6 | 126.1 | 0.99 | −147.98 | 0.621 |
# | −30° | 1102 Hz | 59.0 | 12.6 | 7.9 | +38.4 | 126.1 | 0.99 | −140.04 | 87.523 |
# | −45° | 900 Hz | 63.5 | 12.5 | 16.0 | +37.9 | 126.1 | 0.99 | −137.22 | 67.322 |
# | −52° | 784 Hz | 64.6 | 12.5 | 18.0 | +32.7 | 254.6 | 2.01 | −134.40 | 28.029 |
# | −60° | 636 Hz | 62.1 | 12.6 | 31.6 | +31.0 | 126.1 | 0.99 | −135.17 | 21.788 |
# | −68° | 477 Hz | 62.1 | 12.6 | 17.0 | +33.3 | 126.1 | 0.99 | −131.55 | 20.087 |
# | −75° | 330 Hz | 52.2 | 12.6 | 19.0 | — | 126.1 | 0.99 | −131.93 | 11.311 |
# | −82° | 177 Hz | 56.7 | 12.6 | 29.8 | — | 126.1 | 0.99 | −132.74 | 9.498 |
# | −90°\* | 0 Hz | 57.0 | 12.6 | 100.0 | — | 252.2 | 1.99 | −137.66 | 1.362 |

# %% [markdown]
# ### 절 4.30 `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm__map.png)
#
# **그림 222.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm__band.png)
#
# **그림 223.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 62.0 | 12.6 | 11.5 | +37.5 | 126.1 | 0.99 | −141.03 | 92.787 |

# %% [markdown]
# ### 절 4.31 `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm__map.png)
#
# **그림 224.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm__band.png)
#
# **그림 225.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop0.9mm` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 87.1 | +0.3 | 53.3 ⚠튐 | 0.42 | −104.13 | 0.008 |
# | −30° | 1102 Hz | 39.7 | 12.6 | 77.1 | +19.6 | 254.6 | 2.01 | −160.42 | 15.925 |

# %% [markdown]
# ### 절 4.32 `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm__map.png)
#
# **그림 226.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm__band.png)
#
# **그림 227.** `sionna_p4000000000_onlyrefr_r15_n8192_shell0.75mm_prop1.43mm` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 41.0 | 12.6 | 61.3 | +22.7 | 126.1 | 0.99 | −155.27 | 39.360 |

# %% [markdown]
# ### 절 4.33 `sionna_p4000000000_onlyrefr_r240_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 240 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r240_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r240_n8192__map.png)
#
# **그림 228.** `sionna_p4000000000_onlyrefr_r240_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r240_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r240_n8192__band.png)
#
# **그림 229.** `sionna_p4000000000_onlyrefr_r240_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 56.1 | 12.5 | 89.7 | +24.4 | 506.8 | 4.00 | −193.91 | 0.000 |
# | −30° | 1102 Hz | 68.8 | 12.6 | 43.5 | +28.2 | 126.1 | 0.99 | −193.18 | 65.250 |

# %% [markdown]
# ### 절 4.34 `sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 240 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 230.** `sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 231.** `sionna_p4000000000_onlyrefr_r240_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ◐ 덜 참(2,199/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.35 `sionna_p4000000000_onlyrefr_r30_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r30_n8192__map.png)
#
# **그림 232.** `sionna_p4000000000_onlyrefr_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r30_n8192__band.png)
#
# **그림 233.** `sionna_p4000000000_onlyrefr_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 87.4 | +0.0 | 55.8 ⚠튐 | 0.44 | −108.44 | 0.012 |
# | −30° | 1102 Hz | 63.6 | 12.6 | 29.3 | +33.0 | 126.1 | 0.99 | −156.64 | 34.444 |

# %% [markdown]
# ### 절 4.36 `sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 234.** `sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 235.** `sionna_p4000000000_onlyrefr_r30_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 65.1 | 12.6 | 17.7 | +37.4 | 126.1 | 0.99 | −155.04 | 59.132 |

# %% [markdown]
# ### 절 4.37 `sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 480 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 236.** `sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 237.** `sionna_p4000000000_onlyrefr_r480_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ◐ 덜 참(862/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.38 `sionna_p4000000000_onlyrefr_r60_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r60_n8192__map.png)
#
# **그림 238.** `sionna_p4000000000_onlyrefr_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r60_n8192__band.png)
#
# **그림 239.** `sionna_p4000000000_onlyrefr_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 86.7 | −0.1 | 21.8 ⚠튐 | 0.17 | −121.01 | 0.003 |
# | −30° | 1102 Hz | 69.7 | 12.6 | 38.8 | +31.0 | 126.1 | 0.99 | −169.73 | 18.103 |

# %% [markdown]
# ### 절 4.39 `sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 240.** `sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 241.** `sionna_p4000000000_onlyrefr_r60_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 62.0 | 12.6 | 30.7 | +31.6 | 126.1 | 0.99 | −170.23 | 6.422 |

# %% [markdown]
# ### 절 4.40 `sionna_p4000000000_onlyrefr_s1000plus_r120_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 120 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r120_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r120_n8192__map.png)
#
# **그림 242.** `sionna_p4000000000_onlyrefr_s1000plus_r120_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r120_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r120_n8192__band.png)
#
# **그림 243.** `sionna_p4000000000_onlyrefr_s1000plus_r120_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 42.2 | 10.8 | 38.2 | +22.4 | 150.2 | 1.01 | −176.78 | 0.739 |

# %% [markdown]
# ### 절 4.41 `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192__map.png)
#
# **그림 244.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192__band.png)
#
# **그림 245.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 30.3 | 10.9 | 62.4 | +22.0 | 746.0 | 5.01 | −140.95 | 0.004 |
# | −30° | 1802 Hz | 36.5 | 10.8 | 14.0 | +30.2 | 147.7 | 0.99 | −136.81 | 0.281 |
# | −52° | 1281 Hz | 56.0 | 10.9 | 14.9 | +31.7 | 150.2 | 1.01 | −128.29 | 1.887 |
# | −60° | 1040 Hz | 65.7 | 10.9 | 22.2 | +32.5 | 147.7 | 0.99 | −127.39 | 0.300 |
# | −68° | 779 Hz | 55.2 | 10.8 | 37.7 | +25.6 | 147.7 | 0.99 | −129.47 | 4.381 |
# | −82° | 290 Hz | 12.0 | 10.9 | 88.2 | — | 147.7 | 0.99 | −115.95 | 0.190 |

# %% [markdown]
# ### 절 4.42 `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 22.5° · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5__map.png)
#
# **그림 246.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5__band.png)
#
# **그림 247.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az22.5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 29.4 | 10.8 | 13.7 | +33.3 | 595.8 | 4.00 | −135.34 | 0.005 |

# %% [markdown]
# ### 절 4.43 `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 방위 45° · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45__map.png)
#
# **그림 248.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45__band.png)
#
# **그림 249.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_az45` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 53.2 | 10.8 | 8.7 | +33.9 | 595.8 | 4.00 | −137.09 | 0.040 |

# %% [markdown]
# ### 절 4.44 `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 250.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 251.** `sionna_p4000000000_onlyrefr_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 34.1 | 10.9 | 63.9 | +21.2 | 746.0 | 5.01 | −141.03 | 0.004 |
# | −15° | 2010 Hz | 27.2 | 10.8 | 58.8 | +20.2 | 445.6 | 2.99 | −139.96 | 0.117 |
# | −30° | 1802 Hz | 43.0 | 10.8 | 19.1 | +29.8 | 147.7 | 0.99 | −138.06 | 0.213 |
# | −45° | 1471 Hz | 50.6 | 10.9 | 17.8 | +32.3 | 150.2 | 1.01 | −131.56 | 0.210 |
# | −52° | 1281 Hz | 52.7 | 10.9 | 18.2 | +30.3 | 150.2 | 1.01 | −130.13 | 1.281 |
# | −60° | 1040 Hz | 57.3 | 10.9 | 22.6 | +30.2 | 147.7 | 0.99 | −128.98 | 0.207 |
# | −68° | 779 Hz | 51.3 | 10.8 | 44.0 | +24.9 | 147.7 | 0.99 | −131.20 | 2.943 |
# | −75° | 538 Hz | 18.6 | 10.8 | 84.7 | +9.4 | 150.2 ⚠튐 | 1.01 | −117.41 | 1.793 |
# | −82° | 290 Hz | 70.3 | 10.9 | 24.6 | — | 147.7 | 0.99 | −126.14 | 0.018 |
# | −90°\* | 0 Hz | 82.4 | 10.8 | 100.0 | — | 891.3 | 5.99 | −129.59 | 0.000 |

# %% [markdown]
# ### 절 4.45 `sionna_p4000000000_onlyrefr_s1000plus_r240_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 240 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r240_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r240_n8192__map.png)
#
# **그림 252.** `sionna_p4000000000_onlyrefr_s1000plus_r240_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r240_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r240_n8192__band.png)
#
# **그림 253.** `sionna_p4000000000_onlyrefr_s1000plus_r240_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 51.9 | 10.8 | 44.8 | +19.2 | 152.6 | 1.02 | −186.17 | 0.678 |

# %% [markdown]
# ### 절 4.46 `sionna_p4000000000_onlyrefr_s1000plus_r30_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r30_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r30_n8192__map.png)
#
# **그림 254.** `sionna_p4000000000_onlyrefr_s1000plus_r30_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r30_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r30_n8192__band.png)
#
# **그림 255.** `sionna_p4000000000_onlyrefr_s1000plus_r30_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 51.9 | 10.8 | 23.5 | +27.3 | 147.7 | 0.99 | −152.68 | 0.340 |

# %% [markdown]
# ### 절 4.47 `sionna_p4000000000_onlyrefr_s1000plus_r60_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 굴절만 켬 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r60_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r60_n8192__map.png)
#
# **그림 256.** `sionna_p4000000000_onlyrefr_s1000plus_r60_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_onlyrefr_s1000plus_r60_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_onlyrefr_s1000plus_r60_n8192__band.png)
#
# **그림 257.** `sionna_p4000000000_onlyrefr_s1000plus_r60_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 45.8 | 10.8 | 30.9 | +27.2 | 150.2 | 1.01 | −164.64 | 0.341 |

# %% [markdown]
# ### 절 4.48 `sionna_p4000000000_stockdef_r15_n8192`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: **PathSolver 순정 기본값**(굴절 켬 · 회절 끔 · 모서리 끔 · 확산 끔) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_stockdef_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_stockdef_r15_n8192__map.png)
#
# **그림 258.** `sionna_p4000000000_stockdef_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_stockdef_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_stockdef_r15_n8192__band.png)
#
# **그림 259.** `sionna_p4000000000_stockdef_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.2 | 12.5 | 86.2 | +0.9 | 84.9 ⚠튐 | 0.67 | −94.77 | 0.070 |
# | −15° | 1230 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −30° | 1102 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −45° | 900 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −60° | 636 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −75° | 330 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |
# | −90° | 0 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.49 `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R0D0E0F0` = 넷 다 끔(정반사·LOS 는 켬) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d1__map.png)
#
# **그림 260.** `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d1__band.png)
#
# **그림 261.** `sionna_p4000000000_swR0D0E0F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.50 `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D0E0F0` = 넷 다 끔(정반사·LOS 는 켬) · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d3__map.png)
#
# **그림 262.** `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F0_r15_n8192_d3__band.png)
#
# **그림 263.** `sionna_p4000000000_swR0D0E0F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.51 `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 264.** `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 265.** `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 12.6 | 13.5 | 89.1 | −0.3 | 458.5 ⚠튐 | 3.82 | −93.18 | 0.058 |
# | −30° | 1018 Hz | 81.2 | 13.5 | 0.9 | +49.2 | 118.9 | 0.99 | −136.64 | 6.028 |
# | −60° | 588 Hz | 95.3 | 13.5 | 16.0 | +44.5 | 242.6 | 2.02 | −132.59 | 22.068 |
# | −90°\* | 0 Hz | 99.0 | 13.4 | 100.0 | — | 240.2 | 2.00 | −134.63 | 0.066 |

# %% [markdown]
# ### 절 4.52 `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 266.** `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 267.** `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.1 | 13.5 | 89.2 | +0.1 | 436.7 | 3.64 | −92.75 | 0.064 |

# %% [markdown]
# ### 절 4.53 `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 268.** `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 269.** `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 13.4 | 13.5 | 88.4 | −0.7 | 29.1 ⚠튐 | 0.24 | −93.47 | 0.054 |

# %% [markdown]
# ### 절 4.54 `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 270.** `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 271.** `sionna_p4000000000_swR0D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.2 | 13.5 | 88.5 | −0.1 | 80.1 ⚠튐 | 0.67 | −92.13 | 0.073 |
# | −30° | 1018 Hz | 14.9 | 13.5 | 7.6 | +25.5 | 235.3 | 1.96 | −135.87 | 7.118 |
# | −60° | 588 Hz | 27.2 | 13.5 | 3.0 | +49.3 | 237.8 | 1.98 | −127.34 | 48.717 |
# | −90°\* | 0 Hz | 71.6 | 13.4 | 100.0 | — | 359.1 | 2.99 | −132.66 | 0.103 |

# %% [markdown]
# ### 절 4.55 `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 272.** `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 273.** `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.2 | 8.7 | 89.7 | −1.7 | 432.9 ⚠튐 | 2.36 | −97.66 | 0.082 |
# | −30° | 887 Hz | 90.4 | 8.7 | 13.7 | +47.7 | 367.6 | 2.00 | −148.14 | 4.325 |
# | −60° | 512 Hz | 89.8 | 8.7 | 2.5 | — | 183.8 | 1.00 | −131.36 | 10.782 |
# | −90°\* | 0 Hz | 97.2 | 8.7 | 100.0 | — | 367.6 | 2.00 | −143.34 | 0.375 |

# %% [markdown]
# ### 절 4.56 `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 274.** `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 275.** `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.1 | 8.7 | 90.0 | +1.1 | 592.5 ⚠튐 | 3.23 | −97.50 | 0.085 |

# %% [markdown]
# ### 절 4.57 `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 276.** `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 277.** `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 9.0 | 8.7 | 90.4 | −0.3 | 350.7 ⚠튐 | 1.91 | −97.66 | 0.082 |

# %% [markdown]
# ### 절 4.58 `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 278.** `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 279.** `sionna_p4000000000_swR0D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.6 | 8.7 | 90.3 | +3.1 | 282.9 ⚠튐 | 1.54 | −97.21 | 0.091 |
# | −30° | 887 Hz | 14.5 | 8.7 | 3.8 | +44.0 | 365.2 | 1.99 | −143.37 | 11.973 |
# | −60° | 512 Hz | 34.7 | 8.7 | 5.6 | — | 183.8 | 1.00 | −131.98 | 9.463 |
# | −90°\* | 0 Hz | 42.7 | 8.7 | 100.0 | — | 377.3 | 2.06 | −142.01 | 0.510 |

# %% [markdown]
# ### 절 4.59 `sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 280.** `sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 281.** `sionna_p4000000000_swR0D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 85.5 | −0.6 | 24.2 ⚠튐 | 0.19 | −91.04 | 0.073 |
# | −30° | 1102 Hz | 80.1 | 12.6 | 0.5 | +56.7 | 126.1 | 0.99 | −125.27 | 48.423 |
# | −60° | 636 Hz | 92.8 | 12.6 | 1.6 | +51.6 | 126.1 | 0.99 | −117.11 | 19.338 |

# %% [markdown]
# ### 절 4.60 `sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 282.** `sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 283.** `sionna_p4000000000_swR0D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 85.5 | −0.6 | 24.2 ⚠튐 | 0.19 | −91.04 | 0.073 |
# | −30° | 1102 Hz | 80.1 | 12.6 | 0.5 | +56.7 | 126.1 | 0.99 | −125.27 | 48.423 |
# | −60° | 636 Hz | 92.8 | 12.6 | 1.6 | +51.6 | 126.1 | 0.99 | −117.11 | 19.338 |

# %% [markdown]
# ### 절 4.61 `sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 284.** `sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 285.** `sionna_p4000000000_swR0D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 85.5 | −0.6 | 24.2 ⚠튐 | 0.19 | −91.04 | 0.073 |
# | −30° | 1102 Hz | 80.1 | 12.6 | 0.5 | +56.7 | 126.1 | 0.99 | −125.27 | 48.423 |
# | −60° | 636 Hz | 92.8 | 12.6 | 1.6 | +51.7 | 126.1 | 0.99 | −117.11 | 19.338 |

# %% [markdown]
# ### 절 4.62 `sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 286.** `sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 287.** `sionna_p4000000000_swR0D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 85.5 | −0.6 | 24.2 ⚠튐 | 0.19 | −91.04 | 0.073 |
# | −30° | 1102 Hz | 80.1 | 12.6 | 0.5 | +56.7 | 126.1 | 0.99 | −125.27 | 48.424 |
# | −60° | 636 Hz | 92.8 | 12.6 | 1.6 | +51.6 | 126.1 | 0.99 | −117.11 | 19.338 |

# %% [markdown]
# ### 절 4.63 `sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 288.** `sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 289.** `sionna_p4000000000_swR0D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 85.5 | −0.6 | 24.2 ⚠튐 | 0.19 | −91.04 | 0.073 |
# | −30° | 1102 Hz | 80.1 | 12.6 | 0.5 | +56.7 | 126.1 | 0.99 | −125.27 | 48.423 |
# | −60° | 636 Hz | 92.8 | 12.6 | 1.6 | +51.6 | 126.1 | 0.99 | −117.11 | 19.338 |

# %% [markdown]
# ### 절 4.64 `sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 290.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 291.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 85.3 | 12.5 | 8.1 | +44.6 | 126.1 | 0.99 | −146.68 | 1.058 |
# | −30° | 1102 Hz | 84.5 | 12.6 | 2.3 | +52.8 | 126.1 | 0.99 | −135.65 | 13.993 |

# %% [markdown]
# ### 절 4.65 `sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 292.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 293.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 77.5 | 12.5 | 8.6 | +43.0 | 126.1 | 0.99 | −146.43 | 0.303 |
# | −30° | 1102 Hz | 81.1 | 12.6 | 1.4 | +50.7 | 126.1 | 0.99 | −134.45 | 51.184 |

# %% [markdown]
# ### 절 4.66 `sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 294.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 295.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 71.9 | 12.5 | 6.1 | +44.9 | 252.2 | 1.99 | −147.07 | 3.068 |
# | −30° | 1102 Hz | 84.7 | 12.6 | 1.4 | +53.2 | 252.2 | 1.99 | −134.22 | 39.387 |

# %% [markdown]
# ### 절 4.67 `sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 296.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 297.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 78.1 | 12.5 | 5.8 | +44.3 | 254.6 | 2.01 | −146.53 | 0.071 |
# | −30° | 1102 Hz | 82.1 | 12.6 | 1.2 | +51.4 | 126.1 | 0.99 | −133.93 | 2.762 |

# %% [markdown]
# ### 절 4.68 `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 298.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 299.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.4 | +1.6 | 97.0 ⚠튐 | 0.77 | −97.21 | 0.041 |
# | −30° | 1102 Hz | 78.3 | 12.6 | 1.0 | +53.3 | 126.1 | 0.99 | −135.90 | 25.464 |
# | −60° | 636 Hz | 89.0 | 12.6 | 2.7 | +47.9 | 126.1 | 0.99 | −127.95 | 78.620 |

# %% [markdown]
# ### 절 4.69 `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 300.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 301.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 87.4 | +0.9 | 33.9 ⚠튐 | 0.27 | −95.63 | 0.058 |
# | −30° | 1102 Hz | 78.8 | 12.6 | 1.0 | +53.2 | 126.1 | 0.99 | −135.87 | 39.647 |
# | −60° | 636 Hz | 91.1 | 12.6 | 3.3 | +47.8 | 126.1 | 0.99 | −127.90 | 29.303 |

# %% [markdown]
# ### 절 4.70 `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 302.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 303.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 87.1 | −0.7 | 21.8 ⚠튐 | 0.17 | −95.93 | 0.054 |
# | −30° | 1102 Hz | 79.3 | 12.6 | 1.1 | +53.3 | 126.1 | 0.99 | −135.95 | 8.635 |
# | −60° | 636 Hz | 90.1 | 12.6 | 3.0 | +47.3 | 126.1 | 0.99 | −127.90 | 18.145 |

# %% [markdown]
# ### 절 4.71 `sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 304.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 305.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 85.3 | −0.6 | 50.9 ⚠튐 | 0.40 | −95.62 | 0.052 |
# | −30° | 1102 Hz | 12.5 | 12.6 | 88.4 | +0.1 | 460.7 ⚠튐 | 3.64 | −99.86 | 0.907 |
# | −60° | 636 Hz | 13.1 | 12.6 | 93.3 | −0.5 | 274.0 | 2.16 | −94.28 | 1.034 |

# %% [markdown]
# ### 절 4.72 `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 306.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 307.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs1.4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 85.3 | −0.5 | 21.8 ⚠튐 | 0.17 | −97.26 | 0.088 |
# | −30° | 1102 Hz | 81.9 | 12.6 | 1.5 | +51.6 | 126.1 | 0.99 | −135.22 | 11.467 |

# %% [markdown]
# ### 절 4.73 `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 308.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 309.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_fs2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 87.1 | +0.3 | 99.4 ⚠튐 | 0.79 | −97.84 | 0.076 |
# | −30° | 1102 Hz | 82.4 | 12.6 | 1.4 | +53.6 | 126.1 | 0.99 | −135.37 | 3.107 |

# %% [markdown]
# ### 절 4.74 `sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 310.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 311.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 85.0 | +0.1 | 50.9 ⚠튐 | 0.40 | −96.01 | 0.053 |
# | −30° | 1102 Hz | 80.6 | 12.6 | 1.1 | +53.1 | 126.1 | 0.99 | −135.85 | 43.486 |
# | −60° | 636 Hz | 90.4 | 12.6 | 3.3 | +47.3 | 126.1 | 0.99 | −128.17 | 12.864 |
# | −90°\* | 0 Hz | 98.4 | 12.6 | 100.0 | — | 126.1 | 0.99 | −135.88 | 0.279 |

# %% [markdown]
# ### 절 4.75 `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 312.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 313.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 87.5 | +0.2 | 50.9 ⚠튐 | 0.40 | −96.74 | 0.045 |
# | −30° | 1102 Hz | 12.8 | 12.6 | 0.3 | +1.4 | 31.5 | 0.25 | −137.94 | 32.077 |
# | −60° | 636 Hz | 12.6 | 12.6 | 0.1 | +0.4 | 31.5 | 0.25 | −125.83 | 20.456 |
# | −90°\* | 0 Hz | 6.3 | 12.6 | 100.0 | — | 63.0 | 0.50 | −134.73 | 0.362 |

# %% [markdown]
# ### 절 4.76 `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 314.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 315.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 87.1 | −0.1 | 58.2 ⚠튐 | 0.46 | −96.74 | 0.045 |
# | −30° | 1102 Hz | 41.0 | 12.6 | 0.5 | −0.0 | 63.0 | 0.50 | −135.50 | 45.296 |
# | −60° | 636 Hz | 38.3 | 12.6 | 0.8 | +4.9 | 63.0 | 0.50 | −127.14 | 15.854 |
# | −90°\* | 0 Hz | 53.6 | 12.6 | 100.0 | — | 63.0 | 0.50 | −135.13 | 0.331 |

# %% [markdown]
# ### 절 4.77 `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 316.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 317.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 88.1 | −2.4 | 31.5 ⚠튐 | 0.25 | −96.02 | 0.053 |
# | −30° | 1102 Hz | 17.3 | 12.6 | 0.3 | +6.8 | 31.5 | 0.25 | −136.76 | 38.325 |
# | −60° | 636 Hz | 20.1 | 12.6 | 0.4 | −1.9 | 31.5 | 0.25 | −126.32 | 18.659 |
# | −90°\* | 0 Hz | 31.1 | 12.6 | 100.0 | — | 126.1 | 0.99 | −134.72 | 0.363 |

# %% [markdown]
# ### 절 4.78 `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 318.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 319.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_fs0.7_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.6 | 12.5 | 87.4 | +2.2 | 50.9 ⚠튐 | 0.40 | −96.51 | 0.047 |
# | −30° | 1102 Hz | 77.9 | 12.6 | 0.9 | +48.0 | 126.1 | 0.99 | −137.99 | 46.977 |

# %% [markdown]
# ### 절 4.79 `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 320.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 321.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 86.9 | +0.2 | 33.9 ⚠튐 | 0.27 | −99.13 | 0.026 |
# | −30° | 1102 Hz | 74.6 | 12.6 | 1.4 | +49.5 | 126.1 | 0.99 | −141.18 | 19.608 |

# %% [markdown]
# ### 절 4.80 `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 322.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 323.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 11.3 | 12.5 | 87.8 | +0.5 | 53.3 ⚠튐 | 0.42 | −95.97 | 0.119 |
# | −30° | 1102 Hz | 93.7 | 12.6 | 5.7 | +50.1 | 126.1 | 0.99 | −132.28 | 24.229 |

# %% [markdown]
# ### 절 4.81 `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 324.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 325.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 87.6 | +0.8 | 60.6 ⚠튐 | 0.48 | −96.13 | 0.051 |
# | −30° | 1102 Hz | 92.5 | 12.6 | 2.9 | +53.9 | 126.1 | 0.99 | −132.26 | 72.387 |

# %% [markdown]
# ### 절 4.82 `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 326.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 327.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 87.2 | −1.4 | 50.9 ⚠튐 | 0.40 | −95.39 | 0.133 |
# | −30° | 1102 Hz | 99.0 | 12.6 | 35.3 | +49.7 | 126.1 | 0.99 | −130.88 | 5.672 |

# %% [markdown]
# ### 절 4.83 `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 328.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 329.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 86.8 | −0.1 | 26.7 ⚠튐 | 0.21 | −94.77 | 0.070 |
# | −30° | 1102 Hz | 98.4 | 12.6 | 24.8 | +49.6 | 126.1 | 0.99 | −131.09 | 69.325 |

# %% [markdown]
# ### 절 4.84 `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 330.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 331.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 85.0 | +0.0 | 50.9 ⚠튐 | 0.40 | −95.90 | 0.054 |
# | −15° | 1230 Hz | 76.5 | 12.6 | 6.4 | +43.4 | 126.1 | 0.99 | −145.49 | 0.264 |
# | −30° | 1102 Hz | 80.6 | 12.6 | 1.1 | +53.1 | 126.1 | 0.99 | −135.85 | 43.486 |
# | −45° | 900 Hz | 86.4 | 12.5 | 1.2 | +55.3 | 126.1 | 0.99 | −130.83 | 65.379 |
# | −60° | 636 Hz | 90.4 | 12.6 | 3.3 | +47.3 | 126.1 | 0.99 | −128.17 | 12.864 |
# | −75° | 330 Hz | 95.0 | 12.6 | 1.8 | — | 126.1 | 0.99 | −123.04 | 16.261 |

# %% [markdown]
# ### 절 4.85 `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 332.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 333.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 85.0 | +0.1 | 50.9 ⚠튐 | 0.40 | −96.01 | 0.053 |
# | −15° | 1230 Hz | 76.5 | 12.6 | 6.4 | +43.4 | 126.1 | 0.99 | −145.49 | 0.264 |
# | −30° | 1102 Hz | 80.6 | 12.6 | 1.1 | +53.1 | 126.1 | 0.99 | −135.85 | 43.486 |
# | −45° | 900 Hz | 86.4 | 12.5 | 1.2 | +55.3 | 126.1 | 0.99 | −130.83 | 65.379 |
# | −60° | 636 Hz | 90.4 | 12.6 | 3.3 | +47.3 | 126.1 | 0.99 | −128.17 | 12.864 |
# | −75° | 330 Hz | 95.0 | 12.6 | 1.8 | — | 126.1 | 0.99 | −123.04 | 16.261 |

# %% [markdown]
# ### 절 4.86 `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 334.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 335.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 85.0 | +0.3 | 50.9 ⚠튐 | 0.40 | −95.80 | 0.056 |
# | −15° | 1230 Hz | 76.5 | 12.6 | 6.4 | +43.4 | 126.1 | 0.99 | −145.49 | 0.264 |
# | −30° | 1102 Hz | 80.6 | 12.6 | 1.1 | +53.1 | 126.1 | 0.99 | −135.85 | 43.486 |
# | −45° | 900 Hz | 86.4 | 12.5 | 1.2 | +55.3 | 126.1 | 0.99 | −130.83 | 65.379 |
# | −60° | 636 Hz | 90.4 | 12.6 | 3.3 | +47.3 | 126.1 | 0.99 | −128.17 | 12.864 |
# | −75° | 330 Hz | 95.0 | 12.6 | 1.8 | — | 126.1 | 0.99 | −123.04 | 16.261 |

# %% [markdown]
# ### 절 4.87 `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 336.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 337.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 85.0 | +0.1 | 50.9 ⚠튐 | 0.40 | −96.01 | 0.053 |
# | −30° | 1102 Hz | 80.6 | 12.6 | 1.1 | +53.1 | 126.1 | 0.99 | −135.85 | 43.486 |
# | −60° | 636 Hz | 90.4 | 12.6 | 3.3 | +47.3 | 126.1 | 0.99 | −128.17 | 12.864 |

# %% [markdown]
# ### 절 4.88 `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 338.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 339.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 85.0 | +0.1 | 50.9 ⚠튐 | 0.40 | −96.01 | 0.053 |
# | −30° | 1102 Hz | 80.6 | 12.6 | 1.1 | +53.1 | 126.1 | 0.99 | −135.85 | 43.485 |
# | −60° | 636 Hz | 90.4 | 12.6 | 3.3 | +47.3 | 126.1 | 0.99 | −128.17 | 12.864 |

# %% [markdown]
# ### 절 4.89 `sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 340.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 341.** `sionna_p4000000000_swR0D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 87.6 | +0.5 | 109.1 ⚠튐 | 0.86 | −96.61 | 0.046 |
# | −30° | 1102 Hz | 19.0 | 12.6 | 1.0 | +35.2 | 259.5 | 2.05 | −134.28 | 52.484 |
# | −60° | 636 Hz | 17.0 | 12.6 | 2.3 | +49.0 | 249.8 | 1.97 | −126.12 | 19.105 |
# | −90°\* | 0 Hz | 63.5 | 12.6 | 100.0 | — | 126.1 | 0.99 | −134.08 | 0.421 |

# %% [markdown]
# ### 절 4.90 `sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 342.** `sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 343.** `sionna_p4000000000_swR0D0E0F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 74.5 | 12.5 | 10.9 | +40.9 | 380.7 | 3.01 | −162.29 | 0.684 |
# | −30° | 1102 Hz | 80.7 | 12.6 | 2.7 | +46.3 | 126.1 | 0.99 | −150.19 | 78.879 |

# %% [markdown]
# ### 절 4.91 `sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 344.** `sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 345.** `sionna_p4000000000_swR0D0E0F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 77.0 | 12.5 | 8.2 | +41.5 | 128.5 | 1.01 | −161.75 | 0.175 |
# | −30° | 1102 Hz | 80.8 | 12.6 | 2.2 | +49.4 | 126.1 | 0.99 | −149.76 | 4.293 |

# %% [markdown]
# ### 절 4.92 `sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 346.** `sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 347.** `sionna_p4000000000_swR0D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 87.1 | +1.3 | 60.6 ⚠튐 | 0.48 | −106.84 | 0.018 |
# | −15° | 1230 Hz | 74.6 | 12.6 | 14.1 | +37.1 | 126.1 | 0.99 | −160.43 | 0.382 |
# | −30° | 1102 Hz | 79.0 | 12.6 | 3.5 | +48.3 | 126.1 | 0.99 | −152.80 | 20.378 |
# | −45° | 900 Hz | 84.6 | 12.5 | 3.7 | +50.0 | 126.1 | 0.99 | −147.89 | 90.464 |
# | −60° | 636 Hz | 89.1 | 12.6 | 12.6 | +41.0 | 126.1 | 0.99 | −146.59 | 15.716 |
# | −75° | 330 Hz | 93.3 | 12.6 | 4.9 | — | 126.1 | 0.99 | −140.69 | 21.270 |
# | −90°\* | 0 Hz | 97.4 | 12.6 | 100.0 | — | 252.2 | 1.99 | −150.53 | 0.498 |

# %% [markdown]
# ### 절 4.93 `sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 45 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 348.** `sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 349.** `sionna_p4000000000_swR0D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.4 | 12.5 | 87.0 | +0.1 | 50.9 ⚠튐 | 0.40 | −111.98 | 0.012 |
# | −15° | 1230 Hz | 76.9 | 12.6 | 19.0 | +38.2 | 254.6 | 2.01 | −169.15 | 0.462 |
# | −30° | 1102 Hz | 79.0 | 12.6 | 3.2 | +47.0 | 126.1 | 0.99 | −159.66 | 14.797 |
# | −45° | 900 Hz | 82.2 | 12.5 | 5.6 | +47.6 | 126.1 | 0.99 | −156.71 | 56.100 |
# | −60° | 636 Hz | 89.8 | 12.6 | 15.8 | +46.2 | 126.1 | 0.99 | −155.04 | 76.628 |
# | −75° | 330 Hz | 96.3 | 12.6 | 26.5 | — | 126.1 | 0.99 | −152.46 | 12.845 |
# | −90°\* | 0 Hz | 96.8 | 12.6 | 100.0 | — | 128.5 | 1.01 | −158.21 | 1.010 |

# %% [markdown]
# ### 절 4.94 `sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 350.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 351.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 79.4 | 12.5 | 8.5 | +42.4 | 126.1 | 0.99 | −173.18 | 1.015 |
# | −30° | 1102 Hz | 81.8 | 12.6 | 6.8 | +44.2 | 252.2 | 1.99 | −166.28 | 21.916 |

# %% [markdown]
# ### 절 4.95 `sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 352.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 353.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 77.8 | 12.5 | 7.2 | +43.5 | 380.7 | 3.01 | −169.72 | 0.728 |
# | −30° | 1102 Hz | 79.9 | 12.6 | 9.5 | +43.8 | 126.1 | 0.99 | −167.67 | 6.365 |

# %% [markdown]
# ### 절 4.96 `sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 354.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 355.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.0 | −0.2 | 24.2 ⚠튐 | 0.19 | −117.04 | 0.007 |
# | −15° | 1230 Hz | 77.9 | 12.6 | 22.8 | +38.6 | 123.7 | 0.98 | −174.51 | 5.538 |
# | −30° | 1102 Hz | 81.4 | 12.6 | 7.4 | +43.6 | 126.1 | 0.99 | −167.64 | 82.302 |
# | −45° | 900 Hz | 86.2 | 12.5 | 10.6 | +46.2 | 126.1 | 0.99 | −164.02 | 32.890 |
# | −60° | 636 Hz | 87.0 | 12.6 | 20.9 | +41.8 | 254.6 | 2.01 | −162.28 | 30.913 |
# | −75° | 330 Hz | 92.6 | 12.6 | 18.7 | — | 126.1 | 0.99 | −159.22 | 24.121 |
# | −90°\* | 0 Hz | 98.1 | 12.6 | 100.0 | — | 126.1 | 0.99 | −160.49 | 3.710 |

# %% [markdown]
# ### 절 4.97 `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 356.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 357.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 87.0 | +3.6 | 24.2 ⚠튐 | 0.19 | −117.04 | 0.007 |
# | −30° | 1102 Hz | 37.6 | 12.6 | 3.8 | +1.9 | 63.0 | 0.50 | −168.12 | 80.577 |

# %% [markdown]
# ### 절 4.98 `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 358.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 359.** `sionna_p4000000000_swR0D0E0F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.1 | −0.1 | 60.6 ⚠튐 | 0.48 | −118.00 | 0.005 |
# | −30° | 1102 Hz | 22.9 | 12.6 | 2.7 | +2.4 | 31.5 | 0.25 | −169.29 | 75.717 |

# %% [markdown]
# ### 절 4.99 `sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 90 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 360.** `sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 361.** `sionna_p4000000000_swR0D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 89.2 | 12.5 | 18.0 | +42.3 | 254.6 | 2.01 | −180.38 | 0.000 |
# | −15° | 1230 Hz | 78.8 | 12.6 | 13.7 | +37.7 | 254.6 | 2.01 | −178.54 | 2.391 |
# | −30° | 1102 Hz | 79.3 | 12.6 | 6.0 | +45.3 | 126.1 | 0.99 | −174.18 | 12.177 |
# | −45° | 900 Hz | 83.1 | 12.5 | 13.9 | +43.1 | 126.1 | 0.99 | −172.99 | 28.365 |
# | −60° | 636 Hz | 87.9 | 12.6 | 33.2 | +42.8 | 254.6 | 2.01 | −171.18 | 22.448 |
# | −75° | 330 Hz | 94.8 | 12.6 | 63.9 | — | 252.2 | 1.99 | −169.62 | 14.003 |
# | −90°\* | 0 Hz | 96.3 | 12.6 | 100.0 | — | 126.1 | 0.99 | −170.57 | 11.722 |

# %% [markdown]
# ### 절 4.100 `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 90 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 362.** `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 363.** `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.1 | −0.0 | 21.8 ⚠튐 | 0.17 | −127.55 | 0.001 |
# | −30° | 1102 Hz | 33.7 | 12.6 | 2.6 | +1.0 | 63.0 | 0.50 | −174.07 | 12.479 |

# %% [markdown]
# ### 절 4.101 `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 90 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 364.** `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 365.** `sionna_p4000000000_swR0D0E0F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.1 | −0.2 | 26.7 ⚠튐 | 0.21 | −122.78 | 0.004 |
# | −30° | 1102 Hz | 19.7 | 12.6 | 1.9 | +6.0 | 31.5 | 0.25 | −175.02 | 10.248 |

# %% [markdown]
# ### 절 4.102 `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 366.** `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 367.** `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 31.0 | 10.9 | 44.4 | +25.7 | 891.3 | 5.99 | −141.60 | 0.004 |
# | −30° | 1802 Hz | 40.0 | 10.8 | 4.4 | +38.7 | 147.7 | 0.99 | −133.70 | 0.586 |
# | −60° | 1040 Hz | 87.8 | 10.9 | 3.9 | +46.8 | 743.5 | 4.99 | −122.94 | 0.813 |
# | −90°\* | 0 Hz | 99.8 | 10.8 | 100.0 | — | 891.3 | 5.99 | −120.27 | 0.003 |

# %% [markdown]
# ### 절 4.103 `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 368.** `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 369.** `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 25.6 | 10.9 | 31.1 | +1.1 | 595.8 | 4.00 | −141.34 | 0.004 |

# %% [markdown]
# ### 절 4.104 `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 370.** `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 371.** `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 12.2 | 10.9 | 17.3 | +2.3 | 520.7 | 3.50 | −141.07 | 0.004 |

# %% [markdown]
# ### 절 4.105 `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D0E0F1` = 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 372.** `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 373.** `sionna_p4000000000_swR0D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 9.4 | 10.9 | 27.7 | +7.7 | 852.5 | 5.72 | −141.21 | 0.004 |
# | −30° | 1802 Hz | 8.1 | 10.8 | 2.9 | +12.1 | 152.6 | 1.02 | −132.34 | 0.798 |
# | −60° | 1040 Hz | 10.8 | 10.9 | 2.0 | +10.2 | 302.7 | 2.03 | −121.63 | 1.094 |
# | −90°\* | 0 Hz | 68.6 | 10.8 | 100.0 | — | 736.3 | 4.95 | −125.20 | 0.001 |

# %% [markdown]
# ### 절 4.106 `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R0D1E0F0` = 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d1__map.png)
#
# **그림 374.** `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d1__band.png)
#
# **그림 375.** `sionna_p4000000000_swR0D1E0F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.6 | 12.6 | 88.9 | −0.5 | 417.1 ⚠튐 | 3.29 | −125.17 | 0.109 |

# %% [markdown]
# ### 절 4.107 `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D1E0F0` = 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d3__map.png)
#
# **그림 376.** `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F0_r15_n8192_d3__band.png)
#
# **그림 377.** `sionna_p4000000000_swR0D1E0F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.2 | 12.6 | 89.1 | +1.5 | 344.3 ⚠튐 | 2.72 | −123.70 | 0.152 |

# %% [markdown]
# ### 절 4.108 `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D1E0F1` = 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F1_r15_n8192_d3__map.png)
#
# **그림 378.** `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E0F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E0F1_r15_n8192_d3__band.png)
#
# **그림 379.** `sionna_p4000000000_swR0D1E0F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.3 | 12.6 | 83.1 | +9.1 | 252.2 | 1.99 | −123.44 | 0.160 |

# %% [markdown]
# ### 절 4.109 `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R0D1E1F0` = 회절 + 모서리 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d1__map.png)
#
# **그림 380.** `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d1__band.png)
#
# **그림 381.** `sionna_p4000000000_swR0D1E1F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.6 | 12.6 | 89.0 | −0.3 | 417.1 ⚠튐 | 3.29 | −125.14 | 0.109 |

# %% [markdown]
# ### 절 4.110 `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D1E1F0` = 회절 + 모서리 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d3__map.png)
#
# **그림 382.** `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F0_r15_n8192_d3__band.png)
#
# **그림 383.** `sionna_p4000000000_swR0D1E1F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.2 | 12.6 | 89.1 | +1.3 | 344.3 ⚠튐 | 2.72 | −123.71 | 0.152 |

# %% [markdown]
# ### 절 4.111 `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 384.** `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 385.** `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.2 | 13.5 | 88.9 | +0.1 | 458.5 | 3.82 | −92.78 | 0.057 |
# | −30° | 1018 Hz | 14.7 | 13.5 | 88.1 | +4.6 | 480.4 ⚠튐 | 4.00 | −115.57 | 0.562 |
# | −60° | 588 Hz | 15.3 | 13.5 | 85.8 | +10.9 | 118.9 | 0.99 | −123.85 | 0.115 |
# | −90°\* | 0 Hz | 34.8 | 13.4 | 100.0 | — | 118.9 | 0.99 | −123.06 | 0.425 |

# %% [markdown]
# ### 절 4.112 `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 386.** `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 387.** `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.5 | 13.5 | 88.7 | +0.2 | 422.1 | 3.52 | −92.40 | 0.062 |

# %% [markdown]
# ### 절 4.113 `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 388.** `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 389.** `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.1 | 13.5 | 87.7 | −0.2 | 422.1 ⚠튐 | 3.52 | −93.13 | 0.052 |

# %% [markdown]
# ### 절 4.114 `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 390.** `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 391.** `sionna_p4000000000_swR0D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.6 | 13.5 | 88.3 | +0.5 | 465.8 ⚠튐 | 3.88 | −91.66 | 0.073 |
# | −30° | 1018 Hz | 16.1 | 13.5 | 89.1 | +1.8 | 504.6 ⚠튐 | 4.21 | −116.43 | 0.461 |
# | −60° | 588 Hz | 14.1 | 13.5 | 64.5 | +17.1 | 237.8 | 1.98 | −121.68 | 0.189 |
# | −90°\* | 0 Hz | 22.7 | 13.4 | 100.0 | — | 128.6 | 1.07 | −123.42 | 0.392 |

# %% [markdown]
# ### 절 4.115 `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 392.** `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 393.** `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 7.9 | 8.7 | 89.2 | −0.6 | 432.9 ⚠튐 | 2.36 | −95.95 | 0.115 |
# | −30° | 887 Hz | 9.2 | 8.7 | 90.4 | +2.2 | 365.2 ⚠튐 | 1.99 | −130.63 | 0.045 |
# | −60° | 512 Hz | 11.0 | 8.7 | 55.0 | — | 183.8 | 1.00 | −127.88 | 0.074 |
# | −90°\* | 0 Hz | 9.1 | 8.7 | 100.0 | — | 587.7 | 3.21 | −94.66 | 0.792 |

# %% [markdown]
# ### 절 4.116 `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 394.** `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 395.** `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 7.9 | 8.7 | 90.1 | +0.5 | 592.5 ⚠튐 | 3.23 | −95.91 | 0.116 |

# %% [markdown]
# ### 절 4.117 `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 396.** `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 397.** `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.5 | 8.7 | 90.4 | −0.9 | 505.4 ⚠튐 | 2.76 | −95.98 | 0.114 |

# %% [markdown]
# ### 절 4.118 `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 398.** `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 399.** `sionna_p4000000000_swR0D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 9.4 | 8.7 | 90.7 | +2.2 | 370.0 ⚠튐 | 2.02 | −95.74 | 0.121 |
# | −30° | 887 Hz | 8.0 | 8.7 | 86.7 | +4.5 | 365.2 ⚠튐 | 1.99 | −130.58 | 0.045 |
# | −60° | 512 Hz | 9.9 | 8.7 | 56.7 | — | 186.2 | 1.02 | −128.69 | 0.061 |
# | −90°\* | 0 Hz | 8.4 | 8.7 | 100.0 | — | 224.9 ⚠튐 | 1.23 | −102.36 | 0.134 |

# %% [markdown]
# ### 절 4.119 `sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 400.** `sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 401.** `sionna_p4000000000_swR0D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 82.5 | +4.1 | 128.5 | 1.01 | −88.64 | 0.078 |
# | −30° | 1102 Hz | 12.6 | 12.6 | 75.9 | +12.0 | 252.2 | 1.99 | −116.25 | 0.414 |
# | −60° | 636 Hz | 14.6 | 12.6 | 53.3 | +13.6 | 126.1 | 0.99 | −113.02 | 2.804 |

# %% [markdown]
# ### 절 4.120 `sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 402.** `sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 403.** `sionna_p4000000000_swR0D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 82.4 | +4.1 | 128.5 | 1.01 | −88.63 | 0.078 |
# | −30° | 1102 Hz | 12.7 | 12.6 | 75.8 | +12.1 | 252.2 | 1.99 | −116.27 | 0.412 |
# | −60° | 636 Hz | 14.4 | 12.6 | 53.1 | +13.7 | 126.1 | 0.99 | −113.01 | 2.808 |

# %% [markdown]
# ### 절 4.121 `sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 404.** `sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 405.** `sionna_p4000000000_swR0D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 82.5 | +4.1 | 128.5 | 1.01 | −88.64 | 0.078 |
# | −30° | 1102 Hz | 12.5 | 12.6 | 75.9 | +12.0 | 252.2 | 1.99 | −116.26 | 0.413 |
# | −60° | 636 Hz | 14.4 | 12.6 | 53.1 | +13.8 | 126.1 | 0.99 | −113.01 | 2.805 |

# %% [markdown]
# ### 절 4.122 `sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 406.** `sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 407.** `sionna_p4000000000_swR0D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 82.5 | +4.1 | 128.5 | 1.01 | −88.59 | 0.079 |
# | −30° | 1102 Hz | 12.6 | 12.6 | 75.8 | +12.0 | 252.2 | 1.99 | −116.26 | 0.413 |
# | −60° | 636 Hz | 14.5 | 12.6 | 53.1 | +13.7 | 126.1 | 0.99 | −113.02 | 2.803 |

# %% [markdown]
# ### 절 4.123 `sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 408.** `sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 409.** `sionna_p4000000000_swR0D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 82.4 | +4.1 | 128.5 | 1.01 | −88.65 | 0.078 |
# | −30° | 1102 Hz | 12.7 | 12.6 | 75.8 | +12.1 | 252.2 | 1.99 | −116.24 | 0.415 |
# | −60° | 636 Hz | 14.4 | 12.6 | 53.1 | +13.8 | 126.1 | 0.99 | −113.01 | 2.807 |

# %% [markdown]
# ### 절 4.124 `sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 410.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 411.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 19.1 | 12.5 | 55.7 | +13.5 | 126.1 | 0.99 | −100.93 | 11.334 |
# | −30° | 1102 Hz | 14.7 | 12.6 | 47.1 | +18.9 | 126.1 | 0.99 | −132.38 | 25.015 |

# %% [markdown]
# ### 절 4.125 `sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 412.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 413.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 27.0 | 12.5 | 69.1 | +10.1 | 126.1 | 0.99 | −105.89 | 0.489 |
# | −30° | 1102 Hz | 15.5 | 12.6 | 64.8 | +16.2 | 126.1 | 0.99 | −131.26 | 77.037 |

# %% [markdown]
# ### 절 4.126 `sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 414.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 415.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.5 | 12.5 | 81.4 | +4.7 | 380.7 | 3.01 | −103.94 | 0.098 |
# | −30° | 1102 Hz | 13.1 | 12.6 | 43.2 | +19.7 | 252.2 | 1.99 | −131.35 | 61.988 |

# %% [markdown]
# ### 절 4.127 `sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 416.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 417.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 74.3 | +4.8 | 126.1 | 0.99 | −106.67 | 0.900 |
# | −30° | 1102 Hz | 12.1 | 12.6 | 74.3 | +11.2 | 380.7 ⚠튐 | 3.01 | −125.69 | 0.547 |

# %% [markdown]
# ### 절 4.128 `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 418.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 419.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.6 | 12.5 | 74.5 | +11.8 | 380.7 | 3.01 | −94.19 | 0.043 |
# | −30° | 1102 Hz | 12.5 | 12.6 | 75.3 | +11.7 | 506.8 | 4.00 | −125.62 | 0.145 |
# | −60° | 636 Hz | 13.2 | 12.6 | 59.7 | +12.8 | 126.1 | 0.99 | −122.89 | 0.378 |

# %% [markdown]
# ### 절 4.129 `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 420.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 421.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.6_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.5 | 12.5 | 75.5 | +10.4 | 254.6 | 2.01 | −93.42 | 0.057 |
# | −30° | 1102 Hz | 12.2 | 12.6 | 78.8 | +10.9 | 506.8 | 4.00 | −124.80 | 0.372 |
# | −60° | 636 Hz | 13.5 | 12.6 | 64.7 | +11.9 | 126.1 | 0.99 | −122.37 | 0.197 |

# %% [markdown]
# ### 절 4.130 `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 422.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 423.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_bs0.8_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.6 | 12.5 | 76.4 | +9.7 | 380.7 | 3.01 | −93.69 | 0.054 |
# | −30° | 1102 Hz | 13.2 | 12.6 | 81.9 | +8.5 | 506.8 | 4.00 | −123.74 | 0.349 |
# | −60° | 636 Hz | 13.8 | 12.6 | 70.7 | +10.8 | 126.1 | 0.99 | −121.04 | 0.388 |

# %% [markdown]
# ### 절 4.131 `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d1__map.png)
#
# **그림 424.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d1__band.png)
#
# **그림 425.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.7 | 12.6 | 81.0 | +9.1 | 252.2 | 1.99 | −124.73 | 0.118 |

# %% [markdown]
# ### 절 4.132 `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d3__map.png)
#
# **그림 426.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_d3__band.png)
#
# **그림 427.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 11.3 | 12.6 | 83.2 | +9.0 | 252.2 | 1.99 | −123.42 | 0.161 |

# %% [markdown]
# ### 절 4.133 `sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 428.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 429.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.8 | 12.5 | 72.8 | +9.3 | 254.6 ⚠튐 | 2.01 | −93.18 | 0.080 |
# | −30° | 1102 Hz | 12.7 | 12.6 | 88.9 | −0.1 | 460.7 | 3.64 | −99.07 | 0.914 |
# | −60° | 636 Hz | 13.4 | 12.6 | 93.6 | +0.5 | 274.0 | 2.16 | −93.56 | 1.290 |

# %% [markdown]
# ### 절 4.134 `sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 430.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 431.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 15.0 | 12.5 | 70.7 | +10.1 | 126.1 ⚠튐 | 0.99 | −93.90 | 0.077 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 78.7 | +11.3 | 632.9 | 5.00 | −124.85 | 0.198 |
# | −60° | 636 Hz | 15.1 | 12.6 | 67.8 | +11.5 | 254.6 | 2.01 | −122.59 | 2.272 |
# | −90°\* | 0 Hz | 12.2 | 12.6 | 100.0 | — | 114.0 ⚠튐 | 0.90 | −102.96 | 0.021 |

# %% [markdown]
# ### 절 4.135 `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 432.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 433.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 71.8 | −0.1 | 31.5 | 0.25 | −94.43 | 0.069 |
# | −30° | 1102 Hz | 12.6 | 12.6 | 84.9 | −1.4 | 94.6 | 0.75 | −124.53 | 0.213 |
# | −60° | 636 Hz | 11.7 | 12.6 | 57.5 | +1.1 | 31.5 | 0.25 | −121.62 | 2.825 |
# | −90°\* | 0 Hz | 12.5 | 12.6 | 100.0 | — | 80.0 ⚠튐 | 0.63 | −105.69 | 0.011 |

# %% [markdown]
# ### 절 4.136 `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 434.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 435.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 68.9 | +1.2 | 63.0 | 0.50 | −94.41 | 0.069 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 79.6 | −0.5 | 380.7 | 3.01 | −124.22 | 0.229 |
# | −60° | 636 Hz | 12.4 | 12.6 | 59.3 | +2.5 | 126.1 | 0.99 | −122.28 | 2.437 |
# | −90°\* | 0 Hz | 12.2 | 12.6 | 100.0 | — | 36.4 ⚠튐 | 0.29 | −109.43 | 0.005 |

# %% [markdown]
# ### 절 4.137 `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 436.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 437.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 71.3 | −2.9 | 31.5 | 0.25 | −94.02 | 0.075 |
# | −30° | 1102 Hz | 13.1 | 12.6 | 82.9 | +1.5 | 189.1 | 1.49 | −124.51 | 0.214 |
# | −60° | 636 Hz | 11.9 | 12.6 | 53.8 | −2.4 | 63.0 | 0.50 | −121.84 | 2.698 |
# | −90°\* | 0 Hz | 12.7 | 12.6 | 100.0 | — | 48.5 ⚠튐 | 0.38 | −104.34 | 0.015 |

# %% [markdown]
# ### 절 4.138 `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 438.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 439.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps0.7_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 18.8 | 12.5 | 80.7 | +9.3 | 380.7 ⚠튐 | 3.01 | −97.57 | 0.033 |
# | −30° | 1102 Hz | 12.1 | 12.6 | 84.9 | +5.1 | 506.8 | 4.00 | −125.75 | 0.161 |

# %% [markdown]
# ### 절 4.139 `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 440.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 441.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_fs1.4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 83.2 | +2.6 | 126.1 | 0.99 | −93.43 | 0.049 |
# | −30° | 1102 Hz | 12.1 | 12.6 | 88.5 | +0.4 | 24.2 ⚠튐 | 0.19 | −109.94 | 1.006 |

# %% [markdown]
# ### 절 4.140 `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 442.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 443.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps1.4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.5 | 12.5 | 71.1 | +10.5 | 126.1 | 0.99 | −93.39 | 0.088 |
# | −30° | 1102 Hz | 13.6 | 12.6 | 78.9 | +11.9 | 506.8 | 4.00 | −122.47 | 0.342 |

# %% [markdown]
# ### 절 4.141 `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 444.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 445.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_fs2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.1 | 12.5 | 80.3 | +1.8 | 126.1 | 0.99 | −92.55 | 0.198 |
# | −30° | 1102 Hz | 12.0 | 12.6 | 88.4 | −0.9 | 130.9 | 1.03 | −94.28 | 57.256 |

# %% [markdown]
# ### 절 4.142 `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 446.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 447.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_ps2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 17.9 | 12.5 | 71.1 | +9.9 | 126.1 | 0.99 | −89.71 | 0.207 |
# | −30° | 1102 Hz | 16.8 | 12.6 | 79.9 | +10.0 | 126.1 | 0.99 | −122.20 | 0.362 |

# %% [markdown]
# ### 절 4.143 `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 448.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 449.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 15.0 | 12.5 | 70.7 | +10.1 | 126.1 ⚠튐 | 0.99 | −93.90 | 0.077 |
# | −15° | 1230 Hz | 12.3 | 12.6 | 86.5 | +1.3 | 43.6 ⚠튐 | 0.34 | −120.21 | 0.178 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 78.8 | +11.2 | 632.9 | 5.00 | −124.85 | 0.198 |
# | −45° | 900 Hz | 12.7 | 12.5 | 90.0 | +3.4 | 506.8 ⚠튐 | 4.00 | −109.40 | 0.247 |
# | −60° | 636 Hz | 15.1 | 12.6 | 67.8 | +11.5 | 254.6 | 2.01 | −122.57 | 2.280 |
# | −75° | 330 Hz | 12.4 | 12.6 | 88.0 | — | 126.1 | 0.99 | −112.31 | 0.194 |

# %% [markdown]
# ### 절 4.144 `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 450.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 451.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 15.0 | 12.5 | 70.7 | +10.1 | 126.1 ⚠튐 | 0.99 | −93.90 | 0.077 |
# | −15° | 1230 Hz | 12.3 | 12.6 | 86.5 | +1.2 | 43.6 ⚠튐 | 0.34 | −120.21 | 0.178 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 78.8 | +11.2 | 632.9 | 5.00 | −124.84 | 0.198 |
# | −45° | 900 Hz | 12.7 | 12.5 | 90.0 | +3.4 | 506.8 ⚠튐 | 4.00 | −109.40 | 0.247 |
# | −60° | 636 Hz | 15.1 | 12.6 | 67.8 | +11.5 | 254.6 | 2.01 | −122.59 | 2.272 |
# | −75° | 330 Hz | 12.4 | 12.6 | 88.0 | — | 126.1 | 0.99 | −112.31 | 0.194 |

# %% [markdown]
# ### 절 4.145 `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 452.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 453.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 15.0 | 12.5 | 70.7 | +10.1 | 126.1 ⚠튐 | 0.99 | −93.90 | 0.077 |
# | −15° | 1230 Hz | 12.3 | 12.6 | 86.6 | +1.2 | 43.6 ⚠튐 | 0.34 | −120.21 | 0.178 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 78.8 | +11.2 | 632.9 | 5.00 | −124.86 | 0.197 |
# | −45° | 900 Hz | 12.7 | 12.5 | 90.0 | +3.4 | 506.8 ⚠튐 | 4.00 | −109.40 | 0.247 |
# | −60° | 636 Hz | 15.1 | 12.6 | 67.8 | +11.5 | 254.6 | 2.01 | −122.57 | 2.280 |
# | −75° | 330 Hz | 12.4 | 12.6 | 88.0 | — | 126.1 | 0.99 | −112.31 | 0.194 |

# %% [markdown]
# ### 절 4.146 `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 454.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 455.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 15.0 | 12.5 | 70.7 | +10.1 | 126.1 ⚠튐 | 0.99 | −93.90 | 0.077 |
# | −30° | 1102 Hz | 12.8 | 12.6 | 78.8 | +11.2 | 632.9 | 5.00 | −124.85 | 0.198 |
# | −60° | 636 Hz | 15.1 | 12.6 | 67.8 | +11.5 | 254.6 | 2.01 | −122.59 | 2.272 |

# %% [markdown]
# ### 절 4.147 `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 456.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 457.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 15.0 | 12.5 | 70.7 | +10.1 | 126.1 ⚠튐 | 0.99 | −93.90 | 0.077 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 78.8 | +11.2 | 632.9 | 5.00 | −124.84 | 0.198 |
# | −60° | 636 Hz | 15.1 | 12.6 | 67.8 | +11.5 | 254.6 | 2.01 | −122.57 | 2.280 |

# %% [markdown]
# ### 절 4.148 `sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 458.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 459.** `sionna_p4000000000_swR0D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 11.7 | 12.5 | 68.4 | +8.3 | 259.5 | 2.05 | −94.06 | 0.075 |
# | −30° | 1102 Hz | 13.0 | 12.6 | 78.7 | +6.8 | 388.0 | 3.06 | −124.56 | 0.212 |
# | −60° | 636 Hz | 12.2 | 12.6 | 56.9 | +18.3 | 249.8 | 1.97 | −121.59 | 2.844 |
# | −90°\* | 0 Hz | 13.1 | 12.6 | 100.0 | — | 70.3 ⚠튐 | 0.56 | −102.07 | 0.026 |

# %% [markdown]
# ### 절 4.149 `sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 460.** `sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 461.** `sionna_p4000000000_swR0D1E1F1_r30_n8192_az45_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.4 | 12.5 | 83.4 | −0.7 | 126.1 | 0.99 | −119.18 | 0.109 |
# | −30° | 1102 Hz | 20.7 | 12.6 | 18.8 | +24.5 | 126.1 | 0.99 | −149.52 | 87.157 |

# %% [markdown]
# ### 절 4.150 `sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 462.** `sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 463.** `sionna_p4000000000_swR0D1E1F1_r30_n8192_az90_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 15.8 | 12.5 | 81.6 | +1.1 | 126.1 | 0.99 | −120.18 | 56.374 |
# | −30° | 1102 Hz | 13.1 | 12.6 | 75.5 | +12.8 | 380.7 | 3.01 | −140.37 | 0.143 |

# %% [markdown]
# ### 절 4.151 `sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 464.** `sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 465.** `sionna_p4000000000_swR0D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 87.0 | +2.0 | 60.6 ⚠튐 | 0.48 | −105.85 | 0.018 |
# | −15° | 1230 Hz | 12.4 | 12.6 | 87.8 | −0.4 | 121.2 ⚠튐 | 0.96 | −133.66 | 0.156 |
# | −30° | 1102 Hz | 12.5 | 12.6 | 85.3 | +5.8 | 254.6 | 2.01 | −138.62 | 0.127 |
# | −45° | 900 Hz | 12.9 | 12.5 | 79.0 | +12.1 | 252.2 | 1.99 | −138.02 | 0.081 |
# | −60° | 636 Hz | 14.5 | 12.6 | 88.4 | +5.5 | 126.1 | 0.99 | −135.95 | 0.434 |
# | −75° | 330 Hz | 13.2 | 12.6 | 88.1 | — | 126.1 | 0.99 | −130.62 | 0.241 |
# | −90°\* | 0 Hz | 12.6 | 12.6 | 100.0 | — | 118.8 ⚠튐 | 0.94 | −105.58 | 0.065 |

# %% [markdown]
# ### 절 4.152 `sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 45 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 466.** `sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 467.** `sionna_p4000000000_swR0D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 87.1 | −0.1 | 434.1 ⚠튐 | 3.43 | −112.68 | 0.008 |
# | −15° | 1230 Hz | 12.7 | 12.6 | 87.2 | +0.7 | 60.6 ⚠튐 | 0.48 | −145.29 | 0.131 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 83.4 | +8.7 | 126.1 | 0.99 | −147.35 | 0.142 |
# | −45° | 900 Hz | 14.5 | 12.5 | 80.3 | +11.0 | 252.2 | 1.99 | −146.12 | 0.040 |
# | −60° | 636 Hz | 14.0 | 12.6 | 87.9 | +8.5 | 126.1 | 0.99 | −144.09 | 0.213 |
# | −75° | 330 Hz | 13.6 | 12.6 | 92.4 | — | 126.1 | 0.99 | −139.10 | 0.088 |
# | −90°\* | 0 Hz | 13.0 | 12.6 | 100.0 | — | 50.9 ⚠튐 | 0.40 | −107.15 | 0.055 |

# %% [markdown]
# ### 절 4.153 `sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 468.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 469.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_az45_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 18.3 | 12.5 | 82.3 | +0.7 | 126.1 | 0.99 | −134.67 | 1.662 |
# | −30° | 1102 Hz | 80.8 | 12.6 | 7.2 | +43.0 | 252.2 | 1.99 | −165.36 | 48.894 |

# %% [markdown]
# ### 절 4.154 `sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 470.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 471.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_az90_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.9 | 12.5 | 86.0 | −0.2 | 63.0 ⚠튐 | 0.50 | −146.49 | 67.902 |
# | −30° | 1102 Hz | 13.1 | 12.6 | 84.5 | +7.2 | 378.3 ⚠튐 | 2.99 | −155.71 | 0.034 |

# %% [markdown]
# ### 절 4.155 `sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 472.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 473.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 86.7 | −0.2 | 24.2 ⚠튐 | 0.19 | −116.31 | 0.006 |
# | −15° | 1230 Hz | 12.9 | 12.6 | 87.2 | +1.1 | 65.5 ⚠튐 | 0.52 | −150.32 | 0.103 |
# | −30° | 1102 Hz | 16.7 | 12.6 | 85.3 | +5.3 | 254.6 ⚠튐 | 2.01 | −153.59 | 0.081 |
# | −45° | 900 Hz | 13.9 | 12.5 | 82.1 | +10.8 | 252.2 | 1.99 | −153.69 | 0.023 |
# | −60° | 636 Hz | 13.8 | 12.6 | 87.1 | +7.6 | 126.1 | 0.99 | −152.02 | 0.069 |
# | −75° | 330 Hz | 13.2 | 12.6 | 93.1 | — | 126.1 ⚠튐 | 0.99 | −146.10 | 0.068 |
# | −90°\* | 0 Hz | 12.4 | 12.6 | 100.0 | — | 65.5 ⚠튐 | 0.52 | −114.86 | 0.022 |

# %% [markdown]
# ### 절 4.156 `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 474.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 475.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 86.6 | +3.5 | 24.2 ⚠튐 | 0.19 | −116.90 | 0.005 |
# | −30° | 1102 Hz | 12.5 | 12.6 | 85.2 | +1.0 | 380.7 ⚠튐 | 3.01 | −152.76 | 0.098 |

# %% [markdown]
# ### 절 4.157 `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 476.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 477.** `sionna_p4000000000_swR0D1E1F1_r60_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 86.8 | −1.2 | 53.3 ⚠튐 | 0.42 | −117.58 | 0.005 |
# | −30° | 1102 Hz | 12.6 | 12.6 | 86.5 | +0.6 | 254.6 ⚠튐 | 2.01 | −153.38 | 0.085 |

# %% [markdown]
# ### 절 4.158 `sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 90 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 478.** `sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 479.** `sionna_p4000000000_swR0D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 22.9 | 12.5 | 81.4 | +2.2 | 252.2 | 1.99 | −139.77 | 0.000 |
# | −15° | 1230 Hz | 12.6 | 12.6 | 87.3 | +0.8 | 77.6 ⚠튐 | 0.61 | −157.85 | 0.033 |
# | −30° | 1102 Hz | 13.6 | 12.6 | 77.6 | +11.7 | 506.8 ⚠튐 | 4.00 | −163.19 | 0.007 |
# | −45° | 900 Hz | 14.2 | 12.5 | 83.7 | +9.5 | 254.6 ⚠튐 | 2.01 | −161.41 | 0.009 |
# | −60° | 636 Hz | 14.0 | 12.6 | 90.1 | +8.3 | 126.1 ⚠튐 | 0.99 | −160.62 | 0.015 |
# | −75° | 330 Hz | 15.7 | 12.6 | 95.3 | — | 252.2 ⚠튐 | 1.99 | −155.11 | 0.031 |
# | −90°\* | 0 Hz | 12.3 | 12.6 | 100.0 | — | 414.7 ⚠튐 | 3.27 | −121.87 | 0.010 |

# %% [markdown]
# ### 절 4.159 `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 90 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 480.** `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 481.** `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 84.9 | +1.2 | 31.5 ⚠튐 | 0.25 | −127.30 | 0.001 |
# | −30° | 1102 Hz | 12.7 | 12.6 | 73.8 | +1.6 | 380.7 ⚠튐 | 3.01 | −165.74 | 0.004 |

# %% [markdown]
# ### 절 4.160 `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 90 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 482.** `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 483.** `sionna_p4000000000_swR0D1E1F1_r90_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.6 | 12.5 | 86.8 | −0.5 | 26.7 ⚠튐 | 0.21 | −122.70 | 0.004 |
# | −30° | 1102 Hz | 12.8 | 12.6 | 77.5 | +0.8 | 126.1 ⚠튐 | 0.99 | −164.84 | 0.005 |

# %% [markdown]
# ### 절 4.161 `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 484.** `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 485.** `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 11.4 | 10.9 | 78.5 | −1.1 | 145.3 ⚠튐 | 0.98 | −93.92 | 1.512 |
# | −30° | 1802 Hz | 10.4 | 10.8 | 78.1 | +5.8 | 147.7 | 0.99 | −119.67 | 1.191 |
# | −60° | 1040 Hz | 10.9 | 10.9 | 88.8 | +3.9 | 472.3 | 3.17 | −103.54 | 0.097 |
# | −90°\* | 0 Hz | 52.8 | 10.8 | 100.0 | — | 891.3 | 5.99 | −116.44 | 0.001 |

# %% [markdown]
# ### 절 4.162 `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 486.** `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 487.** `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 11.9 | 10.9 | 80.6 | −0.5 | 162.3 ⚠튐 | 1.09 | −93.88 | 1.524 |

# %% [markdown]
# ### 절 4.163 `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 488.** `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 489.** `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 10.8 | 10.9 | 78.9 | +0.9 | 46.0 ⚠튐 | 0.31 | −93.60 | 1.631 |

# %% [markdown]
# ### 절 4.164 `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R0D1E1F1` = 회절 + 모서리 회절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 490.** `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 491.** `sionna_p4000000000_swR0D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 12.3 | 10.9 | 78.8 | −1.0 | 249.5 ⚠튐 | 1.68 | −93.37 | 1.716 |
# | −30° | 1802 Hz | 11.2 | 10.8 | 76.8 | +1.8 | 186.5 | 1.25 | −119.38 | 1.272 |
# | −60° | 1040 Hz | 9.6 | 10.9 | 88.0 | +2.0 | 268.8 | 1.80 | −103.37 | 0.101 |
# | −90°\* | 0 Hz | 32.7 | 10.8 | 100.0 | — | 736.3 | 4.95 | −118.44 | 0.000 |

# %% [markdown]
# ### 절 4.165 `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D0E0F0` = 굴절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F0_r15_n8192_d1__map.png)
#
# **그림 492.** `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F0_r15_n8192_d1__band.png)
#
# **그림 493.** `sionna_p4000000000_swR1D0E0F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | ∅ 에코 없음 | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 4.166 `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 494.** `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 495.** `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 12.4 | 13.5 | 88.1 | +0.1 | 424.6 ⚠튐 | 3.54 | −97.34 | 0.022 |
# | −30° | 1018 Hz | 73.4 | 13.5 | 10.4 | +36.7 | 121.3 | 1.01 | −141.15 | 8.607 |
# | −60° | 588 Hz | 71.1 | 13.5 | 65.3 | +25.0 | 118.9 | 0.99 | −138.27 | 19.055 |
# | −90°\* | 0 Hz | 70.3 | 13.4 | 100.0 | — | 240.2 | 2.00 | −137.54 | 0.287 |

# %% [markdown]
# ### 절 4.167 `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 496.** `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 497.** `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.3 | 13.5 | 88.4 | −0.9 | 441.6 ⚠튐 | 3.68 | −96.40 | 0.027 |

# %% [markdown]
# ### 절 4.168 `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 498.** `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 499.** `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.6 | 13.5 | 88.5 | −2.3 | 390.6 ⚠튐 | 3.25 | −97.05 | 0.024 |

# %% [markdown]
# ### 절 4.169 `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 500.** `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 501.** `sionna_p4000000000_swR1D0E0F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 13.4 | 13.5 | 88.9 | −0.9 | 82.5 ⚠튐 | 0.69 | −95.95 | 0.030 |
# | −30° | 1018 Hz | 17.4 | 13.5 | 16.2 | +24.2 | 123.7 | 1.03 | −140.37 | 10.140 |
# | −60° | 588 Hz | 21.3 | 13.5 | 25.9 | +32.1 | 237.8 | 1.98 | −135.53 | 30.595 |
# | −90°\* | 0 Hz | 35.5 | 13.4 | 100.0 | — | 245.0 | 2.04 | −137.67 | 0.279 |

# %% [markdown]
# ### 절 4.170 `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1__map.png)
#
# **그림 502.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1__band.png)
#
# **그림 503.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.7 | 8.7 | 89.7 | −0.8 | 522.4 ⚠튐 | 2.85 | −103.51 | 0.021 |
# | −15° | 990 Hz | 49.2 | 8.6 | 52.2 | +28.7 | 367.6 | 2.00 | −156.78 | 2.917 |
# | −30° | 887 Hz | 71.0 | 8.7 | 39.7 | +36.2 | 181.4 | 0.99 | −150.99 | 61.137 |
# | −45° | 725 Hz | 60.7 | 8.7 | 14.3 | +39.3 | 183.8 | 1.00 | −140.58 | 26.336 |
# | −60° | 512 Hz | 59.2 | 8.7 | 22.1 | — | 183.8 | 1.00 | −138.29 | 22.591 |
# | −75° | 265 Hz | 54.4 | 8.7 | 34.7 | — | 183.8 | 1.00 | −139.55 | 6.400 |
# | −90°\* | 0 Hz | 45.7 | 8.7 | 100.0 | — | 183.8 | 1.00 | −144.05 | 3.457 |

# %% [markdown]
# ### 절 4.171 `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 504.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 505.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.5 | 8.7 | 89.6 | +0.6 | 527.2 ⚠튐 | 2.88 | −104.18 | 0.018 |
# | −30° | 887 Hz | 72.9 | 8.7 | 48.0 | +35.3 | 367.6 | 2.00 | −151.65 | 90.335 |
# | −60° | 512 Hz | 59.7 | 8.7 | 19.3 | — | 183.8 | 1.00 | −137.70 | 25.781 |
# | −90°\* | 0 Hz | 39.1 | 8.7 | 100.0 | — | 367.6 | 2.00 | −144.18 | 2.556 |

# %% [markdown]
# ### 절 4.172 `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 506.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 507.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.7 | 8.7 | 89.5 | −0.0 | 481.3 ⚠튐 | 2.62 | −101.18 | 0.037 |

# %% [markdown]
# ### 절 4.173 `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 508.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 509.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.8 | 8.7 | 89.7 | −1.4 | 394.2 ⚠튐 | 2.15 | −102.42 | 0.028 |

# %% [markdown]
# ### 절 4.174 `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 510.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 511.** `sionna_p4000000000_swR1D0E0F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.4 | 8.7 | 90.3 | +0.7 | 258.8 ⚠튐 | 1.41 | −100.51 | 0.043 |
# | −30° | 887 Hz | 15.8 | 8.7 | 18.8 | +28.7 | 179.0 | 0.98 | −148.26 | 95.431 |
# | −60° | 512 Hz | 19.4 | 8.7 | 27.6 | — | 183.8 | 1.00 | −138.77 | 21.280 |
# | −90°\* | 0 Hz | 17.8 | 8.7 | 100.0 | — | 181.4 | 0.99 | −143.90 | 2.725 |

# %% [markdown]
# ### 절 4.175 `sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 512.** `sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 513.** `sionna_p4000000000_swR1D0E0F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 85.2 | +1.6 | 26.7 ⚠튐 | 0.21 | −92.91 | 0.047 |
# | −30° | 1102 Hz | 63.1 | 12.6 | 6.6 | +40.2 | 126.1 | 0.99 | −131.51 | 9.857 |
# | −60° | 636 Hz | 62.9 | 12.6 | 21.7 | +29.8 | 126.1 | 0.99 | −126.33 | 29.006 |

# %% [markdown]
# ### 절 4.176 `sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 514.** `sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 515.** `sionna_p4000000000_swR1D0E0F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 85.2 | +1.6 | 26.7 ⚠튐 | 0.21 | −92.91 | 0.047 |
# | −30° | 1102 Hz | 63.1 | 12.6 | 6.6 | +40.2 | 126.1 | 0.99 | −131.51 | 9.857 |
# | −60° | 636 Hz | 62.9 | 12.6 | 21.7 | +29.8 | 126.1 | 0.99 | −126.33 | 29.006 |

# %% [markdown]
# ### 절 4.177 `sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 516.** `sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 517.** `sionna_p4000000000_swR1D0E0F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 85.2 | +1.6 | 26.7 ⚠튐 | 0.21 | −92.91 | 0.047 |
# | −30° | 1102 Hz | 63.1 | 12.6 | 6.6 | +40.2 | 126.1 | 0.99 | −131.51 | 9.857 |
# | −60° | 636 Hz | 62.9 | 12.6 | 21.7 | +29.8 | 126.1 | 0.99 | −126.33 | 29.006 |

# %% [markdown]
# ### 절 4.178 `sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 518.** `sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 519.** `sionna_p4000000000_swR1D0E0F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 85.2 | +1.6 | 26.7 ⚠튐 | 0.21 | −92.91 | 0.047 |
# | −30° | 1102 Hz | 63.1 | 12.6 | 6.6 | +40.2 | 126.1 | 0.99 | −131.51 | 9.857 |
# | −60° | 636 Hz | 62.9 | 12.6 | 21.7 | +29.8 | 126.1 | 0.99 | −126.33 | 29.006 |

# %% [markdown]
# ### 절 4.179 `sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 520.** `sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 521.** `sionna_p4000000000_swR1D0E0F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.0 | 12.5 | 85.2 | +1.6 | 26.7 ⚠튐 | 0.21 | −92.91 | 0.047 |
# | −30° | 1102 Hz | 63.1 | 12.6 | 6.6 | +40.2 | 126.1 | 0.99 | −131.51 | 9.857 |
# | −60° | 636 Hz | 62.9 | 12.6 | 21.7 | +29.8 | 126.1 | 0.99 | −126.33 | 29.006 |

# %% [markdown]
# ### 절 4.180 `sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 522.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 523.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 49.9 | 12.5 | 56.4 | +29.0 | 126.1 | 0.99 | −149.68 | 2.377 |
# | −30° | 1102 Hz | 68.1 | 12.6 | 20.3 | +37.9 | 126.1 | 0.99 | −141.23 | 16.167 |

# %% [markdown]
# ### 절 4.181 `sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 524.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 525.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 50.2 | 12.5 | 40.6 | +30.4 | 254.6 | 2.01 | −147.30 | 1.469 |
# | −30° | 1102 Hz | 59.5 | 12.6 | 7.7 | +38.1 | 126.1 | 0.99 | −139.04 | 28.791 |

# %% [markdown]
# ### 절 4.182 `sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 526.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 527.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 51.7 | 12.5 | 49.4 | +27.2 | 126.1 | 0.99 | −148.30 | 28.237 |
# | −30° | 1102 Hz | 65.1 | 12.6 | 10.1 | +39.7 | 252.2 | 1.99 | −140.17 | 92.245 |

# %% [markdown]
# ### 절 4.183 `sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 528.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 529.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 38.7 | 12.5 | 28.6 | +28.9 | 126.1 | 0.99 | −147.60 | 0.281 |
# | −30° | 1102 Hz | 61.8 | 12.6 | 7.0 | +40.8 | 126.1 | 0.99 | −138.43 | 6.941 |

# %% [markdown]
# ### 절 4.184 `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_d3__map.png)
#
# **그림 530.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_d3__band.png)
#
# **그림 531.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 61.6 | 12.6 | 11.8 | +37.5 | 126.1 | 0.99 | −140.96 | 31.974 |

# %% [markdown]
# ### 절 4.185 `sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 532.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 533.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.2 | 12.5 | 85.4 | −0.3 | 106.7 ⚠튐 | 0.84 | −97.18 | 0.037 |
# | −30° | 1102 Hz | 13.0 | 12.6 | 88.6 | −0.1 | 460.7 ⚠튐 | 3.64 | −103.09 | 0.427 |
# | −60° | 636 Hz | 13.0 | 12.6 | 93.2 | −1.1 | 72.7 ⚠튐 | 0.57 | −95.80 | 0.723 |

# %% [markdown]
# ### 절 4.186 `sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 534.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 535.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 85.4 | −0.1 | 106.7 ⚠튐 | 0.84 | −97.45 | 0.038 |
# | −30° | 1102 Hz | 58.7 | 12.6 | 8.2 | +38.5 | 126.1 | 0.99 | −139.69 | 91.289 |
# | −60° | 636 Hz | 62.7 | 12.6 | 32.4 | +30.8 | 254.6 | 2.01 | −135.21 | 26.599 |
# | −90°\* | 0 Hz | 57.2 | 12.6 | 100.0 | — | 252.2 | 1.99 | −137.62 | 1.393 |

# %% [markdown]
# ### 절 4.187 `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 536.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 537.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.9 | +0.1 | 97.0 ⚠튐 | 0.77 | −99.13 | 0.026 |
# | −30° | 1102 Hz | 11.2 | 12.6 | 3.7 | −3.9 | 31.5 | 0.25 | −141.17 | 88.349 |
# | −60° | 636 Hz | 13.1 | 12.6 | 7.9 | +2.3 | 31.5 | 0.25 | −133.44 | 35.852 |
# | −90°\* | 0 Hz | 9.9 | 12.6 | 100.0 | — | 80.0 | 0.63 | −137.52 | 1.422 |

# %% [markdown]
# ### 절 4.188 `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 538.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 539.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 14.4 | 12.5 | 86.7 | +1.9 | 72.7 ⚠튐 | 0.57 | −99.13 | 0.026 |
# | −30° | 1102 Hz | 37.3 | 12.6 | 5.3 | +1.8 | 63.0 | 0.50 | −139.46 | 91.721 |
# | −60° | 636 Hz | 35.0 | 12.6 | 20.1 | −2.1 | 126.1 | 0.99 | −134.32 | 31.048 |
# | −90°\* | 0 Hz | 40.0 | 12.6 | 100.0 | — | 252.2 | 1.99 | −137.62 | 1.392 |

# %% [markdown]
# ### 절 4.189 `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 540.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 541.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.4 | 12.5 | 87.4 | −0.7 | 82.4 ⚠튐 | 0.65 | −99.36 | 0.024 |
# | −30° | 1102 Hz | 19.1 | 12.6 | 4.7 | +1.6 | 31.5 | 0.25 | −140.29 | 90.278 |
# | −60° | 636 Hz | 21.4 | 12.6 | 12.4 | −0.6 | 63.0 | 0.50 | −133.71 | 34.362 |
# | −90°\* | 0 Hz | 15.2 | 12.6 | 100.0 | — | 63.0 | 0.50 | −137.51 | 1.429 |

# %% [markdown]
# ### 절 4.190 `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 542.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 543.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 85.4 | −0.1 | 106.7 ⚠튐 | 0.84 | −97.45 | 0.038 |
# | −15° | 1230 Hz | 58.6 | 12.6 | 49.1 | +27.7 | 128.5 | 1.01 | −147.78 | 0.652 |
# | −30° | 1102 Hz | 58.7 | 12.6 | 8.2 | +38.5 | 126.1 | 0.99 | −139.69 | 91.290 |
# | −45° | 900 Hz | 63.9 | 12.5 | 16.5 | +38.0 | 126.1 | 0.99 | −137.19 | 74.823 |
# | −60° | 636 Hz | 62.7 | 12.6 | 32.4 | +30.8 | 254.6 | 2.01 | −135.21 | 26.600 |
# | −75° | 330 Hz | 52.4 | 12.6 | 19.4 | — | 126.1 | 0.99 | −131.99 | 11.049 |

# %% [markdown]
# ### 절 4.191 `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 544.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 545.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 85.4 | −0.1 | 106.7 ⚠튐 | 0.84 | −97.45 | 0.038 |
# | −15° | 1230 Hz | 58.6 | 12.6 | 49.1 | +27.7 | 128.5 | 1.01 | −147.78 | 0.652 |
# | −30° | 1102 Hz | 58.7 | 12.6 | 8.2 | +38.5 | 126.1 | 0.99 | −139.69 | 91.290 |
# | −45° | 900 Hz | 63.9 | 12.5 | 16.5 | +38.0 | 126.1 | 0.99 | −137.19 | 74.823 |
# | −60° | 636 Hz | 62.7 | 12.6 | 32.4 | +30.8 | 254.6 | 2.01 | −135.21 | 26.600 |
# | −75° | 330 Hz | 52.4 | 12.6 | 19.4 | — | 126.1 | 0.99 | −131.99 | 11.049 |

# %% [markdown]
# ### 절 4.192 `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 546.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 547.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 85.4 | −0.1 | 106.7 ⚠튐 | 0.84 | −97.45 | 0.038 |
# | −15° | 1230 Hz | 58.6 | 12.6 | 49.1 | +27.7 | 128.5 | 1.01 | −147.78 | 0.652 |
# | −30° | 1102 Hz | 58.7 | 12.6 | 8.2 | +38.5 | 126.1 | 0.99 | −139.69 | 91.290 |
# | −45° | 900 Hz | 63.9 | 12.5 | 16.5 | +38.0 | 126.1 | 0.99 | −137.19 | 74.823 |
# | −60° | 636 Hz | 62.7 | 12.6 | 32.4 | +30.8 | 254.6 | 2.01 | −135.21 | 26.600 |
# | −75° | 330 Hz | 52.4 | 12.6 | 19.4 | — | 126.1 | 0.99 | −131.99 | 11.049 |

# %% [markdown]
# ### 절 4.193 `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 548.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 549.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 85.4 | −0.1 | 106.7 ⚠튐 | 0.84 | −97.45 | 0.038 |
# | −30° | 1102 Hz | 58.7 | 12.6 | 8.2 | +38.5 | 126.1 | 0.99 | −139.69 | 91.290 |
# | −60° | 636 Hz | 62.7 | 12.6 | 32.4 | +30.8 | 254.6 | 2.01 | −135.21 | 26.600 |

# %% [markdown]
# ### 절 4.194 `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 550.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 551.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.3 | 12.5 | 85.4 | −0.1 | 106.7 ⚠튐 | 0.84 | −97.45 | 0.038 |
# | −30° | 1102 Hz | 58.7 | 12.6 | 8.2 | +38.5 | 126.1 | 0.99 | −139.69 | 91.290 |
# | −60° | 636 Hz | 62.7 | 12.6 | 32.4 | +30.8 | 254.6 | 2.01 | −135.21 | 26.600 |

# %% [markdown]
# ### 절 4.195 `sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 552.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 553.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 87.8 | +0.5 | 43.6 ⚠튐 | 0.34 | −98.69 | 0.028 |
# | −30° | 1102 Hz | 17.3 | 12.6 | 8.2 | +28.6 | 249.8 | 1.97 | −138.90 | 92.622 |
# | −60° | 636 Hz | 16.9 | 12.6 | 23.1 | +30.9 | 259.5 | 2.05 | −134.10 | 31.802 |
# | −90°\* | 0 Hz | 26.0 | 12.6 | 100.0 | — | 126.1 | 0.99 | −137.27 | 1.507 |

# %% [markdown]
# ### 절 4.196 `sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3__map.png)
#
# **그림 554.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3__band.png)
#
# **그림 555.** `sionna_p4000000000_swR1D0E0F1_r15_n8192_shell0.75mm_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 60.9 | 12.6 | 11.9 | +37.5 | 126.1 | 0.99 | −141.09 | 90.462 |

# %% [markdown]
# ### 절 4.197 `sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 556.** `sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 557.** `sionna_p4000000000_swR1D0E0F1_r30_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.1 | +0.0 | 24.2 ⚠튐 | 0.19 | −111.96 | 0.005 |
# | −15° | 1230 Hz | 57.5 | 12.6 | 53.2 | +26.3 | 128.5 | 1.01 | −160.28 | 4.890 |
# | −30° | 1102 Hz | 65.3 | 12.6 | 18.3 | +36.8 | 126.1 | 0.99 | −154.89 | 58.554 |
# | −45° | 900 Hz | 59.9 | 12.5 | 35.9 | +32.2 | 126.1 | 0.99 | −151.79 | 66.034 |
# | −60° | 636 Hz | 60.9 | 12.6 | 43.1 | +29.2 | 126.1 | 0.99 | −148.78 | 14.912 |
# | −75° | 330 Hz | 58.6 | 12.6 | 43.8 | — | 126.1 | 0.99 | −147.23 | 37.542 |
# | −90°\* | 0 Hz | 51.8 | 12.6 | 100.0 | — | 128.5 | 1.01 | −150.33 | 3.062 |

# %% [markdown]
# ### 절 4.198 `sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 45 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 558.** `sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 559.** `sionna_p4000000000_swR1D0E0F1_r45_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.0 | +0.0 | 21.8 ⚠튐 | 0.17 | −121.52 | 0.001 |
# | −15° | 1230 Hz | 64.2 | 12.6 | 64.0 | +25.9 | 126.1 | 0.99 | −168.41 | 2.001 |
# | −30° | 1102 Hz | 65.1 | 12.6 | 29.8 | +32.7 | 126.1 | 0.99 | −163.42 | 40.608 |
# | −45° | 900 Hz | 62.8 | 12.5 | 43.6 | +32.7 | 252.2 | 1.99 | −159.02 | 42.920 |
# | −60° | 636 Hz | 61.0 | 12.6 | 56.3 | +28.4 | 126.1 | 0.99 | −157.42 | 27.377 |
# | −75° | 330 Hz | 58.4 | 12.6 | 70.5 | — | 126.1 | 0.99 | −155.93 | 14.315 |
# | −90°\* | 0 Hz | 51.1 | 12.6 | 100.0 | — | 254.6 | 2.01 | −157.46 | 7.697 |

# %% [markdown]
# ### 절 4.199 `sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 560.** `sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 561.** `sionna_p4000000000_swR1D0E0F1_r60_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 87.1 | +0.0 | 21.8 ⚠튐 | 0.17 | −121.01 | 0.003 |
# | −15° | 1230 Hz | 59.5 | 12.6 | 68.2 | +23.2 | 380.7 | 3.01 | −172.25 | 2.940 |
# | −30° | 1102 Hz | 60.7 | 12.6 | 31.5 | +30.2 | 126.1 | 0.99 | −170.14 | 6.604 |
# | −45° | 900 Hz | 60.1 | 12.5 | 54.6 | +27.2 | 126.1 | 0.99 | −165.36 | 21.193 |
# | −60° | 636 Hz | 60.5 | 12.6 | 65.1 | +26.0 | 126.1 | 0.99 | −163.00 | 91.408 |
# | −75° | 330 Hz | 54.4 | 12.6 | 62.7 | — | 126.1 | 0.99 | −161.42 | 31.977 |
# | −90°\* | 0 Hz | 46.2 | 12.6 | 100.0 | — | 254.6 | 2.01 | −162.61 | 30.333 |

# %% [markdown]
# ### 절 4.200 `sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 90 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 562.** `sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 563.** `sionna_p4000000000_swR1D0E0F1_r90_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 51.1 | 12.5 | 61.7 | +26.4 | 254.6 | 2.01 | −183.87 | 0.000 |
# | −15° | 1230 Hz | 72.7 | 12.6 | 88.4 | +20.0 | 126.1 | 0.99 | −178.85 | 4.007 |
# | −30° | 1102 Hz | 56.5 | 12.6 | 30.6 | +31.8 | 254.6 | 2.01 | −176.46 | 16.083 |
# | −45° | 900 Hz | 65.1 | 12.5 | 57.2 | +28.9 | 126.1 | 0.99 | −171.97 | 87.698 |
# | −60° | 636 Hz | 60.3 | 12.6 | 80.8 | +24.0 | 380.7 | 3.01 | −171.03 | 31.991 |
# | −75° | 330 Hz | 62.0 | 12.6 | 83.8 | — | 126.1 | 0.99 | −168.29 | 74.210 |
# | −90°\* | 0 Hz | 53.9 | 12.6 | 100.0 | — | 126.1 | 0.99 | −169.20 | 68.819 |

# %% [markdown]
# ### 절 4.201 `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1__map.png)
#
# **그림 564.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1__band.png)
#
# **그림 565.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 30.3 | 10.9 | 62.4 | +22.0 | 746.0 | 5.01 | −140.95 | 0.004 |
# | −15° | 2010 Hz | 25.6 | 10.8 | 48.1 | +20.7 | 147.7 | 0.99 | −138.74 | 0.153 |
# | −30° | 1802 Hz | 36.5 | 10.8 | 14.0 | +30.2 | 147.7 | 0.99 | −136.81 | 0.281 |
# | −45° | 1471 Hz | 51.4 | 10.9 | 12.7 | +32.0 | 147.7 | 0.99 | −129.87 | 0.308 |
# | −60° | 1040 Hz | 65.7 | 10.9 | 22.2 | +32.5 | 147.7 | 0.99 | −127.39 | 0.300 |
# | −75° | 538 Hz | 18.4 | 10.8 | 89.9 | +14.1 | 150.2 | 1.01 | −114.00 | 3.813 |
# | −90°\* | 0 Hz | 13.5 | 10.8 | 100.0 | — | 55.7 ⚠튐 | 0.37 | −115.00 | 0.012 |

# %% [markdown]
# ### 절 4.202 `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 566.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 567.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 34.4 | 10.9 | 61.9 | +21.1 | 746.0 | 5.01 | −140.76 | 0.004 |
# | −30° | 1802 Hz | 43.2 | 10.8 | 18.6 | +29.3 | 147.7 | 0.99 | −137.60 | 0.245 |
# | −60° | 1040 Hz | 57.9 | 10.9 | 23.8 | +30.2 | 743.5 | 4.99 | −129.13 | 0.185 |
# | −90°\* | 0 Hz | 82.3 | 10.8 | 100.0 | — | 891.3 | 5.99 | −129.61 | 0.000 |

# %% [markdown]
# ### 절 4.203 `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 568.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 569.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 38.2 | 10.9 | 47.7 | +1.9 | 893.7 | 6.00 | −140.82 | 0.004 |

# %% [markdown]
# ### 절 4.204 `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 570.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 571.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 16.8 | 10.9 | 25.2 | −0.2 | 782.3 | 5.25 | −140.77 | 0.004 |

# %% [markdown]
# ### 절 4.205 `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D0E0F1` = 굴절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 572.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 573.** `sionna_p4000000000_swR1D0E0F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 8.9 | 10.9 | 52.3 | +6.2 | 762.9 | 5.12 | −141.37 | 0.004 |
# | −30° | 1802 Hz | 8.3 | 10.8 | 14.6 | +11.4 | 152.6 | 1.02 | −137.30 | 0.262 |
# | −60° | 1040 Hz | 8.7 | 10.9 | 18.3 | +8.3 | 302.7 | 2.03 | −128.50 | 0.214 |
# | −90°\* | 0 Hz | 38.0 | 10.8 | 100.0 | — | 591.0 | 3.97 | −132.17 | 0.000 |

# %% [markdown]
# ### 절 4.206 `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D1E0F0` = 굴절 + 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d1__map.png)
#
# **그림 574.** `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d1__band.png)
#
# **그림 575.** `sionna_p4000000000_swR1D1E0F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.1 | 12.6 | 88.8 | +0.5 | 419.5 ⚠튐 | 3.31 | −126.73 | 0.076 |

# %% [markdown]
# ### 절 4.207 `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D1E0F0` = 굴절 + 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d3__map.png)
#
# **그림 576.** `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F0_r15_n8192_d3__band.png)
#
# **그림 577.** `sionna_p4000000000_swR1D1E0F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.0 | 12.6 | 88.4 | +0.8 | 497.1 ⚠튐 | 3.92 | −124.50 | 0.127 |

# %% [markdown]
# ### 절 4.208 `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D1E0F1` = 굴절 + 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F1_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d1__map.png)
#
# **그림 578.** `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F1_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d1__band.png)
#
# **그림 579.** `sionna_p4000000000_swR1D1E0F1_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.3 | 12.6 | 85.7 | +6.3 | 252.2 | 1.99 | −126.56 | 0.078 |

# %% [markdown]
# ### 절 4.209 `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D1E0F1` = 굴절 + 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d3__map.png)
#
# **그림 580.** `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E0F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E0F1_r15_n8192_d3__band.png)
#
# **그림 581.** `sionna_p4000000000_swR1D1E0F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.6 | 12.6 | 86.4 | +4.7 | 254.6 | 2.01 | −124.41 | 0.128 |

# %% [markdown]
# ### 절 4.210 `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: `R1D1E1F0` = 굴절 + 회절 + 모서리 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F0_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d1__map.png)
#
# **그림 582.** `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F0_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d1__band.png)
#
# **그림 583.** `sionna_p4000000000_swR1D1E1F0_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.1 | 12.6 | 88.8 | +0.8 | 419.5 ⚠튐 | 3.31 | −126.80 | 0.074 |

# %% [markdown]
# ### 절 4.211 `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D1E1F0` = 굴절 + 회절 + 모서리 회절 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F0_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d3__map.png)
#
# **그림 584.** `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F0_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F0_r15_n8192_d3__band.png)
#
# **그림 585.** `sionna_p4000000000_swR1D1E1F0_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.0 | 12.6 | 88.3 | +0.8 | 497.1 ⚠튐 | 3.92 | −124.50 | 0.127 |

# %% [markdown]
# ### 절 4.212 `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 586.** `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 587.** `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 12.7 | 13.5 | 88.0 | +0.5 | 424.6 ⚠튐 | 3.54 | −96.90 | 0.022 |
# | −30° | 1018 Hz | 17.4 | 13.5 | 88.9 | +5.4 | 480.4 ⚠튐 | 4.00 | −119.96 | 0.205 |
# | −60° | 588 Hz | 16.4 | 13.5 | 91.0 | +9.5 | 359.1 ⚠튐 | 2.99 | −126.27 | 0.064 |
# | −90°\* | 0 Hz | 31.9 | 13.4 | 100.0 | — | 121.3 | 1.01 | −123.23 | 0.334 |

# %% [markdown]
# ### 절 4.213 `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 588.** `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 589.** `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.2 | 13.5 | 88.1 | −1.1 | 528.9 ⚠튐 | 4.41 | −95.99 | 0.027 |

# %% [markdown]
# ### 절 4.214 `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 590.** `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 591.** `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 14.5 | 13.5 | 88.1 | −2.2 | 376.0 ⚠튐 | 3.13 | −96.72 | 0.023 |

# %% [markdown]
# ### 절 4.215 `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 592.** `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 593.** `sionna_p4000000000_swR1D1E1F1_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 13.1 | 13.5 | 89.2 | −0.4 | 334.8 ⚠튐 | 2.79 | −95.70 | 0.029 |
# | −30° | 1018 Hz | 18.6 | 13.5 | 89.0 | +1.3 | 473.1 ⚠튐 | 3.94 | −121.34 | 0.149 |
# | −60° | 588 Hz | 14.3 | 13.5 | 84.6 | +9.8 | 237.8 | 1.98 | −125.28 | 0.080 |
# | −90°\* | 0 Hz | 17.0 | 13.4 | 100.0 | — | 165.0 | 1.38 | −123.84 | 0.290 |

# %% [markdown]
# ### 절 4.216 `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 594.** `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 595.** `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.5 | 8.7 | 89.5 | +2.5 | 370.0 ⚠튐 | 2.02 | −100.81 | 0.038 |
# | −30° | 887 Hz | 9.5 | 8.7 | 89.8 | +4.8 | 367.6 ⚠튐 | 2.00 | −134.92 | 0.016 |
# | −60° | 512 Hz | 15.1 | 8.7 | 65.1 | — | 183.8 | 1.00 | −134.13 | 0.019 |
# | −90°\* | 0 Hz | 8.5 | 8.7 | 100.0 | — | 493.3 | 2.69 | −94.77 | 0.774 |

# %% [markdown]
# ### 절 4.217 `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 596.** `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 597.** `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.4 | 8.7 | 89.8 | −0.2 | 592.5 ⚠튐 | 3.23 | −99.12 | 0.056 |

# %% [markdown]
# ### 절 4.218 `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 598.** `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 599.** `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.4 | 8.7 | 89.5 | −1.9 | 527.2 ⚠튐 | 2.88 | −99.57 | 0.050 |

# %% [markdown]
# ### 절 4.219 `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 600.** `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 601.** `sionna_p4000000000_swR1D1E1F1_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.4 | 8.7 | 90.0 | +0.6 | 256.3 ⚠튐 | 1.40 | −99.05 | 0.056 |
# | −30° | 887 Hz | 8.2 | 8.7 | 87.9 | +5.4 | 360.3 ⚠튐 | 1.97 | −135.47 | 0.014 |
# | −60° | 512 Hz | 9.6 | 8.7 | 70.5 | — | 186.2 | 1.02 | −134.33 | 0.018 |
# | −90°\* | 0 Hz | 8.7 | 8.7 | 100.0 | — | 396.6 ⚠튐 | 2.16 | −105.73 | 0.062 |

# %% [markdown]
# ### 절 4.220 `sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 602.** `sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 603.** `sionna_p4000000000_swR1D1E1F1_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 81.0 | +5.7 | 252.2 | 1.99 | −90.01 | 0.057 |
# | −30° | 1102 Hz | 12.9 | 12.6 | 83.2 | +8.4 | 252.2 | 1.99 | −118.23 | 0.269 |
# | −60° | 636 Hz | 14.0 | 12.6 | 81.9 | +5.2 | 126.1 | 0.99 | −115.98 | 1.112 |

# %% [markdown]
# ### 절 4.221 `sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 604.** `sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 605.** `sionna_p4000000000_swR1D1E1F1_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 81.0 | +5.7 | 252.2 | 1.99 | −90.02 | 0.057 |
# | −30° | 1102 Hz | 13.0 | 12.6 | 83.1 | +8.2 | 252.2 | 1.99 | −118.24 | 0.269 |
# | −60° | 636 Hz | 13.9 | 12.6 | 81.9 | +5.3 | 126.1 | 0.99 | −115.98 | 1.111 |

# %% [markdown]
# ### 절 4.222 `sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 606.** `sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 607.** `sionna_p4000000000_swR1D1E1F1_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 81.0 | +5.7 | 252.2 | 1.99 | −90.02 | 0.057 |
# | −30° | 1102 Hz | 13.1 | 12.6 | 83.2 | +8.2 | 252.2 | 1.99 | −118.22 | 0.270 |
# | −60° | 636 Hz | 13.9 | 12.6 | 82.0 | +5.3 | 126.1 | 0.99 | −115.98 | 1.112 |

# %% [markdown]
# ### 절 4.223 `sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 608.** `sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 609.** `sionna_p4000000000_swR1D1E1F1_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 81.0 | +5.7 | 252.2 | 1.99 | −90.01 | 0.057 |
# | −30° | 1102 Hz | 13.1 | 12.6 | 83.1 | +8.3 | 252.2 | 1.99 | −118.24 | 0.269 |
# | −60° | 636 Hz | 13.9 | 12.6 | 82.0 | +5.4 | 126.1 | 0.99 | −115.99 | 1.109 |

# %% [markdown]
# ### 절 4.224 `sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 10 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 610.** `sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 611.** `sionna_p4000000000_swR1D1E1F1_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 81.1 | +5.7 | 252.2 | 1.99 | −90.00 | 0.057 |
# | −30° | 1102 Hz | 13.1 | 12.6 | 83.1 | +8.2 | 252.2 | 1.99 | −118.21 | 0.271 |
# | −60° | 636 Hz | 13.9 | 12.6 | 82.0 | +5.3 | 126.1 | 0.99 | −115.99 | 1.110 |

# %% [markdown]
# ### 절 4.225 `sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 방위 22.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 612.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 613.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_az22.5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 21.7 | 12.5 | 47.5 | +15.5 | 126.1 | 0.99 | −101.94 | 9.232 |
# | −30° | 1102 Hz | 16.8 | 12.6 | 72.7 | +13.0 | 126.1 | 0.99 | −134.63 | 51.645 |

# %% [markdown]
# ### 절 4.226 `sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 방위 45° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 614.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 615.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_az45_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 29.8 | 12.5 | 66.9 | +10.3 | 126.1 | 0.99 | −106.52 | 0.415 |
# | −30° | 1102 Hz | 16.1 | 12.6 | 79.3 | +12.5 | 126.1 ⚠튐 | 0.99 | −133.12 | 70.862 |

# %% [markdown]
# ### 절 4.227 `sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 방위 67.5° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 616.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 617.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_az67.5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.8 | 12.5 | 79.7 | +5.2 | 380.7 | 3.01 | −105.50 | 0.068 |
# | −30° | 1102 Hz | 15.0 | 12.6 | 67.9 | +14.4 | 252.2 | 1.99 | −134.37 | 93.980 |

# %% [markdown]
# ### 절 4.228 `sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 방위 90° · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 618.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 619.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_az90_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.5 | 12.5 | 73.0 | +4.9 | 126.1 | 0.99 | −106.99 | 0.869 |
# | −30° | 1102 Hz | 12.8 | 12.6 | 80.3 | +10.1 | 380.7 | 3.01 | −127.56 | 0.321 |

# %% [markdown]
# ### 절 4.229 `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 3 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_d3 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_d3__map.png)
#
# **그림 620.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_d3 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_d3__band.png)
#
# **그림 621.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_d3` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1102 Hz | 12.6 | 12.6 | 86.3 | +4.6 | 254.6 | 2.01 | −124.42 | 0.128 |

# %% [markdown]
# ### 절 4.230 `sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 622.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 623.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_envoutdoor01_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.1 | 12.5 | 67.7 | +11.0 | 254.6 | 2.01 | −94.75 | 0.056 |
# | −30° | 1102 Hz | 12.8 | 12.6 | 88.7 | −0.5 | 436.5 ⚠튐 | 3.45 | −102.06 | 0.455 |
# | −60° | 636 Hz | 13.3 | 12.6 | 92.7 | +0.2 | 412.2 ⚠튐 | 3.25 | −96.33 | 0.673 |

# %% [markdown]
# ### 절 4.231 `sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 624.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 625.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.1 | 12.5 | 66.9 | +11.3 | 126.1 | 0.99 | −95.05 | 0.059 |
# | −30° | 1102 Hz | 13.2 | 12.6 | 81.0 | +9.9 | 252.2 | 1.99 | −127.50 | 0.106 |
# | −60° | 636 Hz | 15.8 | 12.6 | 84.1 | +7.6 | 252.2 | 1.99 | −125.62 | 1.361 |
# | −90°\* | 0 Hz | 12.9 | 12.6 | 100.0 | — | 63.0 ⚠튐 | 0.50 | −111.33 | 0.003 |

# %% [markdown]
# ### 절 4.232 `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 626.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 627.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf157600_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 60.5 | −0.6 | 31.5 | 0.25 | −96.12 | 0.046 |
# | −30° | 1102 Hz | 12.0 | 12.6 | 85.1 | −0.8 | 94.6 ⚠튐 | 0.75 | −127.23 | 0.113 |
# | −60° | 636 Hz | 12.1 | 12.6 | 75.9 | −1.1 | 31.5 | 0.25 | −125.60 | 1.368 |
# | −90°\* | 0 Hz | 11.8 | 12.6 | 99.9 | — | 269.2 ⚠튐 | 2.12 | −112.75 | 0.002 |

# %% [markdown]
# ### 절 4.233 `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 628.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 629.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 61.8 | +1.5 | 63.0 | 0.50 | −95.91 | 0.049 |
# | −30° | 1102 Hz | 13.4 | 12.6 | 82.3 | +1.2 | 380.7 | 3.01 | −126.88 | 0.123 |
# | −60° | 636 Hz | 14.0 | 12.6 | 78.4 | −1.8 | 126.1 | 0.99 | −125.37 | 1.440 |
# | −90°\* | 0 Hz | 12.1 | 12.6 | 100.0 | — | 26.7 ⚠튐 | 0.21 | −110.38 | 0.004 |

# %% [markdown]
# ### 절 4.234 `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 630.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 631.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.7 | 12.5 | 58.7 | −1.9 | 31.5 | 0.25 | −96.31 | 0.044 |
# | −30° | 1102 Hz | 13.1 | 12.6 | 83.2 | +1.5 | 189.1 | 1.49 | −127.43 | 0.108 |
# | −60° | 636 Hz | 11.8 | 12.6 | 76.3 | −0.4 | 63.0 | 0.50 | −125.32 | 1.459 |
# | −90°\* | 0 Hz | 12.6 | 12.6 | 100.0 | — | 63.0 ⚠튐 | 0.50 | −108.55 | 0.006 |

# %% [markdown]
# ### 절 4.235 `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 632.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 633.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep1_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.1 | 12.5 | 66.9 | +11.4 | 126.1 | 0.99 | −95.05 | 0.059 |
# | −15° | 1230 Hz | 13.0 | 12.6 | 87.6 | +1.0 | 77.6 ⚠튐 | 0.61 | −122.99 | 0.097 |
# | −30° | 1102 Hz | 13.2 | 12.6 | 81.0 | +9.9 | 252.2 | 1.99 | −127.50 | 0.106 |
# | −45° | 900 Hz | 12.7 | 12.5 | 90.5 | +1.8 | 506.8 ⚠튐 | 4.00 | −113.92 | 0.087 |
# | −60° | 636 Hz | 15.8 | 12.6 | 84.2 | +7.6 | 252.2 | 1.99 | −125.64 | 1.352 |
# | −75° | 330 Hz | 12.9 | 12.6 | 94.0 | — | 126.1 ⚠튐 | 0.99 | −117.15 | 0.062 |

# %% [markdown]
# ### 절 4.236 `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 634.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 635.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.1 | 12.5 | 66.9 | +11.4 | 126.1 | 0.99 | −95.05 | 0.059 |
# | −15° | 1230 Hz | 12.9 | 12.6 | 87.6 | +1.0 | 77.6 ⚠튐 | 0.61 | −123.00 | 0.097 |
# | −30° | 1102 Hz | 13.2 | 12.6 | 81.0 | +10.0 | 252.2 | 1.99 | −127.51 | 0.106 |
# | −45° | 900 Hz | 12.7 | 12.5 | 90.5 | +1.8 | 506.8 ⚠튐 | 4.00 | −113.92 | 0.087 |
# | −60° | 636 Hz | 15.8 | 12.6 | 84.2 | +7.6 | 252.2 | 1.99 | −125.64 | 1.352 |
# | −75° | 330 Hz | 12.9 | 12.6 | 94.0 | — | 126.1 ⚠튐 | 0.99 | −117.15 | 0.062 |

# %% [markdown]
# ### 절 4.237 `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 636.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 637.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep3_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.1 | 12.5 | 66.9 | +11.3 | 126.1 | 0.99 | −95.05 | 0.059 |
# | −15° | 1230 Hz | 13.0 | 12.6 | 87.6 | +1.0 | 77.6 ⚠튐 | 0.61 | −122.99 | 0.097 |
# | −30° | 1102 Hz | 13.2 | 12.6 | 81.0 | +9.9 | 252.2 | 1.99 | −127.50 | 0.106 |
# | −45° | 900 Hz | 12.7 | 12.5 | 90.5 | +1.8 | 506.8 ⚠튐 | 4.00 | −113.92 | 0.087 |
# | −60° | 636 Hz | 15.8 | 12.6 | 84.2 | +7.6 | 252.2 | 1.99 | −125.64 | 1.352 |
# | −75° | 330 Hz | 12.9 | 12.6 | 94.0 | — | 126.1 ⚠튐 | 0.99 | −117.15 | 0.062 |

# %% [markdown]
# ### 절 4.238 `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 638.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 639.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep4_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.1 | 12.5 | 66.9 | +11.4 | 126.1 | 0.99 | −95.05 | 0.059 |
# | −30° | 1102 Hz | 13.2 | 12.6 | 81.0 | +9.9 | 252.2 | 1.99 | −127.50 | 0.106 |
# | −60° | 636 Hz | 15.8 | 12.6 | 84.2 | +7.6 | 252.2 | 1.99 | −125.64 | 1.352 |

# %% [markdown]
# ### 절 4.239 `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 640.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 641.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rep5_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 16.1 | 12.5 | 66.9 | +11.4 | 126.1 | 0.99 | −95.05 | 0.059 |
# | −30° | 1102 Hz | 13.2 | 12.6 | 81.0 | +9.9 | 252.2 | 1.99 | −127.50 | 0.106 |
# | −60° | 636 Hz | 15.8 | 12.6 | 84.2 | +7.6 | 252.2 | 1.99 | −125.64 | 1.352 |

# %% [markdown]
# ### 절 4.240 `sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 642.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 643.** `sionna_p4000000000_swR1D1E1F1_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.1 | 12.5 | 59.2 | +10.6 | 259.5 | 2.05 | −95.49 | 0.054 |
# | −30° | 1102 Hz | 12.3 | 12.6 | 83.4 | +3.9 | 378.3 | 2.99 | −127.15 | 0.116 |
# | −60° | 636 Hz | 12.5 | 12.6 | 80.6 | +12.4 | 249.8 | 1.97 | −125.04 | 1.555 |
# | −90°\* | 0 Hz | 13.1 | 12.6 | 100.0 | — | 29.1 ⚠튐 | 0.23 | −110.74 | 0.004 |

# %% [markdown]
# ### 절 4.241 `sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 30 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 644.** `sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 645.** `sionna_p4000000000_swR1D1E1F1_r30_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 13.8 | 12.5 | 86.0 | +1.0 | 24.2 ⚠튐 | 0.19 | −110.78 | 0.006 |
# | −15° | 1230 Hz | 12.7 | 12.6 | 87.4 | +0.5 | 21.8 ⚠튐 | 0.17 | −136.38 | 0.087 |
# | −30° | 1102 Hz | 12.5 | 12.6 | 83.5 | +7.9 | 378.3 | 2.99 | −142.69 | 0.050 |
# | −45° | 900 Hz | 14.7 | 12.5 | 84.6 | +10.5 | 252.2 | 1.99 | −142.48 | 0.029 |
# | −60° | 636 Hz | 17.8 | 12.6 | 83.9 | +8.7 | 126.1 | 0.99 | −141.50 | 0.121 |
# | −75° | 330 Hz | 15.1 | 12.6 | 91.1 | — | 126.1 | 0.99 | −136.21 | 0.064 |
# | −90°\* | 0 Hz | 12.1 | 12.6 | 100.0 | — | 21.8 ⚠튐 | 0.17 | −113.23 | 0.011 |

# %% [markdown]
# ### 절 4.242 `sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 45 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 646.** `sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 647.** `sionna_p4000000000_swR1D1E1F1_r45_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 15.8 | 12.5 | 85.5 | +0.2 | 63.0 ⚠튐 | 0.50 | −120.13 | 0.002 |
# | −15° | 1230 Hz | 13.4 | 12.6 | 87.3 | +1.5 | 55.8 ⚠튐 | 0.44 | −149.24 | 0.055 |
# | −30° | 1102 Hz | 16.7 | 12.6 | 77.5 | +12.0 | 378.3 ⚠튐 | 2.99 | −154.84 | 0.025 |
# | −45° | 900 Hz | 19.8 | 12.5 | 78.8 | +12.1 | 632.9 | 5.00 | −151.03 | 0.013 |
# | −60° | 636 Hz | 16.7 | 12.6 | 87.3 | +8.3 | 126.1 | 0.99 | −150.78 | 0.046 |
# | −75° | 330 Hz | 20.4 | 12.6 | 91.7 | — | 126.1 ⚠튐 | 0.99 | −147.53 | 0.013 |
# | −90°\* | 0 Hz | 12.7 | 12.6 | 100.0 | — | 400.1 ⚠튐 | 3.16 | −116.16 | 0.007 |

# %% [markdown]
# ### 절 4.243 `sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 60 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 648.** `sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 649.** `sionna_p4000000000_swR1D1E1F1_r60_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 12.8 | 12.5 | 86.8 | +0.0 | 21.8 ⚠튐 | 0.17 | −119.03 | 0.003 |
# | −15° | 1230 Hz | 13.1 | 12.6 | 87.3 | +0.7 | 87.3 ⚠튐 | 0.69 | −156.31 | 0.026 |
# | −30° | 1102 Hz | 20.6 | 12.6 | 86.4 | +3.3 | 506.8 ⚠튐 | 4.00 | −158.38 | 0.028 |
# | −45° | 900 Hz | 21.5 | 12.5 | 80.9 | +10.6 | 506.8 | 4.00 | −159.40 | 0.006 |
# | −60° | 636 Hz | 24.3 | 12.6 | 83.6 | +11.4 | 126.1 ⚠튐 | 0.99 | −157.28 | 0.020 |
# | −75° | 330 Hz | 41.9 | 12.6 | 69.6 | — | 126.1 ⚠튐 | 0.99 | −157.44 | 0.005 |
# | −90°\* | 0 Hz | 12.4 | 12.6 | 100.0 | — | 475.3 ⚠튐 | 3.75 | −122.70 | 0.004 |

# %% [markdown]
# ### 절 4.244 `sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 90 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI Matrice 4E, 박자 126.667 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 650.** `sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 651.** `sionna_p4000000000_swR1D1E1F1_r90_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 126.667 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1273 Hz | 22.9 | 12.5 | 81.4 | +2.0 | 252.2 | 1.99 | −139.76 | 0.000 |
# | −15° | 1230 Hz | 13.3 | 12.6 | 87.6 | +0.4 | 77.6 ⚠튐 | 0.61 | −160.01 | 0.021 |
# | −30° | 1102 Hz | 53.6 | 12.6 | 33.1 | +30.9 | 506.8 | 4.00 | −176.69 | 0.000 |
# | −45° | 900 Hz | 44.3 | 12.5 | 66.9 | +18.6 | 126.1 ⚠튐 | 0.99 | −167.43 | 0.002 |
# | −60° | 636 Hz | 16.7 | 12.6 | 91.4 | +6.8 | 252.2 ⚠튐 | 1.99 | −163.52 | 0.008 |
# | −75° | 330 Hz | 28.1 | 12.6 | 92.1 | — | 126.1 ⚠튐 | 0.99 | −158.59 | 0.014 |
# | −90°\* | 0 Hz | 12.6 | 12.6 | 100.0 | — | 458.3 ⚠튐 | 3.62 | −130.76 | 0.001 |

# %% [markdown]
# ### 절 4.245 `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 652.** `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 653.** `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 11.1 | 10.9 | 79.5 | −0.5 | 186.5 | 1.25 | −96.02 | 0.942 |
# | −30° | 1802 Hz | 10.1 | 10.8 | 79.3 | +4.1 | 227.7 | 1.53 | −121.93 | 0.768 |
# | −60° | 1040 Hz | 10.5 | 10.9 | 89.4 | +2.8 | 532.8 | 3.58 | −107.34 | 0.075 |
# | −90°\* | 0 Hz | 28.0 | 10.8 | 100.0 | — | 746.0 | 5.01 | −120.09 | 0.000 |

# %% [markdown]
# ### 절 4.246 `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 654.** `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 655.** `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 11.3 | 10.9 | 80.8 | −0.8 | 135.6 ⚠튐 | 0.91 | −96.03 | 0.936 |

# %% [markdown]
# ### 절 4.247 `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 656.** `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 657.** `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 10.4 | 10.9 | 77.8 | +1.7 | 60.5 | 0.41 | −95.28 | 1.114 |

# %% [markdown]
# ### 절 4.248 `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 2 · 스위치: `R1D1E1F1` = 굴절 + 회절 + 모서리 회절 + 확산 반사 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 micro-Doppler maps](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__map.png)
#
# **그림 658.** `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2 blade-band rhythm spectrum](../outputs/figures/atlas/02switch__sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2__band.png)
#
# **그림 659.** `sionna_p4000000000_swR1D1E1F1_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe_d2` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 11.2 | 10.9 | 78.1 | +0.5 | 113.8 | 0.76 | −95.61 | 1.030 |
# | −30° | 1802 Hz | 11.3 | 10.8 | 79.2 | +1.2 | 174.4 | 1.17 | −121.71 | 0.808 |
# | −60° | 1040 Hz | 10.9 | 10.9 | 87.5 | +1.3 | 399.6 | 2.68 | −107.14 | 0.079 |
# | −90°\* | 0 Hz | 17.7 | 10.8 | 100.0 | — | 762.9 | 5.12 | −122.41 | 0.000 |
