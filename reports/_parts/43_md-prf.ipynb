# %% [markdown]
# # 리포트 43 — 상시 기준신호가 주는 것은 날개끝 확산이 아니라 블레이드 통과율까지다
#
# > ### 한 일
# > **조명원 네 모드(상시 셋 + 측위 세션 옵션인 PRS)의 반복률과 날개끝 도플러가 요구하는 표본율을 같은 표에 놓고 어디까지 접히는지 셌다.**
#
# ### 결과
# 1. 날개끝 도플러를 접힘 없이 보려면 표본율이 1980 Hz [^1] 필요하다.
# 2. 그 자리에 LTE CRS 는 1000 Hz [^2], 5G SSB 는 50 Hz [^3], 5G NR-PRS 는 200 Hz [^4] 다.
# 3. 네 모드 전부 요구치 아래에 있다 — 살아남는 것은 **블레이드 통과율(플래시선)** 이다.
# 4. 블레이드 통과율은 헤드라인 기체(Matrice 4E) 126.7 Hz [^5] · 이 표의 기체(Mini 5 Pro) 183.3 Hz [^6] 로 둘 다 LTE·WiFi 의 나이퀴스트 안에 든다. 5G 쪽 두 모드에서는 그 통과율마저 접힌다.
# 5. ⭐ 날개끝 확산을 보려면 기준 안테나가 **풀 파형을 받아야** 하고, 그건 «상시 신호만 쓴다» 와 다른 조건이다.

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 요구 표본율 | 날개끝 도플러의 두 배 — 양쪽으로 퍼지므로 나이퀴스트가 f_tip 의 2배를 요구한다 |
# | 모드별 반복률 | LTE CRS · 5G SSB 는 표준이 정한 상시 신호의 반복 주기에서 읽었다. **WiFi VHT-LTF 는 선언값**이다 — 패킷이 언제 나가는지는 표준이 아니라 트래픽이 정하므로 `src/waveforms.py` 의 `PILOT_RATE_HZ` 를 쓴다. **5G NR-PRS 는 상시 신호가 아니라 측위 세션이 설정될 때 켜지는 옵션**이라 낙관적 상한으로만 읽는다 |
# | 표적 | Mini 5 Pro · 5G NR 3.5 GHz · 호버 회전수 — 같은 규약을 다른 기체로 옮기면 f_tip 이 함께 움직인다 |
# | 무엇을 안 물었나 | 통과율만으로 검출·분류를 어디까지 할 수 있는지는 별도 질문이다 |
#
# ### 재현
#
# ```bash
# PYTHONPATH=src ~/.venvs/py312/bin/python src/experiment_md_range.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/md_range_sweep.json` |
# | 소요 | 약 12 분 (GPU 1장) |
#
# ### 앞 편에서
#
# | 어디서 | 무엇을 알고 와야 하나 |
# |---|---|
# | 앞 편 | [편 35 «슬로타임 복소열»](35_md-slowtime.ipynb) — f_tip 과 f_flash 의 정의 |
#
# ---

# %% [markdown]
# ## 남이 쏘는 신호를 쓰면 표본율을 못 고른다
#
# 패시브 레이더는 남이 쏘는 신호를 쓴다. 그 신호가 얼마나 자주 반복되는지가 우리가 볼 수 있는 도플러의 상한을 정한다.
#
# 날개끝 도플러를 접힘 없이 보려면 표본율이 그 두 배는 돼야 한다. 그 요구치와 각 모드가 실제로 주는 반복률을 같은 표에 놓으면 어디까지 보이는지가 바로 읽힌다.

# %% [markdown]
# ## 네 모드의 반복률과 요구 표본율
#
# | 모드 | 반복률 | 요구 표본율 | 접힘 없이 보이나 |
# |---|---|---|---|
# | WiFi VHT-LTF | 1000 Hz | 1980 Hz | 아니오 |
# | LTE CRS | 1000 Hz | 1980 Hz | 아니오 |
# | 5G SSB | 50 Hz | 1980 Hz | 아니오 |
# | 5G NR-PRS | 200 Hz | 1980 Hz | 아니오 |
#
# 출처 [^7]
#
# 표적은 mini5pro [^8] · 반송파 3.5e+09 Hz [^9] · 호버 5500 rpm [^10] 이고, 이때 날개끝 주파수가 989.8 Hz [^11] · 블레이드 통과율이 183.3 Hz [^6] 다.

# %% [markdown]
# ## 그래서 무엇이 남는가
#
# ⚠ 표의 네 줄 중 셋만 상시다 — 5G NR-PRS 는 측위 세션이 설정될 때 켜지는 옵션이라, 그 줄은 «상시로 기대하는 값» 이 아니라 낙관적 상한이다. WiFi 줄의 반복률도 표준이 정한 값이 아니라 트래픽 가정에서 온 선언값이다.
#
# 네 모드 전부 요구 표본율 아래에 있으므로 날개끝 확산은 접힌다. 살아남는 것은 **블레이드 통과율** 이다 — 헤드라인 기체(Matrice 4E)에서 126.7 Hz [^5] · 이 표의 기체(Mini 5 Pro)에서 183.3 Hz [^6] 이고, 둘 다 LTE·WiFi 의 나이퀴스트 안에 든다.
#
# 5G 쪽 두 모드는 반복률이 낮아 그 통과율마저 접는다. 5G 가 치르는 두 배의 대가가 마이크로도플러 축에서도 그대로 나타난다.
#
# ⭐ 이 구분이 실험 설계를 바꾼다. 날개끝 확산을 보려면 기준 안테나가 **풀 파형을 받아야** 하고, 그건 «상시 신호만 쓴다» 와 다른 조건이다.
#
# 그 기준 안테나가 «완벽하다» 는 가정을 푸는 편이 따로 있다 — [리포트 11-2 «기준채널이 현실이면 얼마를 잃는가»](11_2_two_channel.ipynb) 가 기준채널의 잡음·다중경로를 단일축으로 흔들어 검출이 무는 대가를 재고, 그 편의 마지막 절이 «검출이 죽은 칸에서 빗살은 어디까지 남는가» 를 같은 사슬에서 본다.

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 통과율만 보이는 조건에서 탐지·분류를 돌린다 | 상시 신호만으로 어디까지 가는지가 수치로 갈린다 | 검출 결과 편의 파형축 |
# | 기준 안테나를 풀 파형 포착으로 두는 팔을 따로 설계한다 | 날개끝 확산을 쓰는 조건과 상시 신호만 쓰는 조건의 대가가 나란히 선다 | [편 67 «실측 하드웨어»](67_hardware.ipynb) · [리포트 11-2](11_2_two_channel.ipynb) 의 기준채널 요구치 |
# | 지면 반사가 만드는 선을 블레이드 선과 대조한다 | 환경이 이 무늬를 훼손하는지, 가짜 선이 구별되는지가 정해진다 | [편 69 «야외 부지 기하»](69_site-geometry.ipynb) |
# | 정지 로터 세션과 별도로 회전 세션을 잡는다 | 마이크로도플러가 앵커와의 사과-대-사과를 깨지 않고 들어온다 | [편 72 «자세 통제»](72_attitude.ipynb) |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 11개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/md_range_sweep.json` | `cells[0].prf_feasibility.LTE CRS.required_prf_hz` | 1980 |
# | [^2] | `outputs/md_range_sweep.json` | `cells[0].prf_feasibility.LTE CRS.mode_prf_hz` | 1000 |
# | [^3] | `outputs/md_range_sweep.json` | `cells[0].prf_feasibility.5G SSB.mode_prf_hz` | 50 |
# | [^4] | `outputs/md_range_sweep.json` | `cells[0].prf_feasibility.5G NR-PRS.mode_prf_hz` | 200 |
# | [^5] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly.physics.f_flash` | 126.7 |
# | [^6] | `outputs/md_range_sweep.json` | `cells[0].flash_hz` | 183.3 |
# | [^7] | `outputs/md_range_sweep.json` | `cells[0].prf_feasibility` | (4항목 묶음) |
# | [^8] | `outputs/md_range_sweep.json` | `cells[0].drone` | mini5pro |
# | [^9] | `outputs/md_range_sweep.json` | `cells[0].fc_hz` | 3.5e+09 |
# | [^10] | `outputs/md_range_sweep.json` | `cells[0].rpm` | 5500 |
# | [^11] | `outputs/md_range_sweep.json` | `cells[0].f_tip_hz` | 989.8 |
