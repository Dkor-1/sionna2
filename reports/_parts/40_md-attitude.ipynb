# %% [markdown]
# # 리포트 40 — 지상 레이더는 기체를 아래에서 보므로 가림이 무는 자세가 우리 자세다
#
# > ### 한 일
# > **같은 기체를 코 쪽·배 쪽·배 옆 세 자세에서 돌려 가림과 변조가 자세에 따라 어떻게 움직이는지 쟀다.**
#
# ### 결과
# 1. 프로펠러는 동체 **위**에 있다 — 위에서 내려다보는 자세에서는 날개가 통째로 드러나고, 아래에서 보는 자세에서 가림이 문다.
# 2. 코 쪽(앙각 15 도 [^1])의 가림 효과는 변조 깊이 +4.44 dB [^2] · 레벨 -0.04 dB [^3] 다.
# 3. 배 쪽(앙각 -15 도 [^4])에서는 -4.79 dB [^5] · +1.31 dB [^6], 배 옆(방위 90 도 [^7])에서는 +23.19 dB [^8] · -0.85 dB [^9] 다.
# 4. ⚠ 세 자세의 dB 는 판 선택 위에 있다 — 판을 반 칸 옮기면 변조 깊이가 판 셋에서 26.52 dB [^10] p-p 로 흩어지고, 원장은 «레벨 차가 판 선택을 견디는가» 에 아니오 [^11] 라고 적는다. 이 편이 세우는 것은 **가림이 자세에 따라 다르게 문다**는 존재다.
# 5. 자유공간 바이스태틱의 이등분선 앙각은 전 구간 음수라 우리는 드론 배를 본다 — 자세 스윕이 그 문장에 독립적인 근거를 붙였다.

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 자세 세 칸 | 코 쪽(앙각 +15°) · 배 쪽(앙각 −15°) · 배 옆(방위 90° · 앙각 −15°). 기체 좌표계에서 앙각이 음수면 아래에서 보는 것이다 |
# | 가림 단일축 | 칸마다 «동체가 막느냐» 만 다른 두 팔을 돌려 그 자세의 가림 효과를 낸다 |
# | 왜 배 쪽이 헤드라인인가 | 지상 레이더는 비행 중인 기체를 아래에서 본다 — 자유공간 바이스태틱 기하가 이미 그렇게 적혀 있다 |
# | Mini 5 Pro | 프로펠러와 모터 벨이 겹친 삼각형이 남아 있어 헤드라인에서 뺐다. 같은 그림을 그 기체로도 그려 따로 뒀다 |
# | ⭐얼린 광선 격자 | 세 칸의 여섯 팔이 모두 로터 한 바퀴의 합집합 경계상자로 만든 판 한 장을 쓴다. 그래야 프레임 사이 위상차가 표적의 운동만 담는다 |
# | ⚠ 부호와 크기를 인용하는 범위 | 자세를 고정한 채 판만 반 칸 옮겨도 가림 dB 의 부호가 갈린다(변조 깊이 판 셋 p-p 26.52 dB [^10] · 레벨 차가 판 선택을 견디는가 = 아니오 [^11]). 이 절은 **가림이 자세에 따라 다르게 문다**는 존재를 쓰고, 부호와 크기는 판 앙상블 평균 뒤로 미룬다 |
#
# ### 재현
#
# ```bash
# PYTHONPATH=src ~/.venvs/py312/bin/python benchmark/report15b_microdoppler_recompute.py
# PYTHONPATH=src ~/.venvs/py312/bin/python benchmark/report15b_stamp_provenance.py
# PYTHONPATH=src ~/.venvs/py312/bin/python benchmark/build_report15b_figs.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/report15b_microdoppler.json`, `outputs/report15b_series.npz` |
# | 소요 | 약 25 분 (GPU 1장 — 광선 추적이 6칸 × 4팔) |
# | 비고 | 메쉬 지문(`mesh_provenance`)은 도장 스크립트 `benchmark/report15b_stamp_provenance.py` 가 찍는다 — ⚠ 지금 원장의 최상위 키는 `_meta` 와 `cells` 둘이고, 지문은 그 스크립트를 돌린 다음 세대부터 실린다 |
#
# ### 앞 편에서
#
# | 어디서 | 무엇을 알고 와야 하나 |
# |---|---|
# | 앞 편 | [편 38 «가림 축»](38_md-occlusion.ipynb) — 칸마다 도는 단일축 |
#
# ---

# %% [markdown]
# ## 자세가 답을 바꾼다
#
# 프로펠러는 동체 **위**에 있다. 그래서 위에서 내려다보면 날개가 통째로 드러나고, 그 자세에서 가림은 0 에 가깝다.
#
# 지상 레이더는 비행 중인 기체를 **아래에서** 보므로 기체 좌표계로 앙각이 음수이고, 거기서 가림이 문다.
#
# ⛔ 이 편의 자세 축은 **아래 표(원장)** 로 읽는다. 자세·기체별 요약 그림 `../outputs/figures/report15b_f3.png` 의 dB 라벨은 지금 서 있는 원장 `outputs/report15b_microdoppler.json` 의 값과 다르다 — 그림 빌더(`benchmark/build_report15b_figs.py::fig3_summary`)를 다시 돌리면 그 라벨이 아래 표와 같은 세대가 되고, 그때 이 자리에 들어온다.

# %% [markdown]
# ## 세 자세의 값
#
# | 자세 | 방위 | 앙각 | 가림 · 변조 깊이 | 가림 · 레벨 |
# |---|---|---|---|---|
# | 코 쪽 | 0° [^12] | 15° [^1] | +4.44 dB [^2] | -0.04 dB [^3] |
# | 배 쪽 ⭐ | 0° [^13] | -15° [^4] | -4.79 dB [^5] | +1.31 dB [^6] |
# | 배 옆 | 90° [^7] | -15° [^14] | +23.19 dB [^8] | -0.85 dB [^9] |
#
# 세 줄이 서로 다른 값을 낸다 — **가림이 자세에 따라 다르게 문다**는 것이 이 편의 내용이고, 그 dB 의 부호와 크기는 아래 절이 판 앙상블 평균 뒤로 미룬다.
#
# 마이크로도플러는 프레임 사이 위상차로 재는 양이라, 광선 격자가 프레임마다 움직이면 그 움직임이 표적 운동과 같은 자리에 실린다. 그래서 커널은 자세 전체에 한 격자를 고정하고(`grid_ref`), **이 표는 그 얼린 판으로 다시 난 원장에서 나왔다** [^15]. 옛 판의 값은 `outputs/prefreeze/` 에 사본으로 있다.
#
# ⚠ 메쉬 지문(`mesh_provenance`)은 도장 스크립트를 돌린 다음 세대부터 이 원장에 실린다. 지문이 찍히면 표가 어떤 메쉬 세대에서 났는지까지 자기가 말한다.

# %% [markdown]
# ## 판 한 장이 그 dB 의 부호를 정한다
#
# 판의 중심만 **반 칸** 옮긴 같은 크기의 판으로 같은 자세를 다시 태우면 가림 dB 가 판마다 이렇게 갈린다 — 세 판(P0 · 반 칸 둘)의 값이다.
#
# | 칸 | 가림 · 변조 깊이 (판 셋) | 가림 · 레벨 (판 셋) |
# |---|---|---|
# | `matrice4e/belly` | -17.98 [^16] / -18.27 [^17] / +8.26 [^18] | +1.53 [^19] / +2.12 [^20] / -2.04 [^21] |
# | `matrice4e/nose` | +14.47 [^22] / -9.95 [^23] / +0.09 [^24] | -0.19 [^25] / +0.21 [^26] / -0.19 [^27] |
#
# ⭐ 한 자세 안에서 부호가 갈린다. 변조 깊이의 판 셋 흩어짐 26.52 dB [^10] p-p 가 위 세 자세의 크기를 삼키고, 원장은 «레벨 차가 판 선택을 견디는가» 에 아니오 [^11] 라고 적는다 [^28].
#
# ⇒ 이 편이 세우는 것은 **가림이 자세에 따라 다르게 문다**는 존재이고, 그 dB 의 부호와 크기는 판 앙상블 평균(오프셋 여러 판의 평균)이 낸다. 기전은 [편 18 «커널이 하는 일»](18_kernel-what.ipynb) 이 잰다.

# %% [markdown]
# ## 이 결론은 우리 기하 명세와 같은 방향이다
#
# 자유공간 바이스태틱의 이등분선 앙각은 전 구간 음수라 우리는 드론 배를 본다. 자세 스윕이 그 문장에 **독립적인 근거**를 붙였다 — 기하 명세와 광선 추적이 서로 다른 길로 같은 자세를 가리킨다.
#
# ⚠ Mini 5 Pro 는 프로펠러와 모터 벨이 겹친 삼각형이 남아 있어 헤드라인에서 뺐다. 같은 그림을 그 기체로도 그려 `../outputs/figures/report15b_f1b.png` · `../outputs/figures/report15b_f2b.png` 에 뒀다 — 겹침이 정리되기 전 값이라는 것을 알고 읽는다.

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 가림을 자세 전면(방위×앙각 격자)으로 넓힌다 | 어느 자세에서 얼마나 무는지의 지도가 서고, 그 지도가 분류기의 입력이 된다 | 이 편의 세 칸을 격자로 |
# | Mini 5 Pro 의 프롭·벨 겹침을 정리하고 같은 세 칸을 다시 돌린다 | 두 기체의 자세 의존이 같은 잣대 위에 올라온다 | `src/drone_cad.py` 메쉬 정정 → 이 편 재실행 |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 28개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/nose.el_deg` | 15 |
# | [^2] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/nose.findings.occlusion_ptp_db` | 4.44 |
# | [^3] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/nose.findings.occlusion_level_db` | -0.042 |
# | [^4] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly.el_deg` | -15 |
# | [^5] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly.findings.occlusion_ptp_db` | -4.792 |
# | [^6] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly.findings.occlusion_level_db` | 1.315 |
# | [^7] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly_side.az_deg` | 90 |
# | [^8] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly_side.findings.occlusion_ptp_db` | 23.19 |
# | [^9] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly_side.findings.occlusion_level_db` | -0.847 |
# | [^10] | `outputs/freeze_plate_sensitivity.json` | `verdict.occlusion_ptp_plate_ptp_db` | 26.52 |
# | [^11] | `outputs/freeze_plate_sensitivity.json` | `verdict.occlusion_level_survives_plate_choice` | 아니오 |
# | [^12] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/nose.az_deg` | 0 |
# | [^13] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly.az_deg` | 0 |
# | [^14] | `outputs/report15b_microdoppler.json` | `cells.matrice4e/belly_side.el_deg` | -15 |
# | [^15] | `outputs/report15b_microdoppler.json` | `_meta.grid_frozen` | 예 |
# | [^16] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/belly.findings.occlusion_ptp_db.values[0]` | -17.98 |
# | [^17] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/belly.findings.occlusion_ptp_db.values[1]` | -18.27 |
# | [^18] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/belly.findings.occlusion_ptp_db.values[2]` | 8.259 |
# | [^19] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/belly.findings.occlusion_level_db.values[0]` | 1.533 |
# | [^20] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/belly.findings.occlusion_level_db.values[1]` | 2.122 |
# | [^21] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/belly.findings.occlusion_level_db.values[2]` | -2.041 |
# | [^22] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/nose.findings.occlusion_ptp_db.values[0]` | 14.47 |
# | [^23] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/nose.findings.occlusion_ptp_db.values[1]` | -9.951 |
# | [^24] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/nose.findings.occlusion_ptp_db.values[2]` | 0.094 |
# | [^25] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/nose.findings.occlusion_level_db.values[0]` | -0.194 |
# | [^26] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/nose.findings.occlusion_level_db.values[1]` | 0.209 |
# | [^27] | `outputs/freeze_plate_sensitivity.json` | `cells.matrice4e/nose.findings.occlusion_level_db.values[2]` | -0.191 |
# | [^28] | `outputs/freeze_plate_sensitivity.json` | `verdict.how_to_read_ko` | 판 셋의 흩어짐(p-p)이 곧 «판 한 장을 골랐을 때 절대 dB 에 붙는 값» 이다. 리포트가 인… |
