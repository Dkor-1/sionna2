# %% [markdown]
# # 리포트 79 — −75° 에서 추적 대역 몫은 고정 대역보다 38.72 dB 크고, 그 차이를 만든 것은 대역을 어디에 놓았는가 하나다
#
# > ### 한 일
# > **앙각 7 점의 같은 시계열에서 프로펠러 대역을 두 가지로 잡아 서로 견주고, 같은 양을 세 정규화(전체 전력·반송파·대역외 기준띠)로 함께 냈다.**
#
# ### 결과
# 1. −75° 에서 추적 대역 몫은 -10.88 dB [^1], 고정 대역 몫은 -49.60 dB [^2] — 차이 +38.72 dB [^3] 다. 두 몫의 분모가 같은 시계열이라 이 차는 대역 선택 하나만 담는다.
# 2. 고정 대역이 비는 것은 대역 산수가 정한다 — 그 하단이 그 앙각의 f_tip 보다 위라 겹치는 폭이 0 이다.
# 3. 같은 폭 대역외 기준띠로 견주면 추적 대역은 그 띠 위 +44.60 dB [^4], 고정 대역은 +0.95 dB [^5] 로 띠 높이에 앉는다 — 이 두 여유는 띠를 2.6 kHz 한 자리에 놓아 얻은 값이다.
# 4. −75° 추적 대역이 담은 것은 f_flash 의 1·2 차 빗살이고, 그 선의 SNR 은 59.2 dB [^6] 와 51.7 dB [^7] 다.
# 5. −60° 에서는 반송파 몫이 -14.05 dB [^8] 로 내려앉아 «전체 대비» 몫이 혼자 뛴다 — 그래서 반송파 기준 +8.46 dB [^9] 를 나란히 싣는다.

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 추적 대역 | 0.35~1.0 × f_tip(el) — 앙각마다 다시 잡는다 [^10] |
# | 고정 대역 | 430.1~1228.7 Hz 고정 (덱의 −15° 대역) [^11] — 그 상단은 1228.7 Hz [^12] 다 |
# | 바닥 잣대 | 대역외 기준띠 — 같은 폭을 2600 Hz 위로 옮긴 것. 블레이드가 원리적으로 못 오는 자리라 «바닥» 을 읽는다 [^13] |
# | 몫의 정의 | 대역 전력 / 전체 전력 [dB] — 눈금 무관. verify 의 share_of_total_power_db 와 같은 정의 [^14] |
# | 스펙트럼 | 4096 점 한나 창 FFT, Δf = 4.81 Hz (verify_nadir_flash.decompose 와 같은 규약) [^15] |
# | 정규화 둘 | 전체 전력 대비 몫과 반송파(동체선) 대비 몫을 칸마다 함께 낸다 |
#
# ### 재현
#
# ```bash
# PYTHONPATH=src:benchmark ~/.venvs/py312/bin/python benchmark/build_ch1_elevation_figs.py
# PYTHONPATH=src:benchmark ~/.venvs/py312/bin/python benchmark/build_part79_normalization_fig.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/ch1_elevation_figdata.json`, `outputs/figures/ch1_f4_bandenergy.png`, `outputs/figures/part79_normalization.png` |
# | 소요 | 정규화 그림 약 1 초 (CPU). 앙각 그림 다섯 장의 시간은 미측정 |
# | 비고 | 두 스크립트 모두 원장을 읽어 CPU 로 FFT 한다[^16] |
#
# ### 앞 편에서
#
# | 어디서 | 무엇을 알고 와야 하나 |
# |---|---|
# | [편 78 «스윕 설계»](78_el-sweep-design.ipynb) | 앙각 7 점이 무엇을 어떤 잣대로 쟀고 어느 행을 인용해도 되나 |
#
# ---

# %% [markdown]
# ## 프로펠러 대역은 앙각을 따라 내려간다
#
# 블레이드 끝이 만드는 도플러는 **날개끝 주파수 f_tip** 에서 멈춘다 — 기체에서 가장 빠른 산란체가 날개끝이기 때문이다. 그 f_tip 은 관측 앙각을 내리면 함께 내려간다.
#
# 우리 팔의 표를 그대로 읽으면 f_tip 은 0° 의 1272.9 Hz [^17] 에서 −75° 의 329.5 Hz [^18] 로 내려가고, −90° 에서 0.0 Hz [^19] 가 된다 — cos(el) 을 곱한 값 그대로다.
#
# 그러니 **대역을 어디에 놓느냐**가 판정을 정한다. 여기서는 두 가지로 놓고 잰다.

# %% [markdown]
# ## 두 대역, 그리고 바닥을 읽는 자
#
# | 대역 | 어디에 놓나 | −75° 에서의 폭 |
# |---|---|---|
# | 추적 대역 | 0.35~1.0 × f_tip(el) — 앙각마다 다시 잡는다 [^10] | 214 Hz [^20] |
# | 고정 대역 | 8/11 덱이 −15° 의 f_tip 으로 못 박은 자리에 그대로 둔다 | 799 Hz [^21] |
#
# 두 대역 모두 **자기와 같은 폭의 대역외 기준띠**와 견준다[^13]. 그 띠는 2.6 kHz 위에 있어 블레이드가 원리적으로 못 오는 자리다 — 대역 몫이 그 띠와 같으면 그것은 신호가 아니라 **바닥**이다.

# %% [markdown]
# ## −75° 한 자리에서 두 대역이 갈린다
#
# | 무엇을 | 대역 몫 | 같은 폭 기준띠 | 띠 위 여유 |
# |---|---|---|---|
# | 추적 대역, −75° | -10.88 dB [^1] | -55.48 dB [^22] | +44.60 dB [^4] |
# | 고정 대역, −75° | -49.60 dB [^2] | -50.55 dB [^23] | +0.95 dB [^5] |
# | 고정 대역, −90° | -51.64 dB [^24] | -51.47 dB [^25] | -0.17 dB [^26] |

# %% [markdown]
# 추적 대역은 −75° 에서 고정 대역보다 좁다. 좁은 대역이 전체 전력의 +38.72 dB [^3] 만큼 더 큰 몫을 가져갔다는 것은 그 에너지가 거기에 **몰려 있다**는 뜻이다. 두 몫의 분모가 같은 시계열이라 이 차는 대역 선택 하나만 담는다.
#
# 고정 대역이 비는 것은 대역 산수가 정한다 — 그 하단 430.1 Hz 가 −75° 의 f_tip 329.5 Hz [^18] 보다 위라 겹치는 폭이 0.0000 [^27] 다.

# %% [markdown]
# ## −75° 의 추적 대역을 채운 것은 저차 빗살이다
#
# f_flash 의 정수배에 선 빗살 선 SNR 을 원장이 30 차까지 싣는다[^28]. −75° 에서 추적 대역(115.3~329.5 Hz)에 드는 차수는 1·2 차이고, 그 두 선은 59.2 dB [^6] 와 51.7 dB [^7] 로 서 있다. 덱 대역이 담는 4~9 차는 같은 칸에서 9.1 dB [^29] ~ 17.3 dB [^30] 다.
#
# f_flash 는 앙각과 무관하고 f_tip 만 cos(el) 로 줄기 때문에, 창이 담는 차수는 앙각이 내려갈수록 낮아진다. −75° 에서 추적 대역이 얻는 이득은 날개끝 신호를 지킨 대가라기보다 창이 가장 센 저차 빗살 위로 내려앉은 결과다.

# %% [markdown]
# −90° 는 f_tip 이 0 이라 추적 대역의 폭도 0 이다 — 그 칸은 «측정 불가» 로 비워 뒀다[^31]. 값이 비는 이유는 신호가 약해서가 아니라 **잴 대역이 없어서**다.
#
# 같은 −90° 에서 고정 대역 -51.64 dB [^24] 와 그 기준띠 -51.47 dB [^25] 는 -0.17 dB [^26] 안에서 같다. 같다는 것은 두 띠에 **같은 f_flash 빗살이 지나간다**는 뜻이다 — 고정 대역 안 차수 4~9 는 국소 바닥 위 4.4 dB [^32] ~ 24.5 dB [^33], 기준띠 안 차수 21~26 은 8.1 dB [^34] ~ 21.4 dB [^35] 로 서 있다. 이 잣대가 −90° 에서 재는 것은 «대역이 비었나» 라기보다 «블레이드만의 초과분이 있나» 이고, 그 초과분은 0.17 dB 안에서 0 이다.

# %% [markdown]
# ![ch1_f4_bandenergy](../outputs/figures/ch1_f4_bandenergy.png)
#
# **그림 1.** 앙각을 내리면 프로펠러 대역 에너지가 정말 주는가?
#
# 점선이 각 팔의 대역외 기준띠다. **자기 점선 위에 앉은 표식은 바닥에 앉은 것**이고, 오른쪽 패널의 −75°·−90° 에서 붉은 선이 정확히 그렇게 된다.

# %% [markdown]
# ## 앙각 7 점 전부
#
# | 칸 | f_tip [Hz] | 추적 몫 [dB] | 추적 기준띠 [dB] | 고정 몫 [dB] | 고정 기준띠 [dB] |
# |---|---|---|---|---|---|
# | ours/el+0 | 1272.9 | -15.58 | -40.18 | -15.59 | -41.13 |
# | ours/el-15 | 1229.5 | -21.46 | -36.42 | -21.46 | -36.42 |
# | ours/el-30 | 1102.4 | -6.58 | -27.89 | -6.56 | -27.80 |
# | ours/el-45 | 900.1 | -10.68 | -35.20 | -10.82 | -34.44 |
# | ours/el-60 | 636.5 | -5.58 | -31.11 | -15.31 | -29.61 |
# | ours/el-75 | 329.5 | -10.88 | -55.48 | -49.60 | -50.55 |
# | ours/el-90 | 0.0 | 측정 불가 | 측정 불가 | -51.64 | -51.47 |
#
# 출처 [^36]

# %% [markdown]
# 추적 대역이 자기 대역외 기준띠 위로 서는 여유는 f_tip 이 살아 있는 여섯 앙각에서 −15° 의 +14.96 dB [^37] 가 가장 좁고 −75° 의 +44.60 dB [^4] 가 가장 넓다. 이 여유는 한 칸 안에서 두 대역의 비라 팔마다 다른 절대 눈금과 무관하다.
#
# 같은 여섯 점을 전체 전력 대비 «몫» 으로 보면 −15° 의 -21.46 dB [^38] 와 −60° 의 -5.58 dB [^39] 사이, 폭 15.9 dB [^40] 안에 흩어진다. 그 폭은 잣대를 바꾸면 달라진다 — 기준띠 위 여유로는 29.64 dB, 반송파 기준으로는 28.11 dB 다. 앙각이 내려가는 동안 몫은 단조롭지 않다: −15°, −30°, −45°, −60° 가 각각 -6.58 dB [^41] 와 -10.68 dB [^42] 를 사이에 두고 오르내린다.
#
# 고정 대역도 −60° 까지는 자기 기준띠 위로 +14.30 dB [^43] 남아 있다가 −75° 에서 그 띠에 닿는다. 그 지점부터 고정 대역은 f_tip 위에 통째로 놓인다.

# %% [markdown]
# ## 분모를 바꿔도 같은 결론이 서는가
#
# ![part79_normalization](../outputs/figures/part79_normalization.png)
#
# **그림 2.** 전체 전력으로 나눈 몫과 반송파로 나눈 몫이 어디서 갈라지는가?

# %% [markdown]
# | 칸 | 반송파 몫 [dB] | 전체 대비 추적 몫 [dB] | 반송파 대비 추적 몫 [dB] |
# |---|---|---|---|
# | ours/el+0 | -1.90 | -15.58 | -13.69 |
# | ours/el-15 | -1.81 | -21.46 | -19.65 |
# | ours/el-30 | -3.32 | -6.58 | -3.27 |
# | ours/el-45 | -2.43 | -10.68 | -8.25 |
# | ours/el-60 | -14.05 | -5.58 | +8.46 |
# | ours/el-75 | -2.13 | -10.88 | -8.75 |
# | ours/el-90 | -1.76 | 측정 불가 | 측정 불가 |
#
# 출처 [^36]

# %% [markdown]
# 몫의 분모는 **전체 전력**이고, 그 전력의 대부분은 동체선(반송파)이다 — 우리 팔의 반송파 몫은 −60° 를 뺀 여섯 점에서 -1.81 dB [^44] ~ -3.32 dB [^45] 안에 있다. 그래서 반송파가 내려앉는 칸에서는 분자가 그대로여도 몫이 올라간다. −60° 가 그 자리다 — 반송파 몫이 -14.05 dB [^8] 로 내려앉고, 전체 대비 추적 몫 -5.58 dB [^39] 가 우리 팔 여섯 점 중 가장 커진다.

# %% [markdown]
# 이 내려앉음은 **우리 팔 한 칸의 성질이다.** 같은 −60° 에서 PathSolver 11.1M 은 -3.13 dB [^46], 250M 은 -2.10 dB [^47] 로 다른 앙각과 같다.
#
# 정규화를 반송파로 바꾸는 것은 이 칸을 되돌려 놓지 못한다 — 전체 전력의 대부분이 반송파라 두 분모가 함께 내려앉기 때문이다. 반송파 기준으로 재면 −60° 는 +8.46 dB [^9] 로 우리 팔 여섯 점 중 유일한 양수가 되어 오히려 더 튄다.
#
# 분모가 약분되는 잣대는 **같은 폭의 대역외 기준띠와의 여유**다. 그 잣대에서 −60° 는 +25.52 dB [^48] 로 0° 의 +24.60 dB [^49] · −45° 의 +24.52 dB [^50] 와 나란하고, −75° 가 +44.60 dB [^4] 로 가장 높다. 헤드라인 자리인 −75° 는 반송파 몫이 -2.13 dB [^51] 로 통상값 안에 있어, 전체 대비와 반송파 대비가 여섯 점 중 같은 순위를 준다[^52].

# %% [markdown]
# ## 대역에 무언가 남는 것과 프로펠러가 보이는 것은 다른 일이다
#
# | 칸 | 고정 몫 [dB] | 기준띠 [dB] | f_tip [Hz] |
# |---|---|---|---|
# | ours/el-75 | -49.60 | -50.55 | 329.5 |
# | sionna/el-75 | -10.58 | -23.50 | 329.5 |
# | sionna_p250000000/el-75 | -22.04 | -36.06 | 329.5 |
# | ours/el-90 | -51.64 | -51.47 | 0.0 |
# | sionna/el-90 | -7.16 | -20.20 | 0.0 |
# | sionna_p250000000/el-90 | -16.92 | -32.87 | 0.0 |
#
# 출처 [^36]

# %% [markdown]
# −75° 에서 고정 대역은 f_tip = 329.5 Hz [^18] 위에 통째로 놓인다 — 겹치는 폭이 0.0000 [^27] 다. 우리 팔은 그 자리를 기준띠 높이로 비워 두고, PathSolver 팔들은 +12.93 dB [^53] 와 +14.03 dB [^54] 를 채워 넣는다.

# %% [markdown]
# ⭐그 세 숫자가 재는 범위는 여기까지다. 기준띠에도 빗살 21~26 차가 들어 있어서, 이 여유는 «빗살 든 칸 대 빈 칸» 이 아니라 **빗살 대 빗살**의 대비다 — 같은 −75° 에서 11.1M 팔의 고정 대역 차수 4~9 는 국소 바닥 위 31.5 dB [^55] ~ 39.7 dB [^56] 이고, 기준띠 차수 21~26 은 15.1 dB [^57] ~ 23.3 dB [^58] 다. 빗살의 간격은 회전 입력 f_flash 가 정하므로, 빗살이 섰다는 사실은 산란 커널의 점수와 다른 물건이다.
#
# 가르는 것은 대역을 f_tip 따라 옮겼을 때다 — 같은 −75° 에서 우리 팔의 추적 대역은 자기 기준띠보다 +44.60 dB [^4] 높다. 빗살이 f_tip 위에서도 살아남는다는 것은 관측 사실이고, 그 빗살이 블레이드 도플러인지 자세별 경로 집합의 깜빡임인지는 [편 87 «광선 예산»](87_budget-not-physics.ipynb) 이 예산 축에서 가른다.

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 검출기의 도플러 대역을 앙각 추정값의 f_tip 에 묶는다 | −75° 이하에서 고정 대역이 잃는 여유를 추적 대역이 되찾는지가 검출 확률로 결정된다 | `src/passive_process.py` 의 대역 설정 |
# | −75° 와 −90° 사이에 앙각 한 점을 더 잰다 | 추적 대역의 폭이 언제 0 으로 닫히는지가 관측으로 정해진다 | `benchmark/elevation_sweep_md.py --els -82.5` |
# | 기하 겹침 예측을 이 두 대역 위에서 다시 채점한다 | «대역이 겹치는 만큼 에너지가 준다» 는 예측의 성립 범위가 확정된다 | `outputs/ch1_elevation_figdata.json` 의 `prediction.fixed_band_overlap_frac` |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 58개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.share_track_db` | -10.88 |
# | [^2] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.share_fixed_db` | -49.6 |
# | [^3] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.share_track_db → 같은 칸의 share_fixed_db 를 뺀 값` | -10.88 (파생) |
# | [^4] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.share_track_db → 같은 칸의 share_track_oob_db 를 뺀 값` | -10.88 (파생) |
# | [^5] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.share_fixed_db → 같은 칸의 share_fixed_oob_db 를 뺀 값` | -49.6 (파생) |
# | [^6] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.comb_snr_db[0]` | 59.2 |
# | [^7] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.comb_snr_db[1]` | 51.7 |
# | [^8] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-60.carrier_share_db` | -14.05 |
# | [^9] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-60.share_track_rel_carrier_db` | 8.46 |
# | [^10] | `outputs/ch1_elevation_figdata.json` | `_meta.band_track_ko` | 0.35~1.0 × f_tip(el) — 앙각마다 다시 잡는다 |
# | [^11] | `outputs/ch1_elevation_figdata.json` | `_meta.band_fixed_ko` | 430.1~1228.7 Hz 고정 (덱의 −15° 대역) |
# | [^12] | `outputs/report07_three_engines.json` | `_meta.f_tip_hz` | 1229 |
# | [^13] | `outputs/ch1_elevation_figdata.json` | `_meta.oob_ko` | 대역외 기준띠 — 같은 폭을 2600 Hz 위로 옮긴 것. 블레이드가 원리적으로 못 오는 자리라 «… |
# | [^14] | `outputs/ch1_elevation_figdata.json` | `_meta.share_ko` | 대역 전력 / 전체 전력 [dB] — 눈금 무관. verify 의 share_of_total_pow… |
# | [^15] | `outputs/ch1_elevation_figdata.json` | `_meta.spectrum_ko` | 4096 점 한나 창 FFT, Δf = 4.81 Hz (verify_nadir_flash.decom… |
# | [^16] | `outputs/ch1_elevation_figdata.json` | `_meta.gpu_ko` | GPU 를 쓰지 않았다. 원장만 읽고 CPU 로 FFT 했다. |
# | [^17] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el+0.f_tip_hz` | 1273 |
# | [^18] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.f_tip_hz` | 329.5 |
# | [^19] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.f_tip_hz` | 0 |
# | [^20] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.f_tip_hz → 0.65 를 곱한 추적 대역 폭` | 329.5 (파생) |
# | [^21] | `outputs/report07_three_engines.json` | `_meta.f_tip_hz → 0.65 를 곱한 고정 대역 폭` | 1229 (파생) |
# | [^22] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.share_track_oob_db` | -55.48 |
# | [^23] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.share_fixed_oob_db` | -50.55 |
# | [^24] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.share_fixed_db` | -51.64 |
# | [^25] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.share_fixed_oob_db` | -51.47 |
# | [^26] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.share_fixed_db → 같은 칸의 share_fixed_oob_db 를 뺀 값` | -51.64 (파생) |
# | [^27] | `outputs/ch1_elevation_figdata.json` | `prediction.fixed_band_overlap_frac.-75` | 0 |
# | [^28] | `outputs/ch1_elevation_figdata.json` | `_meta.comb_ko` | 빗살 선 SNR = k·f_flash ±12 Hz 전력 / 그 옆 30~70 Hz 중앙값 |
# | [^29] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.comb_snr_db[7]` | 9.1 |
# | [^30] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.comb_snr_db[6]` | 17.3 |
# | [^31] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.share_track_db` | null |
# | [^32] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.comb_snr_db[3]` | 4.4 |
# | [^33] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.comb_snr_db[6]` | 24.5 |
# | [^34] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.comb_snr_db[23]` | 8.1 |
# | [^35] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-90.comb_snr_db[20]` | 21.4 |
# | [^36] | `outputs/ch1_elevation_figdata.json` | `cells` | (21항목 묶음) |
# | [^37] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-15.share_track_db → 같은 칸의 share_track_oob_db 를 뺀 값` | -21.46 (파생) |
# | [^38] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-15.share_track_db` | -21.46 |
# | [^39] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-60.share_track_db` | -5.584 |
# | [^40] | `outputs/ch1_elevation_figdata.json` | `gates.G6_ours_track_share_span_db` | 15.9 |
# | [^41] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-30.share_track_db` | -6.584 |
# | [^42] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-45.share_track_db` | -10.68 |
# | [^43] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-60.share_fixed_db → 같은 칸의 share_fixed_oob_db 를 뺀 값` | -15.31 (파생) |
# | [^44] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-15.carrier_share_db` | -1.81 |
# | [^45] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-30.carrier_share_db` | -3.32 |
# | [^46] | `outputs/ch1_elevation_figdata.json` | `cells.sionna/el-60.carrier_share_db` | -3.13 |
# | [^47] | `outputs/ch1_elevation_figdata.json` | `cells.sionna_p250000000/el-60.carrier_share_db` | -2.1 |
# | [^48] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-60.share_track_db → 같은 칸의 share_track_oob_db 를 뺀 값` | -5.584 (파생) |
# | [^49] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el+0.share_track_db → 같은 칸의 share_track_oob_db 를 뺀 값` | -15.58 (파생) |
# | [^50] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-45.share_track_db → 같은 칸의 share_track_oob_db 를 뺀 값` | -10.68 (파생) |
# | [^51] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.carrier_share_db` | -2.13 |
# | [^52] | `outputs/ch1_elevation_figdata.json` | `cells.ours/el-75.share_track_rel_carrier_db` | -8.75 |
# | [^53] | `outputs/ch1_elevation_figdata.json` | `cells.sionna/el-75.share_fixed_db → 같은 칸의 share_fixed_oob_db 를 뺀 값` | -10.58 (파생) |
# | [^54] | `outputs/ch1_elevation_figdata.json` | `cells.sionna_p250000000/el-75.share_fixed_db → 같은 칸의 share_fixed_oob_db 를 뺀 값` | -22.04 (파생) |
# | [^55] | `outputs/ch1_elevation_figdata.json` | `cells.sionna/el-75.comb_snr_db[7]` | 31.5 |
# | [^56] | `outputs/ch1_elevation_figdata.json` | `cells.sionna/el-75.comb_snr_db[3]` | 39.7 |
# | [^57] | `outputs/ch1_elevation_figdata.json` | `cells.sionna/el-75.comb_snr_db[24]` | 15.1 |
# | [^58] | `outputs/ch1_elevation_figdata.json` | `cells.sionna/el-75.comb_snr_db[21]` | 23.3 |
