# %% [markdown]
# # 리포트 61 — 그 순위는 자세평균이면 하나로 모이고, 자세평균 뒤집힘 문턱은 현실 봉투 안이다
#
# > ### 한 일
# > **σ 오차를 공통모드와 차분 두 종류로 나눠 넣고, 각각에서 밴드 순위가 어디까지 버티는지를 단일 자세·자세평균 두 인용 방식의 뒤집힘 문턱과 몬테카를로 보존확률로 재었다.**
#
# ### 결과
# 1. σ 는 SNR 에 선형이라 σ 오프셋 Δ dB 가 곧 SNR 오프셋 Δ dB 다 — 선형성 잔차 1.2e-05 [^1].
# 2. 공통모드 ±10 dB 에서 15칸 전부 순위가 유지되고, 절대거리만 -43.3% [^2] ~ +76.4% [^3] 움직인다.
# 3. 뒤집는 것은 차분 오차다 — 단일 자세 뒤집힘 문턱은 0.61 [^4] ~ 7.42 dB [^5], 자세평균 문턱은 0.09 [^6] ~ 2.95 dB [^7] 이고, 현실 봉투는 5.01 dB [^8] 다.
# 4. 취약성을 정하는 것은 기체 크기가 아니라 밴드 간 σ 로브 산포다 — 크기와 뒤집힘 문턱의 상관은 -0.62 [^9] 다.
# 5. σ 격자를 블레이드 형상 갱신본으로 바꾸는 것만으로 R90 이 최대 17.9% [^10] 움직이고 순위쌍 1 [^11]개가 뒤집힌다.

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 두 종류의 오차 | **공통모드**는 세 밴드를 함께 옮기고, **차분**은 밴드마다 다르게 옮긴다. 순위를 뒤집을 수 있는 것은 차분뿐이다 |
# | 선형성 | σ 는 SNR 에 선형이라 dB 오프셋이 그대로 옮겨간다 — 그 사실을 잔차로 확인하고 쓴다 |
# | 몬테카를로 | 밴드별 독립 오차 2 dB 를 넣고 순위 보존 확률을 기체마다 잰다 |
# | 관측된 파급 | 메쉬 갱신 하나가 옮긴 R90 과 바뀐 순위쌍 수를 함께 적는다 — 통제되지 않은 σ 변화의 크기를 관측값으로 두기 위해서다 |
#
# ### 재현
#
# ```bash
# cd /workspace/sionna
# PYTHONPATH=src ~/.venvs/py312/bin/python src/experiment_detection.py
# PYTHONPATH=src ~/.venvs/py312/bin/python src/build_part10_results.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/sigma_sensitivity.json` |
# | 소요 | σ 격자 · 검지거리 4단계 · 검증 · 스윕을 합쳐 7.8 h [^12] (GPU 2 [^13]장). 이 빌더 자신은 CPU 수 초다 |
#
# ### 앞 편에서
#
# | 어디서 | 무엇을 알고 와야 하나 |
# |---|---|
# | [편 60 «앵커 σ 위의 R90 은 비교가능 12칸에서…»](60_r90.ipynb) | 앵커 σ 위의 R90 표와 밴드 순서 |
#
# ---

# %% [markdown]
# ## 오차를 두 종류로 나눈다
#
# **공통모드**는 세 밴드를 함께 옮기고, **차분**은 밴드마다 다르게 옮긴다. σ 는 SNR 에 선형이라 σ 오프셋 Δ dB 가 곧 SNR 오프셋 Δ dB 다(선형성 잔차 1.2e-05 [^1]).

# %% [markdown]
# | 오차 종류 | 무엇이 움직이나 | 크기 |
# |---|---|---|
# | 공통모드 ±10 dB | 순위 유지 · 절대거리만 이동 | 15칸 전부 순위 불변 · 거리 -43.3% [^2] ~ +76.4% [^3] |
# | 차분(밴드별) — 단일 자세 ψ=0 | 순위가 뒤집힐 수 있는 축 | 뒤집힘 문턱 0.61 [^4] ~ 7.42 dB [^5] (현실 봉투 5.01 dB [^8]) · 봉투 안에서 3 [^14]/5 [^15]기체가 뒤집힌다 |
# | 차분(밴드별) — 자세평균 σ | 합의 순위가 뒤집히는 축 | 뒤집힘 문턱 0.09 [^6] ~ 2.95 dB [^7] — 5기체가 모두 현실 봉투 안에 든다 |
# | 밴드별 독립 오차 2 dB (몬테카를로) | 순위 보존 확률 | 0.28 [^16] ~ 0.82 [^17] |

# %% [markdown]
# ## 취약성을 정하는 것은 크기가 아니다
#
# 가장 작은 mini5pro [^18] (전장 0.378 m [^19], LTE 에서 D/λ = 2.32 [^20]) 가 가장 견고하다.
#
# 크기와 뒤집힘 문턱의 상관은 -0.62 [^9] 다 — 취약성을 정하는 것은 **밴드 간 σ 로브 산포**다.

# %% [markdown]
# ![fig1](../outputs/figures/report05_pf3_robust.png)
#
# **그림 1.** σ 오차가 공통모드일 때와 밴드별일 때 순위는 각각 어디까지 버티는가?

# %% [markdown]
# ## 통제되지 않은 σ 변화의 관측된 파급
#
# σ 격자를 블레이드 형상 갱신본으로 바꾸는 것만으로 R90 이 최대 17.9% [^10] 움직이고 순위쌍 1 [^11]개가 뒤집힌다.
#
# ⚠ 이 사슬은 2026-08-04 [^21] 형상 정정 **전** 메쉬 위에 있다 — 다섯 기체 중 Matrice 4E 가 그 정정을 받았다 [^22].
#
# ⚠ 이 σ 원장은 Γ(θ) 각도 모양(기본 켬, 2026-08-07 10:58:22 [^23]) 이전 커널의 산출이다 — 방위평균 전체 드론 σ 이동은 +0.08 [^24] ~ +0.10 dB [^25], 프롭 채널 레벨 이동은 +5.16 [^26] ~ +6.48 dB [^27] 다. σ 격자를 Γ(θ) 켠 커널로 재생성한 뒤 이 편을 다시 짓는다.
#
# 하한 0.61 dB [^4] 를 내는 행이 그 정정을 받은 Matrice 4E 다. 이 하한은 **단일 자세** 기준이고, 같은 기체를 **자세평균**으로 읽으면 1.30 dB [^28] 다 — 실측 캠페인이 판정 문턱으로 드는 수가 그것이다([편 76 «기울기 판정의 문턱은 세션간 진폭 재현성이고»](76_session-drift.ipynb)).
#
# 자세평균 판에서 문턱이 가장 얇은 기체는 mavic4pro 이고 그 값은 0.09 dB [^29] 다 — 합의 순위의 아래 두 밴드가 그만큼 붙어 있다.

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 형상 정정 후 메쉬로 σ 민감도를 다시 돌린다 | 뒤집힘 문턱의 하한이 현재 메쉬 위에 서고, 위 표의 차분 행이 갱신된다 | `benchmark/sigma_sensitivity.py` |
# | 밴드 간 σ 로브 산포를 기체 특성으로 정량화한다 | 어느 기체가 왜 견고한지가 크기가 아닌 양으로 설명된다 | [편 17 «도전성 재질이 면적의 45.3% 로 Σ\|Γ\|A…»](17_materials.ipynb) |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 29개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/sigma_sensitivity.json` | `_meta.sigma_linearity_check` | 1.229e-05 |
# | [^2] | `outputs/sigma_sensitivity.json` | `common_mode.abs_range_shift_at_10db_pct.minus10` | -43.31 |
# | [^3] | `outputs/sigma_sensitivity.json` | `common_mode.abs_range_shift_at_10db_pct.plus10` | 76.39 |
# | [^4] | `outputs/sigma_sensitivity.json` | `differential.smallest_flip_span_db_overall` | 0.6145 |
# | [^5] | `outputs/sigma_sensitivity.json` | `differential.largest_flip_span_db_overall` | 7.418 |
# | [^6] | `outputs/sigma_sensitivity.json` | `aspect_averaged.smallest_flip_span_db_overall` | 0.08856 |
# | [^7] | `outputs/sigma_sensitivity.json` | `aspect_averaged.by_drone → 5기체 smallest_flip_span_db 최대` | (5항목 묶음) (파생) |
# | [^8] | `outputs/sigma_sensitivity.json` | `differential.realistic_span_db` | 5.013 |
# | [^9] | `outputs/sigma_sensitivity.json` | `size_vs_fragility.corr_extent_vs_flip_single` | -0.6182 |
# | [^10] | `outputs/sigma_sensitivity.json` | `staleness_and_mesh_update.by_drone → 5기체 max_range_change_pct 최대` | (5항목 묶음) (파생) |
# | [^11] | `outputs/sigma_sensitivity.json` | `staleness_and_mesh_update.n_orders_changed` | 1 |
# | [^12] | `outputs/report05_derived.json` | `runtime.total_h` | 7.773 |
# | [^13] | `outputs/report13_freespace.json` | `meta.gpus` | 2 |
# | [^14] | `outputs/sigma_sensitivity.json` | `differential.n_drones_flipping_inside_realistic` | 3 |
# | [^15] | `outputs/sigma_sensitivity.json` | `differential.n_drones` | 5 |
# | [^16] | `outputs/sigma_sensitivity.json` | `monte_carlo_per_band_error → 5기체 최소` | (5항목 묶음) (파생) |
# | [^17] | `outputs/sigma_sensitivity.json` | `monte_carlo_per_band_error → 5기체 최대` | (5항목 묶음) (파생) |
# | [^18] | `outputs/sigma_sensitivity.json` | `size_vs_fragility.smallest_airframe` | mini5pro |
# | [^19] | `outputs/sigma_sensitivity.json` | `size_vs_fragility.by_drone.mini5pro.extent_m` | 0.3777 |
# | [^20] | `outputs/sigma_sensitivity.json` | `size_vs_fragility.by_drone.mini5pro.D_over_lambda_lte` | 2.322 |
# | [^21] | `outputs/meshfix_applied.json` | `_meta.date` | 2026-08-04 |
# | [^22] | `outputs/meshfix_attack.json` | `Q6_invalidated_outputs.critical[3]` | (4항목 묶음) |
# | [^23] | `outputs/angle_gamma_impact.json` | `_meta.generated` | 2026-08-07 10:58:22 |
# | [^24] | `outputs/angle_gamma_impact.json` | `whole_drone_sigma_az24_el_-15.mini5pro.delta_db` | 0.08 |
# | [^25] | `outputs/angle_gamma_impact.json` | `whole_drone_sigma_az24_el_-15.matrice4e.delta_db` | 0.1 |
# | [^26] | `outputs/angle_gamma_impact.json` | `propeller_channel_el_-15_3p5GHz.matrice4e.level_delta_db` | 5.16 |
# | [^27] | `outputs/angle_gamma_impact.json` | `propeller_channel_el_-15_3p5GHz.mini5pro.level_delta_db` | 6.48 |
# | [^28] | `outputs/sigma_sensitivity.json` | `aspect_averaged.by_drone.matrice4e.smallest_flip_span_db` | 1.298 |
# | [^29] | `outputs/sigma_sensitivity.json` | `aspect_averaged.by_drone.mavic4pro.smallest_flip_span_db` | 0.08856 |
