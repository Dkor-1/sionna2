# %% [markdown]
# # 도감 C — 기체 3 종 — 박자가 기체마다 다르다
#
# [← 도감 지도](A_atlas.ipynb) 로 돌아간다. 이 편은 도감의 **절 5** 하나다 — 주제마다 파일을 나눴다.

# %% [markdown]
# ---
#
# ## 절 5. 기체 3 종 — 박자가 기체마다 다르다
#
# > **묻는 것** — 표적 기체를 바꾸면 그림의 박자가 **그 기체의 박자**로 따라가나 — 분류 축이 성립하나.
#
# 팔 33 개 · 칸 167 개 · 그림 73 장. 그림 파일은 전부 `outputs/figures/atlas/03airframe__…` 로 시작한다.

# %% [markdown]
# ![airframes — 03airframe__000-overview-rhythm.png](../outputs/figures/atlas/03airframe__000-overview-rhythm.png)
#
# **그림 660.** 이 주제의 팔 × 앙각 **리듬 몫[%]** 지도 — 개별 그림을 열기 전에 어디를 볼지 정하는 판이다. `—` 는 원장에 그 칸이 없다는 뜻이고, **빗금 친 칸은 색눈금에 올리면 안 되는 칸**이다: −90° 열(잣대 퇴화) · ◐ 자세가 덜 참 · ○ 안 움직임 · ∅ 에코 없음. ⚠이 지도는 **상한 위**만 보는 잣대라 낮은 값이 «날개가 없다» 는 뜻이 아니다.

# %% [markdown]
# ![airframes — 03airframe__01-compare-tile+0-p1.png](../outputs/figures/atlas/03airframe__01-compare-tile+0-p1.png)
#
# **그림 661.** 앙각이 **0° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![airframes — 03airframe__01-compare-tile-30-p1.png](../outputs/figures/atlas/03airframe__01-compare-tile-30-p1.png)
#
# **그림 662.** 앙각이 **−30° 하나뿐인** 팔들을 한 장에 타일로 — 전부 정지 성분을 뺀 판이라 «움직이는 것» 만 남았다.

# %% [markdown]
# ![airframes — 03airframe__02-compare-stack-p1.png](../outputs/figures/atlas/03airframe__02-compare-stack-p1.png)
#
# **그림 663.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![airframes — 03airframe__02-compare-stack-p2.png](../outputs/figures/atlas/03airframe__02-compare-stack-p2.png)
#
# **그림 664.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![airframes — 03airframe__02-compare-stack-p3.png](../outputs/figures/atlas/03airframe__02-compare-stack-p3.png)
#
# **그림 665.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ![airframes — 03airframe__02-compare-stack-p4.png](../outputs/figures/atlas/03airframe__02-compare-stack-p4.png)
#
# **그림 666.** 팔을 세로로 쌓고 앙각을 가로로 편 판 — 같은 앙각 열을 위아래로 훑으면 팔 사이 차이가 보인다.

# %% [markdown]
# ### 절 5.1 요약 수치 — 팔 × 앙각의 리듬 몫 [%]
#
# 날개끝 상한 **위**에 남은 에너지 가운데 예측 박자의 정수배에 앉은 몫이다. ⚠**상한 위만 재는 잣대**라 낮은 값이 «날개가 없다» 는 뜻이 아니다(절 13.7 · 팔마다의 표에 상한 **아래**를 보는 «빗살 대비[dB]» 를 함께 실었다). 백색잡음 값은 칸마다 다르다 — DJI Matrice 4E ≈ 12.6 · DJI Mavic 4 Pro ≈ 13.5 · DJI Mini 5 Pro ≈ 8.7 · DJI S1000+ ≈ 10.8.
#
# | 팔 | 표적 · 박자 | 거리 | 0° | −4° | −8° | −11° | −15° | −30° | −45° | −52° | −60° | −68° | −75° | −82° | −90° |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# | `ours_mavic4pro_r15_n8192` | DJI Mavic 4 Pro · 120 Hz | 15 m | 76 | — | — | — | 72 | 86 | 74 | — | 78 | — | 52 | — | — |
# | `ours_mavic4pro_r15_n8192_mfixbatteryi5` | DJI Mavic 4 Pro · 120 Hz | 15 m | 76 | — | — | — | 72 | 86 | 74 | — | 78 | — | 52 | — | — |
# | `ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 15 m | 71 | — | — | — | 67 | 87 | 73 | 62 | 77 | 69 | 50 | 77 | 65\* |
# | `ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 15 m | 45 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 15 m | 20 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 15 m | 59 | — | — | — | — | 84 | — | — | — | — | — | — | — |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 15 m | ◐ | — | — | — | — | ◐ | — | — | — | — | — | — | — |
# | `ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 15 m | 14 | — | — | — | — | ◐ | — | — | 24 | — | — | — | 30\* |
# | `ours_mini5pro_r15_n8192` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 66 | — | — | — | 66 | 83 | 72 | 60 | 59 | 52 | 58 | 95 | 61\* |
# | `ours_mini5pro_r15_n8192_mfixbatteryi5` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 66 | — | — | — | 66 | 83 | 72 | — | ◐ | — | — | — | — |
# | `ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 72 | — | — | — | 65 | 87 | 72 | 64 | 57 | 54 | 62 | 96 | 57\* |
# | `ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 43 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 24 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 2 | — | — | — | — | ◐ | — | — | 22 | — | — | — | 23\* |
# | `ours_s1000plus_r15_n8192` | DJI S1000+ · 148.9 Hz | 15 m | 53 | — | — | — | 49 | 70 | 49 | 43 | 81 | 80 | 82 | 98 | 99\* |
# | `ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` | DJI S1000+ · 148.9 Hz | 15 m | 58 | — | — | — | 44 | 73 | 54 | 50 | 78 | 78 | 82 | 98 | 99\* |
# | `ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe` | DJI S1000+ · 148.9 Hz | 15 m | 27 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe` | DJI S1000+ · 148.9 Hz | 15 m | 21 | — | — | — | — | — | — | — | — | — | — | — | — |
# | `ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` | DJI S1000+ · 148.9 Hz | 15 m | 10 | — | — | — | — | ◐ | — | — | 12 | — | — | — | 74\* |
# | `sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` | DJI Mavic 4 Pro · 120 Hz | 15 m | — | — | — | — | — | — | — | 86 | — | 90 | — | 94 | — |
# | `sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` | DJI Mini 5 Pro · 183.333 Hz | 15 m | — | — | — | — | — | — | — | 87 | — | 92 | — | 93 | — |
# | `sionna_p4000000000_mavic4pro_r15_n8192_d1` | DJI Mavic 4 Pro · 120 Hz | 15 m | — | — | — | — | — | 85 | — | — | 96 | — | — | — | — |
# | `sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1` | DJI Mavic 4 Pro · 120 Hz | 15 m | 13 | — | — | — | 84 | 81 | 90 | 86 | 95 | 97 | 97 | 98 | 99\* |
# | `sionna_p4000000000_mini5pro_r15_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | 87 | 82 | 84 | 80 | 89 | 94 | 89 | 90 | 94 | 93 | 98 | 96\* |
# | `sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 9 | — | — | — | 81 | 93 | 95 | 90 | 90 | 95 | 93 | 98 | 97\* |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | — | — | — | — | — | 89 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | — | — | — | — | — | 84 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` | DJI Mini 5 Pro · 183.333 Hz | 15 m | 8 | — | — | — | — | 11 | — | — | 14 | — | — | — | — |
# | `sionna_p4000000000_phys_s1000plus_r15_n8192_d1` | DJI S1000+ · 148.9 Hz | 15 m | 12 | — | — | — | 11 | 11 | 12 | — | 17 | — | 17 | — | 18\* |
# | `sionna_p4000000000_s1000plus_r15_n8192_d1` | DJI S1000+ · 148.9 Hz | 15 m | 28 | 27 | 23 | 24 | 24 | 36 | 62 | 77 | 90 | 93 | 19 | 14 | 23\* |
# | `sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1` | DJI S1000+ · 148.9 Hz | 15 m | 28 | — | — | — | 22 | 40 | 62 | 76 | 89 | 91 | 21 | 30 | 100\* |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1` | DJI S1000+ · 148.9 Hz | 15 m | — | — | — | — | — | 34 | — | — | — | — | — | — | — |
# | `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` | DJI S1000+ · 148.9 Hz | 15 m | — | — | — | — | — | 23 | — | — | — | — | — | — | — |
#
# 표기 — `—` 원장에 없는 칸 · `∅` 아무것도 안 돌아옴 · `◐` 자세가 덜 참 · `○` 움직이는 것이 없음 · `*` −90° 는 잣대 퇴화.

# %% [markdown]
# ### 절 5.2 `ours_mavic4pro_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192__map.png)
#
# **그림 667.** `ours_mavic4pro_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192__band.png)
#
# **그림 668.** `ours_mavic4pro_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 76.0 | 13.5 | 6.9 | +41.5 | 118.9 | 0.99 | −72.79 | 2.428 |
# | −15° | 1135 Hz | 71.8 | 13.4 | 13.6 | +34.4 | 121.3 | 1.01 | −71.78 | 0.185 |
# | −30° | 1018 Hz | 86.2 | 13.5 | 7.0 | +40.5 | 118.9 | 0.99 | −68.47 | 2.070 |
# | −45° | 831 Hz | 74.5 | 13.5 | 3.3 | +43.1 | 118.9 | 0.99 | −68.43 | 3.019 |
# | −60° | 588 Hz | 78.4 | 13.5 | 2.9 | +41.0 | 240.2 | 2.00 | −65.97 | 2.246 |
# | −75° | 304 Hz | 51.8 | 13.4 | 0.3 | — | 118.9 | 0.99 | −59.31 | 3.561 |

# %% [markdown]
# ### 절 5.3 `ours_mavic4pro_r15_n8192_mfixbatteryi5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_mfixbatteryi5 micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_mfixbatteryi5__map.png)
#
# **그림 669.** `ours_mavic4pro_r15_n8192_mfixbatteryi5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_mfixbatteryi5 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_mfixbatteryi5__band.png)
#
# **그림 670.** `ours_mavic4pro_r15_n8192_mfixbatteryi5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 76.0 | 13.5 | 6.9 | +41.5 | 118.9 | 0.99 | −72.79 | 2.428 |
# | −15° | 1135 Hz | 71.8 | 13.4 | 13.6 | +34.4 | 121.3 | 1.01 | −71.78 | 0.185 |
# | −30° | 1018 Hz | 86.2 | 13.5 | 7.0 | +40.5 | 118.9 | 0.99 | −68.47 | 2.070 |
# | −45° | 831 Hz | 74.5 | 13.5 | 3.3 | +43.1 | 118.9 | 0.99 | −68.43 | 3.019 |
# | −60° | 588 Hz | 78.4 | 13.5 | 2.9 | +41.0 | 240.2 | 2.00 | −65.97 | 2.246 |
# | −75° | 304 Hz | 51.8 | 13.4 | 0.3 | — | 118.9 | 0.99 | −59.31 | 3.561 |

# %% [markdown]
# ### 절 5.4 `ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 671.** `ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 672.** `ours_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 71.1 | 13.5 | 5.0 | +41.5 | 118.9 | 0.99 | −72.13 | 2.604 |
# | −15° | 1135 Hz | 67.0 | 13.4 | 12.8 | +34.4 | 121.3 | 1.01 | −72.02 | 0.177 |
# | −30° | 1018 Hz | 87.4 | 13.5 | 8.9 | +38.7 | 118.9 | 0.99 | −69.22 | 1.745 |
# | −45° | 831 Hz | 73.3 | 13.5 | 3.8 | +42.7 | 118.9 | 0.99 | −69.14 | 2.565 |
# | −52° | 724 Hz | 62.2 | 13.4 | 3.5 | +39.8 | 240.2 | 2.00 | −68.87 | 0.906 |
# | −60° | 588 Hz | 77.3 | 13.5 | 5.7 | +42.0 | 240.2 | 2.00 | −68.81 | 1.123 |
# | −68° | 440 Hz | 69.4 | 13.4 | 2.4 | +45.7 | 240.2 | 2.00 | −67.03 | 14.327 |
# | −75° | 304 Hz | 49.8 | 13.4 | 0.3 | — | 118.9 | 0.99 | −60.29 | 2.741 |
# | −82° | 164 Hz | 76.7 | 13.4 | 0.7 | — | 118.9 | 0.99 | −60.19 | 2.096 |
# | −90°\* | 0 Hz | 65.1 | 13.4 | 100.0 | — | 118.9 | 0.99 | −84.20 | 0.012 |

# %% [markdown]
# ### 절 5.5 `ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe__map.png)
#
# **그림 673.** `ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe__band.png)
#
# **그림 674.** `ours_mavic4pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 44.6 | 13.5 | 4.9 | +0.5 | 60.7 | 0.51 | −72.94 | 2.188 |

# %% [markdown]
# ### 절 5.6 `ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe__map.png)
#
# **그림 675.** `ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe__band.png)
#
# **그림 676.** `ours_mavic4pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 20.2 | 13.5 | 2.3 | +2.6 | 179.5 | 1.50 | −74.24 | 1.644 |

# %% [markdown]
# ### 절 5.7 `ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe__map.png)
#
# **그림 677.** `ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe__band.png)
#
# **그림 678.** `ours_mavic4pro_r15_n8192_rotlegacy_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 59.4 | 13.5 | 4.6 | +43.8 | 118.9 | 0.99 | −71.89 | 2.747 |
# | −30° | 1018 Hz | 83.8 | 13.5 | 11.5 | +40.0 | 118.9 | 0.99 | −69.99 | 1.450 |

# %% [markdown]
# ### 절 5.8 `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe__map.png)
#
# **그림 679.** `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe__band.png)
#
# **그림 680.** `ours_mavic4pro_r15_n8192_rotoutdoor_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −30° | 1018 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 5.9 `ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 681.** `ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 682.** `ours_mavic4pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 13.9 | 13.5 | 3.9 | +30.6 | 21.8 | 0.18 | −70.88 | 3.595 |
# | −30° | 1018 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 588 Hz | 24.5 | 13.5 | 1.6 | +44.9 | 368.8 | 3.07 | −64.31 | 2.946 |
# | −90°\* | 0 Hz | 30.3 | 13.4 | 100.0 | — | 237.8 | 1.98 | −84.86 | 0.010 |

# %% [markdown]
# ### 절 5.10 `ours_mini5pro_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192__map.png)
#
# **그림 683.** `ours_mini5pro_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192__band.png)
#
# **그림 684.** `ours_mini5pro_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.9 | +47.5 | 183.8 | 1.00 | −74.44 | 2.970 |
# | −15° | 990 Hz | 65.8 | 8.6 | 34.6 | +35.5 | 367.6 | 2.00 | −79.60 | 1.044 |
# | −30° | 887 Hz | 83.0 | 8.7 | 32.7 | +39.8 | 183.8 | 1.00 | −77.61 | 1.864 |
# | −45° | 725 Hz | 72.3 | 8.7 | 5.4 | +46.3 | 183.8 | 1.00 | −72.62 | 1.598 |
# | −52° | 631 Hz | 60.3 | 8.7 | 3.1 | +48.9 | 183.8 | 1.00 | −72.47 | 1.313 |
# | −60° | 512 Hz | 58.8 | 8.7 | 1.4 | — | 183.8 | 1.00 | −68.34 | 3.678 |
# | −68° | 384 Hz | 52.5 | 8.6 | 0.9 | — | 183.8 | 1.00 | −67.65 | 20.373 |
# | −75° | 265 Hz | 57.5 | 8.7 | 3.4 | — | 183.8 | 1.00 | −72.32 | 0.291 |
# | −82° | 143 Hz | 95.0 | 8.7 | 100.0 | — | 183.8 | 1.00 | −77.51 | 0.095 |
# | −90°\* | 0 Hz | 61.3 | 8.7 | 100.0 | — | 183.8 | 1.00 | −86.18 | 0.143 |

# %% [markdown]
# ### 절 5.11 `ours_mini5pro_r15_n8192_mfixbatteryi5`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_mfixbatteryi5 micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_mfixbatteryi5__map.png)
#
# **그림 685.** `ours_mini5pro_r15_n8192_mfixbatteryi5` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_mfixbatteryi5 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_mfixbatteryi5__band.png)
#
# **그림 686.** `ours_mini5pro_r15_n8192_mfixbatteryi5` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 65.9 | 8.7 | 6.9 | +47.5 | 183.8 | 1.00 | −74.44 | 2.969 |
# | −15° | 990 Hz | 65.8 | 8.6 | 34.6 | +35.5 | 367.6 | 2.00 | −79.60 | 1.041 |
# | −30° | 887 Hz | 83.0 | 8.7 | 32.7 | +39.8 | 183.8 | 1.00 | −77.61 | 1.869 |
# | −45° | 725 Hz | 72.3 | 8.7 | 5.4 | +46.3 | 183.8 | 1.00 | −72.62 | 1.595 |
# | −60° | 512 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |

# %% [markdown]
# ### 절 5.12 `ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 687.** `ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 688.** `ours_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 72.3 | 8.7 | 8.8 | +46.7 | 183.8 | 1.00 | −74.36 | 3.360 |
# | −15° | 990 Hz | 64.9 | 8.6 | 38.9 | +37.1 | 367.6 | 2.00 | −80.04 | 0.954 |
# | −30° | 887 Hz | 87.0 | 8.7 | 40.8 | +42.3 | 732.8 | 4.00 | −78.23 | 1.661 |
# | −45° | 725 Hz | 71.7 | 8.7 | 8.9 | +46.5 | 183.8 | 1.00 | −74.62 | 0.965 |
# | −52° | 631 Hz | 63.7 | 8.7 | 3.5 | +47.5 | 183.8 | 1.00 | −73.17 | 1.142 |
# | −60° | 512 Hz | 57.3 | 8.7 | 1.2 | — | 183.8 | 1.00 | −68.28 | 3.646 |
# | −68° | 384 Hz | 54.0 | 8.6 | 0.9 | — | 183.8 | 1.00 | −67.11 | 28.634 |
# | −75° | 265 Hz | 62.3 | 8.7 | 2.8 | — | 183.8 | 1.00 | −71.02 | 0.383 |
# | −82° | 143 Hz | 96.5 | 8.7 | 100.0 | — | 183.8 | 1.00 | −76.40 | 0.118 |
# | −90°\* | 0 Hz | 57.3 | 8.7 | 100.0 | — | 183.8 | 1.00 | −86.85 | 0.123 |

# %% [markdown]
# ### 절 5.13 `ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe__map.png)
#
# **그림 689.** `ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe__band.png)
#
# **그림 690.** `ours_mini5pro_r15_n8192_prf39400_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 43.2 | 8.7 | 6.0 | +1.8 | 91.9 | 0.50 | −75.04 | 2.881 |

# %% [markdown]
# ### 절 5.14 `ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe__map.png)
#
# **그림 691.** `ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe__band.png)
#
# **그림 692.** `ours_mini5pro_r15_n8192_prf78800_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 23.5 | 8.7 | 4.6 | +6.4 | 45.9 | 0.25 | −75.15 | 2.809 |

# %% [markdown]
# ### 절 5.15 `ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 693.** `ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 694.** `ours_mini5pro_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 1.6 | 8.7 | 5.2 | +34.9 | 188.6 | 1.03 | −72.57 | 4.996 |
# | −30° | 887 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 512 Hz | 22.5 | 8.7 | 3.3 | — | 183.8 | 1.00 | −69.44 | 2.818 |
# | −90°\* | 0 Hz | 23.1 | 8.7 | 100.0 | — | 181.4 | 0.99 | −86.59 | 0.131 |

# %% [markdown]
# ### 절 5.16 `ours_s1000plus_r15_n8192`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192 micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192__map.png)
#
# **그림 695.** `ours_s1000plus_r15_n8192` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192__band.png)
#
# **그림 696.** `ours_s1000plus_r15_n8192` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 52.7 | 10.9 | 4.5 | +38.6 | 147.7 | 0.99 | −65.73 | 0.145 |
# | −15° | 2010 Hz | 49.4 | 10.8 | 12.5 | +31.8 | 150.2 | 1.01 | −65.66 | 0.219 |
# | −30° | 1802 Hz | 70.4 | 10.8 | 14.1 | +32.4 | 147.7 | 0.99 | −65.22 | 2.496 |
# | −45° | 1471 Hz | 49.4 | 10.9 | 2.1 | +41.2 | 150.2 | 1.01 | −61.48 | 3.480 |
# | −52° | 1281 Hz | 43.3 | 10.9 | 1.3 | +44.2 | 150.2 | 1.01 | −60.63 | 0.931 |
# | −60° | 1040 Hz | 80.6 | 10.9 | 1.9 | +43.7 | 147.7 | 0.99 | −57.39 | 4.913 |
# | −68° | 779 Hz | 80.2 | 10.8 | 2.1 | +41.0 | 147.7 | 0.99 | −58.78 | 12.379 |
# | −75° | 538 Hz | 82.5 | 10.8 | 1.0 | +51.6 | 150.2 | 1.01 | −54.62 | 50.095 |
# | −82° | 290 Hz | 98.3 | 10.9 | 8.6 | — | 147.7 | 0.99 | −52.78 | 1.548 |
# | −90°\* | 0 Hz | 99.4 | 10.8 | 100.0 | — | 147.7 | 0.99 | −54.93 | 0.371 |

# %% [markdown]
# ### 절 5.17 `ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 697.** `ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 698.** `ours_s1000plus_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 57.5 | 10.9 | 5.0 | +37.1 | 147.7 | 0.99 | −65.36 | 0.158 |
# | −15° | 2010 Hz | 44.0 | 10.8 | 8.5 | +30.4 | 297.9 | 2.00 | −65.36 | 0.237 |
# | −30° | 1802 Hz | 73.4 | 10.8 | 15.3 | +31.9 | 147.7 | 0.99 | −65.23 | 2.614 |
# | −45° | 1471 Hz | 53.9 | 10.9 | 2.8 | +39.7 | 150.2 | 1.01 | −62.82 | 2.641 |
# | −52° | 1281 Hz | 50.4 | 10.9 | 1.8 | +41.0 | 150.2 | 1.01 | −61.90 | 0.710 |
# | −60° | 1040 Hz | 78.5 | 10.9 | 2.8 | +45.3 | 147.7 | 0.99 | −59.39 | 3.080 |
# | −68° | 779 Hz | 77.8 | 10.8 | 4.0 | +40.2 | 297.9 | 2.00 | −61.75 | 6.694 |
# | −75° | 538 Hz | 82.3 | 10.8 | 1.8 | +51.9 | 150.2 | 1.01 | −57.12 | 38.423 |
# | −82° | 290 Hz | 97.9 | 10.9 | 10.6 | — | 147.7 | 0.99 | −54.93 | 0.936 |
# | −90°\* | 0 Hz | 99.0 | 10.8 | 100.0 | — | 147.7 | 0.99 | −57.21 | 0.176 |

# %% [markdown]
# ### 절 5.18 `ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe__map.png)
#
# **그림 699.** `ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe__band.png)
#
# **그림 700.** `ours_s1000plus_r15_n8192_prf39400_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 27.4 | 10.9 | 3.1 | −0.4 | 75.1 | 0.50 | −65.67 | 0.147 |

# %% [markdown]
# ### 절 5.19 `ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe__map.png)
#
# **그림 701.** `ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe__band.png)
#
# **그림 702.** `ours_s1000plus_r15_n8192_prf78800_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 20.8 | 10.9 | 2.2 | +3.4 | 445.6 | 2.99 | −66.15 | 0.132 |

# %% [markdown]
# ### 절 5.20 `ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe`
#
# 엔진 **우리 커널(SBR+PO)**, 동체 포함(가림 있음) · 거리 15 m · 자세 8,192 개 · 격자 λ/12 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__map.png)
#
# **그림 703.** `ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe__band.png)
#
# **그림 704.** `ours_s1000plus_r15_n8192_rotoutdoor_v2_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 9.7 | 10.9 | 3.6 | +3.9 | 145.3 | 0.98 | −64.40 | 0.197 |
# | −30° | 1802 Hz | ◐ 덜 참(4,096/8,192 자세) | — | — | — | — | — | — | — |
# | −60° | 1040 Hz | 12.5 | 10.9 | 1.3 | +9.6 | 285.8 | 1.92 | −58.84 | 3.416 |
# | −90°\* | 0 Hz | 74.5 | 10.8 | 100.0 | — | 147.7 | 0.99 | −62.93 | 0.047 |

# %% [markdown]
# ### 절 5.21 `sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 2,500 만 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 705.** `sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 706.** `sionna_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −52° | 724 Hz | 86.2 | 13.4 | 30.5 | +38.8 | 118.9 | 0.99 | −142.61 | 34.945 |
# | −68° | 440 Hz | 90.4 | 13.4 | 54.8 | +34.7 | 118.9 | 0.99 | −140.75 | 45.855 |
# | −82° | 164 Hz | 94.2 | 13.4 | 57.0 | — | 118.9 | 0.99 | −139.36 | 23.497 |

# %% [markdown]
# ### 절 5.22 `sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 2,500 만 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__map.png)
#
# **그림 707.** `sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe__band.png)
#
# **그림 708.** `sionna_mini5pro_r15_n8192_mfixbatteryi5_blperairframe` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −52° | 631 Hz | 87.4 | 8.7 | 30.0 | +44.3 | 183.8 | 1.00 | −143.71 | 5.888 |
# | −68° | 384 Hz | 92.3 | 8.6 | 51.4 | — | 183.8 | 1.00 | −144.32 | 52.540 |
# | −82° | 143 Hz | 92.7 | 8.7 | 100.0 | — | 183.8 | 1.00 | −146.56 | 8.330 |

# %% [markdown]
# ### 절 5.23 `sionna_p4000000000_mavic4pro_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_mavic4pro_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_mavic4pro_r15_n8192_d1__map.png)
#
# **그림 709.** `sionna_p4000000000_mavic4pro_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mavic4pro_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_mavic4pro_r15_n8192_d1__band.png)
#
# **그림 710.** `sionna_p4000000000_mavic4pro_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1018 Hz | 85.0 | 13.5 | 1.0 | +49.7 | 118.9 | 0.99 | −136.50 | 4.781 |
# | −60° | 588 Hz | 95.7 | 13.5 | 8.1 | +45.0 | 118.9 | 0.99 | −129.73 | 17.402 |

# %% [markdown]
# ### 절 5.24 `sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mavic 4 Pro(**기체 태그**), 박자 120 Hz

# %% [markdown]
# ![sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 711.** `sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 712.** `sionna_p4000000000_mavic4pro_r15_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 120 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1175 Hz | 12.9 | 13.5 | 88.8 | −0.1 | 461.0 ⚠튐 | 3.84 | −94.27 | 0.045 |
# | −15° | 1135 Hz | 84.5 | 13.4 | 5.9 | +41.7 | 118.9 | 0.99 | −146.15 | 1.279 |
# | −30° | 1018 Hz | 80.6 | 13.5 | 0.8 | +49.4 | 118.9 | 0.99 | −136.92 | 4.226 |
# | −45° | 831 Hz | 89.5 | 13.5 | 1.6 | +50.2 | 118.9 | 0.99 | −132.36 | 8.979 |
# | −52° | 724 Hz | 86.4 | 13.4 | 2.5 | +46.8 | 118.9 | 0.99 | −131.23 | 28.448 |
# | −60° | 588 Hz | 95.3 | 13.5 | 15.4 | +44.3 | 118.9 | 0.99 | −132.60 | 13.568 |
# | −68° | 440 Hz | 96.6 | 13.4 | 9.9 | +46.3 | 240.2 | 2.00 | −129.65 | 10.630 |
# | −75° | 304 Hz | 97.2 | 13.4 | 1.7 | — | 118.9 | 0.99 | −121.75 | 19.439 |
# | −82° | 164 Hz | 98.1 | 13.4 | 3.2 | — | 118.9 | 0.99 | −122.95 | 23.947 |
# | −90°\* | 0 Hz | 99.0 | 13.4 | 100.0 | — | 240.2 | 2.00 | −134.51 | 0.068 |

# %% [markdown]
# ### 절 5.25 `sionna_p4000000000_mini5pro_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_d1__map.png)
#
# **그림 713.** `sionna_p4000000000_mini5pro_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_d1__band.png)
#
# **그림 714.** `sionna_p4000000000_mini5pro_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.7 | 8.7 | 89.8 | +0.0 | 365.2 ⚠튐 | 1.99 | −97.66 | 0.082 |
# | −4° | 1022 Hz | 87.1 | 8.7 | 8.2 | +48.2 | 183.8 | 1.00 | −151.27 | 4.135 |
# | −8° | 1015 Hz | 81.6 | 8.7 | 4.9 | +45.7 | 183.8 | 1.00 | −149.87 | 5.991 |
# | −11° | 1006 Hz | 84.2 | 8.6 | 14.7 | +41.7 | 183.8 | 1.00 | −153.72 | 50.367 |
# | −15° | 990 Hz | 80.4 | 8.6 | 22.5 | +42.9 | 183.8 | 1.00 | −156.43 | 1.806 |
# | −30° | 887 Hz | 88.7 | 8.7 | 11.4 | +47.0 | 183.8 | 1.00 | −147.28 | 6.671 |
# | −45° | 725 Hz | 93.7 | 8.7 | 2.9 | +53.5 | 183.8 | 1.00 | −134.18 | 24.613 |
# | −52° | 631 Hz | 89.4 | 8.7 | 2.9 | +54.4 | 183.8 | 1.00 | −134.51 | 10.356 |
# | −60° | 512 Hz | 89.7 | 8.7 | 2.2 | — | 183.8 | 1.00 | −131.13 | 13.645 |
# | −68° | 384 Hz | 94.3 | 8.6 | 2.9 | — | 183.8 | 1.00 | −129.39 | 21.492 |
# | −75° | 265 Hz | 93.2 | 8.7 | 7.7 | — | 183.8 | 1.00 | −134.52 | 4.102 |
# | −82° | 143 Hz | 98.5 | 8.7 | 100.0 | — | 183.8 | 1.00 | −139.34 | 1.124 |
# | −90°\* | 0 Hz | 96.5 | 8.7 | 100.0 | — | 367.6 | 2.00 | −143.67 | 0.351 |

# %% [markdown]
# ### 절 5.26 `sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 715.** `sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 716.** `sionna_p4000000000_mini5pro_r15_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.6 | 8.7 | 89.5 | −1.3 | 527.2 ⚠튐 | 2.88 | −98.55 | 0.067 |
# | −15° | 990 Hz | 81.1 | 8.6 | 34.7 | +41.0 | 367.6 | 2.00 | −157.77 | 1.309 |
# | −30° | 887 Hz | 93.1 | 8.7 | 20.4 | +47.3 | 365.2 | 1.99 | −148.63 | 4.290 |
# | −45° | 725 Hz | 95.3 | 8.7 | 6.0 | +55.2 | 183.8 | 1.00 | −136.29 | 14.781 |
# | −52° | 631 Hz | 89.5 | 8.7 | 3.6 | +57.5 | 183.8 | 1.00 | −135.55 | 8.843 |
# | −60° | 512 Hz | 90.0 | 8.7 | 2.5 | — | 183.8 | 1.00 | −131.33 | 11.356 |
# | −68° | 384 Hz | 94.9 | 8.6 | 2.5 | — | 183.8 | 1.00 | −128.55 | 28.548 |
# | −75° | 265 Hz | 93.4 | 8.7 | 6.4 | — | 183.8 | 1.00 | −133.25 | 5.184 |
# | −82° | 143 Hz | 98.5 | 8.7 | 100.0 | — | 183.8 | 1.00 | −139.64 | 1.054 |
# | −90°\* | 0 Hz | 97.2 | 8.7 | 100.0 | — | 367.6 | 2.00 | −143.40 | 0.376 |

# %% [markdown]
# ### 절 5.27 `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1__map.png)
#
# **그림 717.** `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1__band.png)
#
# **그림 718.** `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 88.7 | 8.7 | 11.4 | +47.0 | 183.8 | 1.00 | −147.28 | 62.985 |

# %% [markdown]
# ### 절 5.28 `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1__map.png)
#
# **그림 719.** `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1__band.png)
#
# **그림 720.** `sionna_p4000000000_mini5pro_r15_n8192_shell0.75mm_prop0.9mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 887 Hz | 84.2 | 8.7 | 12.9 | +40.6 | 183.8 | 1.00 | −162.27 | 7.599 |

# %% [markdown]
# ### 절 5.29 `sionna_p4000000000_phys_mini5pro_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI Mini 5 Pro(**기체 태그**), 박자 183.333 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_mini5pro_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_phys_mini5pro_r15_n8192_d1__map.png)
#
# **그림 721.** `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_mini5pro_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_phys_mini5pro_r15_n8192_d1__band.png)
#
# **그림 722.** `sionna_p4000000000_phys_mini5pro_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 183.333 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 1025 Hz | 8.3 | 8.7 | 88.1 | +2.3 | 367.6 ⚠튐 | 2.00 | −101.46 | 0.032 |
# | −30° | 887 Hz | 11.3 | 8.7 | 89.5 | +5.8 | 367.6 ⚠튐 | 2.00 | −135.64 | 0.014 |
# | −60° | 512 Hz | 14.3 | 8.7 | 73.6 | — | 183.8 | 1.00 | −132.64 | 0.026 |

# %% [markdown]
# ### 절 5.30 `sionna_p4000000000_phys_s1000plus_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 **전부 켬**(굴절 · 회절 · 모서리 회절) · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_phys_s1000plus_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_phys_s1000plus_r15_n8192_d1__map.png)
#
# **그림 723.** `sionna_p4000000000_phys_s1000plus_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_phys_s1000plus_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_phys_s1000plus_r15_n8192_d1__band.png)
#
# **그림 724.** `sionna_p4000000000_phys_s1000plus_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 11.9 | 10.9 | 78.4 | +0.2 | 60.5 ⚠튐 | 0.41 | −96.06 | 7.486 |
# | −15° | 2010 Hz | 11.2 | 10.8 | 77.9 | +1.5 | 249.5 | 1.68 | −119.11 | 0.162 |
# | −30° | 1802 Hz | 11.2 | 10.8 | 78.8 | +4.6 | 145.3 | 0.98 | −122.87 | 1.813 |
# | −45° | 1471 Hz | 12.5 | 10.9 | 69.0 | +13.4 | 150.2 | 1.01 | −122.74 | 0.272 |
# | −60° | 1040 Hz | 17.1 | 10.9 | 65.9 | +16.2 | 297.9 | 2.00 | −121.24 | 0.198 |
# | −75° | 538 Hz | 16.7 | 10.8 | 89.6 | +12.9 | 297.9 | 2.00 | −113.12 | 1.263 |
# | −90°\* | 0 Hz | 17.8 | 10.8 | 100.0 | — | 685.4 ⚠튐 | 4.60 | −114.08 | 0.001 |

# %% [markdown]
# ### 절 5.31 `sionna_p4000000000_s1000plus_r15_n8192_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_d1__map.png)
#
# **그림 725.** `sionna_p4000000000_s1000plus_r15_n8192_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_d1__band.png)
#
# **그림 726.** `sionna_p4000000000_s1000plus_r15_n8192_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 27.9 | 10.9 | 39.6 | +26.7 | 891.3 | 5.99 | −141.11 | 0.004 |
# | −4° | 2076 Hz | 26.6 | 10.9 | 26.6 | +28.2 | 743.5 | 4.99 | −139.08 | 0.007 |
# | −8° | 2060 Hz | 22.7 | 10.9 | 33.9 | +24.3 | 891.3 | 5.99 | −139.48 | 0.088 |
# | −11° | 2042 Hz | 24.1 | 10.9 | 14.4 | +26.9 | 147.7 | 0.99 | −135.85 | 11.483 |
# | −15° | 2010 Hz | 24.0 | 10.8 | 22.7 | +25.2 | 147.7 | 0.99 | −138.15 | 0.138 |
# | −30° | 1802 Hz | 36.3 | 10.8 | 3.6 | +39.6 | 147.7 | 0.99 | −133.30 | 0.640 |
# | −45° | 1471 Hz | 61.5 | 10.9 | 1.5 | +47.0 | 150.2 | 1.01 | −123.53 | 1.212 |
# | −52° | 1281 Hz | 77.1 | 10.9 | 1.3 | +49.0 | 150.2 | 1.01 | −122.12 | 4.238 |
# | −60° | 1040 Hz | 90.0 | 10.9 | 2.8 | +47.4 | 147.7 | 0.99 | −120.94 | 1.359 |
# | −68° | 779 Hz | 93.0 | 10.8 | 5.2 | +44.9 | 147.7 | 0.99 | −122.42 | 12.039 |
# | −75° | 538 Hz | 18.7 | 10.8 | 63.2 | +23.7 | 150.2 | 1.01 | −111.62 | 4.675 |
# | −82° | 290 Hz | 13.7 | 10.9 | 72.0 | — | 147.7 | 0.99 | −110.09 | 0.749 |
# | −90°\* | 0 Hz | 22.6 | 10.8 | 100.0 | — | 147.7 | 0.99 | −107.47 | 0.066 |

# %% [markdown]
# ### 절 5.32 `sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1__map.png)
#
# **그림 727.** `sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1__band.png)
#
# **그림 728.** `sionna_p4000000000_s1000plus_r15_n8192_mfixbatteryi5_blperairframe_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | 0° | 2081 Hz | 27.8 | 10.9 | 44.9 | +25.8 | 891.3 | 5.99 | −142.06 | 0.003 |
# | −15° | 2010 Hz | 21.7 | 10.8 | 32.7 | +25.9 | 147.7 | 0.99 | −139.91 | 0.093 |
# | −30° | 1802 Hz | 40.3 | 10.8 | 4.4 | +40.0 | 147.7 | 0.99 | −134.22 | 0.531 |
# | −45° | 1471 Hz | 62.4 | 10.9 | 2.3 | +45.3 | 150.2 | 1.01 | −125.54 | 0.774 |
# | −52° | 1281 Hz | 76.5 | 10.9 | 1.8 | +47.1 | 150.2 | 1.01 | −123.89 | 2.971 |
# | −60° | 1040 Hz | 89.3 | 10.9 | 4.0 | +46.8 | 147.7 | 0.99 | −122.90 | 0.852 |
# | −68° | 779 Hz | 91.4 | 10.8 | 8.1 | +46.5 | 147.7 | 0.99 | −125.27 | 6.877 |
# | −75° | 538 Hz | 21.4 | 10.8 | 49.4 | +19.1 | 150.2 | 1.01 | −115.14 | 2.171 |
# | −82° | 290 Hz | 30.3 | 10.9 | 37.1 | — | 147.7 | 0.99 | −116.09 | 0.190 |
# | −90°\* | 0 Hz | 99.8 | 10.8 | 100.0 | — | 891.3 | 5.99 | −120.26 | 0.003 |

# %% [markdown]
# ### 절 5.33 `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1__map.png)
#
# **그림 729.** `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1__band.png)
#
# **그림 730.** `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 34.1 | 10.8 | 4.4 | +39.0 | 147.7 | 0.99 | −133.24 | 0.712 |

# %% [markdown]
# ### 절 5.34 `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1`
#
# 엔진 **Sionna RT PathSolver** · 거리 15 m · 자세 8,192 개 · 광선 40 억 발 · 반사 깊이 1 · 스위치: 물리 끔 · 표적 DJI S1000+(**기체 태그**), 박자 148.9 Hz

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1 micro-Doppler maps](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1__map.png)
#
# **그림 731.** `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` — 앙각별 맵. 위 줄이 받은 그대로, 아래 줄이 정지 성분을 뺀 판이다. 흰 점선이 날개끝 상한이고, 구석 상자에는 네 가지가 적힌다 — 리듬 몫[%]과 **그 칸의 백색잡음 값** · 상한 위가 움직이는 에너지의 몇 %인가 · 상한 **아래**를 보는 빗살 대비[dB] · 박자. 수를 낼 자격이 없는 칸은 그 까닭만 적힌다.

# %% [markdown]
# ![sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1 blade-band rhythm spectrum](../outputs/figures/atlas/03airframe__sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1__band.png)
#
# **그림 732.** `sionna_p4000000000_s1000plus_r15_n8192_shell0.75mm_prop0.9mm_d1` — 날개 대역 전력이 뛰는 리듬의 스펙트럼. 세로 점선이 예측 박자 148.9 Hz 의 정수배다.

# %% [markdown]
# | 앙각 | 날개끝 상한 f_tip | 리듬 몫 [%] | (그 칸 백색잡음) | 상한 위 에너지 [%] | 빗살 대비 [dB] | 박자 [Hz] | 박자 ÷ 예측 | 움직이는 전력 [dB] | 움직이는 몫 [%] |
# |---|---|---|---|---|---|---|---|---|---|
# | −30° | 1802 Hz | 23.2 | 10.8 | 51.9 | +26.8 | 743.5 | 4.99 | −144.95 | 0.046 |
