# %% [markdown]
# # 이 편은 갈라졌습니다 — 메쉬 7종의 σ 를 광선 가림 + 재질 PO 로
#
# > ⭐ **새 편은 `reports/` 에 있습니다.** 이 파일은 안내만 남깁니다.
#
# 재구성으로 리포트가 **8편 → 78편**이 됐습니다. 한 편에 중심 메시지 하나만 담고, 편당 **10분** 안에 읽히도록 나눴습니다(전에는 34~88분이었습니다).
#
# 이 편의 내용은 **부 3 「표적 메쉬」 · 부 4 「우리 커널」 · 부 5 「앵커」** 로 갔습니다.
#
# | 새 편 | 제목 |
# |---|---|
# | [`15_mesh-build`](reports/15_mesh-build.ipynb) | 기체 7종을 제원과 제조사 CAD 치수에서 세우고 부품을 재질 그룹으로 유지했다 |
# | [`16_mesh-vs-real`](reports/16_mesh-vs-real.ipynb) | 메쉬 외형이 실제 기체와 얼마나 맞는지를 사진 IoU·CAD 치수·실물 스캔 세 자로 쟀다 |
# | [`18_kernel-what`](reports/18_kernel-what.ipynb) | 가림 판정은 Sionna 광선엔진이 하고, 면적분은 우리 커널이 한다 |
# | [`24_anchor-mode`](reports/24_anchor-mode.ipynb) | σ = A(f)·B₁·B₂ 에서 A(f) 의 기울기만 측정에서 받고, 레벨과 각패턴은 우리 PO 출력이다 |
#
# ---
#
# **어디부터 읽나** — [`reports/00_map.ipynb`](reports/00_map.ipynb) 이 읽는 목적별로 순서를 안내합니다.
#
# **전체 목록** — [`README.md`](README.md) · **다시 돌리기** — [`docs/REPRODUCE.md`](docs/REPRODUCE.md) · **대조표** — [`docs/LEGACY_MIGRATION.md`](docs/LEGACY_MIGRATION.md)
#
# ⚠ 옛 내용을 다시 보려면 옛 빌더를 돌리면 됩니다 — `PYTHONPATH=src python src/make_report02_target.py`
