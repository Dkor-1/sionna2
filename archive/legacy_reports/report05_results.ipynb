# %% [markdown]
# # 이 편은 갈라졌습니다 — 세 조명원의 검출거리를 앵커 σ 위에서
#
# > ⭐ **새 편은 `reports/` 에 있습니다.** 이 파일은 안내만 남깁니다.
#
# 재구성으로 리포트가 **8편 → 78편**이 됐습니다. 한 편에 중심 메시지 하나만 담고, 편당 **10분** 안에 읽히도록 나눴습니다(전에는 34~88분이었습니다).
#
# 이 편의 내용은 **부 10 「결과」** 로 갔습니다.
#
# | 새 편 | 제목 |
# |---|---|
# | [`63_cpi-residual`](reports/63_cpi-residual.ipynb) | 모호속도는 표본화율의 성질이라 CPI 와 무관한 상한이다 |
# | [`64_sigma-free-axis`](reports/64_sigma-free-axis.ipynb) | σ 를 곱하기 전에 이미 세 파형의 순서를 정하는 축이 있다 |
#
# ---
#
# **어디부터 읽나** — [`reports/00_map.ipynb`](reports/00_map.ipynb) 이 읽는 목적별로 순서를 안내합니다.
#
# **전체 목록** — [`README.md`](README.md) · **다시 돌리기** — [`docs/REPRODUCE.md`](docs/REPRODUCE.md) · **대조표** — [`docs/LEGACY_MIGRATION.md`](docs/LEGACY_MIGRATION.md)
#
# ⚠ 옛 내용을 다시 보려면 옛 빌더를 돌리면 됩니다 — `PYTHONPATH=src python src/make_report05_results.py`
