# %% [markdown]
# # 이 편은 갈라졌습니다 — 검출 사슬의 경험 Pfa 와 CFAR 문턱
#
# > ⭐ **새 편은 `reports/` 에 있습니다.** 이 파일은 안내만 남깁니다.
#
# 재구성으로 리포트가 **8편 → 78편**이 됐습니다. 한 편에 중심 메시지 하나만 담고, 편당 **10분** 안에 읽히도록 나눴습니다(전에는 34~88분이었습니다).
#
# 이 편의 내용은 **부 9 「검출기」** 로 갔습니다.
#
# | 새 편 | 제목 |
# |---|---|
# | [`57_sensitivity-chain`](reports/57_sensitivity-chain.ipynb) | 세 밴드에서 값이 다른 항은 λ² 와 σ 둘뿐이다 |
# | [`58_shared-threshold`](reports/58_shared-threshold.ipynb) | 자유공간 형상에서 문턱을 다시 재니 세 밴드가 SNR90 하나를 공유한다 |
#
# ---
#
# **어디부터 읽나** — [`reports/00_map.ipynb`](reports/00_map.ipynb) 이 읽는 목적별로 순서를 안내합니다.
#
# **전체 목록** — [`README.md`](README.md) · **다시 돌리기** — [`docs/REPRODUCE.md`](docs/REPRODUCE.md) · **대조표** — [`docs/LEGACY_MIGRATION.md`](docs/LEGACY_MIGRATION.md)
#
# ⚠ 옛 내용을 다시 보려면 옛 빌더를 돌리면 됩니다 — `PYTHONPATH=src python src/make_report04_detector.py`
