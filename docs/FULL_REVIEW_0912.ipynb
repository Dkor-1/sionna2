# %% [markdown]
# # 리포트 현재 전수 점검 — 저장 자료·분석 시간축·실험 해석 점검
#
# > ### 한 일
# > **현재 저장소를 열거하고 원본·생산 함수·발간 기록을 대조했다.**
#
# ### 결과
# 1. 생산 샤드 7588개 전체 배열을 검사했다 [^1].
# 2. 표집률 사다리 122칸을 재계산했다 [^2].
# 3. 파형 원장 292행을 재현했다 [^3].
# 4. 보완점 10건을 범위별로 기록했다 [^4].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 재고 | 전체 파일 열거와 배열·JSON·노트북 검사 |
# | 수치 | 원본 재계산·합성 대조·생산 함수 실행 |
#
# ### 재현
#
# ```bash
# /workspace/.venvs/py312/bin/python benchmark/review_full_0912.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/full_review_0912.json` |
# | 소요 | CPU 한 코어, 저장 자료 검사 |
#
# ---

# %% [markdown]
# ## 범위와 실행 상태
#
# 전체 열거 19745개. 바이너리 자산은 열거했고, 내용 전부의 과학적 타당성 평가는 별도 작업이다.
#
# [검사별 범위와 큐 조회 기록](FULL_REVIEW_0912.md) [^5]

# %% [markdown]
# ## 1. 새 장면 분석이 다른 조건의 빈 하늘을 대조군으로 선택한다
#
# 장면 요소만 다른 동일 조건의 대조군을 유일하게 선택하고, 기체·PRF·로터 설정·자세 수를 쌍으로 검사한다. 중복 후보는 거절하고 선택 근거를 남긴 뒤 장면 표를 재발간한다. 스위치 이름도 실제 옵션과 맞춘다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^6]

# %% [markdown]
# ## 2. 주 집계와 아틀라스가 표집률 사다리를 기본 시간축으로 읽는다
#
# 샤드 meta[4]를 칸별 prf_hz로 발행하고 일치 여부를 검사한다. STFT 창·시간축·리듬 지표·아틀라스에 그 값을 전달한 뒤 영향받는 원장과 그림을 재생성한다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^7]

# %% [markdown]
# ## 3. Wi-Fi 프레임 평균 길이에 블록 수가 빠졌다
#
# 주석 대신 실제 블록 길이·블록 수·표집률에서 프레임 길이와 반복률을 함께 유도한다. 현재의 이산 평균 모형 안에서 보정한 뒤 파형 표를 다시 생성한다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^8]

# %% [markdown]
# ## 4. 접힌 주파수 띠를 잘라서 실제 주성분을 제외한다
#
# 입력 띠 전체를 접힘 사상으로 옮겨 구간의 합집합을 만든다. 입력 피크와 접힌 피크의 대응도 따로 확인한다. 단순한 상한 자르기나 접힌 중심 주변의 임의 비율 띠를 대체한다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^9]

# %% [markdown]
# ## 5. 파형 표가 서로 다른 조건을 같은 행 이름으로 표시한다
#
# 기체·방위·표집률·로터 설정을 명시적 조건으로 선택하고 표에도 표시한다. 공통 로더에서 PRF·N·idx·유한값과 선택 후 충돌 상태를 검사하고 제외 사유를 기록한다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^10]

# %% [markdown]
# ## 6. 기준선 검사가 사건 수의 변화를 놓친다
#
# 조건별 실제 사건 수·집합 식별자·선택 파일 해시를 저장한다. 낙차 원장도 포함하고, 샤드 재계산 또는 상류 최신성 확인을 구분해 검사한다. generator를 정해진 메타 위치로 옮긴다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^11]

# %% [markdown]
# ## 7. 실외 발주서의 물리 이름과 필터 판정 기준을 고쳐야 한다
#
# R=굴절·D=회절·E=모서리회절을 정확히 적고 정반사는 별도 상시 설정임을 구분한다. 동일 입력의 필터 전후 변화와 장면·빈 하늘 양쪽의 동일 처리 결과를 함께 비교한다. 지면·건물 기여 해석에는 차폐와 경로 상호작용도 남긴다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^12]

# %% [markdown]
# ## 8. 0929의 복소 평탄성에는 전파 지연 기준이 먼저 필요하다
#
# 원시 채널 응답과 공통 지연을 제거한 표적 응답을 나란히 정의한다. 대역 안 성긴 점검이 부반송파 전부의 평탄성을 보증하는 범위도 구분한다. 동일 자세·솔버 설정·수치 민감도를 맞춘 뒤 해석한다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^13]

# %% [markdown]
# ## 9. 기존 전체 감사 생성기는 다른 의존성 누락으로 멈춘다
#
# 생산 저장 함수와 의존성을 함께 불러 실행한다. 장기적으로는 저장 경로를 작은 함수로 분리해, AST 내부 줄을 떼어내는 시험의 의존성 누락을 줄인다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^14]

# %% [markdown]
# ## 10. 선행연구 README가 갱신 전 조사와 옛 원인 설명을 유지한다
#
# README 요약을 현재 원장에서 생성하고 이전 표에는 기준 날짜를 붙인다. DOI가 확인되는 범위 내 기준 논문의 발견률이라는 이름과 분모를 유지하며 전체 문헌의 망라율과 구분한다.
#
# [범위·반례·코드 인용](FULL_REVIEW_0912.md) [^15]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 시간축과 평균 길이를 보정한다 | 발간 지표의 변화 범위 | FULL_REVIEW_0912.md |
# | 입력·기준선 검사를 강화한다 | 자료 선택과 변화 검출 | FULL_REVIEW_0912.md |
# | 발주서의 판정을 관찰로 바꾼다 | 다음 실험이 답하는 범위 | FULL_REVIEW_0912.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 15개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/full_review_0912.json` | `checks.arrays` | (7항목 묶음) |
# | [^2] | `outputs/full_review_0912.json` | `checks.additional.timeaxis` | (6항목 묶음) |
# | [^3] | `outputs/full_review_0912.json` | `checks.additional.waveform` | (12항목 묶음) |
# | [^4] | `outputs/full_review_0912.json` | `findings` | (10행 표) |
# | [^5] | `outputs/full_review_0912.json` | `checks.additional.wide_artifacts` | (11항목 묶음) |
# | [^6] | `outputs/full_review_0912.json` | `findings[0]` | (7항목 묶음) |
# | [^7] | `outputs/full_review_0912.json` | `findings[1]` | (7항목 묶음) |
# | [^8] | `outputs/full_review_0912.json` | `findings[2]` | (7항목 묶음) |
# | [^9] | `outputs/full_review_0912.json` | `findings[3]` | (7항목 묶음) |
# | [^10] | `outputs/full_review_0912.json` | `findings[4]` | (7항목 묶음) |
# | [^11] | `outputs/full_review_0912.json` | `findings[5]` | (7항목 묶음) |
# | [^12] | `outputs/full_review_0912.json` | `findings[6]` | (7항목 묶음) |
# | [^13] | `outputs/full_review_0912.json` | `findings[7]` | (7항목 묶음) |
# | [^14] | `outputs/full_review_0912.json` | `findings[8]` | (7항목 묶음) |
# | [^15] | `outputs/full_review_0912.json` | `findings[9]` | (7항목 묶음) |
