# %% [markdown]
# # 리포트 후속 검토 — 현재 소스와 원장으로 확인한 해석 범위
#
# > ### 한 일
# > **현재 소스와 실험 원장을 대조하고 통계·인덱스 연산을 재계산했다.**
#
# ### 결과
# 1. 검토 항목 10건에 근거와 수정안을 기록했다 [^1].
# 2. 깊이 대조 2건의 교집합과 추가 사건 수를 재계산했다 [^2].
# 3. 설치 솔버 소스 3개의 해시를 기록했다 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 범위 | 지정 소스의 정적 검토와 기존 집계의 산술 확인, 합성 입력의 최소 연산 재현 |
# | 후속 범위 | GPU 원본 재실험, 실제 전계 기준 대조, 과거 실행 파일의 동일성 확인 |
#
# ### 재현
#
# ```bash
# CUDA_VISIBLE_DEVICES='' /workspace/.venvs/py312/bin/python benchmark/review_interpretation_followup_0909.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/interpretation_followup_0909.json` |
# | 소요 | CPU 한 코어의 소스·원장 검토 |
#
# ---

# %% [markdown]
# ## 1. 최빈값 이탈률과 기준 조건 대비 변화율이 다르다
#
# 조건 내부의 반복 변동과 조건 사이의 최빈 경로 수 변화가 관측됐다.
#
# **수정 제안:** 각 설정의 최빈 경로 수와 그 값에서 벗어난 비율을 함께 보고한다. 단일 스레드 기준과의 차이는 별도 열로 둔다. 물리적 오류율 판정은 미확정이다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^4]

# %% [markdown]
# ## 2. 영 진폭이 편차 집계에서 제외된다
#
# 양의 진폭 표본에 대해 계산된 기존 편차는 남는다.
#
# **수정 제안:** 양의 진폭 표본의 편차와 영 진폭·비유한 값의 개수를 분리 기록한다. 과거 실행의 제외 표본 유무는 원시 기록 확인이 필요하다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^5]

# %% [markdown]
# ## 3. CPU 재현과 스레드 의존성으로 특정 내부 원인을 확정한다
#
# 검사한 합성 장면에서 스레드 설정에 따라 반복 결과가 달라졌다.
#
# **수정 제안:** CPU 합성 장면에서 스레드 설정에 따른 변화를 관측했다. 원인이 되는 내부 연산의 특정과 드론 장면으로의 적용은 후속 계측 대상이다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^6]

# %% [markdown]
# ## 4. 경로 상한과 해시 배열을 바꾸는 실험의 적용 범위
#
# 설치본과 기존 대조 코드에서 두 설정의 결합을 확인했다.
#
# **수정 제안:** 이 대조는 경로 저장 상한과 해시 배열 크기를 함께 바꾼 결과다. 각 단계의 유실 원인 분리는 추가 계측 대상이다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^7]

# %% [markdown]
# ## 5. 반사 깊이 비교의 포함관계를 사건 집합 불변으로 요약한다
#
# 깊이 대조의 교집합과 설정별 추가 사건 수를 기존 원장에서 재계산했다.
#
# **수정 제안:** 검사한 깊이 대조에서 얕은 설정의 사건 집합이 깊은 설정에 포함됐으며 추가 사건이 관측됐다. 경로별 변화와 문턱 변화의 기여는 미분리다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^8]

# %% [markdown]
# ## 6. 교집합 기댓값은 선언한 귀무모형 아래의 값이다
#
# 동일한 인덱스로 정렬된 두 사건 집합의 교집합은 기술 통계로 쓸 수 있다.
#
# **수정 제안:** 균일·독립 위치 선택 모형의 기대 교집합을 참고값으로 함께 제시했다. 회전 위상과 군집을 반영한 대조 및 유의성 판정은 후속 분석 대상이다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^9]

# %% [markdown]
# ## 7. 기본 장면의 환경 산란계수 변경이 드론 재질까지 선택한다
#
# 특정 옵션 조합에서 환경만 바꾸는 대조라는 설명과 선택 코드가 어긋난다.
#
# **수정 제안:** 기본 장면에서 환경 산란계수를 지정하는 현재 분기는 드론 부품도 선택한다. 환경만 변경한 대조로 해석하려면 물체·재질별 적용 범위를 확인해야 한다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^10]

# %% [markdown]
# ## 8. 정렬 옵션과 중복 제거를 함께 쓰는 조건부 인덱스 오류
#
# 정렬 옵션이 활성화되는 경우의 중복 제거 합을 별도로 재검토해야 한다.
#
# **수정 제안:** 정렬된 전계 항과 중복 판정 인덱스의 순서를 맞춰야 한다. 해당 옵션을 사용한 결과의 영향 범위는 실행 설정별로 추적한다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^11]

# %% [markdown]
# ## 9. 상한 근접과 실패를 물리적 경로 결과와 구분해야 한다
#
# 상한 근접 경고는 해당 출력의 해석을 보류하는 보수적인 신호로 남긴다.
#
# **수정 제안:** 최종 반환 수의 상한 근접 여부를 기록했다. 후보 단계의 유실 개수는 별도 계측 대상이며 처리 실패와 정상 영 전계는 상태값으로 구분해야 한다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^12]

# %% [markdown]
# ## 10. 모든 물리 옵션과 물리 성분의 독립 분해는 다르다
#
# 지원되는 상호작용 조합 안에서 옵션별 출력을 비교할 수 있다.
#
# **수정 제안:** 설치 구현이 지원하는 상호작용 조합과 지정 깊이에서 옵션별 출력을 비교했다. 후보 집합과 계산 가중치 변화의 기여는 후속 분석 대상이다.
#
# [상세 근거·원문·후속 확인](INTERPRETATION_FOLLOWUP_0909.md) [^13]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 통계의 기준 조건과 제외 표본을 기록한다 | 변동률과 기준 조건 대비 차이의 구분 | INTERPRETATION_FOLLOWUP_0909.md |
# | 옵션별 실행 기록과 후보 단계 계측을 대조한다 | 조건부 구현 문제의 영향 범위 | INTERPRETATION_FOLLOWUP_0909.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 13개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/interpretation_followup_0909.json` | `findings` | (10행 표) |
# | [^2] | `outputs/interpretation_followup_0909.json` | `checks.depth_overlap` | (2행 표) |
# | [^3] | `outputs/interpretation_followup_0909.json` | `checks.installed_sha256` | (3항목 묶음) |
# | [^4] | `outputs/interpretation_followup_0909.json` | `findings[0]` | (8항목 묶음) |
# | [^5] | `outputs/interpretation_followup_0909.json` | `findings[1]` | (8항목 묶음) |
# | [^6] | `outputs/interpretation_followup_0909.json` | `findings[2]` | (8항목 묶음) |
# | [^7] | `outputs/interpretation_followup_0909.json` | `findings[3]` | (8항목 묶음) |
# | [^8] | `outputs/interpretation_followup_0909.json` | `findings[4]` | (8항목 묶음) |
# | [^9] | `outputs/interpretation_followup_0909.json` | `findings[5]` | (8항목 묶음) |
# | [^10] | `outputs/interpretation_followup_0909.json` | `findings[6]` | (8항목 묶음) |
# | [^11] | `outputs/interpretation_followup_0909.json` | `findings[7]` | (8항목 묶음) |
# | [^12] | `outputs/interpretation_followup_0909.json` | `findings[8]` | (8항목 묶음) |
# | [^13] | `outputs/interpretation_followup_0909.json` | `findings[9]` | (8항목 묶음) |
