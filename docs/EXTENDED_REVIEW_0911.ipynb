# %% [markdown]
# # 리포트 현재·확장 점검 — 이전 반례 수정과 새 병합·비교 경로의 보완점
#
# > ### 한 일
# > **기존 수정과 인접 판독 경로를 실제 입력으로 대조했다.**
#
# ### 결과
# 1. 원본 파일 80개로 발간 수를 재계산했다 [^1].
# 2. 남은 보완점 5건의 재현 조건을 적었다 [^2].
# 3. 회귀 검사 조건 5개에서 판정 변화를 확인했다 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 생산 경로 | 현재 main과 함수 범위를 유지한 병합 블록을 실행 |
# | 범위 확장 | 동체 판독·진단 분류·참고 기댓값을 추가 대조 |
#
# ### 재현
#
# ```bash
# CUDA_VISIBLE_DEVICES='' /workspace/.venvs/py312/bin/python benchmark/review_extended_0911.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/extended_review_0911.json` |
# | 소요 | CPU 한 코어, 저장 자료 판독 |
#
# ---

# %% [markdown]
# ## 1. 상한 없는 n_trunc 분기에서 초기화 전 변수 또는 앞 칸의 상한을 쓴다
#
# 상한 없는 진단은 같은 칸의 보류 목록에 넣고, 그 칸의 상한·가정 정책을 결정한 뒤 처리한다. 첫 칸과 뒤 칸, 앞 칸 상한을 바꾼 순서 시험을 함께 둔다.
#
# [조건·실행 결과·소스](EXTENDED_REVIEW_0911.md) [^4]

# %% [markdown]
# ## 2. 보류한 진단은 경고 수에 들어가지만 분류별 표본수에서 빠진다
#
# 보류 목록을 처리하는 루프에서도 실제 적용한 정책의 분류를 올린다. 다른 샤드의 상한을 빌린 경우와 실행 환경 기본값을 쓴 경우의 출처를 기록하고, 분류 합계와 진단 대상 표본수를 대조한다.
#
# [조건·실행 결과·소스](EXTENDED_REVIEW_0911.md) [^5]

# %% [markdown]
# ## 3. 동체 사다리의 생산 로더에는 입력 검증이 연결되지 않았다
#
# 동체 판독기가 실제로 가져오는 read_0918B.load/measure에 인덱스·길이·샤드 메타데이터·유한값·비교 시간축 검사를 연결한다. 각 입력 거절 사유를 원장에 남기고, 기준선 실패 때 전체 결과의 상태를 명시한다.
#
# [조건·실행 결과·소스](EXTENDED_REVIEW_0911.md) [^6]

# %% [markdown]
# ## 4. 기대 자카드는 기대 교집합을 대입한 근삿값이다
#
# 현 식을 유지하면 기대 교집합을 대입한 자카드 근사라고 이름과 식을 함께 적는다. 정확한 기대값이 필요하면 고정 크기 집합의 교집합 분포에 대해 비율 자체를 평균한다.
#
# [조건·실행 결과·소스](EXTENDED_REVIEW_0911.md) [^7]

# %% [markdown]
# ## 5. 마크다운 정정이 노트북 작업 지시까지 전달되지 않았다
#
# 노트북의 항목별 replacement와 next_steps도 fixed 상태에서 생성한다. 마크다운과 노트북이 같은 현재 권고 필드를 읽도록 묶는다.
#
# [조건·실행 결과·소스](EXTENDED_REVIEW_0911.md) [^8]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 병합 분기와 분류 합계를 바로잡는다 | 새 진단 필드의 실행·집계 일관성 | EXTENDED_REVIEW_0911.md |
# | 동체 판독과 보고 문면에 현재 규칙을 연결한다 | 입력 거절 범위와 발간 해석 | EXTENDED_REVIEW_0911.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 8개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/extended_review_0911.json` | `checks.publications` | (6항목 묶음) |
# | [^2] | `outputs/extended_review_0911.json` | `findings` | (5행 표) |
# | [^3] | `outputs/extended_review_0911.json` | `checks.current.harness` | (5항목 묶음) |
# | [^4] | `outputs/extended_review_0911.json` | `findings[0]` | (5항목 묶음) |
# | [^5] | `outputs/extended_review_0911.json` | `findings[1]` | (5항목 묶음) |
# | [^6] | `outputs/extended_review_0911.json` | `findings[2]` | (5항목 묶음) |
# | [^7] | `outputs/extended_review_0911.json` | `findings[3]` | (5항목 묶음) |
# | [^8] | `outputs/extended_review_0911.json` | `findings[4]` | (5항목 묶음) |
