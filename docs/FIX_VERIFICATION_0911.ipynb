# %% [markdown]
# # 리포트 수정 재검증 — 완료된 수정과 남은 실행 경로
#
# > ### 한 일
# > **전달된 완료표를 실제 판독기 실행과 원본 자료로 대조했다.**
#
# ### 결과
# 1. 완료 주장 6건의 상태를 구분했다 [^1].
# 2. 원본 샤드 54개로 발간 수를 검산했다 [^2].
# 3. 잔여 문제와 추가 발견 6건을 기록했다 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 실제 실행 | 임시 입력·출력으로 현재 main을 실행 |
# | 검증기 점검 | 메모리에서 옛 오류를 재도입해 반례 검사의 탐지력을 확인 |
#
# ### 재현
#
# ```bash
# CUDA_VISIBLE_DEVICES='' /workspace/.venvs/py312/bin/python benchmark/review_fix_verification_0911.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/fix_verification_0911.json` |
# | 소요 | CPU 한 코어, GPU 사용 없음 |
#
# ---

# %% [markdown]
# ## 1. 주 원장 병합기를 다른 판독기로 잘못 대응해 미수정 상태를 완료로 보고했다
#
# elevation_sweep_md.analyse의 해당 블록을 대상으로 수정하고, 그 실제 실행 경로에 저장값 영·현재 경고 양수인 샤드를 넣어 확인한다.
#
# [실행 결과·원문·조건](FIX_VERIFICATION_0911.md) [^4]

# %% [markdown]
# ## 2. 장면·자유공간 사이의 시간축과 낙차 판독기 검증은 아직 빠져 있다
#
# 한 기록 내부뿐 아니라 비교 쌍 사이의 N·PRF·인덱스와 실행 조건을 확인한다. 낙차와 동체 판독 경로에도 같은 입력 검증을 적용하고, 미기재 메타데이터는 근거 없이 정상으로 간주하지 않는다.
#
# [실행 결과·원문·조건](FIX_VERIFICATION_0911.md) [^5]

# %% [markdown]
# ## 3. 새 비유한값 검사가 complex64 전계에서는 NaN을 놓친다
#
# 복소 배열 자체에 np.isfinite를 적용해 표본 단위로 센다. 지원하지 않는 자료형이면 명시적으로 거절한다. 허용된 정밀도마다 같은 비유한값 검사를 검증한다.
#
# [실행 결과·원문·조건](FIX_VERIFICATION_0911.md) [^6]

# %% [markdown]
# ## 4. 네 결함이 고쳐졌다는 반례 검증 중 하나는 생산 코드를 실행하지 않는다
#
# 실제 main 또는 main이 호출하는 순수 집계 함수를 반례로 실행한다. 입력만 교체하고, 기대 계산을 검증 대상 대신 실행하지 않는다. 검사마다 대상 함수와 통과 조건을 기록한다.
#
# [실행 결과·원문·조건](FIX_VERIFICATION_0911.md) [^7]

# %% [markdown]
# ## 5. regression으로 실행되지만 보고서는 여전히 미수정 결함이라고 서술한다
#
# 검토 항목에 발견 당시 상태와 현재 재검증 상태를 분리해 둔다. 본문·제목·권장 작업을 현재 상태에서 생성하고, 역사적 수치와 당시 소스는 별도 기록으로 보존한다.
#
# [실행 결과·원문·조건](FIX_VERIFICATION_0911.md) [^8]

# %% [markdown]
# ## 6. 미계측을 표시하는 분기에도 기록이 사라지는 경로가 남아 있다
#
# 전부 미계측인 조건도 상태와 사유를 남긴다. 상한 진단 집계는 npaths의 유무와 독립적으로 수행하고, 요약 불능과 영 경고를 분리한다.
#
# [실행 결과·원문·조건](FIX_VERIFICATION_0911.md) [^9]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 실제 병합기와 모든 비교 쌍을 검증한다 | 완료 범위가 어긋난 부분의 수정 | FIX_VERIFICATION_0911.md |
# | 회귀 검사와 보고 문면을 현재 상태에 연결한다 | 실행 성공과 문제 해결의 구분 | FIX_VERIFICATION_0911.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 9개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/fix_verification_0911.json` | `statuses` | (6행 표) |
# | [^2] | `outputs/fix_verification_0911.json` | `checks.published.n_unique_shards` | 54 |
# | [^3] | `outputs/fix_verification_0911.json` | `findings` | (6행 표) |
# | [^4] | `outputs/fix_verification_0911.json` | `findings[0]` | (5항목 묶음) |
# | [^5] | `outputs/fix_verification_0911.json` | `findings[1]` | (5항목 묶음) |
# | [^6] | `outputs/fix_verification_0911.json` | `findings[2]` | (5항목 묶음) |
# | [^7] | `outputs/fix_verification_0911.json` | `findings[3]` | (5항목 묶음) |
# | [^8] | `outputs/fix_verification_0911.json` | `findings[4]` | (5항목 묶음) |
# | [^9] | `outputs/fix_verification_0911.json` | `findings[5]` | (5항목 묶음) |
