# %% [markdown]
# # 리포트 후속 점검 — 수정 완료 주장과 현재 파생 비교의 재검증
#
# > ### 한 일
# > **저장 자료의 재계산과 임시 입력으로 생산 판독 경로를 확인했다.**
#
# ### 결과
# 1. 주 집계 488행 재계산 [^1].
# 2. 파형 발간 505행 재현 [^2].
# 3. 보완점 11건 기록 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 정상 자료 | 생산 함수 대조·NumPy STFT 검산 |
# | 경계 입력 | 임시 파일로 실제 main과 loader 실행 |
#
# ### 재현
#
# ```bash
# /workspace/.venvs/py312/bin/python benchmark/review_followup_0913.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/followup_review_0913.json` |
# | 소요 | CPU 한 코어·저장 자료 읽기 |
#
# ---

# %% [markdown]
# ## 확인 범위
#
# [기존 항목 판정과 재현 조건](FOLLOWUP_REVIEW_0913.md) [^4]

# %% [markdown]
# ## 1. 입력 검증이 새 판독기의 실제 실행 경로에 여전히 빠져 있다
#
# 등급: 우선 수정 · 임시 반례에서 발간 실패와 오염 재현
#
# 모든 판독기가 같은 입력 관문을 사용하게 한다. 저장된 표본수·표집률·idx 완전성·유한성·세대 충돌 진단을 확인하고 거절 사유를 남긴다. 계산과 문서 생성이 모두 성공한 뒤 검증된 임시 산출물로 교체한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^5]

# %% [markdown]
# ## 2. 완전요인 분석의 보조 표에 기본 기체 날개 통과율이 남아 있다
#
# 등급: 발간 수치에 영향 · 새로 확인
#
# 행별 기체에서 날개 통과율을 구해 columns와 rhythm_share_ref에 전달하고, 사용한 값을 행에 기록한다. 영향받는 보조 표와 파생 설명을 다시 생성한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^6]

# %% [markdown]
# ## 3. 메쉬가 다른 비교가 주판정용 회절 비교에도 들어간다
#
# 등급: 발간 비교의 해석에 영향 · 범위 추가 확인
#
# 변경하려는 스위치 외의 조건이 같은 쌍만 주판정에 사용한다. 짝이 없는 조건은 비교 보류와 이유를 기록하고, 기존 혼합 쌍은 조건 차이를 표시한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^7]

# %% [markdown]
# ## 4. 계수 1 포함 판정이 복소 위상을 버리고 불확도 가정을 확정적으로 쓴다
#
# 등급: 계산·해석 결함 · 실제 비교와 반례로 재현
#
# 복소 계수의 크기와 위상을 따로 보여주고 계수 1과의 복소 거리를 검사한다. 동일 신호·잔차 영의 경계도 처리한다. 현재 sigma를 그대로 신뢰구간으로 재사용하지 말고, 시간 의존성과 실제 반복 설계에 맞는 불확도 근거를 먼저 마련한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^8]

# %% [markdown]
# ## 5. 보류 판정과 계수·위상 확정 설명이 같은 발간물에 공존한다
#
# 등급: 현재 발간 문면에 영향
#
# 설명과 제목을 판정 상태에 따라 생성한다. 보류·실패·입력 부적격 각각의 이유를 쓰고, 잔차 분해나 높은 상관만으로 물리적 원인을 단정하지 않는다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^9]

# %% [markdown]
# ## 6. 직하방에서 존재하지 않는 날개끝 띠의 봉우리 값이 발간된다
#
# 등급: 발간 열 정의와 값 불일치 · 새로 확인
#
# 띠가 없는 경우 띠 전용 peak 열을 명시적으로 null로 둔다. 전체 스펙트럼 봉우리를 유지하려면 기존 전체 봉우리 열로 분리해 표시한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^10]

# %% [markdown]
# ## 7. 아틀라스 안내 노트북뿐 아니라 자체 검사식도 낡았다
#
# 등급: 문면과 검사 오경보 · 새 원인 확인
#
# 행별 반송파·프로펠러 배율·기체를 반영하도록 검사기를 먼저 고친 뒤 안내 노트북을 재생성한다. 이번에 재계산과 일치한 색인 값은 유지한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^11]

# %% [markdown]
# ## 8. 저장 중단 시험의 생산 의존성 누락이 남았다
#
# 등급: 감사 재현 경로 결함
#
# 시험에 현재 생산 의존성을 명시적으로 제공하고, 의도한 저장 예외와 시험 자체의 준비 오류를 구분한다. 실행 준비 오류는 검증 보류로 집계한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^12]

# %% [markdown]
# ## 9. 현재 생성기와 JSON에 옛 중복 선택의 잘못된 이력이 남아 있다
#
# 등급: 현재 발간 이력 설명 오류
#
# 생성기와 JSON의 이력 설명을 ‘값의 정정이 아니라 선택 규칙의 명시화’로 고친다. 되돌린 중간 구현과 그 이전 발간 구현의 이력을 구분한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^13]

# %% [markdown]
# ## 10. 최신 되풀이 대조의 주파수 범위와 판 수·정밀도를 명시해야 한다
#
# 등급: 최신 변경의 해석 범위 보완
#
# 반복이 있는 주파수, 그 조건의 반복 수, 다른 주파수의 단독 실행 수를 나누어 적는다. 재현성은 원정밀도로 저장하고 작은 값은 과학적 표기로 표시한다. 중심 주파수 반복과 대역 전체 수렴성의 범위를 구분한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^14]

# %% [markdown]
# ## 11. 위상·백색잡음 설명이 문서와 코드 머리글에서 서로 다르다
#
# 등급: 문면 정정 부분 완료
#
# 정정된 해석 하나로 코드 머리글·문서 제목·소개·자동 설명을 맞춘다. 크기와 변조구조에 대한 관측이며 위상 평탄성은 별도 분석임을 독자용 문서에도 명시한다.
#
# [수치와 코드 인용](FOLLOWUP_REVIEW_0913.md) [^15]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 입력 관문과 발간 순서를 정비한다 | 오류 입력의 거절과 산출물 보존 | FOLLOWUP_REVIEW_0913.md |
# | 기체별 계산과 조건이 같은 비교 쌍을 적용한다 | 수치·복소 계수·설명의 일치 | FOLLOWUP_REVIEW_0913.md |
# | 검사식과 독자용 문서를 함께 갱신한다 | 되풀이 범위·과거 이력·표 정의 | FOLLOWUP_REVIEW_0913.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 15개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/followup_review_0913.json` | `checks.producer` | (7항목 묶음) |
# | [^2] | `outputs/followup_review_0913.json` | `checks.waveform_publication` | (7항목 묶음) |
# | [^3] | `outputs/followup_review_0913.json` | `findings` | (11행 표) |
# | [^4] | `outputs/followup_review_0913.json` | `checks` | (22항목 묶음) |
# | [^5] | `outputs/followup_review_0913.json` | `findings[0]` | (6항목 묶음) |
# | [^6] | `outputs/followup_review_0913.json` | `findings[1]` | (6항목 묶음) |
# | [^7] | `outputs/followup_review_0913.json` | `findings[2]` | (6항목 묶음) |
# | [^8] | `outputs/followup_review_0913.json` | `findings[3]` | (6항목 묶음) |
# | [^9] | `outputs/followup_review_0913.json` | `findings[4]` | (6항목 묶음) |
# | [^10] | `outputs/followup_review_0913.json` | `findings[5]` | (6항목 묶음) |
# | [^11] | `outputs/followup_review_0913.json` | `findings[6]` | (6항목 묶음) |
# | [^12] | `outputs/followup_review_0913.json` | `findings[7]` | (6항목 묶음) |
# | [^13] | `outputs/followup_review_0913.json` | `findings[8]` | (6항목 묶음) |
# | [^14] | `outputs/followup_review_0913.json` | `findings[9]` | (6항목 묶음) |
# | [^15] | `outputs/followup_review_0913.json` | `findings[10]` | (6항목 묶음) |
