# %% [markdown]
# # 리포트 현재 상태 재점검 — 수정 확인과 판독기의 남은 경계 조건
#
# > ### 한 일
# > **발간 원장의 수정 반영을 확인하고 현재 판독기의 경계 조건을 재현했다.**
#
# ### 결과
# 1. 아틀라스 1433개 칸의 변경 범위를 대조했다 [^1].
# 2. 상한 진단 샤드 617개를 재계산했다 [^2].
# 3. 추가 피드백 6건에 확인 범위와 수정안을 남겼다 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 발간값 확인 | 저장 원장과 원본 신호를 현재 분석 함수로 대조 |
# | 경계 조건 확인 | 실제 입력과 분리한 합성 자료로 현재 함수를 실행 |
#
# ### 재현
#
# ```bash
# CUDA_VISIBLE_DEVICES='' /workspace/.venvs/py312/bin/python benchmark/review_current_state_0911.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/current_state_review_0911.json` |
# | 소요 | CPU 한 코어, GPU 사용 없음 |
#
# ---

# %% [markdown]
# ## 1. 상한 진단 보정이 협곡 판독기에만 적용되고 주 원장 병합에는 남았다
#
# 저장 진단·당시 상한·현재 문턱의 재계산을 병합기에도 함께 보존한다. 상한 미기록이나 실행 조건 혼합은 미확인으로 표시하고, 다른 샤드의 상한을 근거 없이 빌리지 않는다.
#
# [원문·조건·재현 결과](CURRENT_STATE_REVIEW_0911.md) [^4]

# %% [markdown]
# ## 2. 비정수 중앙값을 처리한 새 분기가 화면 출력에서 종료된다
#
# 숫자 저장과 표시 문자열을 분리한다. 정수가 아닌 중앙값도 그대로 보존하고, 복제 배수로 해석할 수 없는 경우에는 사유를 출력한다.
#
# [원문·조건·재현 결과](CURRENT_STATE_REVIEW_0911.md) [^5]

# %% [markdown]
# ## 3. 입력 검증에 기준선·메타데이터·유한값의 빈틈이 남았다
#
# 기준선과 비교 대상에 같은 검증을 적용한다. 예상 표본 수는 실행 조건으로 확인하고, 각 샤드의 선언·시간축·전계 유한성을 함께 검사한다. 온전한 이전 실행을 최신 부분 실행으로 덮어 고르는 방식은 사용하지 않는다.
#
# [원문·조건·재현 결과](CURRENT_STATE_REVIEW_0911.md) [^6]

# %% [markdown]
# ## 4. 부분 계측에서도 전체 사건 집합이 일치했다는 표지가 붙는다
#
# 계측된 공통 모집단에서의 일치와 전체 모집단 판정 가능 여부를 별도 필드로 둔다. 미계측이 있으면 전체 일치는 미확인으로 표시하되 전체 진폭 낙차 수는 유지한다.
#
# [원문·조건·재현 결과](CURRENT_STATE_REVIEW_0911.md) [^7]

# %% [markdown]
# ## 5. 이전 검토의 재현 코드도 현재 소스 변경을 따라가지 못한다
#
# 역사 재현용 입력·소스 커밋과 현재 회귀 검사용 계산을 구분한다. 이번 보고서는 현재 보정된 대역을 그대로 사용하여 발간값을 재계산한다.
#
# [원문·조건·재현 결과](CURRENT_STATE_REVIEW_0911.md) [^8]

# %% [markdown]
# ## 6. 수정된 해석과 예전 판정 문구가 작업 문서에 함께 남았다
#
# 잔존 개수는 같고 사건 목록은 달랐다는 관찰로 통일한다. 이미 실행된 작업 줄은 보존하면서 결과 판독에 적용할 최신 규칙을 원문 가까이에 연결한다.
#
# [원문·조건·재현 결과](CURRENT_STATE_REVIEW_0911.md) [^9]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 출력 분기와 공통 입력 검증을 보완한다 | 경계 입력에서의 종료와 판정 누락 | CURRENT_STATE_REVIEW_0911.md |
# | 병합 진단과 최신 판독 규칙을 연결한다 | 구세대 진단의 재사용과 해석 혼선 | CURRENT_STATE_REVIEW_0911.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 9개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/current_state_review_0911.json` | `checks.atlas` | (8항목 묶음) |
# | [^2] | `outputs/current_state_review_0911.json` | `checks.cap.n_shards` | 617 |
# | [^3] | `outputs/current_state_review_0911.json` | `findings` | (6행 표) |
# | [^4] | `outputs/current_state_review_0911.json` | `findings[0]` | (5항목 묶음) |
# | [^5] | `outputs/current_state_review_0911.json` | `findings[1]` | (5항목 묶음) |
# | [^6] | `outputs/current_state_review_0911.json` | `findings[2]` | (5항목 묶음) |
# | [^7] | `outputs/current_state_review_0911.json` | `findings[3]` | (5항목 묶음) |
# | [^8] | `outputs/current_state_review_0911.json` | `findings[4]` | (5항목 묶음) |
# | [^9] | `outputs/current_state_review_0911.json` | `findings[5]` | (5항목 묶음) |
