# %% [markdown]
# # 리포트 현재 상태 재점검 — 생산 판독과 완료 큐의 추가 조사
#
# > ### 한 일
# > **저장 샤드·실제 판독기·최종 보고서 조립과 완료 큐 자료를 대조했다.**
#
# ### 결과
# 1. 저장 샤드 7720개 전체 배열 검사 [^1].
# 2. 보고서 33개 내용 비교 [^2].
# 3. 완료 C 비교 5개 주파수 판독 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 계산 | CPU 한 코어와 임시 출력에서 생산 main·합성 반례 실행 |
# | 범위 | 저장 자료 무결성·소프트웨어 실행·해석 근거 대조 |
#
# ### 재현
#
# ```bash
# /workspace/.venvs/py312/bin/python benchmark/review_remaining_0914.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/remaining_review_0914.json` |
# | 소요 | CPU 한 코어·저장 자료 검사 |
#
# ---

# %% [markdown]
# ## 이웃 상관의 실수부로 날개 신호의 부재를 결론낸다
#
# 현재 발간 해석
#
# [재현과 수정 방향](REMAINING_REVIEW_0914.md) [^4]

# %% [markdown]
# ## 고도 main이 비교 쌍의 실제 표집률 차이를 통과시킨다
#
# 합성 입력으로 재현한 잠재 계산 결함
#
# [재현과 수정 방향](REMAINING_REVIEW_0914.md) [^5]

# %% [markdown]
# ## 새 대역 모양 민감도의 대조군은 입력 관문을 우회한다
#
# 합성 입력으로 재현한 잠재 비교 결함
#
# [재현과 수정 방향](REMAINING_REVIEW_0914.md) [^6]

# %% [markdown]
# ## 솔버 버전 기록과 비교 차단이 연결되지 않았다
#
# 현재 출처 기록의 한계와 향후 혼합 위험
#
# [재현과 수정 방향](REMAINING_REVIEW_0914.md) [^7]

# %% [markdown]
# ## 고아 파일 정리가 다른 발간의 살아 있는 임시 파일을 지운다
#
# 동시 실행 순서로 재현한 잠재 발간 결함
#
# [재현과 수정 방향](REMAINING_REVIEW_0914.md) [^8]

# %% [markdown]
# ## 기존 감사기의 임시 main 시험이 운영 발간물을 덮는다
#
# 이번 실행에서 발생하고 복원한 감사 격리 결함
#
# [재현과 수정 방향](REMAINING_REVIEW_0914.md) [^9]

# %% [markdown]
# ## 주간 보고서의 정정과 본문·신규성 표현이 갈린다
#
# 외부 원문으로 확인한 현재 문면 오류
#
# [재현과 수정 방향](REMAINING_REVIEW_0914.md) [^10]

# %% [markdown]
# ## 한 스레드에서 같다는 결과가 원인 확정으로 쓰인다
#
# 현재 시험 머리말과 원장 해석 규칙
#
# [재현과 수정 방향](REMAINING_REVIEW_0914.md) [^11]

# %% [markdown]
# ## 큐 A/B — 완료 자료 판독 우선
#
# [자료와 비교 조건](REMAINING_REVIEW_0914.md) [^12]

# %% [markdown]
# ## 큐 C — 완료 원자료의 비교를 이번 감사에서 수행
#
# [자료와 비교 조건](REMAINING_REVIEW_0914.md) [^13]

# %% [markdown]
# ## 큐 D — 완료 끝점 자료 활용
#
# [자료와 비교 조건](REMAINING_REVIEW_0914.md) [^14]

# %% [markdown]
# ## 큐 E — 진행 가치 있음 · 위상 판독 준비
#
# [자료와 비교 조건](REMAINING_REVIEW_0914.md) [^15]

# %% [markdown]
# ## 큐 F — 진행 가치 있음 · 시간 구간 맞추기
#
# [자료와 비교 조건](REMAINING_REVIEW_0914.md) [^16]

# %% [markdown]
# ## 큐 G — 기존 깊이 비교의 혼합 조건 해소
#
# [자료와 비교 조건](REMAINING_REVIEW_0914.md) [^17]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 고도와 예산 대조군의 입력 계약을 연결한다 | 같은 조건 쌍의 수용과 제외 사유 | REMAINING_REVIEW_0914.md |
# | 완료 C 자료를 정식 병합·판독에 연결한다 | 대역 모양의 예산 민감도 | REMAINING_REVIEW_0914.md |
# | 공유 발간 정리와 감사 출력 경로를 격리한다 | 운영 발간물 보존 | REMAINING_REVIEW_0914.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 17개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/remaining_review_0914.json` | `checks.warehouse` | (10항목 묶음) |
# | [^2] | `outputs/remaining_review_0914.json` | `checks.report_chain` | (4항목 묶음) |
# | [^3] | `outputs/remaining_review_0914.json` | `checks.completed_C_reading` | (10항목 묶음) |
# | [^4] | `outputs/remaining_review_0914.json` | `findings[0]` | (6항목 묶음) |
# | [^5] | `outputs/remaining_review_0914.json` | `findings[1]` | (6항목 묶음) |
# | [^6] | `outputs/remaining_review_0914.json` | `findings[2]` | (6항목 묶음) |
# | [^7] | `outputs/remaining_review_0914.json` | `findings[3]` | (6항목 묶음) |
# | [^8] | `outputs/remaining_review_0914.json` | `findings[4]` | (6항목 묶음) |
# | [^9] | `outputs/remaining_review_0914.json` | `findings[5]` | (6항목 묶음) |
# | [^10] | `outputs/remaining_review_0914.json` | `findings[6]` | (6항목 묶음) |
# | [^11] | `outputs/remaining_review_0914.json` | `findings[7]` | (6항목 묶음) |
# | [^12] | `outputs/remaining_review_0914.json` | `queue_assessment[0]` | (3항목 묶음) |
# | [^13] | `outputs/remaining_review_0914.json` | `queue_assessment[1]` | (3항목 묶음) |
# | [^14] | `outputs/remaining_review_0914.json` | `queue_assessment[2]` | (3항목 묶음) |
# | [^15] | `outputs/remaining_review_0914.json` | `queue_assessment[3]` | (3항목 묶음) |
# | [^16] | `outputs/remaining_review_0914.json` | `queue_assessment[4]` | (3항목 묶음) |
# | [^17] | `outputs/remaining_review_0914.json` | `queue_assessment[5]` | (3항목 묶음) |
