# %% [markdown]
# # 리포트 후속 재확인 — 지정 수정은 재현되고 예외 경로는 남아 있다
#
# > ### 한 일
# > **현재 생산 경로와 원본 샤드로 전달된 수정 내역을 확인했다.**
#
# ### 결과
# 1. 원본 샤드 54개에서 발간 수를 재계산했다 [^1].
# 2. 옛 오류 복원 시험을 포함한 회귀 조건 5개를 확인했다 [^2].
# 3. 남은 보완점 5건을 근거·범위와 함께 적었다 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 운영 경로 | 생산 main과 실제 병합 진단 블록을 임시 환경에서 실행 |
# | 추가 반례 | 입력 결측과 메모리 내 오류 복원으로 거절 조건을 확인 |
#
# ### 재현
#
# ```bash
# CUDA_VISIBLE_DEVICES='' /workspace/.venvs/py312/bin/python benchmark/review_postfix_0911.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/postfix_review_0911.json` |
# | 소요 | CPU 한 코어, 저장 자료 판독 |
#
# ---

# %% [markdown]
# ## 1. 회귀 검사에서 결과 행 누락과 일부 오집계를 통과시킨다
#
# 정상 종료와 목표 행 존재·유일성·필드 유효성을 따로 확인한다. 이 합성 입력의 기대값과 결과값을 직접 비교하고, 행 누락은 미확인으로 남긴다. 검사에는 생산식과 별도로 정한 기대 결과를 둔다.
#
# [실행 근거와 범위](POSTFIX_REVIEW_0911.md) [^4]

# %% [markdown]
# ## 2. 시간축·표본수 검사가 낙차 판독과 Hampel 비교에는 덜 연결됐다
#
# 샤드별 선언 N·PRF와 파일명/요청 N을 대조하고, 메타데이터가 없으면 검증 불가 사유를 남긴다. Hampel 쌍도 시간축을 확인한다. 세대 선택은 인덱스와 선언 길이의 완전성을 확인한 뒤 수행한다.
#
# [실행 근거와 범위](POSTFIX_REVIEW_0911.md) [^5]

# %% [markdown]
# ## 3. 주 원장 상한 진단의 예외 분기와 설명이 어긋난다
#
# 확정 재계산·옛 저장값·상한 가정 계산을 분리하고 각 범위와 미확인 표본수를 기록한다. nret/저장 상한이 빠진 경우에는 현재 규칙의 확정값을 미확인으로 둔다. 차이는 우선 저장 당시 규칙과 현재 규칙의 차이로 설명한다.
#
# [실행 근거와 범위](POSTFIX_REVIEW_0911.md) [^6]

# %% [markdown]
# ## 4. 유한한 전계라도 중앙값이 영이면 낙차 판정이 정의되지 않는다
#
# 비율 계산 전 중앙값의 양수·유한 여부를 확인하고, 실패하면 원장에 사유와 미정 판정을 남긴다. 임의의 작은 상수를 더하려면 그에 따른 낙차 정의 변경을 별도로 정해야 한다.
#
# [실행 근거와 범위](POSTFIX_REVIEW_0911.md) [^7]

# %% [markdown]
# ## 5. 고쳐짐 제목 아래의 수정 제안과 마지막 작업 순서는 과거 상태다
#
# fixed 상태에서 replacement와 최종 작업 목록도 함께 분기한다. 완료 항목은 정정 기록과 유지할 검사로 안내하고, 과거 제안에는 과거 기록임을 명시한다. 아틀라스는 완료 기록으로 안내하고 문면을 정정한다.
#
# [실행 근거와 범위](POSTFIX_REVIEW_0911.md) [^8]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 결과 행·기대값·시간축·분모 검사를 보완한다 | 합성 입력에서 확인된 예외 처리 | POSTFIX_REVIEW_0911.md |
# | 상한 진단과 보고서 문면을 현재 상태에 맞춘다 | 실행 결과보다 넓은 완료 표현 | POSTFIX_REVIEW_0911.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 8개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/postfix_review_0911.json` | `checks.published` | (6항목 묶음) |
# | [^2] | `outputs/postfix_review_0911.json` | `checks.harness` | (5항목 묶음) |
# | [^3] | `outputs/postfix_review_0911.json` | `findings` | (5행 표) |
# | [^4] | `outputs/postfix_review_0911.json` | `findings[0]` | (5항목 묶음) |
# | [^5] | `outputs/postfix_review_0911.json` | `findings[1]` | (5항목 묶음) |
# | [^6] | `outputs/postfix_review_0911.json` | `findings[2]` | (5항목 묶음) |
# | [^7] | `outputs/postfix_review_0911.json` | `findings[3]` | (5항목 묶음) |
# | [^8] | `outputs/postfix_review_0911.json` | `findings[4]` | (5항목 묶음) |
