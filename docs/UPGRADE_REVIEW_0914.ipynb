# %% [markdown]
# # 리포트 업그레이드 점검 — 버전 분리와 결정 모드 대조
#
# > ### 한 일
# > **설치·저장 도장·실제 판독기와 CPU 결정 모드를 대조했다.**
#
# ### 결과
# 1. 솔버 관문 종료 0 [^1].
# 2. 기본 모드·결정 모드 2조건 대조 [^2].
# 3. 구버전 다리 짝 24개 확인 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 격리 | CPU 한 코어·임시 출력의 합성 반례와 실제 main |
# | 근거 | 설치 API·소스·원장·샤드와 감독자 로그 |
#
# ### 재현
#
# ```bash
# /workspace/.venvs/py312/bin/python benchmark/review_upgrade_0914.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/upgrade_review_0914.json` |
# | 소요 | CPU 한 코어·저장 자료 읽기 |
#
# ---

# %% [markdown]
# ## 신버전 기본 모드와 결정 모드를 분리해서 읽어야 한다
#
# 현재 생산 설정과 새 실험 결과
#
# [재현과 수정 방향](UPGRADE_REVIEW_0914.md) [^4]

# %% [markdown]
# ## 창고 도장 검사는 전체 패키지 묶음을 대조하지 않는다
#
# 합성 입력으로 확인한 검사 범위의 공백
#
# [재현과 수정 방향](UPGRADE_REVIEW_0914.md) [^5]

# %% [markdown]
# ## 고도 버전 검사는 원장을 보지만 원자료 도장을 확인하지 않는다
#
# 이전 지적이 일부 남은 입력 경로
#
# [재현과 수정 방향](UPGRADE_REVIEW_0914.md) [^6]

# %% [markdown]
# ## 거절할 대조군이 대역 비교의 기준 표집률을 선점한다
#
# 새 입력 검사에서 재현한 순서 의존성
#
# [재현과 수정 방향](UPGRADE_REVIEW_0914.md) [^7]

# %% [markdown]
# ## 유효한 JSON 안의 잘못된 값은 GPU 보류를 해제한다
#
# 운영 규약의 잠재 결함 · 임시 파일에서 재현
#
# [재현과 수정 방향](UPGRADE_REVIEW_0914.md) [^8]

# %% [markdown]
# ## 마지막 구버전 병합을 파형 발간물이 아직 따라가지 못했다
#
# 현재 발간 동기화 문제
#
# [재현과 수정 방향](UPGRADE_REVIEW_0914.md) [^9]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 현재 다리 큐 결과를 같은 조건의 구버전 짝과 비교한다 | 스택 변경에 따른 차이 | UPGRADE_REVIEW_0914.md |
# | 결정 모드를 별도 이름과 도장으로 연결한다 | 옵션 변경 효과와 버전 효과의 분리 | UPGRADE_REVIEW_0914.md |
# | 사후 도장 검사와 대조군 기준 선택을 보완한다 | 자료 수용·거절의 일관성 | UPGRADE_REVIEW_0914.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 9개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/upgrade_review_0914.json` | `checks.solver_gate` | (3항목 묶음) |
# | [^2] | `outputs/upgrade_review_0914.json` | `checks.cpu_modes` | (13항목 묶음) |
# | [^3] | `outputs/upgrade_review_0914.json` | `checks.bridge` | (10항목 묶음) |
# | [^4] | `outputs/upgrade_review_0914.json` | `findings[0]` | (6항목 묶음) |
# | [^5] | `outputs/upgrade_review_0914.json` | `findings[1]` | (6항목 묶음) |
# | [^6] | `outputs/upgrade_review_0914.json` | `findings[2]` | (6항목 묶음) |
# | [^7] | `outputs/upgrade_review_0914.json` | `findings[3]` | (6항목 묶음) |
# | [^8] | `outputs/upgrade_review_0914.json` | `findings[4]` | (6항목 묶음) |
# | [^9] | `outputs/upgrade_review_0914.json` | `findings[5]` | (6항목 묶음) |
