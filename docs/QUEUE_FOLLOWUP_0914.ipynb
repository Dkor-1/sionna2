# %% [markdown]
# # 리포트 수정과 큐 점검 — 수정 재현과 진행 중 실험의 해석 범위
#
# > ### 한 일
# > **현재 생산 함수·발간 행·임시 반례와 완료 샤드를 대조했다.**
#
# ### 결과
# 1. 기체별 보조 표 210행 재현 [^1].
# 2. 파형 505행과 제외 사유 대조 [^2].
# 3. 현재 큐 시작 45줄·종료 35줄 [^3].

# %% [markdown]
# ### 방법
#
# | 무엇을 | 어떻게 얻었나 |
# |---|---|
# | 수정 | 함수 실행·임시 실패 입력·발간 행 정체성 대조 |
# | 큐 | 실행 조건·완료 샤드·관측 통계 |
#
# ### 재현
#
# ```bash
# /workspace/.venvs/py312/bin/python benchmark/review_queue_followup_0914.py
# ```
#
# | | |
# |---|---|
# | 출력 | `outputs/queue_followup_0914.json` |
# | 소요 | CPU 한 코어·저장 자료 읽기 |
#
# ---

# %% [markdown]
# ## 1. 장면 판독기의 조기 반환이 실제 main에서 다시 예외를 낸다
#
# series의 모든 반환을 (전계 또는 None, 사유 목록)으로 통일하고 실제 main에서 자료 없음·미완성·표집률 혼합을 각각 재현한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^4]

# %% [markdown]
# ## 2. 두 raw 판독기가 세대 충돌과 샤드 메타데이터 이상을 여전히 통과시킨다
#
# one_generation의 남은 충돌 진단을 확인하고 모든 샤드의 idx 범위·정수성·중복·meta 표본수·유한 양수 표집률을 대입 전에 대조한다. 명시적으로 해결된 세대 선택까지 일괄 거절하는 처방은 피한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^5]

# %% [markdown]
# ## 3. 발간 텍스트 관문은 정상 문장을 거절하고 다른 표기 값은 통과시킨다
#
# 숫자는 구조화된 원장에서 유한성을 검증하고, 표 렌더러가 숫자·없음·사유를 구분해 출력하게 한다. 텍스트 검사는 보조 검사로 두고 숫자 꼬리표와 Markdown 서식 처리, 정상 사유 문장의 허용을 명시한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^6]

# %% [markdown]
# ## 4. 공통 입력 관문의 예외 없는 반환 약속에도 경계 누락이 있다
#
# 정수 표본수와 유한 양수 표집률을 변환 전후로 검증하고, prf_seen 전체를 원장의 prf와 대조한다. 변환 실패는 사유로 반환한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^7]

# %% [markdown]
# ## 5. 추출 경계 검사가 서로 다른 함수의 지역변수를 합쳐 누락을 가린다
#
# 함수별 스코프를 구분해 전역·자유 이름을 검사하고, 다른 함수의 매개변수나 지역 대입이 의존성을 제공한 것으로 집계되지 않게 한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^8]

# %% [markdown]
# ## 6. 조건 혼합 관문이 깊이 비교에 전파되지 않았다
#
# 깊이 외 조건이 같은 쌍을 구성하고 비교 부적격·계측 불가·기준 초과를 분리한다. G 큐가 채우는 정본 깊이 자료로 해당 쌍을 다시 구성한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^9]

# %% [markdown]
# ## 7. 수정된 판정과 옛 확정 문장이 현재 완전요인 원장에 공존한다
#
# 머리기사·기작 설명·적용 범위를 현재 사용한 비교 쌍과 판정에서 함께 생성한다. 가정 척도 통과와 물리적 기작 입증을 구분하고, 백색잡음 단정도 동일한 규칙으로 정정한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^10]

# %% [markdown]
# ## 8. 아틀라스의 기본 기체 명시 태그 검사가 여전히 오경보를 낸다
#
# 기체별 명세 값과 직접 비교하고 기본 기체와 달라야 한다는 조건은 실제로 다른 박자를 가진 기체에만 적용한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^11]

# %% [markdown]
# ## 9. 대역 판독기가 중심 주파수 레벨 민감도를 대역 모양의 판정 문턱으로 쓴다
#
# 각 예산의 동일 주파수 쌍으로 대역 대비 곡선과 그 변화량을 계산한다. 민감도 기술 통계와 판정 문턱을 구분하고 가정 없는 두 배 기준의 확정 표현을 제거한다.
#
# [재현과 코드 인용](QUEUE_FOLLOWUP_0914.md) [^12]

# %% [markdown]
# ## 큐 A. 조각 장면·굴절
#
# 유용 · 완료 자료부터 판독
#
# [설계·관측 근거](QUEUE_FOLLOWUP_0914.md) [^13]

# %% [markdown]
# ## 큐 B. 고도
#
# 유용 · 판정 문장 수정
#
# [설계·관측 근거](QUEUE_FOLLOWUP_0914.md) [^14]

# %% [markdown]
# ## 큐 C. 광선 예산·대역
#
# 우선 판독 가치 높음
#
# [설계·관측 근거](QUEUE_FOLLOWUP_0914.md) [^15]

# %% [markdown]
# ## 큐 D. 직하방 끝점
#
# 범위 확장에 유용
#
# [설계·관측 근거](QUEUE_FOLLOWUP_0914.md) [^16]

# %% [markdown]
# ## 큐 E. 촘촘한 반송파·위상
#
# 필요하지만 판독 설계가 선행돼야 함
#
# [설계·관측 근거](QUEUE_FOLLOWUP_0914.md) [^17]

# %% [markdown]
# ## 큐 F. 표집률
#
# 가치 있음 · 동일 시간 구간 비교 필수
#
# [설계·관측 근거](QUEUE_FOLLOWUP_0914.md) [^18]

# %% [markdown]
# ## 큐 G. 굴절 깊이 1
#
# 비용 대비 우선 가치 높음
#
# [설계·관측 근거](QUEUE_FOLLOWUP_0914.md) [^19]

# %% [markdown]
# ## 다음 단계
#
# | 다음에 할 일 | 그러면 결정되는 것 | 어디서 |
# |---|---|---|
# | 반환 계약·샤드 관문을 완성한다 | 입력 오류 처리의 일관성 | QUEUE_FOLLOWUP_0914.md |
# | 완료 A·B와 진행 C·G를 우선 판독한다 | 동일 조건의 관측과 민감도 | QUEUE_FOLLOWUP_0914.md |
# | E·F 판독을 합성 신호로 미리 시험한다 | 위상·시간 구간·분해능 조건 | QUEUE_FOLLOWUP_0914.md |

# %% [markdown]
# <!--rs:sources-->
# ## 출처
#
# 본문의 `[^n]` 은 아래 19개 중 하나를 가리킨다. 값은 이 표를 만들 때 JSON 을 다시 열어 채웠다 — 본문 숫자와 같은 파일, 같은 키다.
#
# | | 파일 | 키 | 값 |
# |---|---|---|---|
# | [^1] | `outputs/queue_followup_0914.json` | `checks.other_drone` | (3항목 묶음) |
# | [^2] | `outputs/queue_followup_0914.json` | `checks.accounting` | (11항목 묶음) |
# | [^3] | `outputs/queue_followup_0914.json` | `checks.queue` | (13항목 묶음) |
# | [^4] | `outputs/queue_followup_0914.json` | `findings[0]` | (6항목 묶음) |
# | [^5] | `outputs/queue_followup_0914.json` | `findings[1]` | (6항목 묶음) |
# | [^6] | `outputs/queue_followup_0914.json` | `findings[2]` | (6항목 묶음) |
# | [^7] | `outputs/queue_followup_0914.json` | `findings[3]` | (6항목 묶음) |
# | [^8] | `outputs/queue_followup_0914.json` | `findings[4]` | (6항목 묶음) |
# | [^9] | `outputs/queue_followup_0914.json` | `findings[5]` | (6항목 묶음) |
# | [^10] | `outputs/queue_followup_0914.json` | `findings[6]` | (6항목 묶음) |
# | [^11] | `outputs/queue_followup_0914.json` | `findings[7]` | (6항목 묶음) |
# | [^12] | `outputs/queue_followup_0914.json` | `findings[8]` | (6항목 묶음) |
# | [^13] | `outputs/queue_followup_0914.json` | `queue_assessment[0]` | (4항목 묶음) |
# | [^14] | `outputs/queue_followup_0914.json` | `queue_assessment[1]` | (4항목 묶음) |
# | [^15] | `outputs/queue_followup_0914.json` | `queue_assessment[2]` | (4항목 묶음) |
# | [^16] | `outputs/queue_followup_0914.json` | `queue_assessment[3]` | (4항목 묶음) |
# | [^17] | `outputs/queue_followup_0914.json` | `queue_assessment[4]` | (4항목 묶음) |
# | [^18] | `outputs/queue_followup_0914.json` | `queue_assessment[5]` | (4항목 묶음) |
# | [^19] | `outputs/queue_followup_0914.json` | `queue_assessment[6]` | (4항목 묶음) |
